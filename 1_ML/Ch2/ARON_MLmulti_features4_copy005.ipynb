# %%
import numpy as np
from sklearn.metrics import confusion_matrix, recall_score, cohen_kappa_score

from utils.loader import FactoryLoader
from utils.ml import MLPipeline
from utils.preprocessing import PreprocessingFactory
from utils.feature_extraction import *
from utils.utils import *

VAL_PATH = r"C:\Users\gimes\Src\repos\CADx-Project\dataset\multiclass\val"
TRAIN_PATH = r"C:\Users\gimes\Src\repos\CADx-Project\dataset\multiclass\train"

# %%
percent = 100
random = False
batch_size = 24
th = 0.05

# Initialize the FactoryLoader
factory = PreprocessingFactory()
factory.gaussian_smoothing(5)
factory.clahe(clip_limit=1.5)
factory.pad2square(fill=np.nan)
factory.resize((150,150))
factory.hair_removal()
factory.normalize2float()

factory_loader = FactoryLoader(path=VAL_PATH, batch_size=batch_size, factory=factory, percentage=percent, shuffle=random)

# Create the feature extraction pipeline strategy and add desired features
strategy = FeatureExtractionStrategy()

strategy.add_extractor(GradientExtractor(threshold=th)) # Add gradient feature

strategy.add_extractor(ColorMomentsExtractor("rgb", threshold=th))   # Add color moments feature
strategy.add_extractor(ColorMomentsExtractor("lab", threshold=th))   # Add color moments feature
strategy.add_extractor(ColorMomentsExtractor("hsv", threshold=th))   # Add color moments feature

strategy.add_extractor(LBPExtractor(radius=1, n_points=8))
strategy.add_extractor(LBPExtractor(radius=2, n_points=16))
strategy.add_extractor(LBPExtractor(radius=3, n_points=24))
strategy.add_extractor(LBPExtractor(radius=4, n_points=32))

strategy.add_extractor(FourierTransformExtractor())

strategy.add_extractor(GLCMExtractor(properties=['contrast', 'dissimilarity', 'homogeneity', 'energy', 'correlation',]))

pipeline = MLPipeline(dataset_path=TRAIN_PATH, preprocessing_factory=factory, feature_strategy=strategy, classifiers=[], percentage=percent, verbose=True, shuffle=random, batch_size=batch_size)
# Out:
# INFO:utils.ml:MLPipeline initialized with dataset path: C:\Users\gimes\Src\repos\CADx-Project\dataset\multiclass\train
# INFO:utils.ml:Preprocessing steps

# %%
pipeline.feature_matrix = None
pipeline.run_feature_extraction()
# Out:
# INFO:utils.ml:Running feature extraction...
# Processed 5/212 batches.
# Processed 10/212 batches.
# Processed 15/212 batches.
# Processed 20/212 batches.
# Processed 25/212 batches.
# Processed 30/212 batches.
# Processed 35/212 batches.
# Processed 40/212 batches.
# Processed 45/212 batches.
# Processed 50/212 batches.
# Processed 55/212 batches.
# Processed 60/212 batches.
# Processed 65/212 batches.
# Processed 70/212 batches.
# Processed 75/212 batches.
# Processed 80/212 batches.
# Processed 85/212 batches.
# Processed 90/212 batches.
# Processed 95/212 batches.
# Processed 100/212 batches.
# Processed 105/212 batches.
# Processed 110/212 batches.
# Processed 115/212 batches.
# Processed 120/212 batches.
# Processed 125/212 batches.
# Processed 130/212 batches.
# Processed 135/212 batches.
# Processed 140/212 batches.
# Processed 145/212 batches.
# Processed 150/212 batches.
# Processed 155/212 batches.
# Processed 160/212 batches.
# Processed 165/212 batches.
# Processed 170/212 batches.
# Processed 175/212 batches.
# Processed 180/212 batches.
# Processed 185/212 batches.
# Processed 190/212 batches.
# Processed 195/212 batches.
# Processed 200/212 batches.
# Processed 205/212 batches.
# Processed 210/212 batches.
# INFO:utils.ml:Feature extraction completed. Extracted 5082 features.
# Processed 212/212 batches.

# %%
from xgboost import XGBClassifier
from sklearn.ensemble import RandomForestClassifier

rf1 = RandomForestClassifier(n_estimators=100)
rf2 = RandomForestClassifier(n_estimators=150)
# Random Forest with Out-of-Bag Error (OOB)
rf3 = RandomForestClassifier(n_estimators=100, oob_score=True, random_state=42)
# Random Forest with Bootstrap Disabled
rf4 = RandomForestClassifier(n_estimators=100, bootstrap=False, random_state=42)
# Random Forest with Out-of-Bag Error (OOB)
rf5 = RandomForestClassifier(n_estimators=150, oob_score=True, random_state=42)
# Random Forest with Bootstrap Disabled
rf6 = RandomForestClassifier(n_estimators=150, bootstrap=False, random_state=42)
# Random Forest with Out-of-Bag Error (OOB)
rf7 = RandomForestClassifier(n_estimators=200, oob_score=True, random_state=42)
# Random Forest with Bootstrap Disabled
rf8 = RandomForestClassifier(n_estimators=200, bootstrap=False, random_state=42)


xgb1 = XGBClassifier(n_estimators=350)
xgb2 = XGBClassifier(n_estimators=450)
xgb3 = XGBClassifier(n_estimators=550)
xgb4 = XGBClassifier(learning_rate=0.05, n_estimators=400, max_depth=3, min_child_weight=4, subsample=0.8, colsample_bytree=0.8)
xgb5 = XGBClassifier(learning_rate=0.1, n_estimators=400, max_depth=7, min_child_weight=3, subsample=0.7, colsample_bytree=0.7) # 2ND
xgb6 = XGBClassifier(learning_rate=0.1, n_estimators=400, max_depth=5, min_child_weight=5, gamma=0.2, subsample=0.8, colsample_bytree=0.8) # THIS
xgb7 = XGBClassifier(learning_rate=0.1, n_estimators=400, max_depth=5, min_child_weight=1, subsample=0.8, colsample_bytree=0.8, reg_alpha=0.1, reg_lambda=0.1)
xgb8 = XGBClassifier(learning_rate=0.05, n_estimators=500, max_depth=7, min_child_weight=1, subsample=0.8, colsample_bytree=0.8)
xgb9 = XGBClassifier(learning_rate=0.05, n_estimators=400, max_depth=7, min_child_weight=1, subsample=0.8, colsample_bytree=0.8)
xgb10 = XGBClassifier(learning_rate=0.1, n_estimators=400, max_depth=7, min_child_weight=1, subsample=0.8, colsample_bytree=0.8)
xgb11 = XGBClassifier(learning_rate=0.1, n_estimators=500, max_depth=7, min_child_weight=1, subsample=0.8, colsample_bytree=0.8)


pipeline.classifiers = [rf1, rf2, rf3, rf4, rf5, rf6, rf7, rf8,
                        # svm1, svm2, svm3, svm6, svm7, svm8,
                        xgb1, xgb2, xgb3, xgb4, xgb5, xgb6, xgb7, xgb8, xgb9, xgb10, xgb11]
pipeline.fitted_classifiers = {}

# %%
pipeline.fit_classifiers()
# Out:
# INFO:utils.ml:Fitting classifiers...
# INFO:utils.ml:Fitting classifier: RandomForestClassifier0
# INFO:utils.ml:Top 10 features for RandomForestClassifier0: [('color_moments_lab_B_std', 0.035836623648281996), ('color_moments_lab_B_var', 0.028190839184201014), ('color_moments_rgb_R_iqr', 0.02680915726699322), ('color_moments_rgb_B_std', 0.023399890092729844), ('color_moments_rgb_B_var', 0.022873448718573615), ('color_moments_rgb_R_kurtosis', 0.015037153303222724), ('color_moments_rgb_B_iqr', 0.014629919960877211), ('color_moments_rgb_R_skew', 0.013441741071393424), ('color_moments_lab_L_iqr', 0.013417129191515751), ('color_moments_rgb_B_kurtosis', 0.01340818926157895)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier0; Done in 5.232849836349487 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier1
# INFO:utils.ml:Top 10 features for RandomForestClassifier1: [('color_moments_lab_B_std', 0.03476400943059128), ('color_moments_rgb_B_std', 0.031623347028903674), ('color_moments_lab_B_var', 0.03138916964923281), ('color_moments_rgb_B_var', 0.025085710254541673), ('color_moments_rgb_R_iqr', 0.017511768427773654), ('color_moments_rgb_B_iqr', 0.01690224781003724), ('color_moments_rgb_B_kurtosis', 0.016757386640584147), ('color_moments_lab_L_iqr', 0.016132548014247038), ('color_moments_rgb_G_std', 0.01471895484663871), ('color_moments_lab_L_std', 0.014609870984502388)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier1; Done in 7.7679359912872314 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier2
# INFO:utils.ml:Top 10 features for RandomForestClassifier2: [('color_moments_lab_B_std', 0.03813287032763821), ('color_moments_rgb_B_std', 0.03514291837598689), ('color_moments_rgb_B_var', 0.030945350246790838), ('color_moments_lab_B_var', 0.029348479725696146), ('color_moments_rgb_R_iqr', 0.018096725506912232), ('color_moments_lab_L_iqr', 0.014793805371985984), ('color_moments_rgb_B_iqr', 0.014293636888614345), ('color_moments_lab_L_var', 0.013112402480727836), ('color_moments_rgb_G_std', 0.012937222409633568), ('color_moments_rgb_R_skew', 0.012542393266707632)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier2; Done in 4.724545240402222 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier3
# INFO:utils.ml:Top 10 features for RandomForestClassifier3: [('color_moments_lab_B_std', 0.03784819774189909), ('color_moments_rgb_B_std', 0.037687341850761655), ('color_moments_lab_B_var', 0.03178548726763896), ('color_moments_rgb_B_var', 0.03124575426173995), ('color_moments_rgb_R_iqr', 0.015940433204789245), ('color_moments_lab_L_iqr', 0.014948232178429088), ('color_moments_rgb_B_iqr', 0.013125211684979822), ('color_moments_rgb_R_skew', 0.012568905948531247), ('color_moments_rgb_R_kurtosis', 0.012189831315737653), ('color_moments_lab_L_std', 0.011634776012024263)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier3; Done in 6.409712314605713 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier4
# INFO:utils.ml:Top 10 features for RandomForestClassifier4: [('color_moments_lab_B_std', 0.03833467529830896), ('color_moments_rgb_B_std', 0.03211736456679237), ('color_moments_rgb_B_var', 0.03165346704031226), ('color_moments_lab_B_var', 0.02831268904261856), ('color_moments_rgb_R_iqr', 0.01856373409111658), ('color_moments_lab_L_iqr', 0.017377442301195856), ('color_moments_lab_L_var', 0.015007596169346453), ('color_moments_rgb_R_skew', 0.01347877178926101), ('color_moments_rgb_B_iqr', 0.013141344388659016), ('color_moments_rgb_G_std', 0.011649697596877224)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier4; Done in 6.470994234085083 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier5
# INFO:utils.ml:Top 10 features for RandomForestClassifier5: [('color_moments_lab_B_std', 0.03936066574469064), ('color_moments_rgb_B_std', 0.03484689068040893), ('color_moments_rgb_B_var', 0.032677946165819434), ('color_moments_lab_B_var', 0.02958440441567662), ('color_moments_rgb_R_iqr', 0.017503838074567176), ('color_moments_lab_L_iqr', 0.016097133446599063), ('color_moments_rgb_R_skew', 0.013847455397876114), ('color_moments_rgb_B_iqr', 0.012039176596798505), ('color_moments_rgb_R_kurtosis', 0.011965987439211264), ('color_moments_lab_L_var', 0.011699682314238248)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier5; Done in 9.03928828239441 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier6
# INFO:utils.ml:Top 10 features for RandomForestClassifier6: [('color_moments_lab_B_std', 0.038130415597799054), ('color_moments_rgb_B_var', 0.02985425815351648), ('color_moments_rgb_B_std', 0.02936474879957409), ('color_moments_lab_B_var', 0.028466389738260017), ('color_moments_rgb_R_iqr', 0.023950543913171703), ('color_moments_lab_L_iqr', 0.017140100362966416), ('color_moments_rgb_B_iqr', 0.014615331751514693), ('color_moments_lab_L_var', 0.01395843083580979), ('color_moments_rgb_B_kurtosis', 0.012971634560553096), ('color_moments_rgb_R_skew', 0.012803440531345765)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier6; Done in 8.250133037567139 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier7
# INFO:utils.ml:Top 10 features for RandomForestClassifier7: [('color_moments_lab_B_std', 0.039123725014844325), ('color_moments_rgb_B_std', 0.03181760741014515), ('color_moments_rgb_B_var', 0.02959854502912043), ('color_moments_lab_B_var', 0.0281711717887545), ('color_moments_rgb_R_iqr', 0.023039935930466715), ('color_moments_lab_L_iqr', 0.01646306777352436), ('color_moments_rgb_B_iqr', 0.013669943483884396), ('color_moments_rgb_R_kurtosis', 0.013428444979771964), ('color_moments_rgb_R_skew', 0.013066156142972985), ('color_moments_rgb_B_kurtosis', 0.012611313196660904)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier7; Done in 11.556242227554321 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier8
# INFO:utils.ml:Top 10 features for XGBClassifier8: [('color_moments_rgb_R_iqr', 0.05875168), ('color_moments_rgb_B_std', 0.053066652), ('lbp_rad1_bins8_8', 0.024270965), ('glcm_energy_dist_1_angle_0', 0.023337487), ('color_moments_lab_B_std', 0.022202048), ('color_moments_hsv_H_min', 0.021005463), ('lbp_rad2_bins16_12', 0.015509453), ('lbp_rad1_bins8_4', 0.014121116), ('lbp_rad2_bins16_8', 0.013203258), ('color_moments_rgb_R_skew', 0.012569124)]
# INFO:utils.ml:Fitted classifier: XGBClassifier8; Done in 5.01271390914917 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier9
# INFO:utils.ml:Top 10 features for XGBClassifier9: [('color_moments_rgb_R_iqr', 0.061291024), ('color_moments_rgb_B_std', 0.054079138), ('lbp_rad1_bins8_8', 0.024707088), ('glcm_energy_dist_1_angle_0', 0.023889534), ('color_moments_hsv_H_min', 0.022603238), ('color_moments_lab_B_std', 0.0223062), ('lbp_rad2_bins16_12', 0.016060835), ('lbp_rad1_bins8_4', 0.0138755655), ('lbp_rad2_bins16_8', 0.013336515), ('color_moments_rgb_R_skew', 0.012770925)]
# INFO:utils.ml:Fitted classifier: XGBClassifier9; Done in 6.121657133102417 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier10
# INFO:utils.ml:Top 10 features for XGBClassifier10: [('color_moments_rgb_R_iqr', 0.0633022), ('color_moments_rgb_B_std', 0.054088544), ('lbp_rad1_bins8_8', 0.025415558), ('glcm_energy_dist_1_angle_0', 0.024065388), ('color_moments_hsv_H_min', 0.023879327), ('color_moments_lab_B_std', 0.02249282), ('lbp_rad2_bins16_12', 0.016059598), ('lbp_rad1_bins8_4', 0.013920056), ('lbp_rad2_bins16_8', 0.012749079), ('color_moments_rgb_R_skew', 0.012657649)]
# INFO:utils.ml:Fitted classifier: XGBClassifier10; Done in 7.443185329437256 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier11
# INFO:utils.ml:Top 10 features for XGBClassifier11: [('color_moments_rgb_R_iqr', 0.043670744), ('color_moments_rgb_B_var', 0.034932528), ('color_moments_rgb_B_std', 0.03182079), ('color_moments_lab_B_std', 0.023258759), ('color_moments_lab_B_var', 0.02126525), ('lbp_rad1_bins8_3', 0.018328795), ('lbp_rad1_bins8_4', 0.014034877), ('lbp_rad2_bins16_8', 0.012879609), ('color_moments_rgb_B_min', 0.010608526), ('fourier_transform_magnitude_std', 0.010572497)]
# INFO:utils.ml:Fitted classifier: XGBClassifier11; Done in 3.0723867416381836 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier12
# INFO:utils.ml:Top 10 features for XGBClassifier12: [('color_moments_rgb_B_std', 0.03617794), ('color_moments_rgb_B_var', 0.034050282), ('color_moments_rgb_R_iqr', 0.033817787), ('color_moments_lab_B_var', 0.019697433), ('color_moments_lab_B_std', 0.017010693), ('lbp_rad2_bins16_8', 0.014781565), ('lbp_rad1_bins8_4', 0.01258161), ('color_moments_rgb_R_std', 0.011807123), ('lbp_rad1_bins8_8', 0.010655894), ('color_moments_hsv_H_min', 0.010589195)]
# INFO:utils.ml:Fitted classifier: XGBClassifier12; Done in 7.322093725204468 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier13
# INFO:utils.ml:Top 10 features for XGBClassifier13: [('color_moments_rgb_R_iqr', 0.050605427), ('color_moments_rgb_B_std', 0.036386445), ('color_moments_rgb_B_var', 0.031863745), ('color_moments_lab_B_var', 0.019932875), ('color_moments_lab_B_std', 0.019463226), ('lbp_rad2_bins16_8', 0.01210043), ('lbp_rad1_bins8_4', 0.0118794), ('lbp_rad1_bins8_3', 0.011683893), ('color_moments_rgb_R_std', 0.010771128), ('fourier_transform_magnitude_std', 0.009880967)]
# INFO:utils.ml:Fitted classifier: XGBClassifier13; Done in 4.991172552108765 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier14
# INFO:utils.ml:Top 10 features for XGBClassifier14: [('color_moments_rgb_R_iqr', 0.050477356), ('color_moments_rgb_B_var', 0.03907029), ('color_moments_rgb_B_std', 0.037490744), ('color_moments_hsv_H_min', 0.023067812), ('color_moments_lab_B_std', 0.019774087), ('color_moments_lab_B_var', 0.019757569), ('lbp_rad1_bins8_4', 0.012788941), ('lbp_rad1_bins8_3', 0.011126891), ('color_moments_rgb_R_std', 0.010460618), ('lbp_rad2_bins16_8', 0.010366677)]
# INFO:utils.ml:Fitted classifier: XGBClassifier14; Done in 6.224653005599976 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier15
# INFO:utils.ml:Top 10 features for XGBClassifier15: [('color_moments_rgb_R_iqr', 0.044284627), ('color_moments_rgb_B_std', 0.03692359), ('color_moments_rgb_B_var', 0.036046382), ('color_moments_lab_B_std', 0.01910392), ('color_moments_lab_B_var', 0.018962927), ('lbp_rad2_bins16_8', 0.015233767), ('lbp_rad1_bins8_4', 0.011965807), ('lbp_rad1_bins8_3', 0.011487772), ('color_moments_rgb_R_std', 0.010966292), ('fourier_transform_magnitude_std', 0.010413431)]
# INFO:utils.ml:Fitted classifier: XGBClassifier15; Done in 16.315788745880127 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier16
# INFO:utils.ml:Top 10 features for XGBClassifier16: [('color_moments_rgb_R_iqr', 0.043352406), ('color_moments_rgb_B_var', 0.035867225), ('color_moments_rgb_B_std', 0.035171546), ('color_moments_lab_B_var', 0.019020377), ('color_moments_lab_B_std', 0.01884008), ('lbp_rad2_bins16_8', 0.01542306), ('lbp_rad1_bins8_4', 0.012095936), ('lbp_rad1_bins8_3', 0.011423905), ('color_moments_rgb_R_std', 0.010605446), ('fourier_transform_magnitude_std', 0.010398488)]
# INFO:utils.ml:Fitted classifier: XGBClassifier16; Done in 16.84115767478943 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier17
# INFO:utils.ml:Top 10 features for XGBClassifier17: [('color_moments_rgb_B_var', 0.05228482), ('color_moments_rgb_R_iqr', 0.049585618), ('color_moments_rgb_B_std', 0.03863933), ('color_moments_lab_B_var', 0.020485267), ('color_moments_lab_B_std', 0.017882954), ('lbp_rad1_bins8_4', 0.012331418), ('lbp_rad2_bins16_8', 0.0121397665), ('color_moments_rgb_R_std', 0.011538238), ('lbp_rad1_bins8_3', 0.010832604), ('fourier_transform_magnitude_std', 0.009657565)]
# INFO:utils.ml:Fitted classifier: XGBClassifier17; Done in 15.369879007339478 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier18
# INFO:utils.ml:Top 10 features for XGBClassifier18: [('color_moments_rgb_B_var', 0.051824607), ('color_moments_rgb_R_iqr', 0.051040184), ('color_moments_rgb_B_std', 0.039109305), ('color_moments_lab_B_var', 0.019818833), ('color_moments_lab_B_std', 0.018095408), ('lbp_rad1_bins8_4', 0.012471542), ('lbp_rad2_bins16_8', 0.012149525), ('color_moments_rgb_R_std', 0.011648255), ('lbp_rad1_bins8_3', 0.011329285), ('color_moments_hsv_H_min', 0.010333779)]
# INFO:utils.ml:Fitted classifier: XGBClassifier18; Done in 16.958104610443115 seconds
# INFO:utils.ml:Fitting completed in 165.16 seconds.

# %%
pipeline.predict_with_classifiers(VAL_PATH, percent)
# Out:
# INFO:utils.ml:Predicting with classifiers on dataset: C:\Users\gimes\Src\repos\CADx-Project\dataset\multiclass\val
# Processed 5/53 batches.
# Processed 10/53 batches.
# Processed 15/53 batches.
# Processed 20/53 batches.
# Processed 25/53 batches.
# Processed 30/53 batches.
# Processed 35/53 batches.
# Processed 40/53 batches.
# Processed 45/53 batches.
# Processed 50/53 batches.
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier0
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier1
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier2
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier3
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier4
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier5
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier6
# Processed 53/53 batches.
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier7
# INFO:utils.ml:Predictions made with classifier: XGBClassifier8
# INFO:utils.ml:Predictions made with classifier: XGBClassifier9
# INFO:utils.ml:Predictions made with classifier: XGBClassifier10
# INFO:utils.ml:Predictions made with classifier: XGBClassifier11
# INFO:utils.ml:Predictions made with classifier: XGBClassifier12
# INFO:utils.ml:Predictions made with classifier: XGBClassifier13
# INFO:utils.ml:Predictions made with classifier: XGBClassifier14
# INFO:utils.ml:Predictions made with classifier: XGBClassifier15
# INFO:utils.ml:Predictions made with classifier: XGBClassifier16
# INFO:utils.ml:Predictions made with classifier: XGBClassifier17
# INFO:utils.ml:Predictions made with classifier: XGBClassifier18
# {'GT': array([0, 0, 0, ..., 2, 2, 2]),
#  'RandomForestClassifier0': array([0, 0, 0, ..., 1, 0, 0]),
#  'RandomForestClassifier1': array([0, 0, 0, ..., 1, 0, 0]),
#  'RandomForestClassifier2': array([0, 0, 0, ..., 1, 0, 0]),
#  'RandomForestClassifier3': array([0, 0, 0, ..., 1, 0, 0]),
#  'RandomForestClassifier4': array([0, 0, 0, ..., 1, 0, 0]),
#  'RandomForestClassifier5': array([0, 0, 0, ..., 1, 0, 0]),
#  'RandomForestClassifier6': array([0, 0, 1, ..., 1, 0, 0]),
#  'RandomForestClassifier7': array([0, 0, 0, ..., 1, 0, 0]),
#  'XGBClassifier8': array([0, 0, 0, ..., 1, 0, 0], dtype=int64),
#  'XGBClassifier9': array([0, 0, 0, ..., 1, 0, 0], dtype=int64),
#  'XGBClassifier10': array([0, 0, 0, ..., 1, 0, 0], dtype=int64),
#  'XGBClassifier11': array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#  'XGBClassifier12': array([0, 0, 0, ..., 1, 0, 0], dtype=int64),
#  'XGBClassifier13': array([0, 0, 0, ..., 1, 0, 0], dtype=int64),
#  'XGBClassifier14': array([0, 0, 0, ..., 1, 0, 0], dtype=int64),
#  'XGBClassifier15': array([0, 0, 0, ..., 1, 0, 0], dtype=int64),
#  'XGBClassifier16': array([0, 0, 0, ..., 1, 0, 0], dtype=int64),
#  'XGBClassifier17': array([0, 0, 0, ..., 1, 0, 0], dtype=int64),
#  'XGBClassifier18': array([0, 0, 0, ..., 1, 0, 0], dtype=int64)}

# %%
import pandas as pd

df = pd.DataFrame(data=pipeline.calculate_metrics())
df.T
# Out:
# INFO:utils.ml:Metrics for classifier GT: {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'kappa': 1.0}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier0: {'accuracy': 0.8181102362204724, 'precision': 0.827538775076741, 'recall': 0.6062655189892817, 'f1': 0.6016283301347637, 'kappa': 0.6585735433774649}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier1: {'accuracy': 0.8173228346456692, 'precision': 0.8328090164342988, 'recall': 0.6084729301943858, 'f1': 0.6068594006669649, 'kappa': 0.6571130651745856}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier2: {'accuracy': 0.8133858267716535, 'precision': 0.8164144782641892, 'recall': 0.599550401442587, 'f1': 0.5922436728289787, 'kappa': 0.6493200544329283}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier3: {'accuracy': 0.831496062992126, 'precision': 0.8596862180836959, 'recall': 0.6367154427034694, 'f1': 0.6494340977372557, 'kappa': 0.6848035850141954}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier4: {'accuracy': 0.8188976377952756, 'precision': 0.8278059714116552, 'recall': 0.6058686512824663, 'f1': 0.6018557087306929, 'kappa': 0.6592664137702562}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier5: {'accuracy': 0.8244094488188977, 'precision': 0.8487155736064033, 'recall': 0.6227718884072032, 'f1': 0.6286718473634362, 'kappa': 0.6711540783814663}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier6: {'accuracy': 0.8141732283464567, 'precision': 0.8170025902541687, 'recall': 0.6000420435271494, 'f1': 0.5928870209091746, 'kappa': 0.6505065393011062}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier7: {'accuracy': 0.831496062992126, 'precision': 0.8831588807469174, 'recall': 0.6336609854972516, 'f1': 0.6447560185966145, 'kappa': 0.6843100540359713}
# INFO:utils.ml:Metrics for classifier XGBClassifier8: {'accuracy': 0.8535433070866142, 'precision': 0.8263056505597942, 'recall': 0.6756278865540616, 'f1': 0.6991990521236545, 'kappa': 0.727023116711427}
# INFO:utils.ml:Metrics for classifier XGBClassifier9: {'accuracy': 0.8511811023622047, 'precision': 0.8076594040381405, 'recall': 0.6736198544255475, 'f1': 0.6959911598638132, 'kappa': 0.722821417683631}
# INFO:utils.ml:Metrics for classifier XGBClassifier10: {'accuracy': 0.8496062992125984, 'precision': 0.8065506058346065, 'recall': 0.6726365702564227, 'f1': 0.6949167008428924, 'kappa': 0.720004709489159}
# INFO:utils.ml:Metrics for classifier XGBClassifier11: {'accuracy': 0.8220472440944881, 'precision': 0.7747420893607334, 'recall': 0.6222189958604266, 'f1': 0.630349471728782, 'kappa': 0.666047676226113}
# INFO:utils.ml:Metrics for classifier XGBClassifier12: {'accuracy': 0.8496062992125984, 'precision': 0.821928478026039, 'recall': 0.6597079335984496, 'f1': 0.6790532473125342, 'kappa': 0.7181476782070767}
# INFO:utils.ml:Metrics for classifier XGBClassifier13: {'accuracy': 0.8543307086614174, 'precision': 0.8126394042681744, 'recall': 0.6685889985599839, 'f1': 0.6902316257582264, 'kappa': 0.7270574950859894}
# INFO:utils.ml:Metrics for classifier XGBClassifier14: {'accuracy': 0.8543307086614174, 'precision': 0.8450451591120115, 'recall': 0.6719988596827529, 'f1': 0.6966772389218918, 'kappa': 0.7270866631974129}
# INFO:utils.ml:Metrics for classifier XGBClassifier15: {'accuracy': 0.8511811023622047, 'precision': 0.8260032744309864, 'recall': 0.6649895886817211, 'f1': 0.6850294165190016, 'kappa': 0.7220433743422516}
# INFO:utils.ml:Metrics for classifier XGBClassifier16: {'accuracy': 0.8519685039370078, 'precision': 0.8265411940151627, 'recall': 0.6656589327245591, 'f1': 0.6856151461911143, 'kappa': 0.7235716634326389}
# INFO:utils.ml:Metrics for classifier XGBClassifier17: {'accuracy': 0.8574803149606299, 'precision': 0.8444414897546131, 'recall': 0.6726879903975407, 'f1': 0.6947864874914774, 'kappa': 0.7337532373067461}
# INFO:utils.ml:Metrics for classifier XGBClassifier18: {'accuracy': 0.8566929133858268, 'precision': 0.8438890528452024, 'recall': 0.6721963483129781, 'f1': 0.69424858484897, 'kappa': 0.7323380641814274}
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
#                          accuracy  precision    recall        f1     kappa
# GT                       1.000000   1.000000  1.000000  1.000000  1.000000
# RandomForestClassifier0  0.818110   0.827539  0.606266  0.601628  0.658574
# RandomForestClassifier1  0.817323   0.832809  0.608473  0.606859  0.657113
# RandomForestClassifier2  0.813386   0.816414  0.599550  0.592244  0.649320
# RandomForestClassifier3  0.831496   0.859686  0.636715  0.649434  0.684804
# RandomForestClassifier4  0.818898   0.827806  0.605869  0.601856  0.659266
# RandomForestClassifier5  0.824409   0.848716  0.622772  0.628672  0.671154
# RandomForestClassifier6  0.814173   0.817003  0.600042  0.592887  0.650507
# RandomForestClassifier7  0.831496   0.883159  0.633661  0.644756  0.684310
# XGBClassifier8           0.853543   0.826306  0.675628  0.699199  0.727023
# XGBClassifier9           0.851181   0.807659  0.673620  0.695991  0.722821
# XGBClassifier10          0.849606   0.806551  0.672637  0.694917  0.720005
# XGBClassifier11          0.822047   0.774742  0.622219  0.630349  0.666048
# XGBClassifier12          0.849606   0.821928  0.659708  0.679053  0.718148
# XGBClassifier13          0.854331   0.812639  0.668589  0.690232  0.727057
# XGBClassifier14          0.854331   0.845045  0.671999  0.696677  0.727087
# XGBClassifier15          0.851181   0.826003  0.664990  0.685029  0.722043
# XGBClassifier16          0.851969   0.826541  0.665659  0.685615  0.723572
# XGBClassifier17          0.857480   0.844441  0.672688  0.694786  0.733753
# XGBClassifier18          0.856693   0.843889  0.672196  0.694249  0.732338

# %% [markdown]
# ___
# # Balance the data

# %%
# Backup
pipeline.backup_feature_matrix = pipeline.feature_matrix.copy()
pipeline.backup_labels = pipeline.labels.copy()

# %%
print(pipeline.backup_feature_matrix.shape)
print(pipeline.feature_matrix.shape)

print(pipeline.backup_labels.shape)
print(pipeline.labels.shape)
# Out:
# (5082, 189)
# (5082, 189)
# (5082,)
# (5082,)

# %%
pipeline.get_feature_names()
# Out:
# ['gradient_magnitude_mean',
#  'gradient_magnitude_std',
#  'gradient_direction_mean',
#  'gradient_direction_std',
#  'color_moments_rgb_R_mean',
#  'color_moments_rgb_R_std',
#  'color_moments_rgb_R_skew',
#  'color_moments_rgb_R_kurtosis',
#  'color_moments_rgb_R_median',
#  'color_moments_rgb_R_var',
#  'color_moments_rgb_R_min',
#  'color_moments_rgb_R_max',
#  'color_moments_rgb_R_iqr',
#  'color_moments_rgb_R_entropy',
#  'color_moments_rgb_G_mean',
#  'color_moments_rgb_G_std',
#  'color_moments_rgb_G_skew',
#  'color_moments_rgb_G_kurtosis',
#  'color_moments_rgb_G_median',
#  'color_moments_rgb_G_var',
#  'color_moments_rgb_G_min',
#  'color_moments_rgb_G_max',
#  'color_moments_rgb_G_iqr',
#  'color_moments_rgb_G_entropy',
#  'color_moments_rgb_B_mean',
#  'color_moments_rgb_B_std',
#  'color_moments_rgb_B_skew',
#  'color_moments_rgb_B_kurtosis',
#  'color_moments_rgb_B_median',
#  'color_moments_rgb_B_var',
#  'color_moments_rgb_B_min',
#  'color_moments_rgb_B_max',
#  'color_moments_rgb_B_iqr',
#  'color_moments_rgb_B_entropy',
#  'color_moments_lab_L_mean',
#  'color_moments_lab_L_std',
#  'color_moments_lab_L_skew',
#  'color_moments_lab_L_kurtosis',
#  'color_moments_lab_L_median',
#  'color_moments_lab_L_var',
#  'color_moments_lab_L_min',
#  'color_moments_lab_L_max',
#  'color_moments_lab_L_iqr',
#  'color_moments_lab_L_entropy',
#  'color_moments_lab_A_mean',
#  'color_moments_lab_A_std',
#  'color_moments_lab_A_skew',
#  'color_moments_lab_A_kurtosis',
#  'color_moments_lab_A_median',
#  'color_moments_lab_A_var',
#  'color_moments_lab_A_min',
#  'color_moments_lab_A_max',
#  'color_moments_lab_A_iqr',
#  'color_moments_lab_A_entropy',
#  'color_moments_lab_B_mean',
#  'color_moments_lab_B_std',
#  'color_moments_lab_B_skew',
#  'color_moments_lab_B_kurtosis',
#  'color_moments_lab_B_median',
#  'color_moments_lab_B_var',
#  'color_moments_lab_B_min',
#  'color_moments_lab_B_max',
#  'color_moments_lab_B_iqr',
#  'color_moments_lab_B_entropy',
#  'color_moments_hsv_H_mean',
#  'color_moments_hsv_H_std',
#  'color_moments_hsv_H_skew',
#  'color_moments_hsv_H_kurtosis',
#  'color_moments_hsv_H_median',
#  'color_moments_hsv_H_var',
#  'color_moments_hsv_H_min',
#  'color_moments_hsv_H_max',
#  'color_moments_hsv_H_iqr',
#  'color_moments_hsv_H_entropy',
#  'color_moments_hsv_S_mean',
#  'color_moments_hsv_S_std',
#  'color_moments_hsv_S_skew',
#  'color_moments_hsv_S_kurtosis',
#  'color_moments_hsv_S_median',
#  'color_moments_hsv_S_var',
#  'color_moments_hsv_S_min',
#  'color_moments_hsv_S_max',
#  'color_moments_hsv_S_iqr',
#  'color_moments_hsv_S_entropy',
#  'color_moments_hsv_V_mean',
#  'color_moments_hsv_V_std',
#  'color_moments_hsv_V_skew',
#  'color_moments_hsv_V_kurtosis',
#  'color_moments_hsv_V_median',
#  'color_moments_hsv_V_var',
#  'color_moments_hsv_V_min',
#  'color_moments_hsv_V_max',
#  'color_moments_hsv_V_iqr',
#  'color_moments_hsv_V_entropy',
#  'lbp_rad1_bins8_0',
#  'lbp_rad1_bins8_1',
#  'lbp_rad1_bins8_2',
#  'lbp_rad1_bins8_3',
#  'lbp_rad1_bins8_4',
#  'lbp_rad1_bins8_5',
#  'lbp_rad1_bins8_6',
#  'lbp_rad1_bins8_7',
#  'lbp_rad1_bins8_8',
#  'lbp_rad1_bins8_9',
#  'lbp_rad2_bins16_0',
#  'lbp_rad2_bins16_1',
#  'lbp_rad2_bins16_2',
#  'lbp_rad2_bins16_3',
#  'lbp_rad2_bins16_4',
#  'lbp_rad2_bins16_5',
#  'lbp_rad2_bins16_6',
#  'lbp_rad2_bins16_7',
#  'lbp_rad2_bins16_8',
#  'lbp_rad2_bins16_9',
#  'lbp_rad2_bins16_10',
#  'lbp_rad2_bins16_11',
#  'lbp_rad2_bins16_12',
#  'lbp_rad2_bins16_13',
#  'lbp_rad2_bins16_14',
#  'lbp_rad2_bins16_15',
#  'lbp_rad2_bins16_16',
#  'lbp_rad2_bins16_17',
#  'lbp_rad3_bins24_0',
#  'lbp_rad3_bins24_1',
#  'lbp_rad3_bins24_2',
#  'lbp_rad3_bins24_3',
#  'lbp_rad3_bins24_4',
#  'lbp_rad3_bins24_5',
#  'lbp_rad3_bins24_6',
#  'lbp_rad3_bins24_7',
#  'lbp_rad3_bins24_8',
#  'lbp_rad3_bins24_9',
#  'lbp_rad3_bins24_10',
#  'lbp_rad3_bins24_11',
#  'lbp_rad3_bins24_12',
#  'lbp_rad3_bins24_13',
#  'lbp_rad3_bins24_14',
#  'lbp_rad3_bins24_15',
#  'lbp_rad3_bins24_16',
#  'lbp_rad3_bins24_17',
#  'lbp_rad3_bins24_18',
#  'lbp_rad3_bins24_19',
#  'lbp_rad3_bins24_20',
#  'lbp_rad3_bins24_21',
#  'lbp_rad3_bins24_22',
#  'lbp_rad3_bins24_23',
#  'lbp_rad3_bins24_24',
#  'lbp_rad3_bins24_25',
#  'lbp_rad4_bins32_0',
#  'lbp_rad4_bins32_1',
#  'lbp_rad4_bins32_2',
#  'lbp_rad4_bins32_3',
#  'lbp_rad4_bins32_4',
#  'lbp_rad4_bins32_5',
#  'lbp_rad4_bins32_6',
#  'lbp_rad4_bins32_7',
#  'lbp_rad4_bins32_8',
#  'lbp_rad4_bins32_9',
#  'lbp_rad4_bins32_10',
#  'lbp_rad4_bins32_11',
#  'lbp_rad4_bins32_12',
#  'lbp_rad4_bins32_13',
#  'lbp_rad4_bins32_14',
#  'lbp_rad4_bins32_15',
#  'lbp_rad4_bins32_16',
#  'lbp_rad4_bins32_17',
#  'lbp_rad4_bins32_18',
#  'lbp_rad4_bins32_19',
#  'lbp_rad4_bins32_20',
#  'lbp_rad4_bins32_21',
#  'lbp_rad4_bins32_22',
#  'lbp_rad4_bins32_23',
#  'lbp_rad4_bins32_24',
#  'lbp_rad4_bins32_25',
#  'lbp_rad4_bins32_26',
#  'lbp_rad4_bins32_27',
#  'lbp_rad4_bins32_28',
#  'lbp_rad4_bins32_29',
#  'lbp_rad4_bins32_30',
#  'lbp_rad4_bins32_31',
#  'lbp_rad4_bins32_32',
#  'lbp_rad4_bins32_33',
#  'fourier_transform_magnitude_mean',
#  'fourier_transform_magnitude_std',
#  'glcm_contrast_dist_1_angle_0',
#  'glcm_dissimilarity_dist_1_angle_0',
#  'glcm_homogeneity_dist_1_angle_0',
#  'glcm_energy_dist_1_angle_0',
#  'glcm_correlation_dist_1_angle_0']

# %%
from imblearn.over_sampling import SMOTE

smote = SMOTE(random_state=42)


pipeline.feature_matrix, pipeline.labels = smote.fit_resample(np.nan_to_num(pipeline.feature_matrix), pipeline.labels)

# %%
pipeline.fitted_classifiers = {}
pipeline.fit_classifiers()
# Out:
# INFO:utils.ml:Fitting classifiers...
# INFO:utils.ml:Fitting classifier: RandomForestClassifier0
# INFO:utils.ml:Top 10 features for RandomForestClassifier0: [('color_moments_rgb_B_var', 0.025598212319409112), ('color_moments_lab_B_std', 0.01981796496559757), ('color_moments_rgb_R_iqr', 0.019723423758789282), ('color_moments_lab_B_var', 0.019448206465166474), ('color_moments_rgb_B_std', 0.01870932041167769), ('color_moments_rgb_G_var', 0.013839536982092561), ('color_moments_rgb_G_iqr', 0.013254745886876413), ('color_moments_lab_L_std', 0.012971168282269694), ('color_moments_rgb_R_kurtosis', 0.012922128117509323), ('color_moments_lab_L_iqr', 0.012812086870632953)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier0; Done in 8.149178743362427 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier1
# INFO:utils.ml:Top 10 features for RandomForestClassifier1: [('color_moments_rgb_B_std', 0.023384471136222856), ('color_moments_rgb_B_var', 0.02118293292232135), ('color_moments_lab_B_std', 0.02092732117869457), ('color_moments_lab_B_var', 0.01992895739584239), ('color_moments_rgb_R_iqr', 0.01980489393678664), ('color_moments_rgb_B_iqr', 0.013711765828284239), ('fourier_transform_magnitude_std', 0.012703256602197155), ('color_moments_lab_L_iqr', 0.012204850527649563), ('color_moments_rgb_G_std', 0.012108064307655287), ('color_moments_rgb_G_var', 0.011779331686095112)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier1; Done in 12.203830242156982 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier2
# INFO:utils.ml:Top 10 features for RandomForestClassifier2: [('color_moments_rgb_B_std', 0.029128028865500775), ('color_moments_rgb_B_var', 0.02273660117349868), ('color_moments_lab_B_std', 0.021834726948835592), ('color_moments_lab_B_var', 0.01786033521939652), ('color_moments_lab_L_iqr', 0.01769682348386762), ('color_moments_rgb_R_iqr', 0.015679981014308363), ('color_moments_lab_L_std', 0.012984783553773813), ('color_moments_rgb_R_kurtosis', 0.012693853164068658), ('color_moments_rgb_G_std', 0.012334163204064927), ('color_moments_rgb_B_iqr', 0.012020309268858893)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier2; Done in 7.7874839305877686 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier3
# INFO:utils.ml:Top 10 features for RandomForestClassifier3: [('color_moments_rgb_B_std', 0.029542272717298368), ('color_moments_rgb_B_var', 0.024264588982116062), ('color_moments_lab_B_std', 0.02335680425196511), ('color_moments_lab_B_var', 0.016385388166232265), ('color_moments_rgb_R_iqr', 0.016348000673152917), ('color_moments_lab_L_iqr', 0.015379769790936436), ('color_moments_lab_L_std', 0.01312611331424195), ('color_moments_rgb_B_iqr', 0.012558249367334044), ('fourier_transform_magnitude_std', 0.012282111322129596), ('color_moments_rgb_G_std', 0.011573426130262023)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier3; Done in 11.13194465637207 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier4
# INFO:utils.ml:Top 10 features for RandomForestClassifier4: [('color_moments_rgb_B_std', 0.025983559745084202), ('color_moments_rgb_B_var', 0.024197832002491336), ('color_moments_lab_B_std', 0.02275952723032486), ('color_moments_lab_L_iqr', 0.018990266158153007), ('color_moments_lab_B_var', 0.016722330879839886), ('color_moments_rgb_R_iqr', 0.015002042181744765), ('fourier_transform_magnitude_std', 0.012292473608762173), ('color_moments_lab_L_std', 0.01228547727907868), ('color_moments_rgb_R_kurtosis', 0.012151452454683642), ('color_moments_rgb_G_std', 0.011988974773072683)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier4; Done in 11.60858964920044 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier5
# INFO:utils.ml:Top 10 features for RandomForestClassifier5: [('color_moments_rgb_B_std', 0.02829698891539931), ('color_moments_rgb_B_var', 0.024695146269002582), ('color_moments_lab_B_std', 0.022433954107600414), ('color_moments_rgb_R_iqr', 0.017003839930012636), ('color_moments_lab_L_iqr', 0.01636263607949848), ('color_moments_lab_B_var', 0.015664847122890686), ('color_moments_lab_L_std', 0.01264395840871694), ('color_moments_lab_L_var', 0.012396552125851418), ('fourier_transform_magnitude_std', 0.012259692315267582), ('color_moments_rgb_G_std', 0.011769120410396143)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier5; Done in 17.04878044128418 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier6
# INFO:utils.ml:Top 10 features for RandomForestClassifier6: [('color_moments_rgb_B_std', 0.024330187020803754), ('color_moments_rgb_B_var', 0.023324126240818137), ('color_moments_lab_B_std', 0.022354390216361524), ('color_moments_rgb_R_iqr', 0.018647476637061164), ('color_moments_lab_L_iqr', 0.018170291413301856), ('color_moments_lab_B_var', 0.01637027029830781), ('color_moments_rgb_B_iqr', 0.013154665315471296), ('color_moments_rgb_R_kurtosis', 0.012784967585923438), ('color_moments_rgb_G_std', 0.012275456631883145), ('fourier_transform_magnitude_std', 0.011876109997938115)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier6; Done in 15.730083703994751 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier7
# INFO:utils.ml:Top 10 features for RandomForestClassifier7: [('color_moments_rgb_B_std', 0.02632804312952395), ('color_moments_rgb_B_var', 0.023333808500143095), ('color_moments_lab_B_std', 0.02195365723150902), ('color_moments_rgb_R_iqr', 0.019965970619353342), ('color_moments_lab_L_iqr', 0.01589610282941025), ('color_moments_lab_B_var', 0.01542245504453859), ('color_moments_rgb_B_iqr', 0.013255575758330444), ('color_moments_lab_L_std', 0.012054754919192692), ('color_moments_lab_L_var', 0.012029591213628572), ('fourier_transform_magnitude_std', 0.011855790111733404)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier7; Done in 22.696362733840942 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier8
# INFO:utils.ml:Top 10 features for XGBClassifier8: [('color_moments_rgb_B_std', 0.081624664), ('color_moments_rgb_R_iqr', 0.035971835), ('glcm_energy_dist_1_angle_0', 0.025646267), ('lbp_rad2_bins16_7', 0.01670571), ('gradient_magnitude_mean', 0.016264623), ('fourier_transform_magnitude_std', 0.014105685), ('color_moments_lab_B_std', 0.013940581), ('lbp_rad1_bins8_4', 0.012607182), ('lbp_rad2_bins16_8', 0.012020346), ('color_moments_lab_B_var', 0.011327417)]
# INFO:utils.ml:Fitted classifier: XGBClassifier8; Done in 5.979896306991577 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier9
# INFO:utils.ml:Top 10 features for XGBClassifier9: [('color_moments_rgb_B_std', 0.0827354), ('color_moments_rgb_R_iqr', 0.037089117), ('glcm_energy_dist_1_angle_0', 0.026029862), ('lbp_rad2_bins16_7', 0.016679283), ('gradient_magnitude_mean', 0.016631626), ('color_moments_lab_B_std', 0.014064121), ('fourier_transform_magnitude_std', 0.013640339), ('lbp_rad1_bins8_4', 0.013008772), ('lbp_rad2_bins16_8', 0.012083546), ('lbp_rad1_bins8_3', 0.011577468)]
# INFO:utils.ml:Fitted classifier: XGBClassifier9; Done in 7.550561904907227 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier10
# INFO:utils.ml:Top 10 features for XGBClassifier10: [('color_moments_rgb_B_std', 0.084092185), ('color_moments_rgb_R_iqr', 0.037307926), ('glcm_energy_dist_1_angle_0', 0.025350185), ('gradient_magnitude_mean', 0.01694153), ('lbp_rad2_bins16_7', 0.016829861), ('color_moments_lab_B_std', 0.014069379), ('fourier_transform_magnitude_std', 0.013495789), ('lbp_rad1_bins8_4', 0.01251586), ('lbp_rad2_bins16_8', 0.0121695995), ('lbp_rad1_bins8_3', 0.011665887)]
# INFO:utils.ml:Fitted classifier: XGBClassifier10; Done in 9.642600774765015 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier11
# INFO:utils.ml:Top 10 features for XGBClassifier11: [('color_moments_rgb_B_std', 0.040945455), ('color_moments_rgb_R_iqr', 0.033967394), ('color_moments_rgb_B_var', 0.031061832), ('color_moments_lab_B_std', 0.017321154), ('lbp_rad1_bins8_4', 0.016625464), ('color_moments_lab_L_std', 0.015571378), ('color_moments_lab_L_var', 0.013880073), ('color_moments_rgb_B_entropy', 0.013438778), ('color_moments_lab_B_var', 0.012629092), ('glcm_energy_dist_1_angle_0', 0.012528217)]
# INFO:utils.ml:Fitted classifier: XGBClassifier11; Done in 3.4052677154541016 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier12
# INFO:utils.ml:Top 10 features for XGBClassifier12: [('color_moments_rgb_B_std', 0.042868417), ('color_moments_rgb_B_var', 0.030356249), ('color_moments_rgb_R_iqr', 0.026085768), ('glcm_energy_dist_1_angle_0', 0.016484525), ('lbp_rad1_bins8_4', 0.01309752), ('color_moments_lab_B_std', 0.0119564645), ('gradient_magnitude_mean', 0.011857004), ('fourier_transform_magnitude_std', 0.0114754215), ('color_moments_lab_B_var', 0.011326737), ('color_moments_hsv_S_min', 0.010481426)]
# INFO:utils.ml:Fitted classifier: XGBClassifier12; Done in 11.757712125778198 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier13
# INFO:utils.ml:Top 10 features for XGBClassifier13: [('color_moments_rgb_B_std', 0.054544076), ('color_moments_rgb_R_iqr', 0.031237833), ('color_moments_rgb_B_var', 0.018959448), ('fourier_transform_magnitude_std', 0.013999775), ('glcm_energy_dist_1_angle_0', 0.013989221), ('color_moments_lab_B_var', 0.013608847), ('lbp_rad1_bins8_4', 0.013071259), ('color_moments_lab_B_std', 0.012231255), ('gradient_magnitude_mean', 0.011214362), ('lbp_rad2_bins16_8', 0.009883553)]
# INFO:utils.ml:Fitted classifier: XGBClassifier13; Done in 10.815826892852783 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier14
# INFO:utils.ml:Top 10 features for XGBClassifier14: [('color_moments_rgb_B_std', 0.051543433), ('color_moments_rgb_R_iqr', 0.031753927), ('color_moments_rgb_B_var', 0.02558232), ('fourier_transform_magnitude_std', 0.014918437), ('color_moments_lab_B_var', 0.012712274), ('lbp_rad1_bins8_4', 0.012508077), ('lbp_rad3_bins24_24', 0.0119943805), ('color_moments_lab_B_std', 0.011821731), ('glcm_energy_dist_1_angle_0', 0.011552044), ('gradient_direction_std', 0.010528144)]
# INFO:utils.ml:Fitted classifier: XGBClassifier14; Done in 13.479670524597168 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier15
# INFO:utils.ml:Top 10 features for XGBClassifier15: [('color_moments_rgb_B_std', 0.0468501), ('color_moments_rgb_B_var', 0.02808272), ('color_moments_rgb_R_iqr', 0.027577238), ('glcm_energy_dist_1_angle_0', 0.015782323), ('color_moments_lab_B_var', 0.01320121), ('lbp_rad1_bins8_4', 0.012844918), ('fourier_transform_magnitude_std', 0.012775373), ('gradient_magnitude_mean', 0.01123655), ('lbp_rad2_bins16_8', 0.010964253), ('color_moments_lab_B_std', 0.010871735)]
# INFO:utils.ml:Fitted classifier: XGBClassifier15; Done in 27.44714117050171 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier16
# INFO:utils.ml:Top 10 features for XGBClassifier16: [('color_moments_rgb_B_std', 0.046248145), ('color_moments_rgb_B_var', 0.029459998), ('color_moments_rgb_R_iqr', 0.027412226), ('glcm_energy_dist_1_angle_0', 0.015197512), ('color_moments_lab_B_var', 0.013370451), ('fourier_transform_magnitude_std', 0.013204127), ('lbp_rad1_bins8_4', 0.012788331), ('lbp_rad2_bins16_8', 0.0108224945), ('gradient_magnitude_mean', 0.010709924), ('color_moments_lab_B_std', 0.010615087)]
# INFO:utils.ml:Fitted classifier: XGBClassifier16; Done in 22.660065174102783 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier17
# INFO:utils.ml:Top 10 features for XGBClassifier17: [('color_moments_rgb_B_std', 0.054352917), ('color_moments_rgb_B_var', 0.029637033), ('color_moments_rgb_R_iqr', 0.027765753), ('glcm_energy_dist_1_angle_0', 0.01757239), ('fourier_transform_magnitude_std', 0.014145261), ('lbp_rad1_bins8_4', 0.012816307), ('color_moments_lab_B_var', 0.012052451), ('color_moments_lab_B_std', 0.011163494), ('lbp_rad2_bins16_8', 0.010664552), ('gradient_magnitude_std', 0.009845809)]
# INFO:utils.ml:Fitted classifier: XGBClassifier17; Done in 19.616830825805664 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier18
# INFO:utils.ml:Top 10 features for XGBClassifier18: [('color_moments_rgb_B_std', 0.05524191), ('color_moments_rgb_B_var', 0.029359931), ('color_moments_rgb_R_iqr', 0.02827332), ('glcm_energy_dist_1_angle_0', 0.0174488), ('fourier_transform_magnitude_std', 0.01417935), ('lbp_rad1_bins8_4', 0.012757529), ('color_moments_lab_B_var', 0.011790912), ('color_moments_lab_B_std', 0.011108568), ('lbp_rad2_bins16_8', 0.010749704), ('gradient_magnitude_mean', 0.010106639)]
# INFO:utils.ml:Fitted classifier: XGBClassifier18; Done in 27.767695665359497 seconds
# INFO:utils.ml:Fitting completed in 266.50 seconds.

# %%
pipeline.predict_with_classifiers(VAL_PATH, percent)
# Out:
# INFO:utils.ml:Predicting with classifiers on dataset: C:\Users\gimes\Src\repos\CADx-Project\dataset\multiclass\val
# Processed 5/53 batches.
# Processed 10/53 batches.
# Processed 15/53 batches.
# Processed 20/53 batches.
# Processed 25/53 batches.
# Processed 30/53 batches.
# Processed 35/53 batches.
# Processed 40/53 batches.
# Processed 45/53 batches.
# Processed 50/53 batches.
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier0
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier1
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier2
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier3
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier4
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier5
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier6
# Processed 53/53 batches.
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier7
# INFO:utils.ml:Predictions made with classifier: XGBClassifier8
# INFO:utils.ml:Predictions made with classifier: XGBClassifier9
# INFO:utils.ml:Predictions made with classifier: XGBClassifier10
# INFO:utils.ml:Predictions made with classifier: XGBClassifier11
# INFO:utils.ml:Predictions made with classifier: XGBClassifier12
# INFO:utils.ml:Predictions made with classifier: XGBClassifier13
# INFO:utils.ml:Predictions made with classifier: XGBClassifier14
# INFO:utils.ml:Predictions made with classifier: XGBClassifier15
# INFO:utils.ml:Predictions made with classifier: XGBClassifier16
# INFO:utils.ml:Predictions made with classifier: XGBClassifier17
# INFO:utils.ml:Predictions made with classifier: XGBClassifier18
# {'GT': array([0, 0, 0, ..., 2, 2, 2]),
#  'RandomForestClassifier0': array([0, 0, 2, ..., 1, 0, 0]),
#  'RandomForestClassifier1': array([0, 0, 2, ..., 1, 2, 0]),
#  'RandomForestClassifier2': array([0, 0, 2, ..., 1, 2, 0]),
#  'RandomForestClassifier3': array([0, 0, 2, ..., 1, 2, 0]),
#  'RandomForestClassifier4': array([0, 0, 2, ..., 1, 2, 0]),
#  'RandomForestClassifier5': array([0, 0, 2, ..., 1, 2, 0]),
#  'RandomForestClassifier6': array([0, 0, 2, ..., 1, 2, 0]),
#  'RandomForestClassifier7': array([0, 0, 2, ..., 1, 0, 0]),
#  'XGBClassifier8': array([0, 0, 0, ..., 1, 0, 0], dtype=int64),
#  'XGBClassifier9': array([0, 0, 0, ..., 1, 2, 0], dtype=int64),
#  'XGBClassifier10': array([0, 0, 0, ..., 1, 2, 0], dtype=int64),
#  'XGBClassifier11': array([0, 0, 2, ..., 0, 0, 0], dtype=int64),
#  'XGBClassifier12': array([0, 0, 0, ..., 1, 0, 0], dtype=int64),
#  'XGBClassifier13': array([0, 0, 0, ..., 1, 0, 0], dtype=int64),
#  'XGBClassifier14': array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#  'XGBClassifier15': array([0, 0, 0, ..., 1, 2, 0], dtype=int64),
#  'XGBClassifier16': array([0, 0, 0, ..., 1, 2, 0], dtype=int64),
#  'XGBClassifier17': array([0, 0, 0, ..., 1, 2, 0], dtype=int64),
#  'XGBClassifier18': array([0, 0, 0, ..., 1, 2, 0], dtype=int64)}

# %%
import pandas as pd

df_smote = pd.DataFrame(data=pipeline.calculate_metrics())
df_smote = df_smote.T
df_smote
# Out:
# INFO:utils.ml:Metrics for classifier GT: {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'kappa': 1.0}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier0: {'accuracy': 0.805511811023622, 'precision': 0.6899201794134497, 'recall': 0.6959976981925063, 'f1': 0.6921816634192233, 'kappa': 0.6535756724402213}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier1: {'accuracy': 0.8251968503937008, 'precision': 0.7313685509296235, 'recall': 0.7258711617952386, 'f1': 0.7274374493930725, 'kappa': 0.687181012062737}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier2: {'accuracy': 0.8188976377952756, 'precision': 0.7092743317422663, 'recall': 0.7023673681735035, 'f1': 0.7048667154406604, 'kappa': 0.6749026154702281}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier3: {'accuracy': 0.8244094488188977, 'precision': 0.7118330676988464, 'recall': 0.70112156401921, 'f1': 0.7048206261763315, 'kappa': 0.6846087370985919}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier4: {'accuracy': 0.8181102362204724, 'precision': 0.7042363898287372, 'recall': 0.6954114077599547, 'f1': 0.698754723967706, 'kappa': 0.6729985554287345}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier5: {'accuracy': 0.8299212598425196, 'precision': 0.7254225817442258, 'recall': 0.708328323650467, 'f1': 0.7144727457596058, 'kappa': 0.6938966800867694}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier6: {'accuracy': 0.8118110236220473, 'precision': 0.6975888342669437, 'recall': 0.6878907080024107, 'f1': 0.6916187342063287, 'kappa': 0.6613854714699439}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier7: {'accuracy': 0.8330708661417323, 'precision': 0.7315466512239125, 'recall': 0.7016646262448906, 'f1': 0.7118940154818119, 'kappa': 0.6980368582554237}
# INFO:utils.ml:Metrics for classifier XGBClassifier8: {'accuracy': 0.852755905511811, 'precision': 0.7399905023479167, 'recall': 0.7232967519358802, 'f1': 0.7301544043004798, 'kappa': 0.7337770942255782}
# INFO:utils.ml:Metrics for classifier XGBClassifier9: {'accuracy': 0.8559055118110236, 'precision': 0.7500974256699448, 'recall': 0.734426691892783, 'f1': 0.7410543240284619, 'kappa': 0.7397074634889347}
# INFO:utils.ml:Metrics for classifier XGBClassifier10: {'accuracy': 0.8535433070866142, 'precision': 0.7500535874302656, 'recall': 0.7325963617225445, 'f1': 0.7399699738681592, 'kappa': 0.7352138062763138}
# INFO:utils.ml:Metrics for classifier XGBClassifier11: {'accuracy': 0.8102362204724409, 'precision': 0.6836715745919172, 'recall': 0.7016466039895476, 'f1': 0.6910111785693553, 'kappa': 0.664469039548518}
# INFO:utils.ml:Metrics for classifier XGBClassifier12: {'accuracy': 0.8535433070866142, 'precision': 0.7506718509493654, 'recall': 0.7241437979369937, 'f1': 0.7343720936728116, 'kappa': 0.7345866554008503}
# INFO:utils.ml:Metrics for classifier XGBClassifier13: {'accuracy': 0.8440944881889764, 'precision': 0.7317831567831568, 'recall': 0.7220428818770972, 'f1': 0.7262959216710237, 'kappa': 0.7188807999141416}
# INFO:utils.ml:Metrics for classifier XGBClassifier14: {'accuracy': 0.8551181102362204, 'precision': 0.750065194048167, 'recall': 0.7400439642206559, 'f1': 0.7441986391056646, 'kappa': 0.7392825584405152}
# INFO:utils.ml:Metrics for classifier XGBClassifier15: {'accuracy': 0.8519685039370078, 'precision': 0.7503480864984257, 'recall': 0.7316130775534196, 'f1': 0.7393314622393578, 'kappa': 0.7325153594170816}
# INFO:utils.ml:Metrics for classifier XGBClassifier16: {'accuracy': 0.8496062992125984, 'precision': 0.7418212056735559, 'recall': 0.7270836940935146, 'f1': 0.7331722110319662, 'kappa': 0.7286021168520218}
# INFO:utils.ml:Metrics for classifier XGBClassifier17: {'accuracy': 0.8519685039370078, 'precision': 0.7499492211318559, 'recall': 0.7256818650992597, 'f1': 0.7353881511880522, 'kappa': 0.7317592709101042}
# INFO:utils.ml:Metrics for classifier XGBClassifier18: {'accuracy': 0.8511811023622047, 'precision': 0.7471452604113024, 'recall': 0.7223134677667552, 'f1': 0.7320187982513673, 'kappa': 0.7303736554066805}
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
#                          accuracy  precision    recall        f1     kappa
# GT                       1.000000   1.000000  1.000000  1.000000  1.000000
# RandomForestClassifier0  0.805512   0.689920  0.695998  0.692182  0.653576
# RandomForestClassifier1  0.825197   0.731369  0.725871  0.727437  0.687181
# RandomForestClassifier2  0.818898   0.709274  0.702367  0.704867  0.674903
# RandomForestClassifier3  0.824409   0.711833  0.701122  0.704821  0.684609
# RandomForestClassifier4  0.818110   0.704236  0.695411  0.698755  0.672999
# RandomForestClassifier5  0.829921   0.725423  0.708328  0.714473  0.693897
# RandomForestClassifier6  0.811811   0.697589  0.687891  0.691619  0.661385
# RandomForestClassifier7  0.833071   0.731547  0.701665  0.711894  0.698037
# XGBClassifier8           0.852756   0.739991  0.723297  0.730154  0.733777
# XGBClassifier9           0.855906   0.750097  0.734427  0.741054  0.739707
# XGBClassifier10          0.853543   0.750054  0.732596  0.739970  0.735214
# XGBClassifier11          0.810236   0.683672  0.701647  0.691011  0.664469
# XGBClassifier12          0.853543   0.750672  0.724144  0.734372  0.734587
# XGBClassifier13          0.844094   0.731783  0.722043  0.726296  0.718881
# XGBClassifier14          0.855118   0.750065  0.740044  0.744199  0.739283
# XGBClassifier15          0.851969   0.750348  0.731613  0.739331  0.732515
# XGBClassifier16          0.849606   0.741821  0.727084  0.733172  0.728602
# XGBClassifier17          0.851969   0.749949  0.725682  0.735388  0.731759
# XGBClassifier18          0.851181   0.747145  0.722313  0.732019  0.730374

# %%
highest = df_smote[df_smote["kappa"] == df_smote.iloc[1:]["kappa"].max()]
idx = highest.index[0]

confusion_matrix(pipeline.predictions["GT"], pipeline.predictions[idx])
# Out:
# array([[438,  36,  24],
#        [ 53, 609,  16],
#        [ 33,  21,  40]], dtype=int64)

# %% [markdown]
# ___
# # Borderline SMOTE

# %%
from imblearn.over_sampling import BorderlineSMOTE
smote = BorderlineSMOTE(sampling_strategy='auto', random_state=42)

pipeline.feature_matrix, pipeline.labels = smote.fit_resample(
    np.nan_to_num(pipeline.backup_feature_matrix), pipeline.backup_labels)

print(pipeline.backup_feature_matrix.shape)
print(pipeline.feature_matrix.shape)

print(pipeline.backup_labels.shape)
print(pipeline.labels.shape)
# Out:
# (5082, 189)
# (8139, 189)
# (5082,)
# (8139,)

# %%
pipeline.fitted_classifiers = {}

pipeline.fit_classifiers()
# Out:
# INFO:utils.ml:Fitting classifiers...
# INFO:utils.ml:Fitting classifier: RandomForestClassifier0
# INFO:utils.ml:Top 10 features for RandomForestClassifier0: [('color_moments_rgb_B_std', 0.023421505302294903), ('color_moments_lab_B_std', 0.021776453230077073), ('color_moments_lab_B_var', 0.018737356667564), ('color_moments_rgb_B_var', 0.018174891854928894), ('color_moments_rgb_B_kurtosis', 0.01601242465270787), ('color_moments_lab_L_std', 0.015115134696839116), ('color_moments_lab_L_var', 0.014840766215370187), ('color_moments_rgb_G_skew', 0.013397361523664135), ('color_moments_lab_L_iqr', 0.01285925338918596), ('color_moments_lab_L_kurtosis', 0.012528294161356243)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier0; Done in 7.734049320220947 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier1
# INFO:utils.ml:Top 10 features for RandomForestClassifier1: [('color_moments_rgb_B_std', 0.029811777377535424), ('color_moments_rgb_B_var', 0.020997016752816042), ('color_moments_lab_B_std', 0.02081320469466917), ('color_moments_rgb_B_iqr', 0.018063447732534956), ('color_moments_lab_B_var', 0.01672351410577741), ('color_moments_rgb_G_var', 0.013897974590641684), ('color_moments_rgb_R_iqr', 0.01304106776452919), ('color_moments_lab_L_iqr', 0.012784723753084735), ('color_moments_rgb_G_skew', 0.012034999788002907), ('color_moments_lab_L_var', 0.012016611214879664)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier1; Done in 11.43168044090271 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier2
# INFO:utils.ml:Top 10 features for RandomForestClassifier2: [('color_moments_rgb_B_std', 0.028793308179085226), ('color_moments_rgb_B_var', 0.022532891381121113), ('color_moments_lab_B_std', 0.021477003309237182), ('color_moments_lab_B_var', 0.01756467658236885), ('color_moments_lab_L_iqr', 0.014275362906057609), ('color_moments_rgb_R_iqr', 0.013714508820990227), ('color_moments_rgb_G_std', 0.013264788904941902), ('color_moments_hsv_H_median', 0.01288350826092907), ('color_moments_rgb_G_skew', 0.012587116905179767), ('color_moments_rgb_B_iqr', 0.012401582557988318)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier2; Done in 7.734463453292847 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier3
# INFO:utils.ml:Top 10 features for RandomForestClassifier3: [('color_moments_rgb_B_std', 0.031833717967099606), ('color_moments_lab_B_std', 0.02451087573454705), ('color_moments_rgb_B_var', 0.02191416590925058), ('color_moments_lab_B_var', 0.015980852305027486), ('color_moments_rgb_R_iqr', 0.015681502322516458), ('color_moments_lab_L_iqr', 0.01353917527115876), ('color_moments_rgb_B_iqr', 0.013415580060968763), ('color_moments_hsv_H_skew', 0.012757303665517649), ('color_moments_rgb_G_skew', 0.012586398619398856), ('color_moments_rgb_R_kurtosis', 0.011988545961713752)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier3; Done in 11.091468334197998 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier4
# INFO:utils.ml:Top 10 features for RandomForestClassifier4: [('color_moments_rgb_B_std', 0.026229078792764853), ('color_moments_rgb_B_var', 0.023224573794707125), ('color_moments_lab_B_std', 0.02237500389215378), ('color_moments_lab_L_iqr', 0.016804808002347432), ('color_moments_lab_B_var', 0.015823231943778326), ('color_moments_rgb_R_iqr', 0.014492849987347976), ('color_moments_rgb_G_var', 0.01242232229017609), ('color_moments_rgb_G_std', 0.012205076672533954), ('color_moments_hsv_H_median', 0.012174978748856051), ('color_moments_rgb_G_skew', 0.01182663912913293)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier4; Done in 11.744845867156982 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier5
# INFO:utils.ml:Top 10 features for RandomForestClassifier5: [('color_moments_rgb_B_std', 0.028333788321892168), ('color_moments_lab_B_std', 0.024720898578653148), ('color_moments_rgb_B_var', 0.023281445313459333), ('color_moments_rgb_R_iqr', 0.01606346796740984), ('color_moments_lab_B_var', 0.015777044445303316), ('color_moments_lab_L_iqr', 0.014904180971585523), ('fourier_transform_magnitude_std', 0.01231522975831475), ('color_moments_rgb_G_skew', 0.01219164565506437), ('color_moments_hsv_H_skew', 0.011749667312713815), ('color_moments_rgb_B_iqr', 0.011602057852213757)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier5; Done in 17.632086515426636 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier6
# INFO:utils.ml:Top 10 features for RandomForestClassifier6: [('color_moments_rgb_B_std', 0.02475564344701351), ('color_moments_rgb_B_var', 0.022147844265223125), ('color_moments_lab_B_std', 0.021387895020386672), ('color_moments_rgb_R_iqr', 0.018060960655729902), ('color_moments_lab_L_iqr', 0.016266933095815683), ('color_moments_lab_B_var', 0.01606256757433656), ('color_moments_rgb_R_kurtosis', 0.013083106531872437), ('color_moments_rgb_G_std', 0.012333230101309694), ('color_moments_rgb_B_iqr', 0.012223126862605247), ('color_moments_hsv_H_median', 0.012169376615365149)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier6; Done in 20.711907863616943 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier7
# INFO:utils.ml:Top 10 features for RandomForestClassifier7: [('color_moments_rgb_B_std', 0.025947828593795196), ('color_moments_lab_B_std', 0.023178693376538245), ('color_moments_rgb_B_var', 0.022154059272918275), ('color_moments_rgb_R_iqr', 0.019293392194322908), ('color_moments_lab_B_var', 0.016788993180576903), ('color_moments_lab_L_iqr', 0.014567066997351967), ('color_moments_rgb_B_iqr', 0.012873614382787979), ('color_moments_rgb_R_kurtosis', 0.012818563680399549), ('fourier_transform_magnitude_std', 0.011844056180874744), ('color_moments_rgb_G_skew', 0.011735066795133905)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier7; Done in 34.393553733825684 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier8
# INFO:utils.ml:Top 10 features for XGBClassifier8: [('color_moments_rgb_B_std', 0.06492337), ('color_moments_rgb_R_iqr', 0.039252933), ('color_moments_hsv_H_median', 0.028706646), ('gradient_direction_std', 0.02457947), ('glcm_energy_dist_1_angle_0', 0.019180922), ('color_moments_hsv_S_min', 0.017553417), ('lbp_rad2_bins16_8', 0.013913133), ('color_moments_lab_B_std', 0.013600063), ('color_moments_rgb_R_var', 0.013467444), ('color_moments_lab_B_var', 0.012226194)]
# INFO:utils.ml:Fitted classifier: XGBClassifier8; Done in 10.345723390579224 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier9
# INFO:utils.ml:Top 10 features for XGBClassifier9: [('color_moments_rgb_B_std', 0.0679261), ('color_moments_rgb_R_iqr', 0.03860671), ('color_moments_hsv_H_median', 0.028582232), ('gradient_direction_std', 0.025326066), ('glcm_energy_dist_1_angle_0', 0.020252522), ('color_moments_hsv_S_min', 0.018372245), ('color_moments_lab_B_std', 0.013742446), ('color_moments_rgb_R_var', 0.013209551), ('lbp_rad2_bins16_8', 0.0127529735), ('color_moments_lab_B_var', 0.012307348)]
# INFO:utils.ml:Fitted classifier: XGBClassifier9; Done in 13.142066478729248 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier10
# INFO:utils.ml:Top 10 features for XGBClassifier10: [('color_moments_rgb_B_std', 0.069086336), ('color_moments_rgb_R_iqr', 0.039456856), ('color_moments_hsv_H_median', 0.02794304), ('gradient_direction_std', 0.025642978), ('glcm_energy_dist_1_angle_0', 0.020209007), ('color_moments_hsv_S_min', 0.018263884), ('color_moments_lab_B_std', 0.01367526), ('color_moments_rgb_R_var', 0.01324883), ('lbp_rad2_bins16_8', 0.012633549), ('color_moments_lab_B_var', 0.012483969)]
# INFO:utils.ml:Fitted classifier: XGBClassifier10; Done in 16.237884283065796 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier11
# INFO:utils.ml:Top 10 features for XGBClassifier11: [('color_moments_rgb_R_iqr', 0.03603461), ('color_moments_rgb_B_std', 0.035253186), ('color_moments_hsv_H_median', 0.032968804), ('color_moments_rgb_B_var', 0.0222551), ('gradient_direction_std', 0.021477368), ('color_moments_lab_B_std', 0.016054193), ('lbp_rad2_bins16_8', 0.013556675), ('lbp_rad1_bins8_4', 0.013511638), ('color_moments_lab_B_var', 0.012919975), ('fourier_transform_magnitude_std', 0.012076871)]
# INFO:utils.ml:Fitted classifier: XGBClassifier11; Done in 6.741953134536743 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier12
# INFO:utils.ml:Top 10 features for XGBClassifier12: [('color_moments_rgb_B_std', 0.043790303), ('color_moments_rgb_B_var', 0.026463738), ('color_moments_rgb_R_iqr', 0.022112885), ('color_moments_hsv_H_median', 0.021368468), ('glcm_energy_dist_1_angle_0', 0.014674002), ('gradient_direction_std', 0.013751406), ('lbp_rad1_bins8_4', 0.012450918), ('color_moments_lab_B_var', 0.0118221305), ('color_moments_lab_B_std', 0.011551599), ('gradient_magnitude_mean', 0.011126928)]
# INFO:utils.ml:Fitted classifier: XGBClassifier12; Done in 13.0502610206604 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier13
# INFO:utils.ml:Top 10 features for XGBClassifier13: [('color_moments_rgb_B_std', 0.045965664), ('color_moments_rgb_R_iqr', 0.030650416), ('color_moments_hsv_H_median', 0.025150845), ('color_moments_rgb_B_var', 0.01658443), ('glcm_energy_dist_1_angle_0', 0.016318707), ('fourier_transform_magnitude_std', 0.014327022), ('color_moments_lab_B_var', 0.014111703), ('lbp_rad2_bins16_8', 0.011723877), ('color_moments_lab_B_std', 0.0115108825), ('lbp_rad1_bins8_4', 0.011245225)]
# INFO:utils.ml:Fitted classifier: XGBClassifier13; Done in 6.3574888706207275 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier14
# INFO:utils.ml:Top 10 features for XGBClassifier14: [('color_moments_rgb_B_std', 0.04206537), ('color_moments_rgb_R_iqr', 0.026016967), ('color_moments_hsv_H_median', 0.0224806), ('color_moments_rgb_B_var', 0.020621968), ('glcm_energy_dist_1_angle_0', 0.017951349), ('color_moments_lab_B_var', 0.016259821), ('fourier_transform_magnitude_std', 0.0132628735), ('lbp_rad1_bins8_4', 0.013059043), ('color_moments_lab_B_std', 0.01192465), ('gradient_direction_std', 0.011544923)]
# INFO:utils.ml:Fitted classifier: XGBClassifier14; Done in 8.114870548248291 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier15
# INFO:utils.ml:Top 10 features for XGBClassifier15: [('color_moments_rgb_B_std', 0.043999847), ('color_moments_rgb_R_iqr', 0.027206529), ('color_moments_rgb_B_var', 0.024184197), ('color_moments_hsv_H_median', 0.02253329), ('glcm_energy_dist_1_angle_0', 0.0139125995), ('gradient_direction_std', 0.01274021), ('fourier_transform_magnitude_std', 0.011967775), ('color_moments_lab_B_var', 0.011767755), ('color_moments_lab_B_std', 0.011738283), ('color_moments_hsv_S_min', 0.011187294)]
# INFO:utils.ml:Fitted classifier: XGBClassifier15; Done in 16.093120098114014 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier16
# INFO:utils.ml:Top 10 features for XGBClassifier16: [('color_moments_rgb_B_std', 0.041835602), ('color_moments_rgb_R_iqr', 0.026874246), ('color_moments_rgb_B_var', 0.02418622), ('color_moments_hsv_H_median', 0.022608565), ('glcm_energy_dist_1_angle_0', 0.013433342), ('gradient_direction_std', 0.012968216), ('fourier_transform_magnitude_std', 0.012495702), ('color_moments_lab_B_var', 0.011736966), ('color_moments_lab_B_std', 0.011507819), ('color_moments_hsv_S_min', 0.01133831)]
# INFO:utils.ml:Fitted classifier: XGBClassifier16; Done in 13.187015771865845 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier17
# INFO:utils.ml:Top 10 features for XGBClassifier17: [('color_moments_rgb_B_std', 0.045124244), ('color_moments_rgb_R_iqr', 0.025293065), ('color_moments_hsv_H_median', 0.025015373), ('color_moments_rgb_B_var', 0.02212287), ('glcm_energy_dist_1_angle_0', 0.016468521), ('color_moments_lab_B_var', 0.0132130785), ('gradient_magnitude_mean', 0.011993085), ('gradient_direction_std', 0.011723742), ('color_moments_lab_B_std', 0.011509377), ('lbp_rad1_bins8_4', 0.011252141)]
# INFO:utils.ml:Fitted classifier: XGBClassifier17; Done in 11.010526418685913 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier18
# INFO:utils.ml:Top 10 features for XGBClassifier18: [('color_moments_rgb_B_std', 0.046391044), ('color_moments_rgb_R_iqr', 0.02560277), ('color_moments_hsv_H_median', 0.02480598), ('color_moments_rgb_B_var', 0.022148358), ('glcm_energy_dist_1_angle_0', 0.016829006), ('color_moments_lab_B_var', 0.013207352), ('gradient_magnitude_mean', 0.012560212), ('gradient_direction_std', 0.011700088), ('color_moments_lab_B_std', 0.0116551565), ('lbp_rad1_bins8_4', 0.011203127)]
# INFO:utils.ml:Fitted classifier: XGBClassifier18; Done in 12.697762250900269 seconds
# INFO:utils.ml:Fitting completed in 249.47 seconds.

# %%
pipeline.predict_with_classifiers(VAL_PATH, percent)
# Out:
# INFO:utils.ml:Predicting with classifiers on dataset: C:\Users\gimes\Src\repos\CADx-Project\dataset\multiclass\val
# Processed 5/53 batches.
# Processed 10/53 batches.
# Processed 15/53 batches.
# Processed 20/53 batches.
# Processed 25/53 batches.
# Processed 30/53 batches.
# Processed 35/53 batches.
# Processed 40/53 batches.
# Processed 45/53 batches.
# Processed 50/53 batches.
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier0
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier1
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier2
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier3
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier4
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier5
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier6
# Processed 53/53 batches.
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier7
# INFO:utils.ml:Predictions made with classifier: XGBClassifier8
# INFO:utils.ml:Predictions made with classifier: XGBClassifier9
# INFO:utils.ml:Predictions made with classifier: XGBClassifier10
# INFO:utils.ml:Predictions made with classifier: XGBClassifier11
# INFO:utils.ml:Predictions made with classifier: XGBClassifier12
# INFO:utils.ml:Predictions made with classifier: XGBClassifier13
# INFO:utils.ml:Predictions made with classifier: XGBClassifier14
# INFO:utils.ml:Predictions made with classifier: XGBClassifier15
# INFO:utils.ml:Predictions made with classifier: XGBClassifier16
# INFO:utils.ml:Predictions made with classifier: XGBClassifier17
# INFO:utils.ml:Predictions made with classifier: XGBClassifier18
# {'GT': array([0, 0, 0, ..., 2, 2, 2]),
#  'RandomForestClassifier0': array([0, 0, 2, ..., 1, 0, 0]),
#  'RandomForestClassifier1': array([0, 0, 2, ..., 1, 2, 0]),
#  'RandomForestClassifier2': array([0, 0, 2, ..., 1, 2, 0]),
#  'RandomForestClassifier3': array([0, 0, 2, ..., 1, 0, 0]),
#  'RandomForestClassifier4': array([0, 0, 2, ..., 1, 2, 0]),
#  'RandomForestClassifier5': array([0, 0, 2, ..., 1, 0, 0]),
#  'RandomForestClassifier6': array([0, 0, 2, ..., 1, 2, 0]),
#  'RandomForestClassifier7': array([0, 0, 2, ..., 1, 0, 0]),
#  'XGBClassifier8': array([0, 0, 0, ..., 1, 2, 0], dtype=int64),
#  'XGBClassifier9': array([0, 0, 0, ..., 1, 2, 0], dtype=int64),
#  'XGBClassifier10': array([0, 0, 0, ..., 1, 2, 0], dtype=int64),
#  'XGBClassifier11': array([0, 0, 2, ..., 0, 0, 0], dtype=int64),
#  'XGBClassifier12': array([0, 0, 0, ..., 1, 0, 0], dtype=int64),
#  'XGBClassifier13': array([0, 0, 0, ..., 1, 0, 0], dtype=int64),
#  'XGBClassifier14': array([0, 0, 0, ..., 1, 0, 0], dtype=int64),
#  'XGBClassifier15': array([0, 0, 0, ..., 1, 0, 0], dtype=int64),
#  'XGBClassifier16': array([0, 0, 0, ..., 1, 0, 0], dtype=int64),
#  'XGBClassifier17': array([0, 0, 0, ..., 1, 0, 0], dtype=int64),
#  'XGBClassifier18': array([0, 0, 0, ..., 1, 0, 0], dtype=int64)}

# %%
df_borderline_smote = pd.DataFrame(data=pipeline.calculate_metrics(
    ["accuracy", "precision", "recall", "f1", "kappa"],))
df_borderline_smote = df_borderline_smote.T
df_borderline_smote
# Out:
# INFO:utils.ml:Metrics for classifier GT: {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'kappa': 1.0}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier0: {'accuracy': 0.8125984251968504, 'precision': 0.6906785485699266, 'recall': 0.6811737000093515, 'f1': 0.6839356076513999, 'kappa': 0.6637146480941679}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier1: {'accuracy': 0.8094488188976378, 'precision': 0.6921061329424761, 'recall': 0.6819061849607682, 'f1': 0.684910381765694, 'kappa': 0.6581996930536711}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier2: {'accuracy': 0.8078740157480315, 'precision': 0.6875151485274604, 'recall': 0.6837996560395855, 'f1': 0.6842103529513204, 'kappa': 0.6564386161753684}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier3: {'accuracy': 0.8204724409448819, 'precision': 0.7099172470689498, 'recall': 0.6776375570694251, 'f1': 0.687644759595656, 'kappa': 0.674509786288854}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier4: {'accuracy': 0.8023622047244094, 'precision': 0.6763834583479108, 'recall': 0.6765928964083283, 'f1': 0.6752134324962364, 'kappa': 0.6474251205592179}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier5: {'accuracy': 0.8188976377952756, 'precision': 0.7103624177898545, 'recall': 0.6824077833961844, 'f1': 0.6914505847031731, 'kappa': 0.6725806162344417}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier6: {'accuracy': 0.8070866141732284, 'precision': 0.6776697966230157, 'recall': 0.6737892384198187, 'f1': 0.674461507649205, 'kappa': 0.6544620646766168}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier7: {'accuracy': 0.8244094488188977, 'precision': 0.7179960268608278, 'recall': 0.6766859063694683, 'f1': 0.6891026198804627, 'kappa': 0.6803397850044923}
# INFO:utils.ml:Metrics for classifier XGBClassifier8: {'accuracy': 0.8472440944881889, 'precision': 0.7481920552202576, 'recall': 0.721488098883956, 'f1': 0.7322170398159097, 'kappa': 0.7227922843589951}
# INFO:utils.ml:Metrics for classifier XGBClassifier9: {'accuracy': 0.852755905511811, 'precision': 0.7625044091710759, 'recall': 0.7286948585152131, 'f1': 0.7419315102241931, 'kappa': 0.7323211830211223}
# INFO:utils.ml:Metrics for classifier XGBClassifier10: {'accuracy': 0.8511811023622047, 'precision': 0.7551619569128313, 'recall': 0.7275338723878128, 'f1': 0.7386594645797583, 'kappa': 0.7299368131126293}
# INFO:utils.ml:Metrics for classifier XGBClassifier11: {'accuracy': 0.794488188976378, 'precision': 0.6595794040616189, 'recall': 0.6752975625592813, 'f1': 0.6657565581058561, 'kappa': 0.6370172933384728}
# INFO:utils.ml:Metrics for classifier XGBClassifier12: {'accuracy': 0.8480314960629921, 'precision': 0.7505352282453511, 'recall': 0.7145933889326211, 'f1': 0.7274352244804119, 'kappa': 0.7239018477883762}
# INFO:utils.ml:Metrics for classifier XGBClassifier13: {'accuracy': 0.8440944881889764, 'precision': 0.7247694691527622, 'recall': 0.71089126480188, 'f1': 0.7165504525112358, 'kappa': 0.7183581307205354}
# INFO:utils.ml:Metrics for classifier XGBClassifier14: {'accuracy': 0.8511811023622047, 'precision': 0.7392225151623647, 'recall': 0.7077519895687691, 'f1': 0.7188018016918325, 'kappa': 0.7295144038115672}
# INFO:utils.ml:Metrics for classifier XGBClassifier15: {'accuracy': 0.8480314960629921, 'precision': 0.7328500983569913, 'recall': 0.7113612297681279, 'f1': 0.7194936726408795, 'kappa': 0.7248897808187198}
# INFO:utils.ml:Metrics for classifier XGBClassifier16: {'accuracy': 0.8448818897637795, 'precision': 0.7306929236812237, 'recall': 0.7093946614298782, 'f1': 0.7173541056748606, 'kappa': 0.7193581097755224}
# INFO:utils.ml:Metrics for classifier XGBClassifier17: {'accuracy': 0.8496062992125984, 'precision': 0.735465122050488, 'recall': 0.7119891100207018, 'f1': 0.7209316019096669, 'kappa': 0.727396755327996}
# INFO:utils.ml:Metrics for classifier XGBClassifier18: {'accuracy': 0.8488188976377953, 'precision': 0.7318368629052973, 'recall': 0.7053885535237038, 'f1': 0.7151377839884646, 'kappa': 0.7253732419112149}
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
#                          accuracy  precision    recall        f1     kappa
# GT                       1.000000   1.000000  1.000000  1.000000  1.000000
# RandomForestClassifier0  0.812598   0.690679  0.681174  0.683936  0.663715
# RandomForestClassifier1  0.809449   0.692106  0.681906  0.684910  0.658200
# RandomForestClassifier2  0.807874   0.687515  0.683800  0.684210  0.656439
# RandomForestClassifier3  0.820472   0.709917  0.677638  0.687645  0.674510
# RandomForestClassifier4  0.802362   0.676383  0.676593  0.675213  0.647425
# RandomForestClassifier5  0.818898   0.710362  0.682408  0.691451  0.672581
# RandomForestClassifier6  0.807087   0.677670  0.673789  0.674462  0.654462
# RandomForestClassifier7  0.824409   0.717996  0.676686  0.689103  0.680340
# XGBClassifier8           0.847244   0.748192  0.721488  0.732217  0.722792
# XGBClassifier9           0.852756   0.762504  0.728695  0.741932  0.732321
# XGBClassifier10          0.851181   0.755162  0.727534  0.738659  0.729937
# XGBClassifier11          0.794488   0.659579  0.675298  0.665757  0.637017
# XGBClassifier12          0.848031   0.750535  0.714593  0.727435  0.723902
# XGBClassifier13          0.844094   0.724769  0.710891  0.716550  0.718358
# XGBClassifier14          0.851181   0.739223  0.707752  0.718802  0.729514
# XGBClassifier15          0.848031   0.732850  0.711361  0.719494  0.724890
# XGBClassifier16          0.844882   0.730693  0.709395  0.717354  0.719358
# XGBClassifier17          0.849606   0.735465  0.711989  0.720932  0.727397
# XGBClassifier18          0.848819   0.731837  0.705389  0.715138  0.725373

# %%
highest = df_borderline_smote[df_borderline_smote["kappa"] == df_borderline_smote.iloc[1:]["kappa"].max()]
idx = highest.index[0]

confusion_matrix(pipeline.predictions["GT"], pipeline.predictions[idx])
# Out:
# array([[434,  44,  20],
#        [ 57, 610,  11],
#        [ 34,  21,  39]], dtype=int64)

# %% [markdown]
# ___
# # PCA

# %%
from sklearn.decomposition import PCA
from imblearn.over_sampling import BorderlineSMOTE
smote = BorderlineSMOTE(sampling_strategy='auto', random_state=42)

pipeline.feature_matrix, pipeline.labels = smote.fit_resample(
    np.nan_to_num(pipeline.backup_feature_matrix), pipeline.backup_labels)

pca = PCA(n_components=100)

pipeline.feature_matrix = pca.fit_transform(pipeline.feature_matrix, pipeline.labels)

print(pipeline.backup_feature_matrix.shape)
print(pipeline.feature_matrix.shape)

print(pipeline.backup_labels.shape)
print(pipeline.labels.shape)

print(pca.get_feature_names_out())

pipeline.fitted_classifiers = {}
pipeline.fit_classifiers()
# Out:
# INFO:utils.ml:Fitting classifiers...
# INFO:utils.ml:Fitting classifier: RandomForestClassifier0
# (5082, 189)
# (8139, 100)
# (5082,)
# (8139,)
# ['pca0' 'pca1' 'pca2' 'pca3' 'pca4' 'pca5' 'pca6' 'pca7' 'pca8' 'pca9'
#  'pca10' 'pca11' 'pca12' 'pca13' 'pca14' 'pca15' 'pca16' 'pca17' 'pca18'
#  'pca19' 'pca20' 'pca21' 'pca22' 'pca23' 'pca24' 'pca25' 'pca26' 'pca27'
#  'pca28' 'pca29' 'pca30' 'pca31' 'pca32' 'pca33' 'pca34' 'pca35' 'pca36'
#  'pca37' 'pca38' 'pca39' 'pca40' 'pca41' 'pca42' 'pca43' 'pca44' 'pca45'
#  'pca46' 'pca47' 'pca48' 'pca49' 'pca50' 'pca51' 'pca52' 'pca53' 'pca54'
#  'pca55' 'pca56' 'pca57' 'pca58' 'pca59' 'pca60' 'pca61' 'pca62' 'pca63'
#  'pca64' 'pca65' 'pca66' 'pca67' 'pca68' 'pca69' 'pca70' 'pca71' 'pca72'
#  'pca73' 'pca74' 'pca75' 'pca76' 'pca77' 'pca78' 'pca79' 'pca80' 'pca81'
#  'pca82' 'pca83' 'pca84' 'pca85' 'pca86' 'pca87' 'pca88' 'pca89' 'pca90'
#  'pca91' 'pca92' 'pca93' 'pca94' 'pca95' 'pca96' 'pca97' 'pca98' 'pca99']
# INFO:utils.ml:Top 10 features for RandomForestClassifier0: [('gradient_magnitude_std', 0.05193733288780519), ('gradient_direction_mean', 0.04547206596225948), ('color_moments_rgb_R_var', 0.03499697481519758), ('color_moments_rgb_R_median', 0.024880601172326693), ('gradient_direction_std', 0.02195455477136229), ('color_moments_rgb_R_std', 0.02063196882941278), ('color_moments_rgb_G_iqr', 0.020009975507693185), ('color_moments_rgb_R_skew', 0.01592724709264969), ('color_moments_lab_L_iqr', 0.015840695983661668), ('color_moments_lab_L_skew', 0.015288668979688495)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier0; Done in 7.409027099609375 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier1
# INFO:utils.ml:Top 10 features for RandomForestClassifier1: [('gradient_magnitude_std', 0.05112300921980831), ('gradient_direction_mean', 0.04181836225529221), ('color_moments_rgb_R_var', 0.0339446742308377), ('color_moments_rgb_R_median', 0.026949734788927534), ('gradient_direction_std', 0.02171682265940082), ('color_moments_rgb_R_std', 0.01893047723113227), ('color_moments_rgb_G_iqr', 0.017414992022487787), ('color_moments_lab_L_skew', 0.016270695955998372), ('color_moments_lab_L_iqr', 0.01588662203332418), ('color_moments_rgb_R_skew', 0.01501833716267051)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier1; Done in 11.08242678642273 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier2
# INFO:utils.ml:Top 10 features for RandomForestClassifier2: [('gradient_magnitude_std', 0.054781602232124985), ('gradient_direction_mean', 0.038905931617891826), ('color_moments_rgb_R_var', 0.03383606851308909), ('color_moments_rgb_R_median', 0.02462414296726244), ('gradient_direction_std', 0.022782934665542896), ('color_moments_rgb_R_std', 0.019943270901187783), ('color_moments_rgb_G_iqr', 0.019405937682843682), ('color_moments_lab_L_skew', 0.015592249946920513), ('color_moments_rgb_R_entropy', 0.015123782083534898), ('color_moments_rgb_R_skew', 0.01496828637630777)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier2; Done in 7.8274500370025635 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier3
# INFO:utils.ml:Top 10 features for RandomForestClassifier3: [('gradient_magnitude_std', 0.0552162488342544), ('gradient_direction_mean', 0.03976267104433044), ('color_moments_rgb_R_var', 0.03453743802024597), ('color_moments_rgb_R_median', 0.024334910693517665), ('gradient_direction_std', 0.02227403246859611), ('color_moments_rgb_G_iqr', 0.019875172010254398), ('color_moments_rgb_R_std', 0.019640800660477405), ('color_moments_rgb_R_skew', 0.016114986865787415), ('color_moments_lab_L_skew', 0.015508235479686033), ('color_moments_lab_L_iqr', 0.015298413935332357)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier3; Done in 11.095446825027466 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier4
# INFO:utils.ml:Top 10 features for RandomForestClassifier4: [('gradient_magnitude_std', 0.05420109667415893), ('gradient_direction_mean', 0.04049021507790849), ('color_moments_rgb_R_var', 0.03356157187044869), ('color_moments_rgb_R_median', 0.02559562401031371), ('gradient_direction_std', 0.023156120659503527), ('color_moments_rgb_R_std', 0.02093413820236513), ('color_moments_rgb_G_iqr', 0.019892300603863027), ('color_moments_lab_L_skew', 0.01569904218397317), ('color_moments_rgb_R_skew', 0.014890636286130335), ('color_moments_lab_L_iqr', 0.014732411864123518)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier4; Done in 11.047619581222534 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier5
# INFO:utils.ml:Top 10 features for RandomForestClassifier5: [('gradient_magnitude_std', 0.05433595855966399), ('gradient_direction_mean', 0.04144781662323601), ('color_moments_rgb_R_var', 0.033867198077896996), ('color_moments_rgb_R_median', 0.025651812795634457), ('gradient_direction_std', 0.02298128117910598), ('color_moments_rgb_R_std', 0.02015566551444932), ('color_moments_rgb_G_iqr', 0.01990862028530637), ('color_moments_rgb_R_skew', 0.016208133389096623), ('color_moments_rgb_R_kurtosis', 0.015603007826070934), ('color_moments_lab_L_skew', 0.01553870354417702)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier5; Done in 16.267673015594482 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier6
# INFO:utils.ml:Top 10 features for RandomForestClassifier6: [('gradient_magnitude_std', 0.05500259150025802), ('gradient_direction_mean', 0.041334975751916574), ('color_moments_rgb_R_var', 0.0351879703396169), ('color_moments_rgb_R_median', 0.025175654803124562), ('gradient_direction_std', 0.0231454880719203), ('color_moments_rgb_R_std', 0.02105649333969022), ('color_moments_rgb_G_iqr', 0.019759562220257692), ('color_moments_lab_L_skew', 0.015187639414396761), ('color_moments_lab_L_iqr', 0.015028104446668722), ('color_moments_rgb_R_skew', 0.014381210121314285)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier6; Done in 14.559183597564697 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier7
# INFO:utils.ml:Top 10 features for RandomForestClassifier7: [('gradient_magnitude_std', 0.05366460564593125), ('gradient_direction_mean', 0.042487714902304796), ('color_moments_rgb_R_var', 0.034458461981944376), ('color_moments_rgb_R_median', 0.02553232765692627), ('gradient_direction_std', 0.023055373727564974), ('color_moments_rgb_R_std', 0.02030792176307197), ('color_moments_rgb_G_iqr', 0.019989722406047513), ('color_moments_rgb_R_skew', 0.015661066428306104), ('color_moments_rgb_R_kurtosis', 0.01533601126762115), ('color_moments_lab_L_skew', 0.015228290155176485)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier7; Done in 21.47849726676941 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier8
# INFO:utils.ml:Top 10 features for XGBClassifier8: [('gradient_magnitude_std', 0.048591733), ('color_moments_rgb_R_var', 0.04144236), ('gradient_direction_mean', 0.035826072), ('color_moments_rgb_R_std', 0.025010528), ('color_moments_rgb_R_median', 0.020325843), ('color_moments_rgb_B_mean', 0.019585462), ('color_moments_lab_B_mean', 0.019484634), ('color_moments_rgb_G_iqr', 0.01692348), ('color_moments_rgb_B_min', 0.016724735), ('color_moments_lab_L_skew', 0.016608298)]
# INFO:utils.ml:Fitted classifier: XGBClassifier8; Done in 3.7506463527679443 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier9
# INFO:utils.ml:Top 10 features for XGBClassifier9: [('gradient_magnitude_std', 0.0475259), ('color_moments_rgb_R_var', 0.04207506), ('gradient_direction_mean', 0.035457376), ('color_moments_rgb_R_std', 0.025533415), ('color_moments_rgb_R_median', 0.020373091), ('color_moments_rgb_B_mean', 0.019705262), ('color_moments_lab_B_mean', 0.0191398), ('color_moments_rgb_G_iqr', 0.017396133), ('color_moments_lab_L_skew', 0.01667468), ('color_moments_lab_L_iqr', 0.016498601)]
# INFO:utils.ml:Fitted classifier: XGBClassifier9; Done in 4.324931621551514 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier10
# INFO:utils.ml:Top 10 features for XGBClassifier10: [('gradient_magnitude_std', 0.04684157), ('color_moments_rgb_R_var', 0.042295728), ('gradient_direction_mean', 0.03559391), ('color_moments_rgb_R_std', 0.026118731), ('color_moments_rgb_R_median', 0.02074279), ('color_moments_rgb_B_mean', 0.019687483), ('color_moments_lab_B_mean', 0.019202998), ('color_moments_rgb_G_iqr', 0.01769194), ('color_moments_lab_L_skew', 0.016697347), ('color_moments_lab_L_iqr', 0.016362151)]
# INFO:utils.ml:Fitted classifier: XGBClassifier10; Done in 4.79364275932312 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier11
# INFO:utils.ml:Top 10 features for XGBClassifier11: [('gradient_magnitude_std', 0.036445398), ('color_moments_rgb_R_var', 0.032166433), ('gradient_direction_mean', 0.028357012), ('gradient_direction_std', 0.021761086), ('color_moments_rgb_R_median', 0.02117169), ('color_moments_rgb_R_std', 0.019202298), ('color_moments_rgb_B_min', 0.018469736), ('color_moments_lab_L_iqr', 0.0178076), ('color_moments_rgb_G_iqr', 0.01769884), ('color_moments_lab_B_mean', 0.017070767)]
# INFO:utils.ml:Fitted classifier: XGBClassifier11; Done in 1.9823195934295654 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier12
# INFO:utils.ml:Top 10 features for XGBClassifier12: [('gradient_magnitude_std', 0.03989808), ('color_moments_rgb_R_var', 0.03106508), ('gradient_direction_mean', 0.030355271), ('color_moments_rgb_R_median', 0.020433279), ('gradient_direction_std', 0.019617207), ('color_moments_rgb_R_std', 0.01915633), ('color_moments_rgb_G_iqr', 0.017500266), ('color_moments_rgb_B_mean', 0.017325971), ('color_moments_lab_L_iqr', 0.015898513), ('color_moments_rgb_R_skew', 0.015400212)]
# INFO:utils.ml:Fitted classifier: XGBClassifier12; Done in 5.057247161865234 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier13
# INFO:utils.ml:Top 10 features for XGBClassifier13: [('gradient_magnitude_std', 0.040541396), ('gradient_direction_mean', 0.034130383), ('color_moments_rgb_R_var', 0.03070792), ('color_moments_rgb_R_median', 0.023411935), ('color_moments_rgb_R_std', 0.021649191), ('gradient_direction_std', 0.019684745), ('color_moments_lab_L_iqr', 0.018333621), ('color_moments_lab_B_mean', 0.016423745), ('color_moments_rgb_B_mean', 0.0163051), ('color_moments_rgb_G_iqr', 0.016036376)]
# INFO:utils.ml:Fitted classifier: XGBClassifier13; Done in 3.461728096008301 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier14
# INFO:utils.ml:Top 10 features for XGBClassifier14: [('gradient_magnitude_std', 0.04132643), ('gradient_direction_mean', 0.036198508), ('color_moments_rgb_R_var', 0.034126017), ('color_moments_rgb_R_median', 0.023619), ('gradient_direction_std', 0.02295812), ('color_moments_rgb_R_std', 0.02267365), ('color_moments_lab_L_iqr', 0.0178468), ('color_moments_lab_L_skew', 0.017403068), ('color_moments_rgb_G_iqr', 0.016633874), ('color_moments_lab_B_mean', 0.016554669)]
# INFO:utils.ml:Fitted classifier: XGBClassifier14; Done in 4.229046106338501 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier15
# INFO:utils.ml:Top 10 features for XGBClassifier15: [('gradient_magnitude_std', 0.03893785), ('gradient_direction_mean', 0.034164913), ('color_moments_rgb_R_var', 0.03234607), ('color_moments_rgb_R_std', 0.021434914), ('color_moments_rgb_R_median', 0.020095246), ('gradient_direction_std', 0.019604078), ('color_moments_rgb_G_iqr', 0.01753332), ('color_moments_rgb_B_mean', 0.017067313), ('color_moments_lab_L_iqr', 0.01665185), ('color_moments_lab_B_mean', 0.01604682)]
# INFO:utils.ml:Fitted classifier: XGBClassifier15; Done in 11.731402158737183 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier16
# INFO:utils.ml:Top 10 features for XGBClassifier16: [('gradient_magnitude_std', 0.03819409), ('gradient_direction_mean', 0.033916876), ('color_moments_rgb_R_var', 0.032164857), ('color_moments_rgb_R_std', 0.021344734), ('color_moments_rgb_R_median', 0.019822774), ('gradient_direction_std', 0.01943188), ('color_moments_rgb_G_iqr', 0.017564952), ('color_moments_rgb_B_mean', 0.017253857), ('color_moments_lab_L_iqr', 0.016677871), ('color_moments_lab_B_mean', 0.016321648)]
# INFO:utils.ml:Fitted classifier: XGBClassifier16; Done in 11.182554006576538 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier17
# INFO:utils.ml:Top 10 features for XGBClassifier17: [('gradient_magnitude_std', 0.04042778), ('color_moments_rgb_R_var', 0.033109605), ('gradient_direction_mean', 0.03300527), ('color_moments_rgb_R_median', 0.020587461), ('gradient_direction_std', 0.020522559), ('color_moments_rgb_R_std', 0.02002193), ('color_moments_rgb_G_iqr', 0.018238384), ('color_moments_rgb_B_mean', 0.017098812), ('color_moments_lab_L_iqr', 0.01667897), ('color_moments_lab_B_mean', 0.015973253)]
# INFO:utils.ml:Fitted classifier: XGBClassifier17; Done in 11.399136781692505 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier18
# INFO:utils.ml:Top 10 features for XGBClassifier18: [('gradient_magnitude_std', 0.040812455), ('color_moments_rgb_R_var', 0.033580687), ('gradient_direction_mean', 0.032949544), ('color_moments_rgb_R_median', 0.020870317), ('gradient_direction_std', 0.020442517), ('color_moments_rgb_R_std', 0.0203303), ('color_moments_rgb_G_iqr', 0.01825808), ('color_moments_rgb_B_mean', 0.017066402), ('color_moments_lab_L_iqr', 0.016718155), ('color_moments_lab_B_mean', 0.01577121)]
# INFO:utils.ml:Fitted classifier: XGBClassifier18; Done in 13.660237312316895 seconds
# INFO:utils.ml:Fitting completed in 176.35 seconds.

# %%
# Load and extract features from the new dataset
new_loader = FactoryLoader(path=VAL_PATH, factory=pipeline.loader.get_factory(),
                           percentage=percent, batch_size=pipeline.batch_size)
new_feature_matrix, new_labels = pipeline.feature_strategy.run(new_loader.get_loader())

new_feature_matrix = np.nan_to_num(new_feature_matrix) # Impute nans
new_feature_matrix = pca.transform(new_feature_matrix) # Impute nans

# Store predictions in the class attribute
pipeline.predictions = {"GT": new_labels, }
for clf_name, clf in pipeline.fitted_classifiers.items():

    pipeline.predictions[clf_name] = clf.predict(new_feature_matrix)
    if pipeline.verbose:
        logger.info("Predictions made with classifier: %s", clf_name)
# Out:
# Processed 5/53 batches.
# Processed 10/53 batches.
# Processed 15/53 batches.
# Processed 20/53 batches.
# Processed 25/53 batches.
# Processed 30/53 batches.
# Processed 35/53 batches.
# Processed 40/53 batches.
# Processed 45/53 batches.
# Processed 50/53 batches.
# INFO:utils.utils:Predictions made with classifier: RandomForestClassifier0
# INFO:utils.utils:Predictions made with classifier: RandomForestClassifier1
# INFO:utils.utils:Predictions made with classifier: RandomForestClassifier2
# INFO:utils.utils:Predictions made with classifier: RandomForestClassifier3
# INFO:utils.utils:Predictions made with classifier: RandomForestClassifier4
# INFO:utils.utils:Predictions made with classifier: RandomForestClassifier5
# INFO:utils.utils:Predictions made with classifier: RandomForestClassifier6
# Processed 53/53 batches.
# INFO:utils.utils:Predictions made with classifier: RandomForestClassifier7
# INFO:utils.utils:Predictions made with classifier: XGBClassifier8
# INFO:utils.utils:Predictions made with classifier: XGBClassifier9
# INFO:utils.utils:Predictions made with classifier: XGBClassifier10
# INFO:utils.utils:Predictions made with classifier: XGBClassifier11
# INFO:utils.utils:Predictions made with classifier: XGBClassifier12
# INFO:utils.utils:Predictions made with classifier: XGBClassifier13
# INFO:utils.utils:Predictions made with classifier: XGBClassifier14
# INFO:utils.utils:Predictions made with classifier: XGBClassifier15
# INFO:utils.utils:Predictions made with classifier: XGBClassifier16
# INFO:utils.utils:Predictions made with classifier: XGBClassifier17
# INFO:utils.utils:Predictions made with classifier: XGBClassifier18

# %%
df_pca = pd.DataFrame(data=pipeline.calculate_metrics(avg="macro"))
df_pca = df_pca.T
df_pca
# Out:
# INFO:utils.ml:Metrics for classifier GT: {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'kappa': 1.0}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier0: {'accuracy': 0.8, 'precision': 0.6839895938000075, 'recall': 0.6548365053763034, 'f1': 0.664893747950941, 'kappa': 0.6353446014994076}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier1: {'accuracy': 0.8039370078740158, 'precision': 0.6938762836294275, 'recall': 0.65711701384084, 'f1': 0.6692186554459946, 'kappa': 0.6417225595939454}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier2: {'accuracy': 0.8062992125984252, 'precision': 0.6888683162293187, 'recall': 0.6557151848465853, 'f1': 0.6667785524460194, 'kappa': 0.6458401349439546}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier3: {'accuracy': 0.8078740157480315, 'precision': 0.6894210429366079, 'recall': 0.6394379375280573, 'f1': 0.6513492948275558, 'kappa': 0.6459986931150927}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier4: {'accuracy': 0.8062992125984252, 'precision': 0.6864855732885763, 'recall': 0.6593027479276298, 'f1': 0.6687030569084923, 'kappa': 0.647206287546863}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier5: {'accuracy': 0.8118110236220473, 'precision': 0.6997553772700438, 'recall': 0.6487158701964073, 'f1': 0.6616223198274466, 'kappa': 0.6541410099223803}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier6: {'accuracy': 0.805511811023622, 'precision': 0.6753635635238856, 'recall': 0.653057595347183, 'f1': 0.6605829096987402, 'kappa': 0.6461493687563734}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier7: {'accuracy': 0.8141732283464567, 'precision': 0.7013510868454765, 'recall': 0.6503684984083702, 'f1': 0.6632452892574322, 'kappa': 0.6584823361576642}
# INFO:utils.ml:Metrics for classifier XGBClassifier8: {'accuracy': 0.8535433070866142, 'precision': 0.7455785693629041, 'recall': 0.7112151612790205, 'f1': 0.7238806350668341, 'kappa': 0.7329411073074332}
# INFO:utils.ml:Metrics for classifier XGBClassifier9: {'accuracy': 0.8519685039370078, 'precision': 0.7371087413360239, 'recall': 0.7098764731933445, 'f1': 0.7204528942854607, 'kappa': 0.7304522567680463}
# INFO:utils.ml:Metrics for classifier XGBClassifier10: {'accuracy': 0.8519685039370078, 'precision': 0.7406522876812661, 'recall': 0.7098764731933445, 'f1': 0.7215484369602785, 'kappa': 0.7302061534150233}
# INFO:utils.ml:Metrics for classifier XGBClassifier11: {'accuracy': 0.7834645669291339, 'precision': 0.6502915529760062, 'recall': 0.6702251168736958, 'f1': 0.6574089277010262, 'kappa': 0.6194737897250842}
# INFO:utils.ml:Metrics for classifier XGBClassifier12: {'accuracy': 0.8456692913385827, 'precision': 0.729120480037253, 'recall': 0.704699422808916, 'f1': 0.7144760570110645, 'kappa': 0.7190671385748854}
# INFO:utils.ml:Metrics for classifier XGBClassifier13: {'accuracy': 0.8393700787401575, 'precision': 0.7176493813661956, 'recall': 0.69806723284275, 'f1': 0.7059236511365282, 'kappa': 0.7083404630888803}
# INFO:utils.ml:Metrics for classifier XGBClassifier14: {'accuracy': 0.8433070866141732, 'precision': 0.731874710903207, 'recall': 0.6972932841010687, 'f1': 0.7100180709709606, 'kappa': 0.7135035255174915}
# INFO:utils.ml:Metrics for classifier XGBClassifier15: {'accuracy': 0.8322834645669291, 'precision': 0.7124653098104425, 'recall': 0.6927539442903101, 'f1': 0.7006762429032655, 'kappa': 0.6954731305780957}
# INFO:utils.ml:Metrics for classifier XGBClassifier16: {'accuracy': 0.8283464566929134, 'precision': 0.7054205694152794, 'recall': 0.6897626279926711, 'f1': 0.6962588668760143, 'kappa': 0.6888122577802556}
# INFO:utils.ml:Metrics for classifier XGBClassifier17: {'accuracy': 0.841732283464567, 'precision': 0.7359547479697599, 'recall': 0.7052956695923215, 'f1': 0.717178885644887, 'kappa': 0.7115645366863423}
# INFO:utils.ml:Metrics for classifier XGBClassifier18: {'accuracy': 0.8456692913385827, 'precision': 0.7447145877378435, 'recall': 0.7079315819734093, 'f1': 0.7217427705630205, 'kappa': 0.7181816535033694}
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
#                          accuracy  precision    recall        f1     kappa
# GT                       1.000000   1.000000  1.000000  1.000000  1.000000
# RandomForestClassifier0  0.800000   0.683990  0.654837  0.664894  0.635345
# RandomForestClassifier1  0.803937   0.693876  0.657117  0.669219  0.641723
# RandomForestClassifier2  0.806299   0.688868  0.655715  0.666779  0.645840
# RandomForestClassifier3  0.807874   0.689421  0.639438  0.651349  0.645999
# RandomForestClassifier4  0.806299   0.686486  0.659303  0.668703  0.647206
# RandomForestClassifier5  0.811811   0.699755  0.648716  0.661622  0.654141
# RandomForestClassifier6  0.805512   0.675364  0.653058  0.660583  0.646149
# RandomForestClassifier7  0.814173   0.701351  0.650368  0.663245  0.658482
# XGBClassifier8           0.853543   0.745579  0.711215  0.723881  0.732941
# XGBClassifier9           0.851969   0.737109  0.709876  0.720453  0.730452
# XGBClassifier10          0.851969   0.740652  0.709876  0.721548  0.730206
# XGBClassifier11          0.783465   0.650292  0.670225  0.657409  0.619474
# XGBClassifier12          0.845669   0.729120  0.704699  0.714476  0.719067
# XGBClassifier13          0.839370   0.717649  0.698067  0.705924  0.708340
# XGBClassifier14          0.843307   0.731875  0.697293  0.710018  0.713504
# XGBClassifier15          0.832283   0.712465  0.692754  0.700676  0.695473
# XGBClassifier16          0.828346   0.705421  0.689763  0.696259  0.688812
# XGBClassifier17          0.841732   0.735955  0.705296  0.717179  0.711565
# XGBClassifier18          0.845669   0.744715  0.707932  0.721743  0.718182

# %%
highest = df_pca[df_pca["kappa"] == df_pca.iloc[1:]["kappa"].max()]
idx = highest.index[0]

confusion_matrix(pipeline.predictions["GT"], pipeline.predictions[idx])
# Out:
# array([[436,  40,  22],
#        [ 52, 615,  11],
#        [ 35,  26,  33]], dtype=int64)
