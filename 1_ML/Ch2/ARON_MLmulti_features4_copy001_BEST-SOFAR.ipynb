# %%
import numpy as np
from sklearn.metrics import confusion_matrix, recall_score, cohen_kappa_score

from utils.loader import FactoryLoader
from utils.ml import MLPipeline
from utils.preprocessing import PreprocessingFactory
from utils.feature_extraction import *
from utils.utils import *

VAL_PATH = r"C:\Users\gimes\Src\repos\CADx-Project\dataset\multiclass\val"
TRAIN_PATH = r"C:\Users\gimes\Src\repos\CADx-Project\dataset\multiclass\train"
# Out:
# INFO:numexpr.utils:Note: NumExpr detected 16 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.

# %%
percent = 100
random = False
batch_size = 24
th = 0.01

# Initialize the FactoryLoader
factory = PreprocessingFactory()
factory.gaussian_smoothing(5)
factory.clahe(clip_limit=1.5)
factory.pad2square(fill=np.nan)
factory.resize((150,150))
factory.hair_removal()
factory.normalize2float()

factory_loader = FactoryLoader(path=VAL_PATH, batch_size=batch_size, factory=factory, percentage=percent, shuffle=random)

# Create the feature extraction pipeline strategy and add desired features
strategy = FeatureExtractionStrategy()

strategy.add_extractor(GradientExtractor(threshold=th)) # Add gradient feature

strategy.add_extractor(ColorMomentsExtractor("rgb", threshold=th))   # Add color moments feature
strategy.add_extractor(ColorMomentsExtractor("lab", threshold=th))   # Add color moments feature
strategy.add_extractor(ColorMomentsExtractor("hsv", threshold=th))   # Add color moments feature

strategy.add_extractor(LBPExtractor(radius=1, n_points=8))
strategy.add_extractor(LBPExtractor(radius=2, n_points=16))
strategy.add_extractor(LBPExtractor(radius=3, n_points=24))
strategy.add_extractor(LBPExtractor(radius=4, n_points=32))

strategy.add_extractor(FourierTransformExtractor())

strategy.add_extractor(GLCMExtractor(properties=['contrast', 'dissimilarity', 'homogeneity', 'energy', 'correlation',]))

pipeline = MLPipeline(dataset_path=TRAIN_PATH, preprocessing_factory=factory, feature_strategy=strategy, classifiers=[], percentage=percent, verbose=True, shuffle=random, batch_size=batch_size)
# Out:
# INFO:utils.ml:MLPipeline initialized with dataset path: C:\Users\gimes\Src\repos\CADx-Project\dataset\multiclass\train
# INFO:utils.ml:Preprocessing steps

# %%
pipeline.feature_matrix = None
pipeline.run_feature_extraction()
# Out:
# INFO:utils.ml:Running feature extraction...
# Processed 5/212 batches.
# Processed 10/212 batches.
# Processed 15/212 batches.
# Processed 20/212 batches.
# Processed 25/212 batches.
# Processed 30/212 batches.
# Processed 35/212 batches.
# Processed 40/212 batches.
# Processed 45/212 batches.
# Processed 50/212 batches.
# Processed 55/212 batches.
# Processed 60/212 batches.
# Processed 65/212 batches.
# Processed 70/212 batches.
# Processed 75/212 batches.
# Processed 80/212 batches.
# Processed 85/212 batches.
# Processed 90/212 batches.
# Processed 95/212 batches.
# Processed 100/212 batches.
# Processed 105/212 batches.
# Processed 110/212 batches.
# Processed 115/212 batches.
# Processed 120/212 batches.
# Processed 125/212 batches.
# Processed 130/212 batches.
# Processed 135/212 batches.
# Processed 140/212 batches.
# Processed 145/212 batches.
# Processed 150/212 batches.
# Processed 155/212 batches.
# Processed 160/212 batches.
# Processed 165/212 batches.
# Processed 170/212 batches.
# Processed 175/212 batches.
# Processed 180/212 batches.
# Processed 185/212 batches.
# Processed 190/212 batches.
# Processed 195/212 batches.
# Processed 200/212 batches.
# Processed 205/212 batches.
# Processed 210/212 batches.
# INFO:utils.ml:Feature extraction completed. Extracted 5082 features.
# Processed 212/212 batches.

# %%
from xgboost import XGBClassifier
from sklearn.ensemble import RandomForestClassifier

rf1 = RandomForestClassifier(n_estimators=100)
rf2 = RandomForestClassifier(n_estimators=150)
# Random Forest with Out-of-Bag Error (OOB)
rf3 = RandomForestClassifier(n_estimators=100, oob_score=True, random_state=42)
# Random Forest with Bootstrap Disabled
rf4 = RandomForestClassifier(n_estimators=100, bootstrap=False, random_state=42)
# Random Forest with Out-of-Bag Error (OOB)
rf5 = RandomForestClassifier(n_estimators=150, oob_score=True, random_state=42)
# Random Forest with Bootstrap Disabled
rf6 = RandomForestClassifier(n_estimators=150, bootstrap=False, random_state=42)
# Random Forest with Out-of-Bag Error (OOB)
rf7 = RandomForestClassifier(n_estimators=200, oob_score=True, random_state=42)
# Random Forest with Bootstrap Disabled
rf8 = RandomForestClassifier(n_estimators=200, bootstrap=False, random_state=42)


xgb1 = XGBClassifier(n_estimators=350)
xgb2 = XGBClassifier(n_estimators=450)
xgb3 = XGBClassifier(n_estimators=550)
xgb4 = XGBClassifier(learning_rate=0.05, n_estimators=400, max_depth=3, min_child_weight=4, subsample=0.8, colsample_bytree=0.8)
xgb5 = XGBClassifier(learning_rate=0.1, n_estimators=400, max_depth=7, min_child_weight=3, subsample=0.7, colsample_bytree=0.7) # 2ND
xgb6 = XGBClassifier(learning_rate=0.1, n_estimators=400, max_depth=5, min_child_weight=5, gamma=0.2, subsample=0.8, colsample_bytree=0.8) # THIS
xgb7 = XGBClassifier(learning_rate=0.1, n_estimators=400, max_depth=5, min_child_weight=1, subsample=0.8, colsample_bytree=0.8, reg_alpha=0.1, reg_lambda=0.1)
xgb8 = XGBClassifier(learning_rate=0.05, n_estimators=500, max_depth=7, min_child_weight=1, subsample=0.8, colsample_bytree=0.8)
xgb9 = XGBClassifier(learning_rate=0.05, n_estimators=400, max_depth=7, min_child_weight=1, subsample=0.8, colsample_bytree=0.8)
xgb10 = XGBClassifier(learning_rate=0.1, n_estimators=400, max_depth=7, min_child_weight=1, subsample=0.8, colsample_bytree=0.8)
xgb11 = XGBClassifier(learning_rate=0.1, n_estimators=500, max_depth=7, min_child_weight=1, subsample=0.8, colsample_bytree=0.8)


pipeline.classifiers = [rf1, rf2, rf3, rf4, rf5, rf6, rf7, rf8,
                        # svm1, svm2, svm3, svm6, svm7, svm8,
                        xgb1, xgb2, xgb3, xgb4, xgb5, xgb6, xgb7, xgb8, xgb9, xgb10, xgb11]
pipeline.fitted_classifiers = {}

# %%
pipeline.fit_classifiers()
# Out:
# INFO:utils.ml:Fitting classifiers...
# INFO:utils.ml:Fitting classifier: RandomForestClassifier0
# INFO:utils.ml:Top 10 features for RandomForestClassifier0: [('color_moments_rgb_B_std', 0.040408528198535194), ('color_moments_lab_B_std', 0.03738654197896483), ('color_moments_rgb_B_var', 0.032409374376159344), ('color_moments_lab_B_var', 0.02960208853729686), ('color_moments_rgb_R_iqr', 0.02227160917880326), ('color_moments_lab_L_iqr', 0.017395743658709887), ('color_moments_rgb_B_kurtosis', 0.015586246801759478), ('color_moments_rgb_G_var', 0.013556705802290736), ('color_moments_lab_B_skew', 0.012628035944623894), ('color_moments_rgb_R_skew', 0.011956758550238583)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier0; Done in 4.120246648788452 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier1
# INFO:utils.ml:Top 10 features for RandomForestClassifier1: [('color_moments_rgb_B_var', 0.03290412674502063), ('color_moments_lab_B_var', 0.03006016073117809), ('color_moments_rgb_B_std', 0.02863408572584923), ('color_moments_lab_B_std', 0.027934727427156372), ('color_moments_rgb_R_iqr', 0.021948622481827676), ('color_moments_rgb_R_kurtosis', 0.016081917969175283), ('color_moments_rgb_B_iqr', 0.015841044349095546), ('color_moments_rgb_B_kurtosis', 0.015722389928853064), ('color_moments_rgb_B_min', 0.015279223608750824), ('color_moments_rgb_R_skew', 0.013364928705094713)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier1; Done in 6.206681489944458 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier2
# INFO:utils.ml:Top 10 features for RandomForestClassifier2: [('color_moments_lab_B_std', 0.038121985796680906), ('color_moments_rgb_B_std', 0.03728339265733615), ('color_moments_lab_B_var', 0.029616867935675785), ('color_moments_rgb_B_var', 0.028442090108336666), ('color_moments_rgb_B_min', 0.017173458189053956), ('color_moments_lab_L_iqr', 0.016940870442960446), ('color_moments_rgb_R_iqr', 0.016029126758852263), ('color_moments_lab_L_std', 0.014104164518519983), ('color_moments_rgb_G_std', 0.013493312071860058), ('color_moments_rgb_B_iqr', 0.013250021560865032)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier2; Done in 4.195150852203369 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier3
# INFO:utils.ml:Top 10 features for RandomForestClassifier3: [('color_moments_rgb_B_std', 0.03862490438999259), ('color_moments_lab_B_std', 0.035790703735160044), ('color_moments_lab_B_var', 0.034707216599073144), ('color_moments_rgb_B_var', 0.028156586260043664), ('color_moments_lab_L_iqr', 0.01752947547866616), ('color_moments_rgb_R_iqr', 0.017165891651139024), ('color_moments_rgb_B_min', 0.013072751384797115), ('color_moments_lab_L_var', 0.012913094942848978), ('color_moments_rgb_R_kurtosis', 0.012615260348623553), ('color_moments_lab_L_std', 0.012358535776381227)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier3; Done in 5.69095778465271 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier4
# INFO:utils.ml:Top 10 features for RandomForestClassifier4: [('color_moments_lab_B_std', 0.036103049582381405), ('color_moments_rgb_B_std', 0.034555158724720814), ('color_moments_rgb_B_var', 0.029994319663056164), ('color_moments_lab_B_var', 0.027317137033157243), ('color_moments_lab_L_iqr', 0.019891709926726564), ('color_moments_rgb_R_iqr', 0.017188044877756326), ('color_moments_rgb_B_min', 0.015816967382598968), ('color_moments_rgb_R_skew', 0.014180249687515295), ('color_moments_lab_L_std', 0.013360830946303972), ('color_moments_rgb_G_var', 0.012849064669577479)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier4; Done in 6.2163825035095215 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier5
# INFO:utils.ml:Top 10 features for RandomForestClassifier5: [('color_moments_lab_B_std', 0.03670229832502994), ('color_moments_rgb_B_std', 0.03577706456875971), ('color_moments_lab_B_var', 0.03145471624919369), ('color_moments_rgb_B_var', 0.0303174785217751), ('color_moments_lab_L_iqr', 0.017932151124060915), ('color_moments_rgb_R_iqr', 0.017465690256472186), ('color_moments_lab_L_var', 0.014732044311108444), ('color_moments_rgb_R_skew', 0.013837008666735633), ('color_moments_rgb_G_var', 0.0123664587584239), ('color_moments_lab_L_std', 0.012268572477469573)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier5; Done in 12.045025110244751 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier6
# INFO:utils.ml:Top 10 features for RandomForestClassifier6: [('color_moments_lab_B_std', 0.03586880312439566), ('color_moments_rgb_B_std', 0.031649146973040256), ('color_moments_rgb_B_var', 0.02853118678946879), ('color_moments_lab_B_var', 0.02690762869785255), ('color_moments_rgb_R_iqr', 0.021429387323159133), ('color_moments_lab_L_iqr', 0.020067039191155114), ('color_moments_rgb_B_min', 0.015686589160429587), ('color_moments_rgb_B_iqr', 0.013528229776257727), ('color_moments_rgb_R_skew', 0.013078400527082366), ('color_moments_lab_L_std', 0.0128827438092311)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier6; Done in 12.563985586166382 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier7
# INFO:utils.ml:Top 10 features for RandomForestClassifier7: [('color_moments_lab_B_std', 0.03590002647055697), ('color_moments_rgb_B_std', 0.03214523180354235), ('color_moments_lab_B_var', 0.02998356736399364), ('color_moments_rgb_B_var', 0.029494663811399063), ('color_moments_rgb_R_iqr', 0.022314035988868858), ('color_moments_lab_L_iqr', 0.01760000699210335), ('color_moments_lab_L_var', 0.014058819972943585), ('color_moments_rgb_R_skew', 0.013368767024773237), ('color_moments_rgb_B_iqr', 0.013278057765553688), ('color_moments_rgb_R_kurtosis', 0.012708660846944551)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier7; Done in 18.389339685440063 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier8
# INFO:utils.ml:Top 10 features for XGBClassifier8: [('color_moments_rgb_B_var', 0.80400276), ('color_moments_rgb_R_iqr', 0.013121921), ('color_moments_rgb_B_std', 0.008451117), ('color_moments_lab_B_std', 0.0045478884), ('glcm_energy_dist_1_angle_0', 0.0041831937), ('lbp_rad3_bins24_24', 0.0037949283), ('lbp_rad1_bins8_4', 0.0031130912), ('color_moments_rgb_R_std', 0.002523477), ('color_moments_rgb_B_min', 0.0023905875), ('lbp_rad1_bins8_3', 0.0023718313)]
# INFO:utils.ml:Fitted classifier: XGBClassifier8; Done in 7.903598785400391 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier9
# INFO:utils.ml:Top 10 features for XGBClassifier9: [('color_moments_rgb_B_var', 0.8155251), ('color_moments_rgb_R_iqr', 0.012726453), ('color_moments_rgb_B_std', 0.00819212), ('color_moments_lab_B_std', 0.0042901533), ('glcm_energy_dist_1_angle_0', 0.0042431443), ('lbp_rad3_bins24_24', 0.0035375948), ('lbp_rad1_bins8_4', 0.0028597778), ('color_moments_rgb_R_std', 0.0024849293), ('lbp_rad1_bins8_3', 0.0022886791), ('color_moments_rgb_B_min', 0.0022571203)]
# INFO:utils.ml:Fitted classifier: XGBClassifier9; Done in 9.410979986190796 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier10
# INFO:utils.ml:Top 10 features for XGBClassifier10: [('color_moments_rgb_B_var', 0.82403845), ('color_moments_rgb_R_iqr', 0.0123191625), ('color_moments_rgb_B_std', 0.007849159), ('color_moments_lab_B_std', 0.0041166083), ('glcm_energy_dist_1_angle_0', 0.004088186), ('lbp_rad3_bins24_24', 0.0034805809), ('lbp_rad1_bins8_4', 0.002709249), ('color_moments_rgb_R_std', 0.0023854494), ('lbp_rad1_bins8_3', 0.0022576007), ('color_moments_rgb_B_min', 0.0022044296)]
# INFO:utils.ml:Fitted classifier: XGBClassifier10; Done in 14.288235187530518 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier11
# INFO:utils.ml:Top 10 features for XGBClassifier11: [('color_moments_rgb_B_var', 0.04346285), ('color_moments_rgb_R_iqr', 0.037355427), ('color_moments_rgb_B_std', 0.031859197), ('color_moments_lab_B_var', 0.023638645), ('color_moments_lab_B_std', 0.023628946), ('lbp_rad1_bins8_5', 0.020929025), ('lbp_rad1_bins8_4', 0.012718518), ('color_moments_rgb_B_min', 0.012373125), ('lbp_rad2_bins16_8', 0.011679748), ('lbp_rad1_bins8_3', 0.011095982)]
# INFO:utils.ml:Fitted classifier: XGBClassifier11; Done in 5.94220757484436 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier12
# INFO:utils.ml:Top 10 features for XGBClassifier12: [('color_moments_rgb_B_std', 0.038690224), ('color_moments_rgb_R_iqr', 0.03324735), ('color_moments_rgb_B_var', 0.03284815), ('color_moments_lab_B_var', 0.022323277), ('color_moments_lab_B_std', 0.016676685), ('color_moments_rgb_R_std', 0.012462408), ('lbp_rad1_bins8_4', 0.012193888), ('lbp_rad2_bins16_8', 0.010371318), ('lbp_rad1_bins8_8', 0.009379508), ('color_moments_rgb_R_kurtosis', 0.009007063)]
# INFO:utils.ml:Fitted classifier: XGBClassifier12; Done in 13.17882776260376 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier13
# INFO:utils.ml:Top 10 features for XGBClassifier13: [('color_moments_rgb_B_var', 0.050816502), ('color_moments_rgb_R_iqr', 0.048066948), ('color_moments_rgb_B_std', 0.032231737), ('color_moments_lab_B_var', 0.026080491), ('color_moments_lab_B_std', 0.019146163), ('lbp_rad1_bins8_4', 0.011819236), ('color_moments_rgb_B_min', 0.010083316), ('color_moments_rgb_R_std', 0.010042361), ('lbp_rad1_bins8_5', 0.009898381), ('lbp_rad3_bins24_11', 0.009700743)]
# INFO:utils.ml:Fitted classifier: XGBClassifier13; Done in 8.647105693817139 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier14
# INFO:utils.ml:Top 10 features for XGBClassifier14: [('color_moments_rgb_B_var', 0.06627237), ('color_moments_rgb_R_iqr', 0.049857017), ('color_moments_rgb_B_std', 0.03349448), ('color_moments_lab_B_var', 0.0227255), ('color_moments_lab_B_std', 0.01845224), ('lbp_rad1_bins8_4', 0.0116280485), ('color_moments_rgb_R_std', 0.01099094), ('color_moments_rgb_B_min', 0.010651053), ('lbp_rad1_bins8_8', 0.010337593), ('lbp_rad1_bins8_0', 0.010280519)]
# INFO:utils.ml:Fitted classifier: XGBClassifier14; Done in 8.574258089065552 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier15
# INFO:utils.ml:Top 10 features for XGBClassifier15: [('color_moments_rgb_B_var', 0.053882193), ('color_moments_rgb_R_iqr', 0.03764562), ('color_moments_rgb_B_std', 0.03496709), ('color_moments_lab_B_var', 0.020760207), ('color_moments_lab_B_std', 0.019279), ('lbp_rad2_bins16_8', 0.012763308), ('lbp_rad1_bins8_4', 0.011274689), ('color_moments_rgb_R_std', 0.010701122), ('lbp_rad1_bins8_5', 0.0092747295), ('fourier_transform_magnitude_std', 0.00863551)]
# INFO:utils.ml:Fitted classifier: XGBClassifier15; Done in 16.847887754440308 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier16
# INFO:utils.ml:Top 10 features for XGBClassifier16: [('color_moments_rgb_B_var', 0.057638228), ('color_moments_rgb_R_iqr', 0.036800023), ('color_moments_rgb_B_std', 0.033705298), ('color_moments_lab_B_var', 0.020349007), ('color_moments_lab_B_std', 0.018847438), ('lbp_rad2_bins16_8', 0.013019003), ('lbp_rad1_bins8_4', 0.01122551), ('color_moments_rgb_R_std', 0.010397258), ('lbp_rad1_bins8_5', 0.009503389), ('fourier_transform_magnitude_std', 0.008673108)]
# INFO:utils.ml:Fitted classifier: XGBClassifier16; Done in 15.474244117736816 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier17
# INFO:utils.ml:Top 10 features for XGBClassifier17: [('color_moments_rgb_B_var', 0.0561006), ('color_moments_rgb_R_iqr', 0.05103217), ('color_moments_rgb_B_std', 0.02973237), ('color_moments_lab_B_var', 0.024399105), ('color_moments_lab_B_std', 0.017957274), ('lbp_rad1_bins8_5', 0.011357593), ('lbp_rad1_bins8_4', 0.01041041), ('color_moments_rgb_R_std', 0.010332614), ('lbp_rad1_bins8_0', 0.00979427), ('lbp_rad2_bins16_8', 0.009323854)]
# INFO:utils.ml:Fitted classifier: XGBClassifier17; Done in 13.074785709381104 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier18
# INFO:utils.ml:Top 10 features for XGBClassifier18: [('color_moments_rgb_B_var', 0.056109793), ('color_moments_rgb_R_iqr', 0.053199224), ('color_moments_rgb_B_std', 0.030248959), ('color_moments_lab_B_var', 0.024527585), ('color_moments_lab_B_std', 0.017987002), ('lbp_rad1_bins8_5', 0.0113271745), ('color_moments_rgb_R_std', 0.010442826), ('lbp_rad1_bins8_4', 0.010378379), ('lbp_rad1_bins8_0', 0.009438581), ('lbp_rad2_bins16_8', 0.00938454)]
# INFO:utils.ml:Fitted classifier: XGBClassifier18; Done in 16.344298601150513 seconds
# INFO:utils.ml:Fitting completed in 199.13 seconds.

# %%
pipeline.predict_with_classifiers(VAL_PATH, percent)
# Out:
# INFO:utils.ml:Predicting with classifiers on dataset: C:\Users\gimes\Src\repos\CADx-Project\dataset\multiclass\val
# Processed 5/53 batches.
# Processed 10/53 batches.
# Processed 15/53 batches.
# Processed 20/53 batches.
# Processed 25/53 batches.
# Processed 30/53 batches.
# Processed 35/53 batches.
# Processed 40/53 batches.
# Processed 45/53 batches.
# Processed 50/53 batches.
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier0
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier1
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier2
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier3
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier4
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier5
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier6
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier7
# Processed 53/53 batches.
# INFO:utils.ml:Predictions made with classifier: XGBClassifier8
# INFO:utils.ml:Predictions made with classifier: XGBClassifier9
# INFO:utils.ml:Predictions made with classifier: XGBClassifier10
# INFO:utils.ml:Predictions made with classifier: XGBClassifier11
# INFO:utils.ml:Predictions made with classifier: XGBClassifier12
# INFO:utils.ml:Predictions made with classifier: XGBClassifier13
# INFO:utils.ml:Predictions made with classifier: XGBClassifier14
# INFO:utils.ml:Predictions made with classifier: XGBClassifier15
# INFO:utils.ml:Predictions made with classifier: XGBClassifier16
# INFO:utils.ml:Predictions made with classifier: XGBClassifier17
# INFO:utils.ml:Predictions made with classifier: XGBClassifier18
# {'GT': array([0, 0, 0, ..., 2, 2, 2]),
#  'RandomForestClassifier0': array([0, 0, 1, ..., 1, 0, 0]),
#  'RandomForestClassifier1': array([0, 0, 0, ..., 1, 0, 0]),
#  'RandomForestClassifier2': array([0, 0, 0, ..., 1, 0, 0]),
#  'RandomForestClassifier3': array([0, 0, 0, ..., 1, 0, 0]),
#  'RandomForestClassifier4': array([0, 0, 1, ..., 1, 0, 0]),
#  'RandomForestClassifier5': array([0, 0, 0, ..., 1, 0, 0]),
#  'RandomForestClassifier6': array([0, 0, 1, ..., 1, 0, 0]),
#  'RandomForestClassifier7': array([0, 0, 0, ..., 1, 0, 0]),
#  'XGBClassifier8': array([0, 0, 2, ..., 1, 2, 0], dtype=int64),
#  'XGBClassifier9': array([0, 0, 2, ..., 1, 0, 0], dtype=int64),
#  'XGBClassifier10': array([0, 0, 2, ..., 1, 2, 0], dtype=int64),
#  'XGBClassifier11': array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#  'XGBClassifier12': array([0, 0, 0, ..., 1, 0, 0], dtype=int64),
#  'XGBClassifier13': array([0, 0, 0, ..., 1, 0, 0], dtype=int64),
#  'XGBClassifier14': array([0, 0, 0, ..., 1, 0, 0], dtype=int64),
#  'XGBClassifier15': array([0, 0, 0, ..., 1, 0, 0], dtype=int64),
#  'XGBClassifier16': array([0, 0, 0, ..., 1, 0, 0], dtype=int64),
#  'XGBClassifier17': array([0, 0, 0, ..., 1, 0, 0], dtype=int64),
#  'XGBClassifier18': array([0, 0, 0, ..., 1, 0, 0], dtype=int64)}

# %%
import pandas as pd

df = pd.DataFrame(data=pipeline.calculate_metrics())
df.T
# Out:
# INFO:utils.ml:Metrics for classifier GT: {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'kappa': 1.0}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier0: {'accuracy': 0.8259842519685039, 'precision': 0.7898786387715173, 'recall': 0.6165800464142391, 'f1': 0.617684691845005, 'kappa': 0.6730784462635873}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier1: {'accuracy': 0.8196850393700787, 'precision': 0.875855092824211, 'recall': 0.6040166439939133, 'f1': 0.5968697097627658, 'kappa': 0.6605704815480498}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier2: {'accuracy': 0.8236220472440945, 'precision': 0.8783419068781136, 'recall': 0.6127614707874364, 'f1': 0.6115538402922676, 'kappa': 0.6682247786454689}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier3: {'accuracy': 0.8322834645669291, 'precision': 0.7966044331916441, 'recall': 0.6305650645007698, 'f1': 0.6382327544735884, 'kappa': 0.6857020030673422}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier4: {'accuracy': 0.8267716535433071, 'precision': 0.8803635385910976, 'recall': 0.6149057410839618, 'f1': 0.6136340195077076, 'kappa': 0.6741493361696569}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier5: {'accuracy': 0.8322834645669291, 'precision': 0.7965536596253752, 'recall': 0.6305650645007698, 'f1': 0.6381869358323972, 'kappa': 0.6857677206514416}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier6: {'accuracy': 0.8251968503937008, 'precision': 0.8061343918414772, 'recall': 0.6137447549565613, 'f1': 0.6121389931297897, 'kappa': 0.671496616394176}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier7: {'accuracy': 0.8354330708661417, 'precision': 0.8204265159301132, 'recall': 0.6361191959200638, 'f1': 0.6460608839640322, 'kappa': 0.6918620849779429}
# INFO:utils.ml:Metrics for classifier XGBClassifier8: {'accuracy': 0.8559055118110236, 'precision': 0.8063354257831005, 'recall': 0.6801572700139666, 'f1': 0.7027272727272726, 'kappa': 0.73209345432413}
# INFO:utils.ml:Metrics for classifier XGBClassifier9: {'accuracy': 0.8559055118110236, 'precision': 0.7834322655600539, 'recall': 0.6774582167243001, 'f1': 0.6968133791251155, 'kappa': 0.7325091039670738}
# INFO:utils.ml:Metrics for classifier XGBClassifier10: {'accuracy': 0.8582677165354331, 'precision': 0.791922652354307, 'recall': 0.6850420573904228, 'f1': 0.7065274325322964, 'kappa': 0.7370842342549571}
# INFO:utils.ml:Metrics for classifier XGBClassifier11: {'accuracy': 0.8275590551181102, 'precision': 0.7786124701134652, 'recall': 0.6260158943689148, 'f1': 0.6342280022136138, 'kappa': 0.6761200078253822}
# INFO:utils.ml:Metrics for classifier XGBClassifier12: {'accuracy': 0.8535433070866142, 'precision': 0.8206545200653993, 'recall': 0.6689858662667993, 'f1': 0.6903749842923088, 'kappa': 0.7262550410235016}
# INFO:utils.ml:Metrics for classifier XGBClassifier13: {'accuracy': 0.8480314960629921, 'precision': 0.813530747728861, 'recall': 0.6522603311003381, 'f1': 0.6684757615274193, 'kappa': 0.7146300004657011}
# INFO:utils.ml:Metrics for classifier XGBClassifier14: {'accuracy': 0.8503937007874016, 'precision': 0.8654425736952529, 'recall': 0.666486192053723, 'f1': 0.6910916465158143, 'kappa': 0.7193154694050372}
# INFO:utils.ml:Metrics for classifier XGBClassifier15: {'accuracy': 0.8559055118110236, 'precision': 0.8512922204723313, 'recall': 0.6648849839828781, 'f1': 0.6850998046660913, 'kappa': 0.7298123648538677}
# INFO:utils.ml:Metrics for classifier XGBClassifier16: {'accuracy': 0.8535433070866142, 'precision': 0.8622475838745246, 'recall': 0.6601778985646976, 'f1': 0.6793092353437181, 'kappa': 0.7250672725071927}
# INFO:utils.ml:Metrics for classifier XGBClassifier17: {'accuracy': 0.8559055118110236, 'precision': 0.8322314374294573, 'recall': 0.6708161964370379, 'f1': 0.6926598122816062, 'kappa': 0.730656548565495}
# INFO:utils.ml:Metrics for classifier XGBClassifier18: {'accuracy': 0.8566929133858268, 'precision': 0.8380268207769076, 'recall': 0.6774167529340357, 'f1': 0.701991876269333, 'kappa': 0.7324347350971911}
#                          accuracy  precision    recall        f1     kappa
# GT                       1.000000   1.000000  1.000000  1.000000  1.000000
# RandomForestClassifier0  0.825984   0.789879  0.616580  0.617685  0.673078
# RandomForestClassifier1  0.819685   0.875855  0.604017  0.596870  0.660570
# RandomForestClassifier2  0.823622   0.878342  0.612761  0.611554  0.668225
# RandomForestClassifier3  0.832283   0.796604  0.630565  0.638233  0.685702
# RandomForestClassifier4  0.826772   0.880364  0.614906  0.613634  0.674149
# RandomForestClassifier5  0.832283   0.796554  0.630565  0.638187  0.685768
# RandomForestClassifier6  0.825197   0.806134  0.613745  0.612139  0.671497
# RandomForestClassifier7  0.835433   0.820427  0.636119  0.646061  0.691862
# XGBClassifier8           0.855906   0.806335  0.680157  0.702727  0.732093
# XGBClassifier9           0.855906   0.783432  0.677458  0.696813  0.732509
# XGBClassifier10          0.858268   0.791923  0.685042  0.706527  0.737084
# XGBClassifier11          0.827559   0.778612  0.626016  0.634228  0.676120
# XGBClassifier12          0.853543   0.820655  0.668986  0.690375  0.726255
# XGBClassifier13          0.848031   0.813531  0.652260  0.668476  0.714630
# XGBClassifier14          0.850394   0.865443  0.666486  0.691092  0.719315
# XGBClassifier15          0.855906   0.851292  0.664885  0.685100  0.729812
# XGBClassifier16          0.853543   0.862248  0.660178  0.679309  0.725067
# XGBClassifier17          0.855906   0.832231  0.670816  0.692660  0.730657
# XGBClassifier18          0.856693   0.838027  0.677417  0.701992  0.732435

# %% [markdown]
# ___
# # Balance the data

# %%
# Backup
pipeline.backup_feature_matrix = pipeline.feature_matrix.copy()
pipeline.backup_labels = pipeline.labels.copy()

# %%
print(pipeline.backup_feature_matrix.shape)
print(pipeline.feature_matrix.shape)

print(pipeline.backup_labels.shape)
print(pipeline.labels.shape)
# Out:
# (5082, 189)
# (5082, 189)
# (5082,)
# (5082,)

# %%
pipeline.get_feature_names()
# Out:
# ['gradient_magnitude_mean',
#  'gradient_magnitude_std',
#  'gradient_direction_mean',
#  'gradient_direction_std',
#  'color_moments_rgb_R_mean',
#  'color_moments_rgb_R_std',
#  'color_moments_rgb_R_skew',
#  'color_moments_rgb_R_kurtosis',
#  'color_moments_rgb_R_median',
#  'color_moments_rgb_R_var',
#  'color_moments_rgb_R_min',
#  'color_moments_rgb_R_max',
#  'color_moments_rgb_R_iqr',
#  'color_moments_rgb_R_entropy',
#  'color_moments_rgb_G_mean',
#  'color_moments_rgb_G_std',
#  'color_moments_rgb_G_skew',
#  'color_moments_rgb_G_kurtosis',
#  'color_moments_rgb_G_median',
#  'color_moments_rgb_G_var',
#  'color_moments_rgb_G_min',
#  'color_moments_rgb_G_max',
#  'color_moments_rgb_G_iqr',
#  'color_moments_rgb_G_entropy',
#  'color_moments_rgb_B_mean',
#  'color_moments_rgb_B_std',
#  'color_moments_rgb_B_skew',
#  'color_moments_rgb_B_kurtosis',
#  'color_moments_rgb_B_median',
#  'color_moments_rgb_B_var',
#  'color_moments_rgb_B_min',
#  'color_moments_rgb_B_max',
#  'color_moments_rgb_B_iqr',
#  'color_moments_rgb_B_entropy',
#  'color_moments_lab_L_mean',
#  'color_moments_lab_L_std',
#  'color_moments_lab_L_skew',
#  'color_moments_lab_L_kurtosis',
#  'color_moments_lab_L_median',
#  'color_moments_lab_L_var',
#  'color_moments_lab_L_min',
#  'color_moments_lab_L_max',
#  'color_moments_lab_L_iqr',
#  'color_moments_lab_L_entropy',
#  'color_moments_lab_A_mean',
#  'color_moments_lab_A_std',
#  'color_moments_lab_A_skew',
#  'color_moments_lab_A_kurtosis',
#  'color_moments_lab_A_median',
#  'color_moments_lab_A_var',
#  'color_moments_lab_A_min',
#  'color_moments_lab_A_max',
#  'color_moments_lab_A_iqr',
#  'color_moments_lab_A_entropy',
#  'color_moments_lab_B_mean',
#  'color_moments_lab_B_std',
#  'color_moments_lab_B_skew',
#  'color_moments_lab_B_kurtosis',
#  'color_moments_lab_B_median',
#  'color_moments_lab_B_var',
#  'color_moments_lab_B_min',
#  'color_moments_lab_B_max',
#  'color_moments_lab_B_iqr',
#  'color_moments_lab_B_entropy',
#  'color_moments_hsv_H_mean',
#  'color_moments_hsv_H_std',
#  'color_moments_hsv_H_skew',
#  'color_moments_hsv_H_kurtosis',
#  'color_moments_hsv_H_median',
#  'color_moments_hsv_H_var',
#  'color_moments_hsv_H_min',
#  'color_moments_hsv_H_max',
#  'color_moments_hsv_H_iqr',
#  'color_moments_hsv_H_entropy',
#  'color_moments_hsv_S_mean',
#  'color_moments_hsv_S_std',
#  'color_moments_hsv_S_skew',
#  'color_moments_hsv_S_kurtosis',
#  'color_moments_hsv_S_median',
#  'color_moments_hsv_S_var',
#  'color_moments_hsv_S_min',
#  'color_moments_hsv_S_max',
#  'color_moments_hsv_S_iqr',
#  'color_moments_hsv_S_entropy',
#  'color_moments_hsv_V_mean',
#  'color_moments_hsv_V_std',
#  'color_moments_hsv_V_skew',
#  'color_moments_hsv_V_kurtosis',
#  'color_moments_hsv_V_median',
#  'color_moments_hsv_V_var',
#  'color_moments_hsv_V_min',
#  'color_moments_hsv_V_max',
#  'color_moments_hsv_V_iqr',
#  'color_moments_hsv_V_entropy',
#  'lbp_rad1_bins8_0',
#  'lbp_rad1_bins8_1',
#  'lbp_rad1_bins8_2',
#  'lbp_rad1_bins8_3',
#  'lbp_rad1_bins8_4',
#  'lbp_rad1_bins8_5',
#  'lbp_rad1_bins8_6',
#  'lbp_rad1_bins8_7',
#  'lbp_rad1_bins8_8',
#  'lbp_rad1_bins8_9',
#  'lbp_rad2_bins16_0',
#  'lbp_rad2_bins16_1',
#  'lbp_rad2_bins16_2',
#  'lbp_rad2_bins16_3',
#  'lbp_rad2_bins16_4',
#  'lbp_rad2_bins16_5',
#  'lbp_rad2_bins16_6',
#  'lbp_rad2_bins16_7',
#  'lbp_rad2_bins16_8',
#  'lbp_rad2_bins16_9',
#  'lbp_rad2_bins16_10',
#  'lbp_rad2_bins16_11',
#  'lbp_rad2_bins16_12',
#  'lbp_rad2_bins16_13',
#  'lbp_rad2_bins16_14',
#  'lbp_rad2_bins16_15',
#  'lbp_rad2_bins16_16',
#  'lbp_rad2_bins16_17',
#  'lbp_rad3_bins24_0',
#  'lbp_rad3_bins24_1',
#  'lbp_rad3_bins24_2',
#  'lbp_rad3_bins24_3',
#  'lbp_rad3_bins24_4',
#  'lbp_rad3_bins24_5',
#  'lbp_rad3_bins24_6',
#  'lbp_rad3_bins24_7',
#  'lbp_rad3_bins24_8',
#  'lbp_rad3_bins24_9',
#  'lbp_rad3_bins24_10',
#  'lbp_rad3_bins24_11',
#  'lbp_rad3_bins24_12',
#  'lbp_rad3_bins24_13',
#  'lbp_rad3_bins24_14',
#  'lbp_rad3_bins24_15',
#  'lbp_rad3_bins24_16',
#  'lbp_rad3_bins24_17',
#  'lbp_rad3_bins24_18',
#  'lbp_rad3_bins24_19',
#  'lbp_rad3_bins24_20',
#  'lbp_rad3_bins24_21',
#  'lbp_rad3_bins24_22',
#  'lbp_rad3_bins24_23',
#  'lbp_rad3_bins24_24',
#  'lbp_rad3_bins24_25',
#  'lbp_rad4_bins32_0',
#  'lbp_rad4_bins32_1',
#  'lbp_rad4_bins32_2',
#  'lbp_rad4_bins32_3',
#  'lbp_rad4_bins32_4',
#  'lbp_rad4_bins32_5',
#  'lbp_rad4_bins32_6',
#  'lbp_rad4_bins32_7',
#  'lbp_rad4_bins32_8',
#  'lbp_rad4_bins32_9',
#  'lbp_rad4_bins32_10',
#  'lbp_rad4_bins32_11',
#  'lbp_rad4_bins32_12',
#  'lbp_rad4_bins32_13',
#  'lbp_rad4_bins32_14',
#  'lbp_rad4_bins32_15',
#  'lbp_rad4_bins32_16',
#  'lbp_rad4_bins32_17',
#  'lbp_rad4_bins32_18',
#  'lbp_rad4_bins32_19',
#  'lbp_rad4_bins32_20',
#  'lbp_rad4_bins32_21',
#  'lbp_rad4_bins32_22',
#  'lbp_rad4_bins32_23',
#  'lbp_rad4_bins32_24',
#  'lbp_rad4_bins32_25',
#  'lbp_rad4_bins32_26',
#  'lbp_rad4_bins32_27',
#  'lbp_rad4_bins32_28',
#  'lbp_rad4_bins32_29',
#  'lbp_rad4_bins32_30',
#  'lbp_rad4_bins32_31',
#  'lbp_rad4_bins32_32',
#  'lbp_rad4_bins32_33',
#  'fourier_transform_magnitude_mean',
#  'fourier_transform_magnitude_std',
#  'glcm_contrast_dist_1_angle_0',
#  'glcm_dissimilarity_dist_1_angle_0',
#  'glcm_homogeneity_dist_1_angle_0',
#  'glcm_energy_dist_1_angle_0',
#  'glcm_correlation_dist_1_angle_0']

# %%
from imblearn.over_sampling import SMOTE

smote = SMOTE(random_state=42)


pipeline.feature_matrix, pipeline.labels = smote.fit_resample(np.nan_to_num(pipeline.feature_matrix), pipeline.labels)

# %%
pipeline.fitted_classifiers = {}
pipeline.fit_classifiers()
# Out:
# INFO:utils.ml:Fitting classifiers...
# INFO:utils.ml:Fitting classifier: RandomForestClassifier0
# INFO:utils.ml:Top 10 features for RandomForestClassifier0: [('color_moments_rgb_B_std', 0.030740792543905736), ('color_moments_lab_B_std', 0.020227230672391867), ('color_moments_rgb_B_var', 0.019702265630697168), ('color_moments_rgb_R_iqr', 0.018897314328376782), ('color_moments_lab_B_var', 0.016374362731276168), ('color_moments_rgb_B_iqr', 0.013398429636876943), ('color_moments_rgb_G_std', 0.013330974998790586), ('fourier_transform_magnitude_std', 0.012577158643308732), ('color_moments_lab_L_std', 0.012064851241508806), ('color_moments_lab_L_var', 0.011854697946243817)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier0; Done in 7.5829150676727295 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier1
# INFO:utils.ml:Top 10 features for RandomForestClassifier1: [('color_moments_rgb_B_var', 0.02790813292662825), ('color_moments_rgb_B_std', 0.024856979679029226), ('color_moments_lab_B_std', 0.018941892974310804), ('color_moments_rgb_B_iqr', 0.01620101311377192), ('color_moments_lab_B_var', 0.01598765011883436), ('color_moments_lab_L_var', 0.013954237646135657), ('color_moments_rgb_G_std', 0.013367277201734973), ('fourier_transform_magnitude_std', 0.013170824822881823), ('color_moments_rgb_R_iqr', 0.013117264442789978), ('color_moments_lab_L_iqr', 0.012039614501345938)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier1; Done in 11.354628324508667 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier2
# INFO:utils.ml:Top 10 features for RandomForestClassifier2: [('color_moments_rgb_B_std', 0.02862324000733544), ('color_moments_rgb_B_var', 0.024080408882324024), ('color_moments_lab_B_std', 0.02107395084266538), ('color_moments_lab_B_var', 0.0183172911601199), ('color_moments_rgb_R_iqr', 0.01581593172190241), ('color_moments_lab_L_iqr', 0.014275248836362851), ('color_moments_rgb_B_iqr', 0.013422360685902544), ('color_moments_lab_L_std', 0.013067509440168079), ('color_moments_rgb_G_var', 0.012768475753058652), ('color_moments_lab_L_var', 0.012176554818607173)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier2; Done in 7.915298700332642 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier3
# INFO:utils.ml:Top 10 features for RandomForestClassifier3: [('color_moments_rgb_B_std', 0.029469318690082954), ('color_moments_rgb_B_var', 0.022415022651590975), ('color_moments_lab_B_std', 0.022291198985259025), ('color_moments_lab_B_var', 0.015561447721979463), ('color_moments_lab_L_iqr', 0.015007551270323707), ('fourier_transform_magnitude_std', 0.014331180475653512), ('color_moments_rgb_B_iqr', 0.014290199116138264), ('color_moments_rgb_R_iqr', 0.014140270410955969), ('color_moments_lab_L_std', 0.013827701769910465), ('color_moments_rgb_G_std', 0.01241006203294536)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier3; Done in 11.080586671829224 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier4
# INFO:utils.ml:Top 10 features for RandomForestClassifier4: [('color_moments_rgb_B_std', 0.027177555824139266), ('color_moments_rgb_B_var', 0.025925686119085398), ('color_moments_lab_B_std', 0.022163012472920973), ('color_moments_lab_L_iqr', 0.01743397830832764), ('color_moments_lab_B_var', 0.016699144732242877), ('color_moments_rgb_R_iqr', 0.015703619413685952), ('color_moments_lab_L_std', 0.012664724698598943), ('color_moments_rgb_G_var', 0.012102662267436752), ('fourier_transform_magnitude_std', 0.012033658635544044), ('color_moments_lab_L_var', 0.011887398628967911)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier4; Done in 11.650699138641357 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier5
# INFO:utils.ml:Top 10 features for RandomForestClassifier5: [('color_moments_rgb_B_std', 0.0277543282791465), ('color_moments_rgb_B_var', 0.023704612019609377), ('color_moments_lab_B_std', 0.022695326147962925), ('color_moments_lab_L_iqr', 0.01681423498058537), ('color_moments_lab_B_var', 0.015146667402303388), ('color_moments_rgb_R_iqr', 0.014817330031284399), ('fourier_transform_magnitude_std', 0.014202889790465193), ('color_moments_lab_L_std', 0.012976535655969068), ('color_moments_lab_L_var', 0.012542795559567763), ('color_moments_rgb_B_iqr', 0.012376709732753658)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier5; Done in 16.970360279083252 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier6
# INFO:utils.ml:Top 10 features for RandomForestClassifier6: [('color_moments_rgb_B_std', 0.025637020044045243), ('color_moments_rgb_B_var', 0.024631571031888087), ('color_moments_lab_B_std', 0.02133226913365394), ('color_moments_rgb_R_iqr', 0.018676899358947473), ('color_moments_lab_L_iqr', 0.01686504953463482), ('color_moments_lab_B_var', 0.01626077870941877), ('color_moments_rgb_B_iqr', 0.0128327239363568), ('color_moments_rgb_G_skew', 0.01182333258128838), ('color_moments_lab_L_std', 0.011682376639446363), ('color_moments_rgb_G_std', 0.011609368197350924)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier6; Done in 15.860590696334839 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier7
# INFO:utils.ml:Top 10 features for RandomForestClassifier7: [('color_moments_rgb_B_std', 0.026039223941098904), ('color_moments_rgb_B_var', 0.022868514482476173), ('color_moments_lab_B_std', 0.022115154766190047), ('color_moments_rgb_R_iqr', 0.017821152044367086), ('color_moments_lab_L_iqr', 0.016822413187709436), ('color_moments_lab_B_var', 0.015265743428732373), ('color_moments_rgb_B_iqr', 0.013534753586554413), ('fourier_transform_magnitude_std', 0.01300630930345981), ('color_moments_lab_L_std', 0.012663934312418336), ('color_moments_lab_L_var', 0.012174600679882713)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier7; Done in 32.82805514335632 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier8
# INFO:utils.ml:Top 10 features for XGBClassifier8: [('color_moments_rgb_B_std', 0.07779891), ('color_moments_rgb_R_iqr', 0.042856127), ('glcm_energy_dist_1_angle_0', 0.021859843), ('lbp_rad1_bins8_4', 0.014725868), ('color_moments_lab_B_std', 0.013448944), ('color_moments_lab_B_var', 0.01322153), ('color_moments_rgb_B_entropy', 0.013107881), ('fourier_transform_magnitude_std', 0.012490095), ('lbp_rad2_bins16_8', 0.0123809865), ('color_moments_rgb_B_var', 0.012330715)]
# INFO:utils.ml:Fitted classifier: XGBClassifier8; Done in 9.486133098602295 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier9
# INFO:utils.ml:Top 10 features for XGBClassifier9: [('color_moments_rgb_B_std', 0.07918891), ('color_moments_rgb_R_iqr', 0.043061532), ('glcm_energy_dist_1_angle_0', 0.02216579), ('lbp_rad1_bins8_4', 0.0143335955), ('color_moments_lab_B_std', 0.013796051), ('color_moments_rgb_B_entropy', 0.01366157), ('color_moments_lab_B_var', 0.013202505), ('gradient_direction_mean', 0.012688031), ('lbp_rad4_bins32_32', 0.012451394), ('color_moments_rgb_B_var', 0.012436574)]
# INFO:utils.ml:Fitted classifier: XGBClassifier9; Done in 15.56275987625122 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier10
# INFO:utils.ml:Top 10 features for XGBClassifier10: [('color_moments_rgb_B_std', 0.08030596), ('color_moments_rgb_R_iqr', 0.043145068), ('glcm_energy_dist_1_angle_0', 0.022306489), ('lbp_rad1_bins8_4', 0.013987269), ('color_moments_lab_B_std', 0.013745862), ('color_moments_rgb_B_entropy', 0.013453388), ('color_moments_lab_B_var', 0.013126149), ('lbp_rad2_bins16_8', 0.01292579), ('gradient_direction_mean', 0.01281122), ('lbp_rad4_bins32_32', 0.012575646)]
# INFO:utils.ml:Fitted classifier: XGBClassifier10; Done in 19.774361610412598 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier11
# INFO:utils.ml:Top 10 features for XGBClassifier11: [('color_moments_rgb_B_std', 0.044330373), ('color_moments_rgb_R_iqr', 0.035827387), ('color_moments_rgb_B_var', 0.02724718), ('color_moments_lab_B_std', 0.019057717), ('lbp_rad1_bins8_4', 0.014348998), ('color_moments_lab_B_var', 0.013193613), ('glcm_energy_dist_1_angle_0', 0.0123817455), ('color_moments_rgb_G_skew', 0.012232768), ('gradient_direction_std', 0.01216244), ('fourier_transform_magnitude_std', 0.01213493)]
# INFO:utils.ml:Fitted classifier: XGBClassifier11; Done in 8.987874746322632 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier12
# INFO:utils.ml:Top 10 features for XGBClassifier12: [('color_moments_rgb_B_std', 0.04727793), ('color_moments_rgb_B_var', 0.026643269), ('color_moments_rgb_R_iqr', 0.022966117), ('glcm_energy_dist_1_angle_0', 0.015561557), ('lbp_rad1_bins8_4', 0.013990738), ('fourier_transform_magnitude_std', 0.011773398), ('color_moments_lab_B_std', 0.011565054), ('lbp_rad3_bins24_24', 0.011372244), ('color_moments_lab_B_var', 0.010678884), ('gradient_direction_mean', 0.010352696)]
# INFO:utils.ml:Fitted classifier: XGBClassifier12; Done in 20.111857652664185 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier13
# INFO:utils.ml:Top 10 features for XGBClassifier13: [('color_moments_rgb_B_std', 0.049645968), ('color_moments_rgb_R_iqr', 0.03460489), ('color_moments_rgb_B_var', 0.025412584), ('lbp_rad1_bins8_4', 0.014010583), ('glcm_energy_dist_1_angle_0', 0.013294314), ('fourier_transform_magnitude_std', 0.013043493), ('color_moments_lab_B_std', 0.012948664), ('lbp_rad4_bins32_32', 0.012666945), ('color_moments_lab_B_var', 0.012112976), ('lbp_rad2_bins16_8', 0.011015136)]
# INFO:utils.ml:Fitted classifier: XGBClassifier13; Done in 14.73735785484314 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier14
# INFO:utils.ml:Top 10 features for XGBClassifier14: [('color_moments_rgb_B_std', 0.05039884), ('color_moments_rgb_R_iqr', 0.030705595), ('color_moments_rgb_B_var', 0.025525583), ('glcm_energy_dist_1_angle_0', 0.014685659), ('gradient_direction_std', 0.013738738), ('color_moments_lab_B_std', 0.013628077), ('lbp_rad1_bins8_4', 0.013566102), ('fourier_transform_magnitude_std', 0.013184465), ('lbp_rad4_bins32_32', 0.012313591), ('lbp_rad2_bins16_8', 0.011970158)]
# INFO:utils.ml:Fitted classifier: XGBClassifier14; Done in 14.121434211730957 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier15
# INFO:utils.ml:Top 10 features for XGBClassifier15: [('color_moments_rgb_B_std', 0.04922981), ('color_moments_rgb_R_iqr', 0.027501378), ('color_moments_rgb_B_var', 0.024939587), ('glcm_energy_dist_1_angle_0', 0.01735249), ('fourier_transform_magnitude_std', 0.013518154), ('lbp_rad1_bins8_4', 0.01279955), ('color_moments_lab_B_var', 0.012787135), ('color_moments_lab_B_std', 0.011874872), ('color_moments_rgb_G_skew', 0.010436366), ('lbp_rad2_bins16_8', 0.010304437)]
# INFO:utils.ml:Fitted classifier: XGBClassifier15; Done in 30.41754174232483 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier16
# INFO:utils.ml:Top 10 features for XGBClassifier16: [('color_moments_rgb_B_std', 0.04725604), ('color_moments_rgb_R_iqr', 0.027422594), ('color_moments_rgb_B_var', 0.025924303), ('glcm_energy_dist_1_angle_0', 0.016712813), ('fourier_transform_magnitude_std', 0.013882704), ('color_moments_lab_B_var', 0.01279437), ('lbp_rad1_bins8_4', 0.012567885), ('color_moments_lab_B_std', 0.01157597), ('color_moments_rgb_G_skew', 0.010648288), ('lbp_rad2_bins16_8', 0.010089597)]
# INFO:utils.ml:Fitted classifier: XGBClassifier16; Done in 19.62626028060913 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier17
# INFO:utils.ml:Top 10 features for XGBClassifier17: [('color_moments_rgb_B_std', 0.052492227), ('color_moments_rgb_R_iqr', 0.029533263), ('color_moments_rgb_B_var', 0.024097387), ('glcm_energy_dist_1_angle_0', 0.016601741), ('fourier_transform_magnitude_std', 0.013634397), ('lbp_rad1_bins8_4', 0.01335899), ('color_moments_lab_B_std', 0.011903165), ('lbp_rad2_bins16_8', 0.011012977), ('lbp_rad1_bins8_0', 0.011005526), ('color_moments_lab_B_var', 0.010679337)]
# INFO:utils.ml:Fitted classifier: XGBClassifier17; Done in 17.306478261947632 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier18
# INFO:utils.ml:Top 10 features for XGBClassifier18: [('color_moments_rgb_B_std', 0.054637797), ('color_moments_rgb_R_iqr', 0.029337915), ('color_moments_rgb_B_var', 0.023720484), ('glcm_energy_dist_1_angle_0', 0.017122827), ('lbp_rad1_bins8_4', 0.013478435), ('fourier_transform_magnitude_std', 0.013392441), ('color_moments_lab_B_std', 0.0120403655), ('lbp_rad1_bins8_0', 0.01072465), ('lbp_rad2_bins16_8', 0.010537346), ('color_moments_lab_B_var', 0.010535227)]
# INFO:utils.ml:Fitted classifier: XGBClassifier18; Done in 18.434861421585083 seconds
# INFO:utils.ml:Fitting completed in 303.83 seconds.

# %%
pipeline.predict_with_classifiers(VAL_PATH, percent)
# Out:
# INFO:utils.ml:Predicting with classifiers on dataset: C:\Users\gimes\Src\repos\CADx-Project\dataset\multiclass\val
# Processed 5/53 batches.
# Processed 10/53 batches.
# Processed 15/53 batches.
# Processed 20/53 batches.
# Processed 25/53 batches.
# Processed 30/53 batches.
# Processed 35/53 batches.
# Processed 40/53 batches.
# Processed 45/53 batches.
# Processed 50/53 batches.
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier0
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier1
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier2
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier3
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier4
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier5
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier6
# Processed 53/53 batches.
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier7
# INFO:utils.ml:Predictions made with classifier: XGBClassifier8
# INFO:utils.ml:Predictions made with classifier: XGBClassifier9
# INFO:utils.ml:Predictions made with classifier: XGBClassifier10
# INFO:utils.ml:Predictions made with classifier: XGBClassifier11
# INFO:utils.ml:Predictions made with classifier: XGBClassifier12
# INFO:utils.ml:Predictions made with classifier: XGBClassifier13
# INFO:utils.ml:Predictions made with classifier: XGBClassifier14
# INFO:utils.ml:Predictions made with classifier: XGBClassifier15
# INFO:utils.ml:Predictions made with classifier: XGBClassifier16
# INFO:utils.ml:Predictions made with classifier: XGBClassifier17
# INFO:utils.ml:Predictions made with classifier: XGBClassifier18
# {'GT': array([0, 0, 0, ..., 2, 2, 2]),
#  'RandomForestClassifier0': array([0, 0, 2, ..., 1, 2, 0]),
#  'RandomForestClassifier1': array([0, 0, 2, ..., 1, 2, 0]),
#  'RandomForestClassifier2': array([0, 0, 2, ..., 1, 2, 0]),
#  'RandomForestClassifier3': array([0, 0, 2, ..., 1, 2, 0]),
#  'RandomForestClassifier4': array([0, 0, 2, ..., 1, 2, 0]),
#  'RandomForestClassifier5': array([0, 0, 2, ..., 1, 2, 0]),
#  'RandomForestClassifier6': array([0, 0, 2, ..., 1, 2, 0]),
#  'RandomForestClassifier7': array([0, 0, 2, ..., 1, 2, 0]),
#  'XGBClassifier8': array([0, 0, 0, ..., 1, 2, 0], dtype=int64),
#  'XGBClassifier9': array([0, 0, 0, ..., 1, 2, 0], dtype=int64),
#  'XGBClassifier10': array([0, 0, 0, ..., 1, 2, 0], dtype=int64),
#  'XGBClassifier11': array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#  'XGBClassifier12': array([0, 0, 0, ..., 1, 2, 0], dtype=int64),
#  'XGBClassifier13': array([0, 0, 0, ..., 1, 2, 0], dtype=int64),
#  'XGBClassifier14': array([0, 0, 0, ..., 1, 2, 0], dtype=int64),
#  'XGBClassifier15': array([0, 0, 0, ..., 1, 2, 0], dtype=int64),
#  'XGBClassifier16': array([0, 0, 0, ..., 1, 2, 0], dtype=int64),
#  'XGBClassifier17': array([0, 0, 0, ..., 1, 2, 0], dtype=int64),
#  'XGBClassifier18': array([0, 0, 0, ..., 1, 2, 0], dtype=int64)}

# %%
import pandas as pd

df_smote = pd.DataFrame(data=pipeline.calculate_metrics())
df_smote = df_smote.T
df_smote
# Out:
# INFO:utils.ml:Metrics for classifier GT: {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'kappa': 1.0}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier0: {'accuracy': 0.8188976377952756, 'precision': 0.7084854324720506, 'recall': 0.704711017546619, 'f1': 0.7058770690240669, 'kappa': 0.6754054931036169}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier1: {'accuracy': 0.8188976377952756, 'precision': 0.6927685861873787, 'recall': 0.6930262945965749, 'f1': 0.6922901257141919, 'kappa': 0.6759715307544172}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier2: {'accuracy': 0.8149606299212598, 'precision': 0.7046900165119244, 'recall': 0.7058403702048514, 'f1': 0.7045019797884023, 'kappa': 0.6694715531791422}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier3: {'accuracy': 0.8283464566929134, 'precision': 0.7222150724369802, 'recall': 0.712387742144124, 'f1': 0.7161198823761142, 'kappa': 0.6915250158215154}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier4: {'accuracy': 0.8149606299212598, 'precision': 0.7026436960649121, 'recall': 0.7060180721631268, 'f1': 0.7035539369566047, 'kappa': 0.6698985528405648}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier5: {'accuracy': 0.8307086614173228, 'precision': 0.7279046682564371, 'recall': 0.7201492847685224, 'f1': 0.7229724280908507, 'kappa': 0.6962263311305432}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier6: {'accuracy': 0.8181102362204724, 'precision': 0.7080343543003537, 'recall': 0.7079846405013767, 'f1': 0.7073364927800107, 'kappa': 0.6746926229508197}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier7: {'accuracy': 0.8322834645669291, 'precision': 0.7301976861794559, 'recall': 0.718788919564532, 'f1': 0.7230497793449873, 'kappa': 0.6986457943425486}
# INFO:utils.ml:Metrics for classifier XGBClassifier8: {'accuracy': 0.8551181102362204, 'precision': 0.7563224500304538, 'recall': 0.7364564011396114, 'f1': 0.7448018344455205, 'kappa': 0.7379422952702217}
# INFO:utils.ml:Metrics for classifier XGBClassifier9: {'accuracy': 0.8551181102362204, 'precision': 0.7602500318918229, 'recall': 0.7395108583458292, 'f1': 0.7482913667847927, 'kappa': 0.7378364551826888}
# INFO:utils.ml:Metrics for classifier XGBClassifier10: {'accuracy': 0.8559055118110236, 'precision': 0.764536566251128, 'recall': 0.7403579043469427, 'f1': 0.7503502684970719, 'kappa': 0.7391301419681582}
# INFO:utils.ml:Metrics for classifier XGBClassifier11: {'accuracy': 0.8047244094488188, 'precision': 0.6732731811550097, 'recall': 0.6881532279875796, 'f1': 0.6794216710913403, 'kappa': 0.6541439910044056}
# INFO:utils.ml:Metrics for classifier XGBClassifier12: {'accuracy': 0.8543307086614174, 'precision': 0.7519669371586449, 'recall': 0.7300335466008891, 'f1': 0.7390872606668841, 'kappa': 0.7361191602535593}
# INFO:utils.ml:Metrics for classifier XGBClassifier13: {'accuracy': 0.8519685039370078, 'precision': 0.7524283562534929, 'recall': 0.7364780782579259, 'f1': 0.7434481262488594, 'kappa': 0.7324470183239502}
# INFO:utils.ml:Metrics for classifier XGBClassifier14: {'accuracy': 0.8551181102362204, 'precision': 0.7507048727061728, 'recall': 0.7332242419751182, 'f1': 0.74059332962636, 'kappa': 0.7381138097671625}
# INFO:utils.ml:Metrics for classifier XGBClassifier15: {'accuracy': 0.852755905511811, 'precision': 0.7440944800066506, 'recall': 0.7288725604734888, 'f1': 0.7353192829652627, 'kappa': 0.7339643777304805}
# INFO:utils.ml:Metrics for classifier XGBClassifier16: {'accuracy': 0.8503937007874016, 'precision': 0.7375231801476786, 'recall': 0.7182342626011483, 'f1': 0.7260669734326141, 'kappa': 0.7290967796983128}
# INFO:utils.ml:Metrics for classifier XGBClassifier17: {'accuracy': 0.8574803149606299, 'precision': 0.756934322519997, 'recall': 0.744928751597112, 'f1': 0.7499753297634043, 'kappa': 0.7433145884234176}
# INFO:utils.ml:Metrics for classifier XGBClassifier18: {'accuracy': 0.8606299212598425, 'precision': 0.762538639594221, 'recall': 0.7470730218936374, 'f1': 0.7536238667290723, 'kappa': 0.7485581719992305}
#                          accuracy  precision    recall        f1     kappa
# GT                       1.000000   1.000000  1.000000  1.000000  1.000000
# RandomForestClassifier0  0.818898   0.708485  0.704711  0.705877  0.675405
# RandomForestClassifier1  0.818898   0.692769  0.693026  0.692290  0.675972
# RandomForestClassifier2  0.814961   0.704690  0.705840  0.704502  0.669472
# RandomForestClassifier3  0.828346   0.722215  0.712388  0.716120  0.691525
# RandomForestClassifier4  0.814961   0.702644  0.706018  0.703554  0.669899
# RandomForestClassifier5  0.830709   0.727905  0.720149  0.722972  0.696226
# RandomForestClassifier6  0.818110   0.708034  0.707985  0.707336  0.674693
# RandomForestClassifier7  0.832283   0.730198  0.718789  0.723050  0.698646
# XGBClassifier8           0.855118   0.756322  0.736456  0.744802  0.737942
# XGBClassifier9           0.855118   0.760250  0.739511  0.748291  0.737836
# XGBClassifier10          0.855906   0.764537  0.740358  0.750350  0.739130
# XGBClassifier11          0.804724   0.673273  0.688153  0.679422  0.654144
# XGBClassifier12          0.854331   0.751967  0.730034  0.739087  0.736119
# XGBClassifier13          0.851969   0.752428  0.736478  0.743448  0.732447
# XGBClassifier14          0.855118   0.750705  0.733224  0.740593  0.738114
# XGBClassifier15          0.852756   0.744094  0.728873  0.735319  0.733964
# XGBClassifier16          0.850394   0.737523  0.718234  0.726067  0.729097
# XGBClassifier17          0.857480   0.756934  0.744929  0.749975  0.743315
# XGBClassifier18          0.860630   0.762539  0.747073  0.753624  0.748558

# %%
highest = df_smote[df_smote["kappa"] == df_smote.iloc[1:]["kappa"].max()]
idx = highest.index[0]

confusion_matrix(pipeline.predictions["GT"], pipeline.predictions[idx])
# Out:
# array([[429,  45,  24],
#        [ 56, 610,  12],
#        [ 31,  29,  34]], dtype=int64)

# %% [markdown]
# ___
# # Borderline SMOTE

# %%
from imblearn.over_sampling import BorderlineSMOTE
smote = BorderlineSMOTE(sampling_strategy='auto', random_state=42)

pipeline.feature_matrix, pipeline.labels = smote.fit_resample(
    np.nan_to_num(pipeline.backup_feature_matrix), pipeline.backup_labels)

print(pipeline.backup_feature_matrix.shape)
print(pipeline.feature_matrix.shape)

print(pipeline.backup_labels.shape)
print(pipeline.labels.shape)
# Out:
# (5082, 189)
# (8139, 189)
# (5082,)
# (8139,)

# %%
pipeline.fitted_classifiers = {}

pipeline.fit_classifiers()
# Out:
# INFO:utils.ml:Fitting classifiers...
# INFO:utils.ml:Fitting classifier: RandomForestClassifier0
# INFO:utils.ml:Top 10 features for RandomForestClassifier0: [('color_moments_rgb_B_std', 0.029398710661218127), ('color_moments_rgb_B_var', 0.026611462374768635), ('color_moments_lab_B_std', 0.019450339171874685), ('color_moments_lab_B_var', 0.018161508188754717), ('color_moments_rgb_R_iqr', 0.017540792663456876), ('color_moments_rgb_B_iqr', 0.014504145462279312), ('fourier_transform_magnitude_std', 0.014019791232330532), ('color_moments_rgb_B_kurtosis', 0.013690544115288179), ('color_moments_lab_L_iqr', 0.013330220425773736), ('color_moments_rgb_G_skew', 0.013008073807351573)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier0; Done in 7.49016547203064 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier1
# INFO:utils.ml:Top 10 features for RandomForestClassifier1: [('color_moments_lab_B_std', 0.022524877966430074), ('color_moments_rgb_B_var', 0.021860454090072975), ('color_moments_rgb_B_std', 0.01987989486085087), ('color_moments_lab_B_var', 0.018926872233224666), ('color_moments_rgb_R_iqr', 0.015782565689698255), ('color_moments_rgb_B_iqr', 0.014651580041083126), ('color_moments_rgb_B_kurtosis', 0.013652208623572483), ('color_moments_lab_L_std', 0.013133324635229112), ('fourier_transform_magnitude_std', 0.013084704532964548), ('color_moments_rgb_R_kurtosis', 0.012098293598501862)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier1; Done in 11.414890050888062 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier2
# INFO:utils.ml:Top 10 features for RandomForestClassifier2: [('color_moments_rgb_B_std', 0.030112134870242054), ('color_moments_lab_B_std', 0.023023907727185527), ('color_moments_rgb_B_var', 0.020544756834938324), ('color_moments_lab_B_var', 0.017167100140056676), ('color_moments_rgb_G_skew', 0.015090553443385325), ('color_moments_lab_L_iqr', 0.015072315164707792), ('color_moments_rgb_R_kurtosis', 0.014441278299190886), ('color_moments_rgb_R_iqr', 0.01296686164536271), ('fourier_transform_magnitude_std', 0.012518384664904516), ('color_moments_lab_L_std', 0.012240882151012046)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier2; Done in 7.824965953826904 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier3
# INFO:utils.ml:Top 10 features for RandomForestClassifier3: [('color_moments_rgb_B_std', 0.028254284268206722), ('color_moments_lab_B_std', 0.025359724281517407), ('color_moments_rgb_B_var', 0.021403214367564486), ('color_moments_lab_B_var', 0.01705048266367059), ('color_moments_rgb_R_iqr', 0.014283026725845062), ('color_moments_lab_L_iqr', 0.01412682809599653), ('color_moments_lab_L_std', 0.013363904658551593), ('fourier_transform_magnitude_std', 0.013016150805630336), ('color_moments_rgb_B_iqr', 0.01286671680037524), ('color_moments_rgb_G_std', 0.012829878262127664)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier3; Done in 11.608737230300903 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier4
# INFO:utils.ml:Top 10 features for RandomForestClassifier4: [('color_moments_rgb_B_std', 0.028118045981731888), ('color_moments_lab_B_std', 0.023103341874275568), ('color_moments_rgb_B_var', 0.022297933557422038), ('color_moments_lab_L_iqr', 0.0167584238770527), ('color_moments_lab_B_var', 0.016299890699522875), ('color_moments_rgb_G_skew', 0.014384909303036481), ('color_moments_rgb_R_iqr', 0.013630855265361815), ('fourier_transform_magnitude_std', 0.01323509585827739), ('color_moments_rgb_R_kurtosis', 0.012515706213428531), ('color_moments_lab_L_var', 0.011964948729851961)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier4; Done in 11.483039855957031 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier5
# INFO:utils.ml:Top 10 features for RandomForestClassifier5: [('color_moments_rgb_B_std', 0.02726469431699879), ('color_moments_lab_B_std', 0.02491716824841698), ('color_moments_rgb_B_var', 0.023372838278417463), ('color_moments_lab_B_var', 0.017009771841623646), ('color_moments_rgb_R_iqr', 0.015606025503504383), ('color_moments_lab_L_iqr', 0.015238127719668213), ('fourier_transform_magnitude_std', 0.013932131708685886), ('color_moments_rgb_G_skew', 0.013009266019096313), ('color_moments_lab_L_std', 0.012093443083367001), ('color_moments_rgb_B_iqr', 0.01175318194599487)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier5; Done in 16.80496621131897 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier6
# INFO:utils.ml:Top 10 features for RandomForestClassifier6: [('color_moments_rgb_B_std', 0.0262261836672556), ('color_moments_lab_B_std', 0.022466880215570976), ('color_moments_rgb_B_var', 0.021589687368329197), ('color_moments_rgb_R_iqr', 0.017523722174223134), ('color_moments_lab_B_var', 0.016435354243164165), ('color_moments_lab_L_iqr', 0.01618549823231736), ('color_moments_rgb_R_kurtosis', 0.014157610382366006), ('color_moments_rgb_G_skew', 0.013912409318997137), ('fourier_transform_magnitude_std', 0.013286343857318878), ('color_moments_rgb_B_iqr', 0.012189643571208698)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier6; Done in 15.080522537231445 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier7
# INFO:utils.ml:Top 10 features for RandomForestClassifier7: [('color_moments_rgb_B_std', 0.025968756885002203), ('color_moments_lab_B_std', 0.024372780820064645), ('color_moments_rgb_B_var', 0.02270125552844585), ('color_moments_rgb_R_iqr', 0.018646724485546738), ('color_moments_lab_B_var', 0.01718448995600154), ('color_moments_lab_L_iqr', 0.014811216260059976), ('fourier_transform_magnitude_std', 0.013865132609502595), ('color_moments_rgb_B_iqr', 0.01305593430143724), ('color_moments_rgb_G_skew', 0.01292086178373466), ('color_moments_rgb_R_kurtosis', 0.012180893744607653)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier7; Done in 22.37220525741577 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier8
# INFO:utils.ml:Top 10 features for XGBClassifier8: [('color_moments_rgb_B_std', 0.058824014), ('color_moments_rgb_R_iqr', 0.03701367), ('glcm_energy_dist_1_angle_0', 0.02700075), ('color_moments_hsv_H_median', 0.0188952), ('gradient_magnitude_mean', 0.017313516), ('color_moments_lab_B_std', 0.015407979), ('lbp_rad2_bins16_8', 0.015342285), ('color_moments_hsv_H_mean', 0.015072655), ('lbp_rad1_bins8_1', 0.0139460685), ('color_moments_hsv_V_kurtosis', 0.013546953)]
# INFO:utils.ml:Fitted classifier: XGBClassifier8; Done in 6.04550576210022 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier9
# INFO:utils.ml:Top 10 features for XGBClassifier9: [('color_moments_rgb_B_std', 0.061819337), ('color_moments_rgb_R_iqr', 0.03738278), ('glcm_energy_dist_1_angle_0', 0.027995989), ('color_moments_hsv_H_median', 0.01891661), ('gradient_magnitude_mean', 0.01699045), ('color_moments_lab_B_std', 0.015463484), ('color_moments_hsv_H_mean', 0.01541329), ('lbp_rad2_bins16_8', 0.01457768), ('color_moments_hsv_V_kurtosis', 0.013571003), ('lbp_rad1_bins8_1', 0.01316576)]
# INFO:utils.ml:Fitted classifier: XGBClassifier9; Done in 7.204464435577393 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier10
# INFO:utils.ml:Top 10 features for XGBClassifier10: [('color_moments_rgb_B_std', 0.06320241), ('color_moments_rgb_R_iqr', 0.03837291), ('glcm_energy_dist_1_angle_0', 0.028689787), ('color_moments_hsv_H_median', 0.018932592), ('gradient_magnitude_mean', 0.017985327), ('color_moments_hsv_H_mean', 0.015539473), ('color_moments_lab_B_std', 0.015346609), ('lbp_rad2_bins16_8', 0.015058209), ('color_moments_hsv_V_kurtosis', 0.013521304), ('lbp_rad1_bins8_1', 0.013203691)]
# INFO:utils.ml:Fitted classifier: XGBClassifier10; Done in 8.441726684570312 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier11
# INFO:utils.ml:Top 10 features for XGBClassifier11: [('color_moments_rgb_B_std', 0.036656562), ('color_moments_rgb_R_iqr', 0.033337444), ('color_moments_rgb_B_var', 0.027371999), ('color_moments_hsv_H_mean', 0.022306172), ('color_moments_lab_B_std', 0.019583965), ('color_moments_hsv_H_median', 0.018786725), ('fourier_transform_magnitude_std', 0.013574551), ('color_moments_lab_B_var', 0.013092883), ('lbp_rad1_bins8_4', 0.012090641), ('color_moments_rgb_B_entropy', 0.012067223)]
# INFO:utils.ml:Fitted classifier: XGBClassifier11; Done in 3.150952100753784 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier12
# INFO:utils.ml:Top 10 features for XGBClassifier12: [('color_moments_rgb_B_std', 0.043249257), ('color_moments_rgb_B_var', 0.022652082), ('color_moments_rgb_R_iqr', 0.019901264), ('glcm_energy_dist_1_angle_0', 0.018190898), ('color_moments_hsv_H_mean', 0.017023526), ('color_moments_lab_B_var', 0.012558216), ('color_moments_lab_B_std', 0.012356689), ('fourier_transform_magnitude_std', 0.011916616), ('gradient_magnitude_mean', 0.01148252), ('lbp_rad1_bins8_0', 0.010786608)]
# INFO:utils.ml:Fitted classifier: XGBClassifier12; Done in 8.245008707046509 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier13
# INFO:utils.ml:Top 10 features for XGBClassifier13: [('color_moments_rgb_B_std', 0.04754732), ('color_moments_rgb_R_iqr', 0.028001495), ('color_moments_rgb_B_var', 0.021267066), ('color_moments_hsv_H_mean', 0.016462598), ('fourier_transform_magnitude_std', 0.0161304), ('glcm_energy_dist_1_angle_0', 0.014523392), ('color_moments_lab_B_std', 0.014287418), ('color_moments_hsv_H_median', 0.013116806), ('color_moments_lab_B_var', 0.012552696), ('lbp_rad2_bins16_8', 0.011768857)]
# INFO:utils.ml:Fitted classifier: XGBClassifier13; Done in 5.651540756225586 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier14
# INFO:utils.ml:Top 10 features for XGBClassifier14: [('color_moments_rgb_B_std', 0.04413843), ('color_moments_rgb_R_iqr', 0.026805406), ('color_moments_rgb_B_var', 0.02677154), ('fourier_transform_magnitude_std', 0.016744658), ('glcm_energy_dist_1_angle_0', 0.015531504), ('color_moments_lab_B_var', 0.01487108), ('color_moments_hsv_H_median', 0.014730329), ('color_moments_hsv_H_mean', 0.01402079), ('color_moments_lab_B_std', 0.0119996695), ('lbp_rad1_bins8_4', 0.011179352)]
# INFO:utils.ml:Fitted classifier: XGBClassifier14; Done in 6.614745378494263 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier15
# INFO:utils.ml:Top 10 features for XGBClassifier15: [('color_moments_rgb_B_std', 0.041881178), ('color_moments_rgb_B_var', 0.026042152), ('color_moments_rgb_R_iqr', 0.02593516), ('glcm_energy_dist_1_angle_0', 0.020488864), ('fourier_transform_magnitude_std', 0.015342447), ('color_moments_hsv_H_median', 0.014210803), ('color_moments_lab_B_var', 0.013443627), ('color_moments_hsv_H_mean', 0.01339197), ('color_moments_lab_B_std', 0.012661078), ('lbp_rad2_bins16_8', 0.011800471)]
# INFO:utils.ml:Fitted classifier: XGBClassifier15; Done in 17.243797063827515 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier16
# INFO:utils.ml:Top 10 features for XGBClassifier16: [('color_moments_rgb_B_std', 0.040060952), ('color_moments_rgb_B_var', 0.027484322), ('color_moments_rgb_R_iqr', 0.025305122), ('glcm_energy_dist_1_angle_0', 0.019781528), ('fourier_transform_magnitude_std', 0.015701324), ('color_moments_hsv_H_median', 0.014376181), ('color_moments_lab_B_var', 0.013735056), ('color_moments_hsv_H_mean', 0.013650779), ('color_moments_lab_B_std', 0.012460529), ('lbp_rad2_bins16_8', 0.011898706)]
# INFO:utils.ml:Fitted classifier: XGBClassifier16; Done in 16.970841884613037 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier17
# INFO:utils.ml:Top 10 features for XGBClassifier17: [('color_moments_rgb_B_std', 0.043534495), ('color_moments_rgb_R_iqr', 0.029851176), ('color_moments_rgb_B_var', 0.023808112), ('glcm_energy_dist_1_angle_0', 0.021437319), ('fourier_transform_magnitude_std', 0.015803823), ('color_moments_hsv_H_mean', 0.014410233), ('color_moments_hsv_H_median', 0.014155298), ('color_moments_lab_B_var', 0.013348027), ('color_moments_lab_B_std', 0.012600704), ('lbp_rad2_bins16_8', 0.01222156)]
# INFO:utils.ml:Fitted classifier: XGBClassifier17; Done in 17.228052854537964 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier18
# INFO:utils.ml:Top 10 features for XGBClassifier18: [('color_moments_rgb_B_std', 0.04426688), ('color_moments_rgb_R_iqr', 0.030067293), ('color_moments_rgb_B_var', 0.023743693), ('glcm_energy_dist_1_angle_0', 0.022479823), ('fourier_transform_magnitude_std', 0.015633414), ('color_moments_hsv_H_mean', 0.014603501), ('color_moments_hsv_H_median', 0.014146703), ('color_moments_lab_B_var', 0.013391277), ('color_moments_lab_B_std', 0.012545689), ('lbp_rad2_bins16_8', 0.012166694)]
# INFO:utils.ml:Fitted classifier: XGBClassifier18; Done in 18.675435304641724 seconds
# INFO:utils.ml:Fitting completed in 219.57 seconds.

# %%
pipeline.predict_with_classifiers(VAL_PATH, percent)
# Out:
# INFO:utils.ml:Predicting with classifiers on dataset: C:\Users\gimes\Src\repos\CADx-Project\dataset\multiclass\val
# Processed 5/53 batches.
# Processed 10/53 batches.
# Processed 15/53 batches.
# Processed 20/53 batches.
# Processed 25/53 batches.
# Processed 30/53 batches.
# Processed 35/53 batches.
# Processed 40/53 batches.
# Processed 45/53 batches.
# Processed 50/53 batches.
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier0
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier1
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier2
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier3
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier4
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier5
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier6
# Processed 53/53 batches.
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier7
# INFO:utils.ml:Predictions made with classifier: XGBClassifier8
# INFO:utils.ml:Predictions made with classifier: XGBClassifier9
# INFO:utils.ml:Predictions made with classifier: XGBClassifier10
# INFO:utils.ml:Predictions made with classifier: XGBClassifier11
# INFO:utils.ml:Predictions made with classifier: XGBClassifier12
# INFO:utils.ml:Predictions made with classifier: XGBClassifier13
# INFO:utils.ml:Predictions made with classifier: XGBClassifier14
# INFO:utils.ml:Predictions made with classifier: XGBClassifier15
# INFO:utils.ml:Predictions made with classifier: XGBClassifier16
# INFO:utils.ml:Predictions made with classifier: XGBClassifier17
# INFO:utils.ml:Predictions made with classifier: XGBClassifier18
# {'GT': array([0, 0, 0, ..., 2, 2, 2]),
#  'RandomForestClassifier0': array([0, 0, 2, ..., 1, 2, 0]),
#  'RandomForestClassifier1': array([0, 0, 2, ..., 1, 0, 0]),
#  'RandomForestClassifier2': array([0, 0, 2, ..., 1, 0, 0]),
#  'RandomForestClassifier3': array([0, 0, 2, ..., 1, 2, 0]),
#  'RandomForestClassifier4': array([0, 0, 2, ..., 1, 0, 0]),
#  'RandomForestClassifier5': array([0, 0, 2, ..., 1, 2, 0]),
#  'RandomForestClassifier6': array([0, 0, 2, ..., 1, 0, 0]),
#  'RandomForestClassifier7': array([0, 0, 2, ..., 1, 2, 0]),
#  'XGBClassifier8': array([0, 0, 0, ..., 1, 0, 0], dtype=int64),
#  'XGBClassifier9': array([0, 0, 0, ..., 1, 0, 0], dtype=int64),
#  'XGBClassifier10': array([0, 0, 0, ..., 1, 0, 0], dtype=int64),
#  'XGBClassifier11': array([0, 0, 2, ..., 1, 0, 0], dtype=int64),
#  'XGBClassifier12': array([0, 0, 0, ..., 1, 0, 0], dtype=int64),
#  'XGBClassifier13': array([0, 0, 2, ..., 1, 0, 0], dtype=int64),
#  'XGBClassifier14': array([0, 0, 0, ..., 1, 2, 0], dtype=int64),
#  'XGBClassifier15': array([0, 0, 0, ..., 1, 0, 0], dtype=int64),
#  'XGBClassifier16': array([0, 0, 0, ..., 1, 0, 0], dtype=int64),
#  'XGBClassifier17': array([0, 0, 0, ..., 1, 0, 0], dtype=int64),
#  'XGBClassifier18': array([0, 0, 0, ..., 1, 0, 0], dtype=int64)}

# %%
df_borderline_smote = pd.DataFrame(data=pipeline.calculate_metrics(
    ["accuracy", "precision", "recall", "f1", "kappa"],))
df_borderline_smote = df_borderline_smote.T
df_borderline_smote
# Out:
# INFO:utils.ml:Metrics for classifier GT: {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'kappa': 1.0}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier0: {'accuracy': 0.8220472440944881, 'precision': 0.7137752695767318, 'recall': 0.7172625731697265, 'f1': 0.7147359352044425, 'kappa': 0.6825407359232665}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier1: {'accuracy': 0.8181102362204724, 'precision': 0.6996516381156991, 'recall': 0.6957668116765058, 'f1': 0.6969229160757706, 'kappa': 0.6738477889643886}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier2: {'accuracy': 0.8141732283464567, 'precision': 0.691525440831283, 'recall': 0.6873773887995339, 'f1': 0.6881680768053973, 'kappa': 0.6674374531203536}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier3: {'accuracy': 0.831496062992126, 'precision': 0.7330718431320236, 'recall': 0.7084230980282141, 'f1': 0.7178218421060977, 'kappa': 0.6952633396572525}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier4: {'accuracy': 0.8173228346456692, 'precision': 0.7003847228462309, 'recall': 0.6956305735084946, 'f1': 0.6967865488334154, 'kappa': 0.6729434644193926}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier5: {'accuracy': 0.831496062992126, 'precision': 0.7370472326735137, 'recall': 0.7114775552344317, 'f1': 0.7211850541797301, 'kappa': 0.6954477404548673}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier6: {'accuracy': 0.8102362204724409, 'precision': 0.695796983553821, 'recall': 0.6879736355829392, 'f1': 0.690186156143124, 'kappa': 0.6600702805000489}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier7: {'accuracy': 0.831496062992126, 'precision': 0.7318782675847061, 'recall': 0.6969160770364455, 'f1': 0.708802569816136, 'kappa': 0.6943407260785461}
# INFO:utils.ml:Metrics for classifier XGBClassifier8: {'accuracy': 0.8543307086614174, 'precision': 0.7612844000701179, 'recall': 0.7354316531802224, 'f1': 0.7461408775668606, 'kappa': 0.7358390861460278}
# INFO:utils.ml:Metrics for classifier XGBClassifier9: {'accuracy': 0.8551181102362204, 'precision': 0.7638559463996893, 'recall': 0.7361009972230604, 'f1': 0.7474800965751193, 'kappa': 0.737147587894931}
# INFO:utils.ml:Metrics for classifier XGBClassifier10: {'accuracy': 0.8551181102362204, 'precision': 0.7618432174040105, 'recall': 0.7361009972230604, 'f1': 0.746740755760051, 'kappa': 0.737320143884892}
# INFO:utils.ml:Metrics for classifier XGBClassifier11: {'accuracy': 0.7960629921259843, 'precision': 0.6632536796867793, 'recall': 0.684733410513957, 'f1': 0.6709770380051724, 'kappa': 0.6416837692867445}
# INFO:utils.ml:Metrics for classifier XGBClassifier12: {'accuracy': 0.8519685039370078, 'precision': 0.7515670795805827, 'recall': 0.7224497059347664, 'f1': 0.733812926008048, 'kappa': 0.7311757738435694}
# INFO:utils.ml:Metrics for classifier XGBClassifier13: {'accuracy': 0.841732283464567, 'precision': 0.7274939734984208, 'recall': 0.7151698490440769, 'f1': 0.7202825593287917, 'kappa': 0.7144643648126854}
# INFO:utils.ml:Metrics for classifier XGBClassifier14: {'accuracy': 0.8488188976377953, 'precision': 0.7460792131844763, 'recall': 0.7262366480924008, 'f1': 0.7343707438807437, 'kappa': 0.7265901812864972}
# INFO:utils.ml:Metrics for classifier XGBClassifier15: {'accuracy': 0.8488188976377953, 'precision': 0.7397454801558281, 'recall': 0.7176063823485745, 'f1': 0.7263025764856876, 'kappa': 0.7262181182885039}
# INFO:utils.ml:Metrics for classifier XGBClassifier16: {'accuracy': 0.84251968503937, 'precision': 0.7312575558577792, 'recall': 0.7102633845493062, 'f1': 0.7183550059070506, 'kappa': 0.7150409039710284}
# INFO:utils.ml:Metrics for classifier XGBClassifier17: {'accuracy': 0.8606299212598425, 'precision': 0.7615292058479387, 'recall': 0.729279384531158, 'f1': 0.7412940883521854, 'kappa': 0.7471360306689945}
# INFO:utils.ml:Metrics for classifier XGBClassifier18: {'accuracy': 0.8566929133858268, 'precision': 0.7608462989089748, 'recall': 0.7289871215231855, 'f1': 0.7411884026642631, 'kappa': 0.7399005243850292}
#                          accuracy  precision    recall        f1     kappa
# GT                       1.000000   1.000000  1.000000  1.000000  1.000000
# RandomForestClassifier0  0.822047   0.713775  0.717263  0.714736  0.682541
# RandomForestClassifier1  0.818110   0.699652  0.695767  0.696923  0.673848
# RandomForestClassifier2  0.814173   0.691525  0.687377  0.688168  0.667437
# RandomForestClassifier3  0.831496   0.733072  0.708423  0.717822  0.695263
# RandomForestClassifier4  0.817323   0.700385  0.695631  0.696787  0.672943
# RandomForestClassifier5  0.831496   0.737047  0.711478  0.721185  0.695448
# RandomForestClassifier6  0.810236   0.695797  0.687974  0.690186  0.660070
# RandomForestClassifier7  0.831496   0.731878  0.696916  0.708803  0.694341
# XGBClassifier8           0.854331   0.761284  0.735432  0.746141  0.735839
# XGBClassifier9           0.855118   0.763856  0.736101  0.747480  0.737148
# XGBClassifier10          0.855118   0.761843  0.736101  0.746741  0.737320
# XGBClassifier11          0.796063   0.663254  0.684733  0.670977  0.641684
# XGBClassifier12          0.851969   0.751567  0.722450  0.733813  0.731176
# XGBClassifier13          0.841732   0.727494  0.715170  0.720283  0.714464
# XGBClassifier14          0.848819   0.746079  0.726237  0.734371  0.726590
# XGBClassifier15          0.848819   0.739745  0.717606  0.726303  0.726218
# XGBClassifier16          0.842520   0.731258  0.710263  0.718355  0.715041
# XGBClassifier17          0.860630   0.761529  0.729279  0.741294  0.747136
# XGBClassifier18          0.856693   0.760846  0.728987  0.741188  0.739901

# %%
highest = df_borderline_smote[df_borderline_smote["kappa"] == df_borderline_smote.iloc[1:]["kappa"].max()]
idx = highest.index[0]

confusion_matrix(pipeline.predictions["GT"], pipeline.predictions[idx])
# Out:
# array([[444,  33,  21],
#        [ 55, 612,  11],
#        [ 39,  18,  37]], dtype=int64)

# %% [markdown]
# ___
# # PCA

# %%
from sklearn.decomposition import PCA
from imblearn.over_sampling import BorderlineSMOTE
smote = BorderlineSMOTE(sampling_strategy='auto', random_state=42)

pipeline.feature_matrix, pipeline.labels = smote.fit_resample(
    np.nan_to_num(pipeline.backup_feature_matrix), pipeline.backup_labels)

pca = PCA(n_components=100)

pipeline.feature_matrix = pca.fit_transform(pipeline.feature_matrix, pipeline.labels)

print(pipeline.backup_feature_matrix.shape)
print(pipeline.feature_matrix.shape)

print(pipeline.backup_labels.shape)
print(pipeline.labels.shape)

print(pca.get_feature_names_out())

pipeline.fitted_classifiers = {}
pipeline.fit_classifiers()
# Out:
# INFO:utils.ml:Fitting classifiers...
# INFO:utils.ml:Fitting classifier: RandomForestClassifier0
# (5082, 189)
# (8139, 100)
# (5082,)
# (8139,)
# ['pca0' 'pca1' 'pca2' 'pca3' 'pca4' 'pca5' 'pca6' 'pca7' 'pca8' 'pca9'
#  'pca10' 'pca11' 'pca12' 'pca13' 'pca14' 'pca15' 'pca16' 'pca17' 'pca18'
#  'pca19' 'pca20' 'pca21' 'pca22' 'pca23' 'pca24' 'pca25' 'pca26' 'pca27'
#  'pca28' 'pca29' 'pca30' 'pca31' 'pca32' 'pca33' 'pca34' 'pca35' 'pca36'
#  'pca37' 'pca38' 'pca39' 'pca40' 'pca41' 'pca42' 'pca43' 'pca44' 'pca45'
#  'pca46' 'pca47' 'pca48' 'pca49' 'pca50' 'pca51' 'pca52' 'pca53' 'pca54'
#  'pca55' 'pca56' 'pca57' 'pca58' 'pca59' 'pca60' 'pca61' 'pca62' 'pca63'
#  'pca64' 'pca65' 'pca66' 'pca67' 'pca68' 'pca69' 'pca70' 'pca71' 'pca72'
#  'pca73' 'pca74' 'pca75' 'pca76' 'pca77' 'pca78' 'pca79' 'pca80' 'pca81'
#  'pca82' 'pca83' 'pca84' 'pca85' 'pca86' 'pca87' 'pca88' 'pca89' 'pca90'
#  'pca91' 'pca92' 'pca93' 'pca94' 'pca95' 'pca96' 'pca97' 'pca98' 'pca99']
# INFO:utils.ml:Top 10 features for RandomForestClassifier0: [('gradient_magnitude_std', 0.04805003990598174), ('gradient_direction_mean', 0.04748072250048593), ('color_moments_rgb_R_var', 0.0369658256857828), ('color_moments_rgb_R_median', 0.023947030881908637), ('gradient_direction_std', 0.02159185108527501), ('color_moments_lab_L_skew', 0.016217462474809246), ('color_moments_rgb_R_skew', 0.01618377630503589), ('color_moments_lab_L_iqr', 0.01585156552495953), ('color_moments_rgb_G_entropy', 0.015842973073624), ('color_moments_rgb_G_iqr', 0.015318222602136822)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier0; Done in 7.533749580383301 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier1
# INFO:utils.ml:Top 10 features for RandomForestClassifier1: [('gradient_magnitude_std', 0.04830769444374847), ('gradient_direction_mean', 0.04639291040092788), ('color_moments_rgb_R_var', 0.034583853692341314), ('color_moments_rgb_R_median', 0.021751110801085115), ('gradient_direction_std', 0.019543994937078514), ('color_moments_lab_L_skew', 0.018001485088218225), ('color_moments_lab_L_iqr', 0.017232468157725528), ('color_moments_rgb_G_entropy', 0.0163645725885766), ('color_moments_rgb_G_iqr', 0.015035707016600208), ('color_moments_rgb_R_skew', 0.014804844180461671)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier1; Done in 10.85826301574707 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier2
# INFO:utils.ml:Top 10 features for RandomForestClassifier2: [('gradient_magnitude_std', 0.047595767780770036), ('gradient_direction_mean', 0.04430760125557517), ('color_moments_rgb_R_var', 0.03627210413413081), ('gradient_direction_std', 0.021041017495957742), ('color_moments_rgb_R_median', 0.0193112887511052), ('color_moments_lab_L_iqr', 0.017594222311719754), ('color_moments_lab_L_skew', 0.017244039620162854), ('color_moments_rgb_G_entropy', 0.016807698902628548), ('color_moments_rgb_R_skew', 0.015383790112044859), ('color_moments_rgb_R_kurtosis', 0.015309097620320749)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier2; Done in 7.245771884918213 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier3
# INFO:utils.ml:Top 10 features for RandomForestClassifier3: [('gradient_magnitude_std', 0.04845248735501882), ('gradient_direction_mean', 0.04536996520858546), ('color_moments_rgb_R_var', 0.03545472987993272), ('color_moments_rgb_R_median', 0.021693860586867307), ('gradient_direction_std', 0.020945429890037552), ('color_moments_lab_L_skew', 0.017710779565905506), ('color_moments_rgb_G_entropy', 0.017088014105763286), ('color_moments_rgb_R_skew', 0.01696347631558885), ('color_moments_rgb_R_kurtosis', 0.01518983962453856), ('color_moments_lab_L_iqr', 0.015146094381090153)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier3; Done in 10.978632926940918 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier4
# INFO:utils.ml:Top 10 features for RandomForestClassifier4: [('gradient_magnitude_std', 0.04753358496329351), ('gradient_direction_mean', 0.045674338744424905), ('color_moments_rgb_R_var', 0.03450522809738887), ('gradient_direction_std', 0.022070847460536575), ('color_moments_rgb_R_median', 0.020888699491141343), ('color_moments_lab_L_skew', 0.017781313170057687), ('color_moments_lab_L_iqr', 0.017089528806620093), ('color_moments_rgb_G_entropy', 0.016803153118324265), ('color_moments_rgb_R_skew', 0.015679992418112777), ('color_moments_rgb_G_iqr', 0.01511335145074948)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier4; Done in 10.95686960220337 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier5
# INFO:utils.ml:Top 10 features for RandomForestClassifier5: [('gradient_magnitude_std', 0.049181707884994375), ('gradient_direction_mean', 0.046997750404009234), ('color_moments_rgb_R_var', 0.03388044418399339), ('color_moments_rgb_R_median', 0.02240818384096995), ('gradient_direction_std', 0.021011588350532285), ('color_moments_lab_L_skew', 0.017846208114778602), ('color_moments_rgb_G_entropy', 0.01719178063308323), ('color_moments_rgb_R_skew', 0.016280509104424114), ('color_moments_rgb_G_iqr', 0.015267947258391151), ('color_moments_lab_L_iqr', 0.015173708059365106)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier5; Done in 16.46882700920105 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier6
# INFO:utils.ml:Top 10 features for RandomForestClassifier6: [('gradient_magnitude_std', 0.04910209979180815), ('gradient_direction_mean', 0.04719447387990847), ('color_moments_rgb_R_var', 0.03550821224652277), ('gradient_direction_std', 0.02163942787383258), ('color_moments_rgb_R_median', 0.020714463272457417), ('color_moments_rgb_G_entropy', 0.017074888394530013), ('color_moments_lab_L_iqr', 0.017035113241513824), ('color_moments_lab_L_skew', 0.016830211102598795), ('color_moments_rgb_R_skew', 0.015146433454711054), ('color_moments_rgb_G_iqr', 0.014830549599513743)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier6; Done in 18.16156792640686 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier7
# INFO:utils.ml:Top 10 features for RandomForestClassifier7: [('gradient_magnitude_std', 0.04988982570123611), ('gradient_direction_mean', 0.04831744662628193), ('color_moments_rgb_R_var', 0.0354347849552395), ('color_moments_rgb_R_median', 0.021839939118016863), ('gradient_direction_std', 0.020806761058014985), ('color_moments_lab_L_skew', 0.01723844720948291), ('color_moments_rgb_G_entropy', 0.01711072596034292), ('color_moments_rgb_R_skew', 0.015597633920354343), ('color_moments_lab_L_iqr', 0.015458886525967686), ('color_moments_rgb_G_iqr', 0.014887241800106968)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier7; Done in 36.55072212219238 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier8
# INFO:utils.ml:Top 10 features for XGBClassifier8: [('gradient_magnitude_std', 0.04387195), ('color_moments_rgb_R_var', 0.04353409), ('gradient_direction_mean', 0.040136486), ('color_moments_rgb_G_entropy', 0.028368173), ('color_moments_lab_L_iqr', 0.019979667), ('color_moments_lab_L_skew', 0.018703874), ('color_moments_lab_B_kurtosis', 0.01868977), ('color_moments_rgb_B_mean', 0.016659074), ('color_moments_rgb_B_min', 0.016150624), ('color_moments_rgb_R_std', 0.01580126)]
# INFO:utils.ml:Fitted classifier: XGBClassifier8; Done in 7.842277765274048 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier9
# INFO:utils.ml:Top 10 features for XGBClassifier9: [('color_moments_rgb_R_var', 0.044375744), ('gradient_magnitude_std', 0.043301314), ('gradient_direction_mean', 0.04008958), ('color_moments_rgb_G_entropy', 0.028856738), ('color_moments_lab_L_iqr', 0.020084897), ('color_moments_lab_L_skew', 0.018538002), ('color_moments_lab_B_kurtosis', 0.018533466), ('color_moments_rgb_B_mean', 0.016715175), ('color_moments_rgb_B_min', 0.01595514), ('color_moments_rgb_R_std', 0.015775835)]
# INFO:utils.ml:Fitted classifier: XGBClassifier9; Done in 9.614732027053833 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier10
# INFO:utils.ml:Top 10 features for XGBClassifier10: [('color_moments_rgb_R_var', 0.04457968), ('gradient_magnitude_std', 0.04260935), ('gradient_direction_mean', 0.039951082), ('color_moments_rgb_G_entropy', 0.028560894), ('color_moments_lab_L_iqr', 0.020549426), ('color_moments_lab_L_skew', 0.01874065), ('color_moments_lab_B_kurtosis', 0.018014234), ('color_moments_rgb_B_mean', 0.016614754), ('color_moments_rgb_B_min', 0.01597609), ('color_moments_rgb_R_std', 0.0157401)]
# INFO:utils.ml:Fitted classifier: XGBClassifier10; Done in 10.141828298568726 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier11
# INFO:utils.ml:Top 10 features for XGBClassifier11: [('gradient_magnitude_std', 0.03346093), ('gradient_direction_mean', 0.032883763), ('color_moments_rgb_R_var', 0.030933714), ('color_moments_rgb_G_entropy', 0.026838915), ('gradient_direction_std', 0.022326257), ('color_moments_lab_L_iqr', 0.01741627), ('color_moments_lab_L_skew', 0.017084636), ('color_moments_lab_B_kurtosis', 0.016359245), ('color_moments_rgb_R_median', 0.01601659), ('color_moments_rgb_B_std', 0.01537138)]
# INFO:utils.ml:Fitted classifier: XGBClassifier11; Done in 3.7518715858459473 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier12
# INFO:utils.ml:Top 10 features for XGBClassifier12: [('gradient_magnitude_std', 0.03830064), ('color_moments_rgb_R_var', 0.03429393), ('gradient_direction_mean', 0.03151233), ('color_moments_rgb_G_entropy', 0.021441253), ('gradient_direction_std', 0.018256664), ('color_moments_lab_B_kurtosis', 0.017075362), ('color_moments_lab_L_iqr', 0.016978748), ('color_moments_lab_L_skew', 0.016380837), ('color_moments_rgb_R_median', 0.0156119205), ('color_moments_rgb_B_mean', 0.014992395)]
# INFO:utils.ml:Fitted classifier: XGBClassifier12; Done in 8.749520063400269 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier13
# INFO:utils.ml:Top 10 features for XGBClassifier13: [('gradient_magnitude_std', 0.03898164), ('color_moments_rgb_R_var', 0.03563729), ('gradient_direction_mean', 0.034098398), ('color_moments_rgb_G_entropy', 0.022793612), ('gradient_direction_std', 0.018794874), ('color_moments_lab_L_iqr', 0.017527578), ('color_moments_rgb_R_median', 0.01735421), ('color_moments_lab_L_skew', 0.01708947), ('color_moments_rgb_R_std', 0.014782939), ('color_moments_lab_B_kurtosis', 0.014566014)]
# INFO:utils.ml:Fitted classifier: XGBClassifier13; Done in 6.264945030212402 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier14
# INFO:utils.ml:Top 10 features for XGBClassifier14: [('gradient_magnitude_std', 0.039983448), ('gradient_direction_mean', 0.03716985), ('color_moments_rgb_R_var', 0.03469684), ('color_moments_rgb_G_entropy', 0.02466885), ('color_moments_lab_L_iqr', 0.018347636), ('color_moments_rgb_R_median', 0.017227406), ('color_moments_lab_L_skew', 0.017164167), ('gradient_direction_std', 0.015651982), ('color_moments_rgb_B_mean', 0.015209691), ('lbp_rad1_bins8_1', 0.014735908)]
# INFO:utils.ml:Fitted classifier: XGBClassifier14; Done in 7.027925968170166 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier15
# INFO:utils.ml:Top 10 features for XGBClassifier15: [('gradient_magnitude_std', 0.039398264), ('gradient_direction_mean', 0.03651779), ('color_moments_rgb_R_var', 0.034630746), ('color_moments_rgb_G_entropy', 0.022056714), ('color_moments_lab_L_iqr', 0.017891688), ('color_moments_rgb_R_median', 0.01648563), ('gradient_direction_std', 0.016473645), ('color_moments_lab_L_skew', 0.016027976), ('color_moments_rgb_B_mean', 0.015405839), ('color_moments_lab_B_kurtosis', 0.014784834)]
# INFO:utils.ml:Fitted classifier: XGBClassifier15; Done in 15.15785026550293 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier16
# INFO:utils.ml:Top 10 features for XGBClassifier16: [('gradient_magnitude_std', 0.038810607), ('gradient_direction_mean', 0.03618843), ('color_moments_rgb_R_var', 0.034588374), ('color_moments_rgb_G_entropy', 0.021786729), ('color_moments_lab_L_iqr', 0.017831825), ('gradient_direction_std', 0.016285779), ('color_moments_rgb_R_median', 0.016051944), ('color_moments_lab_L_skew', 0.015920235), ('color_moments_rgb_B_mean', 0.015421193), ('color_moments_lab_B_kurtosis', 0.014446546)]
# INFO:utils.ml:Fitted classifier: XGBClassifier16; Done in 11.882818698883057 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier17
# INFO:utils.ml:Top 10 features for XGBClassifier17: [('gradient_magnitude_std', 0.039232716), ('gradient_direction_mean', 0.036379825), ('color_moments_rgb_R_var', 0.032278884), ('color_moments_rgb_G_entropy', 0.021566208), ('color_moments_lab_L_iqr', 0.017682724), ('gradient_direction_std', 0.01745213), ('color_moments_rgb_R_median', 0.017083226), ('color_moments_lab_L_skew', 0.016900089), ('color_moments_rgb_B_mean', 0.015470261), ('color_moments_lab_B_kurtosis', 0.014642328)]
# INFO:utils.ml:Fitted classifier: XGBClassifier17; Done in 8.028298616409302 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier18
# INFO:utils.ml:Top 10 features for XGBClassifier18: [('gradient_magnitude_std', 0.039419144), ('gradient_direction_mean', 0.036366533), ('color_moments_rgb_R_var', 0.032784402), ('color_moments_rgb_G_entropy', 0.021883173), ('color_moments_lab_L_iqr', 0.017676516), ('color_moments_rgb_R_median', 0.017157024), ('gradient_direction_std', 0.017092424), ('color_moments_lab_L_skew', 0.017017271), ('color_moments_rgb_B_mean', 0.015708195), ('color_moments_lab_B_kurtosis', 0.014865643)]
# INFO:utils.ml:Fitted classifier: XGBClassifier18; Done in 8.218432664871216 seconds
# INFO:utils.ml:Fitting completed in 215.43 seconds.

# %%
# Load and extract features from the new dataset
new_loader = FactoryLoader(path=VAL_PATH, factory=pipeline.loader.get_factory(),
                           percentage=percent, batch_size=pipeline.batch_size)
new_feature_matrix, new_labels = pipeline.feature_strategy.run(new_loader.get_loader())

new_feature_matrix = np.nan_to_num(new_feature_matrix) # Impute nans
new_feature_matrix = pca.transform(new_feature_matrix) # Impute nans

# Store predictions in the class attribute
pipeline.predictions = {"GT": new_labels, }
for clf_name, clf in pipeline.fitted_classifiers.items():

    pipeline.predictions[clf_name] = clf.predict(new_feature_matrix)
    if pipeline.verbose:
        logger.info("Predictions made with classifier: %s", clf_name)
# Out:
# Processed 5/53 batches.
# Processed 10/53 batches.
# Processed 15/53 batches.
# Processed 20/53 batches.
# Processed 25/53 batches.
# Processed 30/53 batches.
# Processed 35/53 batches.
# Processed 40/53 batches.
# Processed 45/53 batches.
# Processed 50/53 batches.
# INFO:utils.utils:Predictions made with classifier: RandomForestClassifier0
# INFO:utils.utils:Predictions made with classifier: RandomForestClassifier1
# INFO:utils.utils:Predictions made with classifier: RandomForestClassifier2
# INFO:utils.utils:Predictions made with classifier: RandomForestClassifier3
# INFO:utils.utils:Predictions made with classifier: RandomForestClassifier4
# INFO:utils.utils:Predictions made with classifier: RandomForestClassifier5
# INFO:utils.utils:Predictions made with classifier: RandomForestClassifier6
# Processed 53/53 batches.
# INFO:utils.utils:Predictions made with classifier: RandomForestClassifier7
# INFO:utils.utils:Predictions made with classifier: XGBClassifier8
# INFO:utils.utils:Predictions made with classifier: XGBClassifier9
# INFO:utils.utils:Predictions made with classifier: XGBClassifier10
# INFO:utils.utils:Predictions made with classifier: XGBClassifier11
# INFO:utils.utils:Predictions made with classifier: XGBClassifier12
# INFO:utils.utils:Predictions made with classifier: XGBClassifier13
# INFO:utils.utils:Predictions made with classifier: XGBClassifier14
# INFO:utils.utils:Predictions made with classifier: XGBClassifier15
# INFO:utils.utils:Predictions made with classifier: XGBClassifier16
# INFO:utils.utils:Predictions made with classifier: XGBClassifier17
# INFO:utils.utils:Predictions made with classifier: XGBClassifier18

# %%
df_pca = pd.DataFrame(data=pipeline.calculate_metrics(avg="macro"))
df_pca = df_pca.T
df_pca
# Out:
# INFO:utils.ml:Metrics for classifier GT: {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'kappa': 1.0}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier0: {'accuracy': 0.8062992125984252, 'precision': 0.6991418265419376, 'recall': 0.6711651728359493, 'f1': 0.6815163888488575, 'kappa': 0.6477599689723907}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier1: {'accuracy': 0.805511811023622, 'precision': 0.6791627143611704, 'recall': 0.6444273296033566, 'f1': 0.6540708546707087, 'kappa': 0.6441487430801343}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier2: {'accuracy': 0.8031496062992126, 'precision': 0.6917125468551425, 'recall': 0.6510495632186689, 'f1': 0.663419448385859, 'kappa': 0.639550249533402}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier3: {'accuracy': 0.8062992125984252, 'precision': 0.7068384411409466, 'recall': 0.6571368005127899, 'f1': 0.671467999848446, 'kappa': 0.6454092287576951}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier4: {'accuracy': 0.8133858267716535, 'precision': 0.7011962396577781, 'recall': 0.6588625259841853, 'f1': 0.671379021859195, 'kappa': 0.658346386978138}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier5: {'accuracy': 0.8173228346456692, 'precision': 0.7229497306816896, 'recall': 0.6674296508194328, 'f1': 0.6836436666820247, 'kappa': 0.6648878334174981}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier6: {'accuracy': 0.8118110236220473, 'precision': 0.6992437014516896, 'recall': 0.6550024865671182, 'f1': 0.667456401515635, 'kappa': 0.655217458471157}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier7: {'accuracy': 0.815748031496063, 'precision': 0.7192700238550588, 'recall': 0.6687900160234234, 'f1': 0.6845181612319121, 'kappa': 0.6621879688991952}
# INFO:utils.ml:Metrics for classifier XGBClassifier8: {'accuracy': 0.8519685039370078, 'precision': 0.7520339450982708, 'recall': 0.718862142853722, 'f1': 0.7318104155658655, 'kappa': 0.730164685885294}
# INFO:utils.ml:Metrics for classifier XGBClassifier9: {'accuracy': 0.8519685039370078, 'precision': 0.7519256427351312, 'recall': 0.718862142853722, 'f1': 0.7317492036384134, 'kappa': 0.7302195666519022}
# INFO:utils.ml:Metrics for classifier XGBClassifier10: {'accuracy': 0.852755905511811, 'precision': 0.7508333902200377, 'recall': 0.7224082421445023, 'f1': 0.7338870669015612, 'kappa': 0.7320759740435556}
# INFO:utils.ml:Metrics for classifier XGBClassifier11: {'accuracy': 0.7992125984251969, 'precision': 0.668643975471999, 'recall': 0.6901098399749755, 'f1': 0.6766176196153486, 'kappa': 0.6462990550499998}
# INFO:utils.ml:Metrics for classifier XGBClassifier12: {'accuracy': 0.8480314960629921, 'precision': 0.7460724035716657, 'recall': 0.7043638055643147, 'f1': 0.7190437435219219, 'kappa': 0.7221000263036162}
# INFO:utils.ml:Metrics for classifier XGBClassifier13: {'accuracy': 0.84251968503937, 'precision': 0.7331677134542826, 'recall': 0.7093748747579283, 'f1': 0.7188692915460327, 'kappa': 0.7141030489671691}
# INFO:utils.ml:Metrics for classifier XGBClassifier14: {'accuracy': 0.8433070866141732, 'precision': 0.7242994626104031, 'recall': 0.7041130063466065, 'f1': 0.7121781236228686, 'kappa': 0.7156618318789968}
# INFO:utils.ml:Metrics for classifier XGBClassifier15: {'accuracy': 0.8448818897637795, 'precision': 0.732519088065461, 'recall': 0.7079730457636736, 'f1': 0.7176609693902369, 'kappa': 0.7181491278270704}
# INFO:utils.ml:Metrics for classifier XGBClassifier16: {'accuracy': 0.84251968503937, 'precision': 0.7344012612949782, 'recall': 0.7064981195099862, 'f1': 0.717242274129072, 'kappa': 0.7136544011544012}
# INFO:utils.ml:Metrics for classifier XGBClassifier17: {'accuracy': 0.8448818897637795, 'precision': 0.732145593435916, 'recall': 0.7049185885574558, 'f1': 0.7154841521782518, 'kappa': 0.7176057609824371}
# INFO:utils.ml:Metrics for classifier XGBClassifier18: {'accuracy': 0.8448818897637795, 'precision': 0.7363075000161904, 'recall': 0.7076176418471225, 'f1': 0.7188431830099392, 'kappa': 0.7174909665763325}
#                          accuracy  precision    recall        f1     kappa
# GT                       1.000000   1.000000  1.000000  1.000000  1.000000
# RandomForestClassifier0  0.806299   0.699142  0.671165  0.681516  0.647760
# RandomForestClassifier1  0.805512   0.679163  0.644427  0.654071  0.644149
# RandomForestClassifier2  0.803150   0.691713  0.651050  0.663419  0.639550
# RandomForestClassifier3  0.806299   0.706838  0.657137  0.671468  0.645409
# RandomForestClassifier4  0.813386   0.701196  0.658863  0.671379  0.658346
# RandomForestClassifier5  0.817323   0.722950  0.667430  0.683644  0.664888
# RandomForestClassifier6  0.811811   0.699244  0.655002  0.667456  0.655217
# RandomForestClassifier7  0.815748   0.719270  0.668790  0.684518  0.662188
# XGBClassifier8           0.851969   0.752034  0.718862  0.731810  0.730165
# XGBClassifier9           0.851969   0.751926  0.718862  0.731749  0.730220
# XGBClassifier10          0.852756   0.750833  0.722408  0.733887  0.732076
# XGBClassifier11          0.799213   0.668644  0.690110  0.676618  0.646299
# XGBClassifier12          0.848031   0.746072  0.704364  0.719044  0.722100
# XGBClassifier13          0.842520   0.733168  0.709375  0.718869  0.714103
# XGBClassifier14          0.843307   0.724299  0.704113  0.712178  0.715662
# XGBClassifier15          0.844882   0.732519  0.707973  0.717661  0.718149
# XGBClassifier16          0.842520   0.734401  0.706498  0.717242  0.713654
# XGBClassifier17          0.844882   0.732146  0.704919  0.715484  0.717606
# XGBClassifier18          0.844882   0.736308  0.707618  0.718843  0.717491

# %%
highest = df_pca[df_pca["kappa"] == df_pca.iloc[1:]["kappa"].max()]
idx = highest.index[0]

confusion_matrix(pipeline.predictions["GT"], pipeline.predictions[idx])
# Out:
# array([[433,  44,  21],
#        [ 51, 613,  14],
#        [ 30,  27,  37]], dtype=int64)
