# %%
import numpy as np
from sklearn.metrics import confusion_matrix, recall_score, cohen_kappa_score

from utils.loader import FactoryLoader
from utils.ml import MLPipeline
from utils.preprocessing import PreprocessingFactory
from utils.feature_extraction import *
from utils.utils import *

VAL_PATH = r"C:\Users\gimes\Src\repos\CADx-Project\dataset\multiclass\val"
TRAIN_PATH = r"C:\Users\gimes\Src\repos\CADx-Project\dataset\multiclass\train"
# Out:
# INFO:numexpr.utils:Note: NumExpr detected 16 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.

# %%
percent = 100
random = False
batch_size = 24
th = 0.01

# Initialize the FactoryLoader
factory = PreprocessingFactory()
factory.pad2square(fill=np.nan)
factory.resize((150,150))
factory.normalize2float()

factory_loader = FactoryLoader(path=VAL_PATH, batch_size=batch_size, factory=factory, percentage=percent, shuffle=random)

# Create the feature extraction pipeline strategy and add desired features
strategy = FeatureExtractionStrategy()

strategy.add_extractor(GradientExtractor(threshold=th)) # Add gradient feature

strategy.add_extractor(ColorMomentsExtractor("rgb", threshold=th))   # Add color moments feature
strategy.add_extractor(ColorMomentsExtractor("lab", threshold=th))   # Add color moments feature
strategy.add_extractor(ColorMomentsExtractor("hsv", threshold=th))   # Add color moments feature

strategy.add_extractor(LBPExtractor(radius=1, n_points=8))
strategy.add_extractor(LBPExtractor(radius=2, n_points=16))
strategy.add_extractor(LBPExtractor(radius=3, n_points=24))
strategy.add_extractor(LBPExtractor(radius=4, n_points=32))

strategy.add_extractor(FourierTransformExtractor())

strategy.add_extractor(GLCMExtractor(properties=['contrast', 'dissimilarity', 'homogeneity', 'energy', 'correlation',]))

pipeline = MLPipeline(dataset_path=TRAIN_PATH, preprocessing_factory=factory, feature_strategy=strategy, classifiers=[], percentage=percent, verbose=True, shuffle=random, batch_size=batch_size)
# Out:
# INFO:utils.ml:MLPipeline initialized with dataset path: C:\Users\gimes\Src\repos\CADx-Project\dataset\multiclass\train
# INFO:utils.ml:Preprocessing steps

# %%
pipeline.feature_matrix = None
pipeline.run_feature_extraction()
# Out:
# INFO:utils.ml:Running feature extraction...
# Processed 5/212 batches.
# Processed 10/212 batches.
# Processed 15/212 batches.
# Processed 20/212 batches.
# Processed 25/212 batches.
# Processed 30/212 batches.
# Processed 35/212 batches.
# Processed 40/212 batches.
# Processed 45/212 batches.
# Processed 50/212 batches.
# Processed 55/212 batches.
# Processed 60/212 batches.
# Processed 65/212 batches.
# Processed 70/212 batches.
# Processed 75/212 batches.
# Processed 80/212 batches.
# Processed 85/212 batches.
# Processed 90/212 batches.
# Processed 95/212 batches.
# Processed 100/212 batches.
# Processed 105/212 batches.
# Processed 110/212 batches.
# Processed 115/212 batches.
# Processed 120/212 batches.
# Processed 125/212 batches.
# Processed 130/212 batches.
# Processed 135/212 batches.
# Processed 140/212 batches.
# Processed 145/212 batches.
# Processed 150/212 batches.
# Processed 155/212 batches.
# Processed 160/212 batches.
# Processed 165/212 batches.
# Processed 170/212 batches.
# Processed 175/212 batches.
# Processed 180/212 batches.
# Processed 185/212 batches.
# Processed 190/212 batches.
# Processed 195/212 batches.
# Processed 200/212 batches.
# Processed 205/212 batches.
# Processed 210/212 batches.
# INFO:utils.ml:Feature extraction completed. Extracted 5082 features.
# Processed 212/212 batches.

# %%
from xgboost import XGBClassifier
from sklearn.ensemble import RandomForestClassifier

rf1 = RandomForestClassifier(n_estimators=100)
rf2 = RandomForestClassifier(n_estimators=150)
# Random Forest with Out-of-Bag Error (OOB)
rf3 = RandomForestClassifier(n_estimators=100, oob_score=True, random_state=42)
# Random Forest with Bootstrap Disabled
rf4 = RandomForestClassifier(n_estimators=100, bootstrap=False, random_state=42)
# Random Forest with Out-of-Bag Error (OOB)
rf5 = RandomForestClassifier(n_estimators=150, oob_score=True, random_state=42)
# Random Forest with Bootstrap Disabled
rf6 = RandomForestClassifier(n_estimators=150, bootstrap=False, random_state=42)
# Random Forest with Out-of-Bag Error (OOB)
rf7 = RandomForestClassifier(n_estimators=200, oob_score=True, random_state=42)
# Random Forest with Bootstrap Disabled
rf8 = RandomForestClassifier(n_estimators=200, bootstrap=False, random_state=42)


xgb1 = XGBClassifier(n_estimators=350)
xgb2 = XGBClassifier(n_estimators=450)
xgb3 = XGBClassifier(n_estimators=550)
xgb4 = XGBClassifier(learning_rate=0.05, n_estimators=400, max_depth=3, min_child_weight=4, subsample=0.8, colsample_bytree=0.8)
xgb5 = XGBClassifier(learning_rate=0.1, n_estimators=400, max_depth=7, min_child_weight=3, subsample=0.7, colsample_bytree=0.7) # 2ND
xgb6 = XGBClassifier(learning_rate=0.1, n_estimators=400, max_depth=5, min_child_weight=5, gamma=0.2, subsample=0.8, colsample_bytree=0.8) # THIS
xgb7 = XGBClassifier(learning_rate=0.1, n_estimators=400, max_depth=5, min_child_weight=1, subsample=0.8, colsample_bytree=0.8, reg_alpha=0.1, reg_lambda=0.1)
xgb8 = XGBClassifier(learning_rate=0.05, n_estimators=500, max_depth=7, min_child_weight=1, subsample=0.8, colsample_bytree=0.8)
xgb9 = XGBClassifier(learning_rate=0.05, n_estimators=400, max_depth=7, min_child_weight=1, subsample=0.8, colsample_bytree=0.8)
xgb10 = XGBClassifier(learning_rate=0.1, n_estimators=400, max_depth=7, min_child_weight=1, subsample=0.8, colsample_bytree=0.8)
xgb11 = XGBClassifier(learning_rate=0.1, n_estimators=500, max_depth=7, min_child_weight=1, subsample=0.8, colsample_bytree=0.8)


pipeline.classifiers = [rf1, rf2, rf3, rf4, rf5, rf6, rf7, rf8,
                        # svm1, svm2, svm3, svm6, svm7, svm8,
                        xgb1, xgb2, xgb3, xgb4, xgb5, xgb6, xgb7, xgb8, xgb9, xgb10, xgb11]
pipeline.fitted_classifiers = {}

# %%
pipeline.fit_classifiers()
# Out:
# INFO:utils.ml:Fitting classifiers...
# INFO:utils.ml:Fitting classifier: RandomForestClassifier0
# INFO:utils.ml:Top 10 features for RandomForestClassifier0: [('color_moments_lab_B_var', 0.03989228441192286), ('color_moments_lab_B_std', 0.03892579031123583), ('color_moments_rgb_B_var', 0.020948314154270054), ('color_moments_rgb_B_std', 0.017645031661127276), ('color_moments_rgb_B_iqr', 0.017254162127920053), ('color_moments_rgb_B_kurtosis', 0.016971137053938327), ('color_moments_lab_L_iqr', 0.01682056399822013), ('color_moments_rgb_R_iqr', 0.015114091985386706), ('color_moments_rgb_G_var', 0.011442033459388337), ('color_moments_rgb_R_kurtosis', 0.011242740105242921)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier0; Done in 4.296960353851318 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier1
# INFO:utils.ml:Top 10 features for RandomForestClassifier1: [('color_moments_lab_B_var', 0.035240260679251206), ('color_moments_lab_B_std', 0.031351018404342755), ('color_moments_rgb_B_std', 0.0274872253724826), ('color_moments_rgb_B_var', 0.02560082417269967), ('color_moments_rgb_R_iqr', 0.019280438597945676), ('color_moments_lab_L_iqr', 0.016540176219118304), ('color_moments_rgb_B_iqr', 0.015258077546602208), ('color_moments_rgb_B_kurtosis', 0.013429662855146544), ('color_moments_rgb_R_kurtosis', 0.012184807792232423), ('color_moments_lab_B_iqr', 0.01214800859610007)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier1; Done in 6.476150035858154 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier2
# INFO:utils.ml:Top 10 features for RandomForestClassifier2: [('color_moments_lab_B_std', 0.042639072942335314), ('color_moments_lab_B_var', 0.030741331200755107), ('color_moments_rgb_B_std', 0.02743150372925278), ('color_moments_rgb_B_var', 0.0215541680931319), ('color_moments_rgb_B_iqr', 0.02134721647945711), ('color_moments_lab_L_iqr', 0.018281669523599133), ('color_moments_rgb_R_kurtosis', 0.013903238955128112), ('color_moments_rgb_R_skew', 0.011903103667007375), ('lbp_rad1_bins8_4', 0.011698764462263376), ('color_moments_lab_B_iqr', 0.011048112119126773)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier2; Done in 4.589862585067749 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier3
# INFO:utils.ml:Top 10 features for RandomForestClassifier3: [('color_moments_lab_B_std', 0.04215533160979808), ('color_moments_lab_B_var', 0.03347850302219868), ('color_moments_rgb_B_std', 0.029167092728855218), ('color_moments_rgb_B_var', 0.02265269227054647), ('color_moments_rgb_B_iqr', 0.018096612816907165), ('color_moments_lab_L_iqr', 0.017445550342817362), ('color_moments_rgb_R_skew', 0.012884372984446484), ('color_moments_rgb_R_kurtosis', 0.012607830161659504), ('color_moments_lab_B_iqr', 0.01225729358415847), ('color_moments_rgb_G_std', 0.012065032490516867)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier3; Done in 7.191778898239136 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier4
# INFO:utils.ml:Top 10 features for RandomForestClassifier4: [('color_moments_lab_B_std', 0.04335635032252861), ('color_moments_lab_B_var', 0.029864364592545562), ('color_moments_rgb_B_std', 0.024652664889021444), ('color_moments_rgb_B_var', 0.022586948392925372), ('color_moments_lab_L_iqr', 0.019425877554617374), ('color_moments_rgb_B_iqr', 0.018779667737783824), ('color_moments_rgb_R_skew', 0.0129235893476905), ('color_moments_rgb_R_kurtosis', 0.012691056808686468), ('lbp_rad1_bins8_4', 0.012546203313784903), ('color_moments_rgb_B_kurtosis', 0.011872090620845524)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier4; Done in 6.954869031906128 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier5
# INFO:utils.ml:Top 10 features for RandomForestClassifier5: [('color_moments_lab_B_std', 0.04292541927851917), ('color_moments_lab_B_var', 0.03253355474377454), ('color_moments_rgb_B_std', 0.026255685829604514), ('color_moments_rgb_B_var', 0.023120347299348632), ('color_moments_lab_L_iqr', 0.01810146174226199), ('color_moments_rgb_B_iqr', 0.016698958605887913), ('color_moments_rgb_R_skew', 0.012542635864433816), ('color_moments_rgb_R_kurtosis', 0.012289820343170414), ('color_moments_lab_B_iqr', 0.012205230921354627), ('lbp_rad1_bins8_4', 0.012015253242578511)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier5; Done in 9.654305458068848 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier6
# INFO:utils.ml:Top 10 features for RandomForestClassifier6: [('color_moments_lab_B_std', 0.043239697502764345), ('color_moments_lab_B_var', 0.028893407848556558), ('color_moments_rgb_B_std', 0.02349785379762621), ('color_moments_rgb_B_var', 0.02293124896716027), ('color_moments_rgb_B_iqr', 0.019924046047177513), ('color_moments_lab_L_iqr', 0.01983326263112636), ('color_moments_rgb_R_kurtosis', 0.014817387598469536), ('color_moments_rgb_R_iqr', 0.013778096433999978), ('lbp_rad1_bins8_4', 0.012811231441523683), ('color_moments_rgb_B_kurtosis', 0.011876760778885697)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier6; Done in 9.16592812538147 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier7
# INFO:utils.ml:Top 10 features for RandomForestClassifier7: [('color_moments_lab_B_std', 0.041818895871322335), ('color_moments_lab_B_var', 0.03191911639606706), ('color_moments_rgb_B_std', 0.02403706136621762), ('color_moments_rgb_B_var', 0.021944877399927898), ('color_moments_lab_L_iqr', 0.019762575619565074), ('color_moments_rgb_B_iqr', 0.0183352318855497), ('color_moments_rgb_R_kurtosis', 0.014627062422960871), ('color_moments_rgb_R_iqr', 0.014256781246211808), ('color_moments_rgb_R_skew', 0.011867376685696828), ('color_moments_rgb_B_kurtosis', 0.011789619565626536)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier7; Done in 12.868103981018066 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier8
# INFO:utils.ml:Top 10 features for XGBClassifier8: [('color_moments_hsv_H_min', 0.04749174), ('color_moments_lab_B_std', 0.044639267), ('color_moments_rgb_B_std', 0.028966255), ('lbp_rad1_bins8_4', 0.021214975), ('color_moments_rgb_R_iqr', 0.02093413), ('color_moments_rgb_R_kurtosis', 0.01780471), ('lbp_rad4_bins32_32', 0.014596767), ('color_moments_rgb_B_iqr', 0.014435527), ('lbp_rad1_bins8_8', 0.014361513), ('lbp_rad3_bins24_12', 0.013288922)]
# INFO:utils.ml:Fitted classifier: XGBClassifier8; Done in 5.268554925918579 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier9
# INFO:utils.ml:Top 10 features for XGBClassifier9: [('color_moments_hsv_H_min', 0.05107662), ('color_moments_lab_B_std', 0.04416985), ('color_moments_rgb_B_std', 0.028267205), ('lbp_rad1_bins8_4', 0.021671582), ('color_moments_rgb_R_iqr', 0.021330554), ('color_moments_rgb_R_kurtosis', 0.017264869), ('lbp_rad4_bins32_32', 0.015131693), ('color_moments_rgb_B_iqr', 0.014585728), ('lbp_rad1_bins8_8', 0.014211362), ('lbp_rad3_bins24_12', 0.013301392)]
# INFO:utils.ml:Fitted classifier: XGBClassifier9; Done in 6.25309419631958 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier10
# INFO:utils.ml:Top 10 features for XGBClassifier10: [('color_moments_hsv_H_min', 0.054067444), ('color_moments_lab_B_std', 0.04415432), ('color_moments_rgb_B_std', 0.027385717), ('lbp_rad1_bins8_4', 0.02223051), ('color_moments_rgb_R_iqr', 0.021451473), ('color_moments_rgb_R_kurtosis', 0.016754067), ('lbp_rad1_bins8_8', 0.014465601), ('color_moments_rgb_B_iqr', 0.014455471), ('lbp_rad4_bins32_32', 0.013708058), ('lbp_rad3_bins24_12', 0.012674268)]
# INFO:utils.ml:Fitted classifier: XGBClassifier10; Done in 7.076256036758423 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier11
# INFO:utils.ml:Top 10 features for XGBClassifier11: [('color_moments_lab_B_var', 0.039827842), ('color_moments_rgb_B_iqr', 0.039495356), ('color_moments_lab_B_std', 0.03690706), ('color_moments_rgb_R_kurtosis', 0.024226615), ('color_moments_rgb_B_std', 0.015316519), ('color_moments_rgb_B_var', 0.014950044), ('lbp_rad1_bins8_4', 0.014696026), ('lbp_rad1_bins8_8', 0.013774706), ('color_moments_rgb_R_iqr', 0.013117307), ('lbp_rad3_bins24_12', 0.010854302)]
# INFO:utils.ml:Fitted classifier: XGBClassifier11; Done in 2.705897092819214 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier12
# INFO:utils.ml:Top 10 features for XGBClassifier12: [('color_moments_lab_B_var', 0.035356693), ('color_moments_rgb_B_iqr', 0.02866638), ('color_moments_lab_B_std', 0.026834585), ('color_moments_rgb_B_std', 0.01942716), ('lbp_rad1_bins8_4', 0.017883878), ('color_moments_hsv_H_min', 0.014921725), ('color_moments_rgb_B_var', 0.012820102), ('color_moments_rgb_R_kurtosis', 0.011259086), ('lbp_rad1_bins8_8', 0.01020015), ('lbp_rad4_bins32_32', 0.009658817)]
# INFO:utils.ml:Fitted classifier: XGBClassifier12; Done in 6.7175452709198 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier13
# INFO:utils.ml:Top 10 features for XGBClassifier13: [('color_moments_lab_B_var', 0.032788396), ('color_moments_lab_B_std', 0.029253528), ('color_moments_rgb_B_iqr', 0.028929006), ('color_moments_rgb_B_var', 0.027862975), ('color_moments_rgb_B_std', 0.019305201), ('lbp_rad1_bins8_4', 0.018252237), ('lbp_rad1_bins8_8', 0.01615375), ('color_moments_rgb_R_kurtosis', 0.01492978), ('lbp_rad3_bins24_12', 0.009484968), ('color_moments_rgb_R_iqr', 0.009341047)]
# INFO:utils.ml:Fitted classifier: XGBClassifier13; Done in 4.535857915878296 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier14
# INFO:utils.ml:Top 10 features for XGBClassifier14: [('color_moments_lab_B_var', 0.036193233), ('color_moments_lab_B_std', 0.03091624), ('color_moments_rgb_B_iqr', 0.02603818), ('color_moments_rgb_B_std', 0.022363111), ('color_moments_rgb_B_var', 0.020299619), ('lbp_rad1_bins8_4', 0.017988853), ('color_moments_rgb_R_kurtosis', 0.015837025), ('lbp_rad1_bins8_8', 0.013758577), ('lbp_rad3_bins24_12', 0.011645762), ('color_moments_rgb_R_iqr', 0.010370849)]
# INFO:utils.ml:Fitted classifier: XGBClassifier14; Done in 5.315528869628906 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier15
# INFO:utils.ml:Top 10 features for XGBClassifier15: [('color_moments_lab_B_var', 0.03525749), ('color_moments_lab_B_std', 0.03236504), ('color_moments_rgb_B_iqr', 0.02453572), ('color_moments_rgb_B_var', 0.022493575), ('color_moments_rgb_B_std', 0.017258162), ('lbp_rad1_bins8_4', 0.016353434), ('color_moments_rgb_R_kurtosis', 0.013478764), ('lbp_rad2_bins16_8', 0.010551478), ('color_moments_lab_L_iqr', 0.010445453), ('lbp_rad3_bins24_12', 0.010322528)]
# INFO:utils.ml:Fitted classifier: XGBClassifier15; Done in 11.585425853729248 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier16
# INFO:utils.ml:Top 10 features for XGBClassifier16: [('color_moments_lab_B_var', 0.036657978), ('color_moments_lab_B_std', 0.03217316), ('color_moments_rgb_B_iqr', 0.023209374), ('color_moments_rgb_B_var', 0.022099128), ('color_moments_rgb_B_std', 0.016665744), ('lbp_rad1_bins8_4', 0.015985478), ('color_moments_rgb_R_kurtosis', 0.013781507), ('color_moments_lab_L_iqr', 0.01051053), ('lbp_rad3_bins24_12', 0.010313935), ('lbp_rad2_bins16_8', 0.0102884)]
# INFO:utils.ml:Fitted classifier: XGBClassifier16; Done in 9.758979558944702 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier17
# INFO:utils.ml:Top 10 features for XGBClassifier17: [('color_moments_lab_B_var', 0.036345676), ('color_moments_lab_B_std', 0.02933607), ('color_moments_rgb_B_var', 0.02849925), ('color_moments_rgb_B_iqr', 0.028207947), ('color_moments_rgb_B_std', 0.018669808), ('lbp_rad1_bins8_4', 0.01715414), ('color_moments_rgb_R_kurtosis', 0.01387443), ('lbp_rad1_bins8_8', 0.011429618), ('lbp_rad3_bins24_12', 0.010528435), ('lbp_rad4_bins32_32', 0.009720396)]
# INFO:utils.ml:Fitted classifier: XGBClassifier17; Done in 8.04426383972168 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier18
# INFO:utils.ml:Top 10 features for XGBClassifier18: [('color_moments_lab_B_var', 0.036014825), ('color_moments_lab_B_std', 0.029643606), ('color_moments_rgb_B_var', 0.028985677), ('color_moments_rgb_B_iqr', 0.028163066), ('color_moments_rgb_B_std', 0.018570872), ('lbp_rad1_bins8_4', 0.017309748), ('color_moments_rgb_R_kurtosis', 0.0135980025), ('lbp_rad1_bins8_8', 0.011869487), ('lbp_rad3_bins24_12', 0.010508393), ('lbp_rad4_bins32_32', 0.009917113)]
# INFO:utils.ml:Fitted classifier: XGBClassifier18; Done in 9.243042707443237 seconds
# INFO:utils.ml:Fitting completed in 137.71 seconds.

# %%
pipeline.predict_with_classifiers(VAL_PATH, percent)
# Out:
# INFO:utils.ml:Predicting with classifiers on dataset: C:\Users\gimes\Src\repos\CADx-Project\dataset\multiclass\val
# Processed 5/53 batches.
# Processed 10/53 batches.
# Processed 15/53 batches.
# Processed 20/53 batches.
# Processed 25/53 batches.
# Processed 30/53 batches.
# Processed 35/53 batches.
# Processed 40/53 batches.
# Processed 45/53 batches.
# Processed 50/53 batches.
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier0
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier1
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier2
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier3
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier4
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier5
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier6
# Processed 53/53 batches.
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier7
# INFO:utils.ml:Predictions made with classifier: XGBClassifier8
# INFO:utils.ml:Predictions made with classifier: XGBClassifier9
# INFO:utils.ml:Predictions made with classifier: XGBClassifier10
# INFO:utils.ml:Predictions made with classifier: XGBClassifier11
# INFO:utils.ml:Predictions made with classifier: XGBClassifier12
# INFO:utils.ml:Predictions made with classifier: XGBClassifier13
# INFO:utils.ml:Predictions made with classifier: XGBClassifier14
# INFO:utils.ml:Predictions made with classifier: XGBClassifier15
# INFO:utils.ml:Predictions made with classifier: XGBClassifier16
# INFO:utils.ml:Predictions made with classifier: XGBClassifier17
# INFO:utils.ml:Predictions made with classifier: XGBClassifier18
# {'GT': array([0, 0, 0, ..., 2, 2, 2]),
#  'RandomForestClassifier0': array([0, 0, 0, ..., 1, 0, 0]),
#  'RandomForestClassifier1': array([0, 0, 1, ..., 1, 0, 0]),
#  'RandomForestClassifier2': array([0, 0, 0, ..., 1, 0, 0]),
#  'RandomForestClassifier3': array([0, 0, 1, ..., 1, 0, 0]),
#  'RandomForestClassifier4': array([0, 0, 0, ..., 1, 0, 0]),
#  'RandomForestClassifier5': array([0, 0, 0, ..., 1, 0, 0]),
#  'RandomForestClassifier6': array([0, 0, 1, ..., 1, 0, 0]),
#  'RandomForestClassifier7': array([0, 0, 1, ..., 1, 0, 0]),
#  'XGBClassifier8': array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#  'XGBClassifier9': array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#  'XGBClassifier10': array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#  'XGBClassifier11': array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#  'XGBClassifier12': array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#  'XGBClassifier13': array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#  'XGBClassifier14': array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#  'XGBClassifier15': array([0, 0, 0, ..., 1, 0, 0], dtype=int64),
#  'XGBClassifier16': array([0, 0, 0, ..., 1, 0, 0], dtype=int64),
#  'XGBClassifier17': array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#  'XGBClassifier18': array([0, 0, 0, ..., 0, 0, 0], dtype=int64)}

# %%
import pandas as pd

df = pd.DataFrame(data=pipeline.calculate_metrics())
df = df.T
df
# Out:
# INFO:utils.ml:Metrics for classifier GT: {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'kappa': 1.0}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier0: {'accuracy': 0.8322834645669291, 'precision': 0.8838361179405272, 'recall': 0.6198023752576363, 'f1': 0.622506054356038, 'kappa': 0.6832034964609108}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier1: {'accuracy': 0.831496062992126, 'precision': 0.8469070356231693, 'recall': 0.6187776272982471, 'f1': 0.6215956543293997, 'kappa': 0.6814640138018978}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier2: {'accuracy': 0.8267716535433071, 'precision': 0.8801137405980555, 'recall': 0.6136618273760327, 'f1': 0.6131270380972068, 'kappa': 0.6733264116882267}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier3: {'accuracy': 0.8464566929133859, 'precision': 0.856696112855956, 'recall': 0.6539761002208798, 'f1': 0.6734580986237019, 'kappa': 0.7116432550254299}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier4: {'accuracy': 0.8236220472440945, 'precision': 0.8781034061028558, 'recall': 0.6115175570795074, 'f1': 0.611052232653071, 'kappa': 0.6673868919007399}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier5: {'accuracy': 0.852755905511811, 'precision': 0.8791064280780932, 'recall': 0.662207607811526, 'f1': 0.6836458239397496, 'kappa': 0.7237627539744944}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier6: {'accuracy': 0.8220472440944881, 'precision': 0.8770999974444814, 'recall': 0.6098234650772801, 'f1': 0.6097972619954967, 'kappa': 0.6639220259757291}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier7: {'accuracy': 0.8519685039370078, 'precision': 0.8794320910988985, 'recall': 0.6644150190166301, 'f1': 0.6876894558801888, 'kappa': 0.7223578880779946}
# INFO:utils.ml:Metrics for classifier XGBClassifier8: {'accuracy': 0.8708661417322835, 'precision': 0.8510676272300944, 'recall': 0.7065477752344972, 'f1': 0.7356450957984318, 'kappa': 0.7604798682570276}
# INFO:utils.ml:Metrics for classifier XGBClassifier9: {'accuracy': 0.8740157480314961, 'precision': 0.8531887476247757, 'recall': 0.7088697474892981, 'f1': 0.737843011482683, 'kappa': 0.7663701836845446}
# INFO:utils.ml:Metrics for classifier XGBClassifier10: {'accuracy': 0.8724409448818897, 'precision': 0.8521000396982931, 'recall': 0.7078864633201732, 'f1': 0.7367634609384925, 'kappa': 0.7635476812180501}
# INFO:utils.ml:Metrics for classifier XGBClassifier11: {'accuracy': 0.8259842519685039, 'precision': 0.8094701804942513, 'recall': 0.6269873317408213, 'f1': 0.6343894810005832, 'kappa': 0.6746971474137571}
# INFO:utils.ml:Metrics for classifier XGBClassifier12: {'accuracy': 0.8669291338582678, 'precision': 0.8512779654535024, 'recall': 0.6940376834016541, 'f1': 0.7216850953514097, 'kappa': 0.7522039909669851}
# INFO:utils.ml:Metrics for classifier XGBClassifier13: {'accuracy': 0.8645669291338582, 'precision': 0.830104763509718, 'recall': 0.6900414058165758, 'f1': 0.7143970420549083, 'kappa': 0.7485495902016761}
# INFO:utils.ml:Metrics for classifier XGBClassifier14: {'accuracy': 0.8669291338582678, 'precision': 0.8402599030561296, 'recall': 0.6909832261954363, 'f1': 0.7167488340874907, 'kappa': 0.7522039909669851}
# INFO:utils.ml:Metrics for classifier XGBClassifier15: {'accuracy': 0.8669291338582678, 'precision': 0.8762029139086027, 'recall': 0.678943099328841, 'f1': 0.702612185897777, 'kappa': 0.7508080770552558}
# INFO:utils.ml:Metrics for classifier XGBClassifier16: {'accuracy': 0.8661417322834646, 'precision': 0.8740479916536255, 'recall': 0.6752192980797854, 'f1': 0.6973489135876288, 'kappa': 0.749163491030765}
# INFO:utils.ml:Metrics for classifier XGBClassifier17: {'accuracy': 0.8716535433070867, 'precision': 0.863741843442248, 'recall': 0.6975206417838554, 'f1': 0.7257414569770003, 'kappa': 0.7609893408704648}
# INFO:utils.ml:Metrics for classifier XGBClassifier18: {'accuracy': 0.8700787401574803, 'precision': 0.8627264340872575, 'recall': 0.696359655656455, 'f1': 0.7246707509578157, 'kappa': 0.7580064023503}
#                          accuracy  precision    recall        f1     kappa
# GT                       1.000000   1.000000  1.000000  1.000000  1.000000
# RandomForestClassifier0  0.832283   0.883836  0.619802  0.622506  0.683203
# RandomForestClassifier1  0.831496   0.846907  0.618778  0.621596  0.681464
# RandomForestClassifier2  0.826772   0.880114  0.613662  0.613127  0.673326
# RandomForestClassifier3  0.846457   0.856696  0.653976  0.673458  0.711643
# RandomForestClassifier4  0.823622   0.878103  0.611518  0.611052  0.667387
# RandomForestClassifier5  0.852756   0.879106  0.662208  0.683646  0.723763
# RandomForestClassifier6  0.822047   0.877100  0.609823  0.609797  0.663922
# RandomForestClassifier7  0.851969   0.879432  0.664415  0.687689  0.722358
# XGBClassifier8           0.870866   0.851068  0.706548  0.735645  0.760480
# XGBClassifier9           0.874016   0.853189  0.708870  0.737843  0.766370
# XGBClassifier10          0.872441   0.852100  0.707886  0.736763  0.763548
# XGBClassifier11          0.825984   0.809470  0.626987  0.634389  0.674697
# XGBClassifier12          0.866929   0.851278  0.694038  0.721685  0.752204
# XGBClassifier13          0.864567   0.830105  0.690041  0.714397  0.748550
# XGBClassifier14          0.866929   0.840260  0.690983  0.716749  0.752204
# XGBClassifier15          0.866929   0.876203  0.678943  0.702612  0.750808
# XGBClassifier16          0.866142   0.874048  0.675219  0.697349  0.749163
# XGBClassifier17          0.871654   0.863742  0.697521  0.725741  0.760989
# XGBClassifier18          0.870079   0.862726  0.696360  0.724671  0.758006

# %%
highest = df[df["kappa"] == df.iloc[1:]["kappa"].max()]
idx = highest.index[0]

confusion_matrix(pipeline.predictions["GT"], pipeline.predictions[idx])

# %% [markdown]
# ___
# # Balance the data

# %%
# Backup
pipeline.backup_feature_matrix = pipeline.feature_matrix.copy()
pipeline.backup_labels = pipeline.labels.copy()

# %%
print(pipeline.backup_feature_matrix.shape)
print(pipeline.feature_matrix.shape)

print(pipeline.backup_labels.shape)
print(pipeline.labels.shape)
# Out:
# (5082, 189)
# (5082, 189)
# (5082,)
# (5082,)

# %%
pipeline.get_feature_names()
# Out:
# ['gradient_magnitude_mean',
#  'gradient_magnitude_std',
#  'gradient_direction_mean',
#  'gradient_direction_std',
#  'color_moments_rgb_R_mean',
#  'color_moments_rgb_R_std',
#  'color_moments_rgb_R_skew',
#  'color_moments_rgb_R_kurtosis',
#  'color_moments_rgb_R_median',
#  'color_moments_rgb_R_var',
#  'color_moments_rgb_R_min',
#  'color_moments_rgb_R_max',
#  'color_moments_rgb_R_iqr',
#  'color_moments_rgb_R_entropy',
#  'color_moments_rgb_G_mean',
#  'color_moments_rgb_G_std',
#  'color_moments_rgb_G_skew',
#  'color_moments_rgb_G_kurtosis',
#  'color_moments_rgb_G_median',
#  'color_moments_rgb_G_var',
#  'color_moments_rgb_G_min',
#  'color_moments_rgb_G_max',
#  'color_moments_rgb_G_iqr',
#  'color_moments_rgb_G_entropy',
#  'color_moments_rgb_B_mean',
#  'color_moments_rgb_B_std',
#  'color_moments_rgb_B_skew',
#  'color_moments_rgb_B_kurtosis',
#  'color_moments_rgb_B_median',
#  'color_moments_rgb_B_var',
#  'color_moments_rgb_B_min',
#  'color_moments_rgb_B_max',
#  'color_moments_rgb_B_iqr',
#  'color_moments_rgb_B_entropy',
#  'color_moments_lab_L_mean',
#  'color_moments_lab_L_std',
#  'color_moments_lab_L_skew',
#  'color_moments_lab_L_kurtosis',
#  'color_moments_lab_L_median',
#  'color_moments_lab_L_var',
#  'color_moments_lab_L_min',
#  'color_moments_lab_L_max',
#  'color_moments_lab_L_iqr',
#  'color_moments_lab_L_entropy',
#  'color_moments_lab_A_mean',
#  'color_moments_lab_A_std',
#  'color_moments_lab_A_skew',
#  'color_moments_lab_A_kurtosis',
#  'color_moments_lab_A_median',
#  'color_moments_lab_A_var',
#  'color_moments_lab_A_min',
#  'color_moments_lab_A_max',
#  'color_moments_lab_A_iqr',
#  'color_moments_lab_A_entropy',
#  'color_moments_lab_B_mean',
#  'color_moments_lab_B_std',
#  'color_moments_lab_B_skew',
#  'color_moments_lab_B_kurtosis',
#  'color_moments_lab_B_median',
#  'color_moments_lab_B_var',
#  'color_moments_lab_B_min',
#  'color_moments_lab_B_max',
#  'color_moments_lab_B_iqr',
#  'color_moments_lab_B_entropy',
#  'color_moments_hsv_H_mean',
#  'color_moments_hsv_H_std',
#  'color_moments_hsv_H_skew',
#  'color_moments_hsv_H_kurtosis',
#  'color_moments_hsv_H_median',
#  'color_moments_hsv_H_var',
#  'color_moments_hsv_H_min',
#  'color_moments_hsv_H_max',
#  'color_moments_hsv_H_iqr',
#  'color_moments_hsv_H_entropy',
#  'color_moments_hsv_S_mean',
#  'color_moments_hsv_S_std',
#  'color_moments_hsv_S_skew',
#  'color_moments_hsv_S_kurtosis',
#  'color_moments_hsv_S_median',
#  'color_moments_hsv_S_var',
#  'color_moments_hsv_S_min',
#  'color_moments_hsv_S_max',
#  'color_moments_hsv_S_iqr',
#  'color_moments_hsv_S_entropy',
#  'color_moments_hsv_V_mean',
#  'color_moments_hsv_V_std',
#  'color_moments_hsv_V_skew',
#  'color_moments_hsv_V_kurtosis',
#  'color_moments_hsv_V_median',
#  'color_moments_hsv_V_var',
#  'color_moments_hsv_V_min',
#  'color_moments_hsv_V_max',
#  'color_moments_hsv_V_iqr',
#  'color_moments_hsv_V_entropy',
#  'lbp_rad1_bins8_0',
#  'lbp_rad1_bins8_1',
#  'lbp_rad1_bins8_2',
#  'lbp_rad1_bins8_3',
#  'lbp_rad1_bins8_4',
#  'lbp_rad1_bins8_5',
#  'lbp_rad1_bins8_6',
#  'lbp_rad1_bins8_7',
#  'lbp_rad1_bins8_8',
#  'lbp_rad1_bins8_9',
#  'lbp_rad2_bins16_0',
#  'lbp_rad2_bins16_1',
#  'lbp_rad2_bins16_2',
#  'lbp_rad2_bins16_3',
#  'lbp_rad2_bins16_4',
#  'lbp_rad2_bins16_5',
#  'lbp_rad2_bins16_6',
#  'lbp_rad2_bins16_7',
#  'lbp_rad2_bins16_8',
#  'lbp_rad2_bins16_9',
#  'lbp_rad2_bins16_10',
#  'lbp_rad2_bins16_11',
#  'lbp_rad2_bins16_12',
#  'lbp_rad2_bins16_13',
#  'lbp_rad2_bins16_14',
#  'lbp_rad2_bins16_15',
#  'lbp_rad2_bins16_16',
#  'lbp_rad2_bins16_17',
#  'lbp_rad3_bins24_0',
#  'lbp_rad3_bins24_1',
#  'lbp_rad3_bins24_2',
#  'lbp_rad3_bins24_3',
#  'lbp_rad3_bins24_4',
#  'lbp_rad3_bins24_5',
#  'lbp_rad3_bins24_6',
#  'lbp_rad3_bins24_7',
#  'lbp_rad3_bins24_8',
#  'lbp_rad3_bins24_9',
#  'lbp_rad3_bins24_10',
#  'lbp_rad3_bins24_11',
#  'lbp_rad3_bins24_12',
#  'lbp_rad3_bins24_13',
#  'lbp_rad3_bins24_14',
#  'lbp_rad3_bins24_15',
#  'lbp_rad3_bins24_16',
#  'lbp_rad3_bins24_17',
#  'lbp_rad3_bins24_18',
#  'lbp_rad3_bins24_19',
#  'lbp_rad3_bins24_20',
#  'lbp_rad3_bins24_21',
#  'lbp_rad3_bins24_22',
#  'lbp_rad3_bins24_23',
#  'lbp_rad3_bins24_24',
#  'lbp_rad3_bins24_25',
#  'lbp_rad4_bins32_0',
#  'lbp_rad4_bins32_1',
#  'lbp_rad4_bins32_2',
#  'lbp_rad4_bins32_3',
#  'lbp_rad4_bins32_4',
#  'lbp_rad4_bins32_5',
#  'lbp_rad4_bins32_6',
#  'lbp_rad4_bins32_7',
#  'lbp_rad4_bins32_8',
#  'lbp_rad4_bins32_9',
#  'lbp_rad4_bins32_10',
#  'lbp_rad4_bins32_11',
#  'lbp_rad4_bins32_12',
#  'lbp_rad4_bins32_13',
#  'lbp_rad4_bins32_14',
#  'lbp_rad4_bins32_15',
#  'lbp_rad4_bins32_16',
#  'lbp_rad4_bins32_17',
#  'lbp_rad4_bins32_18',
#  'lbp_rad4_bins32_19',
#  'lbp_rad4_bins32_20',
#  'lbp_rad4_bins32_21',
#  'lbp_rad4_bins32_22',
#  'lbp_rad4_bins32_23',
#  'lbp_rad4_bins32_24',
#  'lbp_rad4_bins32_25',
#  'lbp_rad4_bins32_26',
#  'lbp_rad4_bins32_27',
#  'lbp_rad4_bins32_28',
#  'lbp_rad4_bins32_29',
#  'lbp_rad4_bins32_30',
#  'lbp_rad4_bins32_31',
#  'lbp_rad4_bins32_32',
#  'lbp_rad4_bins32_33',
#  'fourier_transform_magnitude_mean',
#  'fourier_transform_magnitude_std',
#  'glcm_contrast_dist_1_angle_0',
#  'glcm_dissimilarity_dist_1_angle_0',
#  'glcm_homogeneity_dist_1_angle_0',
#  'glcm_energy_dist_1_angle_0',
#  'glcm_correlation_dist_1_angle_0']

# %%
from imblearn.over_sampling import SMOTE

smote = SMOTE(random_state=42)


pipeline.feature_matrix, pipeline.labels = smote.fit_resample(np.nan_to_num(pipeline.feature_matrix), pipeline.labels)

# %%
pipeline.fitted_classifiers = {}
pipeline.fit_classifiers()
# Out:
# INFO:utils.ml:Fitting classifiers...
# INFO:utils.ml:Fitting classifier: RandomForestClassifier0
# INFO:utils.ml:Top 10 features for RandomForestClassifier0: [('color_moments_lab_B_std', 0.022517908709084905), ('color_moments_lab_B_var', 0.02206546208689515), ('color_moments_rgb_B_var', 0.021429789844875667), ('color_moments_lab_L_iqr', 0.01731470636711622), ('color_moments_rgb_B_std', 0.015618958109359366), ('color_moments_rgb_B_iqr', 0.014527995995931664), ('color_moments_rgb_G_std', 0.01323798455843907), ('color_moments_rgb_R_iqr', 0.01311700556451779), ('lbp_rad1_bins8_4', 0.012984705484616294), ('color_moments_rgb_B_kurtosis', 0.012900815412511195)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier0; Done in 8.099308252334595 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier1
# INFO:utils.ml:Top 10 features for RandomForestClassifier1: [('color_moments_lab_B_std', 0.023580736364420193), ('color_moments_lab_B_var', 0.021394836924772734), ('color_moments_lab_L_iqr', 0.019978553525176926), ('color_moments_rgb_B_var', 0.018435938519150926), ('color_moments_rgb_B_iqr', 0.016166639017988777), ('color_moments_rgb_B_kurtosis', 0.014193844455692781), ('color_moments_rgb_G_iqr', 0.012870067708900212), ('lbp_rad1_bins8_4', 0.012817337940015043), ('color_moments_rgb_B_std', 0.012368703495531925), ('color_moments_rgb_R_iqr', 0.011569462356373586)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier1; Done in 11.912094116210938 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier2
# INFO:utils.ml:Top 10 features for RandomForestClassifier2: [('color_moments_lab_B_std', 0.025429148205106538), ('color_moments_rgb_B_std', 0.02230177629461164), ('color_moments_lab_B_var', 0.019197997894131184), ('color_moments_lab_L_iqr', 0.01839847143040361), ('color_moments_rgb_B_var', 0.01568819320187123), ('color_moments_rgb_B_iqr', 0.015177477192881062), ('lbp_rad1_bins8_4', 0.013078268011492809), ('color_moments_lab_L_std', 0.012640264659523058), ('color_moments_rgb_G_iqr', 0.010605687807924315), ('lbp_rad4_bins32_32', 0.010571776142688321)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier2; Done in 8.026831865310669 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier3
# INFO:utils.ml:Top 10 features for RandomForestClassifier3: [('color_moments_lab_B_std', 0.0252014934031412), ('color_moments_rgb_B_std', 0.024782903499682468), ('color_moments_lab_B_var', 0.019368011574932578), ('color_moments_lab_L_iqr', 0.01798168345885219), ('color_moments_rgb_B_var', 0.016740910495078334), ('color_moments_rgb_B_iqr', 0.015244952855614445), ('color_moments_lab_L_std', 0.012549539409897819), ('lbp_rad1_bins8_4', 0.01143135665604412), ('lbp_rad4_bins32_32', 0.01031651743417963), ('color_moments_lab_B_iqr', 0.010227276605873472)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier3; Done in 11.72755217552185 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier4
# INFO:utils.ml:Top 10 features for RandomForestClassifier4: [('color_moments_lab_B_std', 0.025806154710530247), ('color_moments_rgb_B_std', 0.020566220715631574), ('color_moments_lab_L_iqr', 0.020174182077506903), ('color_moments_lab_B_var', 0.017965349837266158), ('color_moments_rgb_B_var', 0.017652751483077878), ('color_moments_rgb_B_iqr', 0.015044157628294546), ('lbp_rad1_bins8_4', 0.012625743470883992), ('color_moments_lab_L_std', 0.01145592110899751), ('color_moments_lab_L_var', 0.010808631272897285), ('color_moments_rgb_R_kurtosis', 0.00985896664334344)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier4; Done in 12.57648253440857 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier5
# INFO:utils.ml:Top 10 features for RandomForestClassifier5: [('color_moments_lab_B_std', 0.02535577436040203), ('color_moments_rgb_B_std', 0.022937098378508748), ('color_moments_lab_L_iqr', 0.019144853964192476), ('color_moments_lab_B_var', 0.018440213588657307), ('color_moments_rgb_B_var', 0.017652992539460354), ('color_moments_rgb_B_iqr', 0.014331757611794277), ('lbp_rad1_bins8_4', 0.01179232388484202), ('color_moments_lab_L_std', 0.011527126116206293), ('glcm_energy_dist_1_angle_0', 0.010597007609010115), ('color_moments_rgb_B_kurtosis', 0.01044929495660018)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier5; Done in 17.6978497505188 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier6
# INFO:utils.ml:Top 10 features for RandomForestClassifier6: [('color_moments_lab_B_std', 0.025227200624812974), ('color_moments_lab_L_iqr', 0.01978954758239505), ('color_moments_rgb_B_std', 0.019691973128668223), ('color_moments_lab_B_var', 0.018129226724048663), ('color_moments_rgb_B_iqr', 0.01805218726774929), ('color_moments_rgb_B_var', 0.016831342804411058), ('lbp_rad1_bins8_4', 0.012283602779213598), ('color_moments_rgb_R_iqr', 0.010915074129763013), ('color_moments_lab_L_std', 0.010572429863487394), ('color_moments_rgb_R_kurtosis', 0.010568065042838201)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier6; Done in 16.40154504776001 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier7
# INFO:utils.ml:Top 10 features for RandomForestClassifier7: [('color_moments_lab_B_std', 0.025100507183872148), ('color_moments_rgb_B_std', 0.020495537182743283), ('color_moments_lab_L_iqr', 0.019561492970160414), ('color_moments_lab_B_var', 0.018122316599786855), ('color_moments_rgb_B_iqr', 0.016657307393756052), ('color_moments_rgb_B_var', 0.01657317209226118), ('lbp_rad1_bins8_4', 0.011422809651248034), ('color_moments_rgb_B_kurtosis', 0.011193071373286836), ('color_moments_rgb_R_iqr', 0.010869347241463663), ('color_moments_lab_L_std', 0.010772036646230816)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier7; Done in 24.124428272247314 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier8
# INFO:utils.ml:Top 10 features for XGBClassifier8: [('color_moments_rgb_B_iqr', 0.06076807), ('color_moments_lab_L_iqr', 0.03897746), ('glcm_energy_dist_1_angle_0', 0.02863116), ('gradient_magnitude_mean', 0.024142804), ('color_moments_lab_B_var', 0.02000029), ('lbp_rad1_bins8_4', 0.018939547), ('gradient_direction_std', 0.017836254), ('color_moments_rgb_B_std', 0.016743688), ('lbp_rad1_bins8_8', 0.014194468), ('color_moments_lab_B_std', 0.014023129)]
# INFO:utils.ml:Fitted classifier: XGBClassifier8; Done in 6.18082857131958 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier9
# INFO:utils.ml:Top 10 features for XGBClassifier9: [('color_moments_rgb_B_iqr', 0.05703776), ('color_moments_lab_L_iqr', 0.039054148), ('glcm_energy_dist_1_angle_0', 0.029810656), ('gradient_magnitude_mean', 0.02427326), ('color_moments_lab_B_var', 0.019798893), ('lbp_rad1_bins8_4', 0.019589702), ('gradient_direction_std', 0.018982824), ('color_moments_rgb_B_std', 0.016821409), ('lbp_rad1_bins8_8', 0.014899094), ('color_moments_lab_B_std', 0.014028375)]
# INFO:utils.ml:Fitted classifier: XGBClassifier9; Done in 8.181337594985962 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier10
# INFO:utils.ml:Top 10 features for XGBClassifier10: [('color_moments_rgb_B_iqr', 0.055289514), ('color_moments_lab_L_iqr', 0.036407117), ('glcm_energy_dist_1_angle_0', 0.02862382), ('gradient_magnitude_mean', 0.024786241), ('lbp_rad1_bins8_4', 0.020330122), ('color_moments_lab_B_var', 0.020011121), ('gradient_direction_std', 0.018902183), ('color_moments_rgb_B_std', 0.01723782), ('lbp_rad1_bins8_8', 0.015374021), ('color_moments_lab_B_std', 0.01403345)]
# INFO:utils.ml:Fitted classifier: XGBClassifier10; Done in 9.68573546409607 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier11
# INFO:utils.ml:Top 10 features for XGBClassifier11: [('color_moments_rgb_B_iqr', 0.07669978), ('color_moments_lab_L_iqr', 0.042971745), ('color_moments_lab_B_std', 0.019537507), ('color_moments_lab_B_var', 0.017902067), ('color_moments_rgb_B_std', 0.017684685), ('glcm_energy_dist_1_angle_0', 0.015742447), ('color_moments_lab_A_iqr', 0.014600476), ('gradient_magnitude_mean', 0.013676565), ('lbp_rad1_bins8_4', 0.013525231), ('color_moments_rgb_R_mean', 0.011726127)]
# INFO:utils.ml:Fitted classifier: XGBClassifier11; Done in 3.4196364879608154 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier12
# INFO:utils.ml:Top 10 features for XGBClassifier12: [('color_moments_rgb_B_iqr', 0.04347128), ('color_moments_lab_L_iqr', 0.03454043), ('color_moments_lab_B_var', 0.017136542), ('glcm_energy_dist_1_angle_0', 0.016654221), ('lbp_rad1_bins8_4', 0.016376644), ('gradient_magnitude_mean', 0.015757468), ('color_moments_lab_B_std', 0.013682165), ('color_moments_rgb_B_std', 0.012791403), ('color_moments_lab_A_iqr', 0.012174861), ('gradient_direction_std', 0.012163854)]
# INFO:utils.ml:Fitted classifier: XGBClassifier12; Done in 9.115402460098267 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier13
# INFO:utils.ml:Top 10 features for XGBClassifier13: [('color_moments_lab_L_iqr', 0.041411567), ('color_moments_rgb_B_iqr', 0.037249036), ('gradient_magnitude_mean', 0.021515576), ('glcm_energy_dist_1_angle_0', 0.019484572), ('color_moments_lab_B_var', 0.018087465), ('lbp_rad1_bins8_4', 0.01769836), ('color_moments_lab_B_std', 0.016447954), ('color_moments_lab_A_iqr', 0.014571427), ('gradient_direction_std', 0.014096793), ('color_moments_rgb_B_std', 0.013694103)]
# INFO:utils.ml:Fitted classifier: XGBClassifier13; Done in 6.214012861251831 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier14
# INFO:utils.ml:Top 10 features for XGBClassifier14: [('color_moments_lab_L_iqr', 0.04184079), ('color_moments_rgb_B_iqr', 0.04079035), ('glcm_energy_dist_1_angle_0', 0.02286803), ('gradient_magnitude_mean', 0.020057326), ('color_moments_lab_B_var', 0.018843938), ('lbp_rad1_bins8_4', 0.018187217), ('color_moments_lab_B_std', 0.014345626), ('color_moments_lab_A_iqr', 0.013288639), ('gradient_direction_std', 0.013245227), ('color_moments_rgb_B_std', 0.012859212)]
# INFO:utils.ml:Fitted classifier: XGBClassifier14; Done in 7.333911895751953 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier15
# INFO:utils.ml:Top 10 features for XGBClassifier15: [('color_moments_rgb_B_iqr', 0.046160415), ('color_moments_lab_L_iqr', 0.033015065), ('color_moments_lab_B_var', 0.019757552), ('glcm_energy_dist_1_angle_0', 0.019385828), ('lbp_rad1_bins8_4', 0.016222766), ('gradient_magnitude_mean', 0.015827984), ('color_moments_lab_A_iqr', 0.014048324), ('color_moments_lab_B_std', 0.013702546), ('gradient_direction_std', 0.01283746), ('color_moments_rgb_B_std', 0.0123062)]
# INFO:utils.ml:Fitted classifier: XGBClassifier15; Done in 15.798860549926758 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier16
# INFO:utils.ml:Top 10 features for XGBClassifier16: [('color_moments_rgb_B_iqr', 0.04664027), ('color_moments_lab_L_iqr', 0.03258872), ('color_moments_lab_B_var', 0.020237196), ('glcm_energy_dist_1_angle_0', 0.018945856), ('lbp_rad1_bins8_4', 0.015980897), ('gradient_magnitude_mean', 0.01514598), ('color_moments_lab_A_iqr', 0.013804363), ('color_moments_lab_B_std', 0.013379927), ('gradient_direction_std', 0.012785962), ('lbp_rad3_bins24_24', 0.011772664)]
# INFO:utils.ml:Fitted classifier: XGBClassifier16; Done in 12.513785600662231 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier17
# INFO:utils.ml:Top 10 features for XGBClassifier17: [('color_moments_rgb_B_iqr', 0.046587385), ('color_moments_lab_L_iqr', 0.036025904), ('glcm_energy_dist_1_angle_0', 0.022075394), ('color_moments_lab_B_var', 0.018949691), ('gradient_magnitude_mean', 0.018647432), ('lbp_rad1_bins8_4', 0.016898189), ('color_moments_lab_B_std', 0.01346768), ('color_moments_lab_A_iqr', 0.0129742995), ('gradient_direction_std', 0.012927666), ('color_moments_rgb_B_std', 0.012272373)]
# INFO:utils.ml:Fitted classifier: XGBClassifier17; Done in 10.211765050888062 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier18
# INFO:utils.ml:Top 10 features for XGBClassifier18: [('color_moments_rgb_B_iqr', 0.046469357), ('color_moments_lab_L_iqr', 0.03653135), ('glcm_energy_dist_1_angle_0', 0.022964504), ('gradient_magnitude_mean', 0.019801725), ('color_moments_lab_B_var', 0.018656097), ('lbp_rad1_bins8_4', 0.017066244), ('color_moments_lab_B_std', 0.013567709), ('color_moments_lab_A_iqr', 0.013106626), ('gradient_direction_std', 0.012799678), ('color_moments_rgb_B_std', 0.012547408)]
# INFO:utils.ml:Fitted classifier: XGBClassifier18; Done in 11.441667079925537 seconds
# INFO:utils.ml:Fitting completed in 210.68 seconds.

# %%
pipeline.predict_with_classifiers(VAL_PATH, percent)
# Out:
# INFO:utils.ml:Predicting with classifiers on dataset: C:\Users\gimes\Src\repos\CADx-Project\dataset\multiclass\val
# Processed 5/53 batches.
# Processed 10/53 batches.
# Processed 15/53 batches.
# Processed 20/53 batches.
# Processed 25/53 batches.
# Processed 30/53 batches.
# Processed 35/53 batches.
# Processed 40/53 batches.
# Processed 45/53 batches.
# Processed 50/53 batches.
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier0
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier1
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier2
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier3
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier4
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier5
# Processed 53/53 batches.
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier6
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier7
# INFO:utils.ml:Predictions made with classifier: XGBClassifier8
# INFO:utils.ml:Predictions made with classifier: XGBClassifier9
# INFO:utils.ml:Predictions made with classifier: XGBClassifier10
# INFO:utils.ml:Predictions made with classifier: XGBClassifier11
# INFO:utils.ml:Predictions made with classifier: XGBClassifier12
# INFO:utils.ml:Predictions made with classifier: XGBClassifier13
# INFO:utils.ml:Predictions made with classifier: XGBClassifier14
# INFO:utils.ml:Predictions made with classifier: XGBClassifier15
# INFO:utils.ml:Predictions made with classifier: XGBClassifier16
# INFO:utils.ml:Predictions made with classifier: XGBClassifier17
# INFO:utils.ml:Predictions made with classifier: XGBClassifier18
# {'GT': array([0, 0, 0, ..., 2, 2, 2]),
#  'RandomForestClassifier0': array([0, 0, 2, ..., 1, 0, 0]),
#  'RandomForestClassifier1': array([0, 0, 2, ..., 1, 0, 0]),
#  'RandomForestClassifier2': array([0, 0, 2, ..., 1, 0, 0]),
#  'RandomForestClassifier3': array([0, 0, 2, ..., 1, 0, 0]),
#  'RandomForestClassifier4': array([0, 0, 2, ..., 1, 0, 0]),
#  'RandomForestClassifier5': array([0, 0, 2, ..., 1, 0, 0]),
#  'RandomForestClassifier6': array([0, 0, 2, ..., 1, 0, 0]),
#  'RandomForestClassifier7': array([0, 0, 2, ..., 1, 0, 0]),
#  'XGBClassifier8': array([0, 0, 2, ..., 0, 2, 0], dtype=int64),
#  'XGBClassifier9': array([0, 0, 2, ..., 0, 2, 0], dtype=int64),
#  'XGBClassifier10': array([0, 0, 2, ..., 0, 2, 0], dtype=int64),
#  'XGBClassifier11': array([0, 0, 2, ..., 0, 0, 0], dtype=int64),
#  'XGBClassifier12': array([0, 0, 2, ..., 0, 0, 0], dtype=int64),
#  'XGBClassifier13': array([0, 0, 2, ..., 0, 0, 0], dtype=int64),
#  'XGBClassifier14': array([0, 0, 2, ..., 0, 0, 0], dtype=int64),
#  'XGBClassifier15': array([0, 0, 2, ..., 0, 0, 0], dtype=int64),
#  'XGBClassifier16': array([0, 0, 2, ..., 0, 0, 0], dtype=int64),
#  'XGBClassifier17': array([0, 0, 2, ..., 0, 0, 0], dtype=int64),
#  'XGBClassifier18': array([0, 0, 2, ..., 0, 0, 0], dtype=int64)}

# %%
import pandas as pd

df_smote = pd.DataFrame(data=pipeline.calculate_metrics())
df_smote = df_smote.T
df_smote
# Out:
# INFO:utils.ml:Metrics for classifier GT: {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'kappa': 1.0}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier0: {'accuracy': 0.8275590551181102, 'precision': 0.718045636666225, 'recall': 0.7187493462206321, 'f1': 0.7182278215097123, 'kappa': 0.6907577563509572}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier1: {'accuracy': 0.8330708661417323, 'precision': 0.7317294240799481, 'recall': 0.7180366479411653, 'f1': 0.7235613691741704, 'kappa': 0.699382776700937}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier2: {'accuracy': 0.8307086614173228, 'precision': 0.7190875680631134, 'recall': 0.7153178079795489, 'f1': 0.7169501694801811, 'kappa': 0.695615435379731}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier3: {'accuracy': 0.8456692913385827, 'precision': 0.7408366367192158, 'recall': 0.7262583252107154, 'f1': 0.7325426255146416, 'kappa': 0.7212304742620872}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier4: {'accuracy': 0.8322834645669291, 'precision': 0.7284108697124968, 'recall': 0.7252867618090514, 'f1': 0.7266418378112531, 'kappa': 0.6985826666369532}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier5: {'accuracy': 0.8480314960629921, 'precision': 0.7526402298698315, 'recall': 0.7309654106288961, 'f1': 0.7399597146660689, 'kappa': 0.7251106914232651}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier6: {'accuracy': 0.831496062992126, 'precision': 0.72594354301973, 'recall': 0.7219183644765468, 'f1': 0.7236406773996434, 'kappa': 0.6971527140144593}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier7: {'accuracy': 0.8472440944881889, 'precision': 0.7466040077316042, 'recall': 0.7267085035050136, 'f1': 0.7351922020480893, 'kappa': 0.7233649812717262}
# INFO:utils.ml:Metrics for classifier XGBClassifier8: {'accuracy': 0.8748031496062992, 'precision': 0.8040849977017185, 'recall': 0.7679627062823565, 'f1': 0.7828972463743794, 'kappa': 0.7725275765113009}
# INFO:utils.ml:Metrics for classifier XGBClassifier9: {'accuracy': 0.8724409448818897, 'precision': 0.7959385022337423, 'recall': 0.7630779189059004, 'f1': 0.7767829967179445, 'kappa': 0.7683410725625932}
# INFO:utils.ml:Metrics for classifier XGBClassifier10: {'accuracy': 0.8708661417322835, 'precision': 0.794689670383267, 'recall': 0.7534643689929492, 'f1': 0.7696804403185925, 'kappa': 0.7649464617829219}
# INFO:utils.ml:Metrics for classifier XGBClassifier11: {'accuracy': 0.8110236220472441, 'precision': 0.6894642984606821, 'recall': 0.714211896856238, 'f1': 0.699076140360544, 'kappa': 0.6660882368407215}
# INFO:utils.ml:Metrics for classifier XGBClassifier12: {'accuracy': 0.8732283464566929, 'precision': 0.7859054970854743, 'recall': 0.763036455115636, 'f1': 0.7730912176478354, 'kappa': 0.7701540924194803}
# INFO:utils.ml:Metrics for classifier XGBClassifier13: {'accuracy': 0.8763779527559055, 'precision': 0.7862101126859624, 'recall': 0.7628370760390459, 'f1': 0.7729092579083199, 'kappa': 0.7760347399446461}
# INFO:utils.ml:Metrics for classifier XGBClassifier14: {'accuracy': 0.8716535433070867, 'precision': 0.7787813678459217, 'recall': 0.7627639787796135, 'f1': 0.769807541872483, 'kappa': 0.7682710046030126}
# INFO:utils.ml:Metrics for classifier XGBClassifier15: {'accuracy': 0.8677165354330708, 'precision': 0.7747439003348809, 'recall': 0.7565405033174812, 'f1': 0.7646432285021266, 'kappa': 0.7605720416013932}
# INFO:utils.ml:Metrics for classifier XGBClassifier16: {'accuracy': 0.8653543307086614, 'precision': 0.7678946785116962, 'recall': 0.7547101731472429, 'f1': 0.760734427535521, 'kappa': 0.7566766310071752}
# INFO:utils.ml:Metrics for classifier XGBClassifier17: {'accuracy': 0.8653543307086614, 'precision': 0.7729060564874194, 'recall': 0.7516557159410251, 'f1': 0.7609414464817058, 'kappa': 0.7560260454582222}
# INFO:utils.ml:Metrics for classifier XGBClassifier18: {'accuracy': 0.8700787401574803, 'precision': 0.7780386585891392, 'recall': 0.7581931315294441, 'f1': 0.7669289845461639, 'kappa': 0.7647884162083287}
#                          accuracy  precision    recall        f1     kappa
# GT                       1.000000   1.000000  1.000000  1.000000  1.000000
# RandomForestClassifier0  0.827559   0.718046  0.718749  0.718228  0.690758
# RandomForestClassifier1  0.833071   0.731729  0.718037  0.723561  0.699383
# RandomForestClassifier2  0.830709   0.719088  0.715318  0.716950  0.695615
# RandomForestClassifier3  0.845669   0.740837  0.726258  0.732543  0.721230
# RandomForestClassifier4  0.832283   0.728411  0.725287  0.726642  0.698583
# RandomForestClassifier5  0.848031   0.752640  0.730965  0.739960  0.725111
# RandomForestClassifier6  0.831496   0.725944  0.721918  0.723641  0.697153
# RandomForestClassifier7  0.847244   0.746604  0.726709  0.735192  0.723365
# XGBClassifier8           0.874803   0.804085  0.767963  0.782897  0.772528
# XGBClassifier9           0.872441   0.795939  0.763078  0.776783  0.768341
# XGBClassifier10          0.870866   0.794690  0.753464  0.769680  0.764946
# XGBClassifier11          0.811024   0.689464  0.714212  0.699076  0.666088
# XGBClassifier12          0.873228   0.785905  0.763036  0.773091  0.770154
# XGBClassifier13          0.876378   0.786210  0.762837  0.772909  0.776035
# XGBClassifier14          0.871654   0.778781  0.762764  0.769808  0.768271
# XGBClassifier15          0.867717   0.774744  0.756541  0.764643  0.760572
# XGBClassifier16          0.865354   0.767895  0.754710  0.760734  0.756677
# XGBClassifier17          0.865354   0.772906  0.751656  0.760941  0.756026
# XGBClassifier18          0.870079   0.778039  0.758193  0.766929  0.764788

# %%
highest = df_smote[df_smote["kappa"] == df_smote.iloc[1:]["kappa"].max()]
idx = highest.index[0]

confusion_matrix(pipeline.predictions["GT"], pipeline.predictions[idx])
# Out:
# array([[440,  33,  25],
#        [ 42, 628,   8],
#        [ 34,  15,  45]], dtype=int64)

# %% [markdown]
# ___
# # Borderline SMOTE

# %%
from imblearn.over_sampling import BorderlineSMOTE
smote = BorderlineSMOTE(sampling_strategy='auto', random_state=42)

pipeline.feature_matrix, pipeline.labels = smote.fit_resample(
    np.nan_to_num(pipeline.backup_feature_matrix), pipeline.backup_labels)

print(pipeline.backup_feature_matrix.shape)
print(pipeline.feature_matrix.shape)

print(pipeline.backup_labels.shape)
print(pipeline.labels.shape)
# Out:
# (5082, 189)
# (8139, 189)
# (5082,)
# (8139,)

# %%
pipeline.fitted_classifiers = {}

pipeline.fit_classifiers()
# Out:
# INFO:utils.ml:Fitting classifiers...
# INFO:utils.ml:Fitting classifier: RandomForestClassifier0
# INFO:utils.ml:Top 10 features for RandomForestClassifier0: [('color_moments_rgb_B_std', 0.022493374450476437), ('color_moments_lab_B_std', 0.021627789726991704), ('color_moments_lab_B_var', 0.0199290353525708), ('color_moments_lab_L_iqr', 0.018618847444709753), ('color_moments_rgb_B_iqr', 0.015344972422508213), ('color_moments_rgb_B_var', 0.01440355928761019), ('color_moments_rgb_G_iqr', 0.014060164979042736), ('color_moments_rgb_G_var', 0.013005492608675584), ('glcm_energy_dist_1_angle_0', 0.011998496772818614), ('color_moments_rgb_R_kurtosis', 0.01191937710894334)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier0; Done in 11.963889122009277 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier1
# INFO:utils.ml:Top 10 features for RandomForestClassifier1: [('color_moments_lab_B_var', 0.021249296279635482), ('color_moments_lab_L_iqr', 0.020328343823046727), ('color_moments_lab_B_std', 0.019827687375178357), ('color_moments_rgb_B_var', 0.016738176027392915), ('color_moments_rgb_B_iqr', 0.016263850629040292), ('color_moments_rgb_B_std', 0.016171522644582565), ('color_moments_lab_L_var', 0.013046633182515616), ('color_moments_rgb_B_kurtosis', 0.011925027025982029), ('color_moments_rgb_R_kurtosis', 0.011329078178744578), ('glcm_energy_dist_1_angle_0', 0.011171271969635257)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier1; Done in 17.56761407852173 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier2
# INFO:utils.ml:Top 10 features for RandomForestClassifier2: [('color_moments_lab_B_std', 0.02396061852093543), ('color_moments_rgb_B_std', 0.02245385890328501), ('color_moments_lab_L_iqr', 0.021249431578641998), ('color_moments_lab_B_var', 0.017249908754316114), ('color_moments_rgb_B_iqr', 0.016807610429783747), ('color_moments_rgb_B_var', 0.015405695377088555), ('color_moments_rgb_G_skew', 0.011959195101669685), ('color_moments_lab_L_std', 0.01157447561607708), ('color_moments_rgb_R_kurtosis', 0.011100481226922938), ('glcm_energy_dist_1_angle_0', 0.010920055717552503)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier2; Done in 8.532209634780884 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier3
# INFO:utils.ml:Top 10 features for RandomForestClassifier3: [('color_moments_lab_B_std', 0.024159614435079035), ('color_moments_rgb_B_std', 0.021832462396785445), ('color_moments_lab_L_iqr', 0.019851300453109802), ('color_moments_rgb_B_iqr', 0.018608401048329934), ('color_moments_lab_B_var', 0.017810794503540874), ('color_moments_rgb_B_var', 0.015797920805647424), ('lbp_rad1_bins8_4', 0.012287531598441839), ('glcm_energy_dist_1_angle_0', 0.011720270393458266), ('color_moments_lab_L_std', 0.011110115618068397), ('color_moments_rgb_G_skew', 0.010642431458826644)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier3; Done in 11.857156753540039 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier4
# INFO:utils.ml:Top 10 features for RandomForestClassifier4: [('color_moments_lab_B_std', 0.023757589750022533), ('color_moments_lab_L_iqr', 0.021898945822142774), ('color_moments_rgb_B_std', 0.020266121157155356), ('color_moments_rgb_B_var', 0.0170450569423603), ('color_moments_lab_B_var', 0.0157204314785382), ('color_moments_rgb_B_iqr', 0.015125492826796856), ('color_moments_rgb_G_skew', 0.011699809145268606), ('glcm_energy_dist_1_angle_0', 0.011492449982418593), ('color_moments_lab_L_std', 0.010768849284197161), ('color_moments_rgb_R_kurtosis', 0.010695449071694608)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier4; Done in 12.202679634094238 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier5
# INFO:utils.ml:Top 10 features for RandomForestClassifier5: [('color_moments_lab_B_std', 0.02388135552842897), ('color_moments_lab_L_iqr', 0.020606229078039683), ('color_moments_rgb_B_std', 0.020472297140084375), ('color_moments_rgb_B_var', 0.01791610166352436), ('color_moments_rgb_B_iqr', 0.017789921454268668), ('color_moments_lab_B_var', 0.01615857713374708), ('lbp_rad1_bins8_4', 0.011862059959702374), ('glcm_energy_dist_1_angle_0', 0.01134681186787775), ('color_moments_rgb_G_skew', 0.010913928402945071), ('color_moments_lab_L_std', 0.010640383877565)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier5; Done in 17.479258060455322 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier6
# INFO:utils.ml:Top 10 features for RandomForestClassifier6: [('color_moments_lab_B_std', 0.024010175397623915), ('color_moments_lab_L_iqr', 0.021113155447715953), ('color_moments_rgb_B_std', 0.018673360435010493), ('color_moments_rgb_B_iqr', 0.01672018827671659), ('color_moments_rgb_B_var', 0.016178495768648403), ('color_moments_lab_B_var', 0.015643292924861413), ('color_moments_rgb_R_kurtosis', 0.012324603638688002), ('color_moments_rgb_G_skew', 0.011461254216352386), ('glcm_energy_dist_1_angle_0', 0.011077212698791878), ('color_moments_rgb_R_iqr', 0.010465185462643623)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier6; Done in 15.991190433502197 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier7
# INFO:utils.ml:Top 10 features for RandomForestClassifier7: [('color_moments_lab_B_std', 0.02312606169675849), ('color_moments_lab_L_iqr', 0.02004062561416467), ('color_moments_rgb_B_iqr', 0.01896564394868487), ('color_moments_rgb_B_std', 0.018687530573860335), ('color_moments_rgb_B_var', 0.01700971651470581), ('color_moments_lab_B_var', 0.015764710833386052), ('lbp_rad1_bins8_4', 0.011979584294668022), ('color_moments_rgb_B_kurtosis', 0.011762489150258341), ('glcm_energy_dist_1_angle_0', 0.011179993342903476), ('color_moments_rgb_R_kurtosis', 0.010873949845490663)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier7; Done in 27.06945776939392 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier8
# INFO:utils.ml:Top 10 features for XGBClassifier8: [('color_moments_lab_L_iqr', 0.0647122), ('color_moments_rgb_B_std', 0.029099802), ('color_moments_lab_B_var', 0.026412623), ('color_moments_rgb_B_iqr', 0.024908645), ('glcm_energy_dist_1_angle_0', 0.02127683), ('lbp_rad4_bins32_32', 0.01900037), ('lbp_rad1_bins8_4', 0.018379444), ('gradient_magnitude_std', 0.017581085), ('gradient_direction_std', 0.014586493), ('color_moments_lab_B_std', 0.011765455)]
# INFO:utils.ml:Fitted classifier: XGBClassifier8; Done in 17.046279907226562 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier9
# INFO:utils.ml:Top 10 features for XGBClassifier9: [('color_moments_lab_L_iqr', 0.062810495), ('color_moments_rgb_B_std', 0.0296027), ('color_moments_lab_B_var', 0.026630819), ('color_moments_rgb_B_iqr', 0.025034783), ('glcm_energy_dist_1_angle_0', 0.021725679), ('lbp_rad1_bins8_4', 0.018573591), ('gradient_magnitude_std', 0.017257597), ('lbp_rad4_bins32_32', 0.016877292), ('gradient_direction_std', 0.014947493), ('color_moments_lab_B_std', 0.011880479)]
# INFO:utils.ml:Fitted classifier: XGBClassifier9; Done in 21.374497175216675 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier10
# INFO:utils.ml:Top 10 features for XGBClassifier10: [('color_moments_lab_L_iqr', 0.06164008), ('color_moments_rgb_B_std', 0.029484052), ('color_moments_lab_B_var', 0.027316244), ('color_moments_rgb_B_iqr', 0.02389095), ('glcm_energy_dist_1_angle_0', 0.022226706), ('lbp_rad1_bins8_4', 0.018464608), ('lbp_rad4_bins32_32', 0.017308945), ('gradient_magnitude_std', 0.017292872), ('gradient_direction_std', 0.015300091), ('color_moments_lab_B_std', 0.011756399)]
# INFO:utils.ml:Fitted classifier: XGBClassifier10; Done in 33.700207471847534 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier11
# INFO:utils.ml:Top 10 features for XGBClassifier11: [('color_moments_lab_L_iqr', 0.056828346), ('color_moments_rgb_B_iqr', 0.046194002), ('color_moments_lab_B_var', 0.017512228), ('color_moments_rgb_B_std', 0.01661451), ('color_moments_lab_B_std', 0.016240263), ('color_moments_rgb_R_mean', 0.0152493855), ('lbp_rad1_bins8_4', 0.0144743975), ('color_moments_hsv_H_mean', 0.01261656), ('lbp_rad4_bins32_32', 0.012460251), ('color_moments_lab_L_skew', 0.012438283)]
# INFO:utils.ml:Fitted classifier: XGBClassifier11; Done in 11.137294292449951 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier12
# INFO:utils.ml:Top 10 features for XGBClassifier12: [('color_moments_lab_L_iqr', 0.05272417), ('color_moments_rgb_B_iqr', 0.027920712), ('color_moments_lab_B_var', 0.017329458), ('lbp_rad4_bins32_32', 0.017114656), ('gradient_magnitude_mean', 0.016552957), ('lbp_rad1_bins8_4', 0.016388642), ('glcm_energy_dist_1_angle_0', 0.014338687), ('color_moments_rgb_B_std', 0.014034727), ('gradient_direction_std', 0.01395396), ('color_moments_lab_B_std', 0.011402105)]
# INFO:utils.ml:Fitted classifier: XGBClassifier12; Done in 18.884764671325684 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier13
# INFO:utils.ml:Top 10 features for XGBClassifier13: [('color_moments_lab_L_iqr', 0.050421726), ('color_moments_rgb_B_iqr', 0.031099916), ('color_moments_lab_B_var', 0.020240813), ('color_moments_rgb_B_std', 0.0184946), ('gradient_direction_std', 0.017133554), ('lbp_rad1_bins8_4', 0.017042235), ('lbp_rad1_bins8_8', 0.015159132), ('color_moments_rgb_B_var', 0.013971007), ('lbp_rad4_bins32_32', 0.01370005), ('glcm_energy_dist_1_angle_0', 0.013573056)]
# INFO:utils.ml:Fitted classifier: XGBClassifier13; Done in 11.862605333328247 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier14
# INFO:utils.ml:Top 10 features for XGBClassifier14: [('color_moments_lab_L_iqr', 0.042282034), ('color_moments_rgb_B_iqr', 0.030297386), ('color_moments_lab_B_var', 0.02007297), ('lbp_rad1_bins8_4', 0.018451143), ('color_moments_rgb_B_std', 0.01819465), ('gradient_direction_std', 0.017477645), ('color_moments_rgb_B_var', 0.015914736), ('glcm_energy_dist_1_angle_0', 0.015107951), ('lbp_rad1_bins8_8', 0.014534772), ('lbp_rad4_bins32_32', 0.0141571)]
# INFO:utils.ml:Fitted classifier: XGBClassifier14; Done in 13.515034914016724 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier15
# INFO:utils.ml:Top 10 features for XGBClassifier15: [('color_moments_lab_L_iqr', 0.05511635), ('color_moments_rgb_B_iqr', 0.027514288), ('color_moments_lab_B_var', 0.019120296), ('color_moments_rgb_B_std', 0.01795), ('lbp_rad4_bins32_32', 0.016370045), ('lbp_rad1_bins8_4', 0.016287977), ('glcm_energy_dist_1_angle_0', 0.01496439), ('lbp_rad1_bins8_8', 0.014379057), ('gradient_direction_std', 0.013639572), ('color_moments_lab_B_std', 0.0121266395)]
# INFO:utils.ml:Fitted classifier: XGBClassifier15; Done in 16.824301958084106 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier16
# INFO:utils.ml:Top 10 features for XGBClassifier16: [('color_moments_lab_L_iqr', 0.0551017), ('color_moments_rgb_B_iqr', 0.027807876), ('color_moments_lab_B_var', 0.019183407), ('color_moments_rgb_B_std', 0.017193409), ('lbp_rad1_bins8_4', 0.016404325), ('lbp_rad4_bins32_32', 0.016139667), ('glcm_energy_dist_1_angle_0', 0.014822358), ('gradient_direction_std', 0.013864314), ('lbp_rad1_bins8_8', 0.01362313), ('color_moments_lab_B_std', 0.011844653)]
# INFO:utils.ml:Fitted classifier: XGBClassifier16; Done in 13.468362808227539 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier17
# INFO:utils.ml:Top 10 features for XGBClassifier17: [('color_moments_lab_L_iqr', 0.05448448), ('color_moments_rgb_B_iqr', 0.025247151), ('color_moments_lab_B_var', 0.020449314), ('lbp_rad4_bins32_32', 0.01949078), ('lbp_rad1_bins8_4', 0.016692081), ('lbp_rad1_bins8_8', 0.015827347), ('color_moments_rgb_B_std', 0.015535777), ('gradient_direction_std', 0.015403464), ('color_moments_rgb_B_var', 0.01380184), ('glcm_energy_dist_1_angle_0', 0.013577331)]
# INFO:utils.ml:Fitted classifier: XGBClassifier17; Done in 12.01119351387024 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier18
# INFO:utils.ml:Top 10 features for XGBClassifier18: [('color_moments_lab_L_iqr', 0.054776877), ('color_moments_rgb_B_iqr', 0.02550247), ('color_moments_lab_B_var', 0.020139713), ('lbp_rad4_bins32_32', 0.019684928), ('lbp_rad1_bins8_4', 0.016621957), ('lbp_rad1_bins8_8', 0.016462676), ('color_moments_rgb_B_std', 0.015801545), ('gradient_direction_std', 0.015482341), ('gradient_magnitude_mean', 0.013945251), ('glcm_energy_dist_1_angle_0', 0.013814694)]
# INFO:utils.ml:Fitted classifier: XGBClassifier18; Done in 17.384775638580322 seconds
# INFO:utils.ml:Fitting completed in 309.89 seconds.

# %%
pipeline.predict_with_classifiers(VAL_PATH, percent)
# Out:
# INFO:utils.ml:Predicting with classifiers on dataset: C:\Users\gimes\Src\repos\CADx-Project\dataset\multiclass\val
# Processed 5/53 batches.
# Processed 10/53 batches.
# Processed 15/53 batches.
# Processed 20/53 batches.
# Processed 25/53 batches.
# Processed 30/53 batches.
# Processed 35/53 batches.
# Processed 40/53 batches.
# Processed 45/53 batches.
# Processed 50/53 batches.
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier0
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier1
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier2
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier3
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier4
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier5
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier6
# Processed 53/53 batches.
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier7
# INFO:utils.ml:Predictions made with classifier: XGBClassifier8
# INFO:utils.ml:Predictions made with classifier: XGBClassifier9
# INFO:utils.ml:Predictions made with classifier: XGBClassifier10
# INFO:utils.ml:Predictions made with classifier: XGBClassifier11
# INFO:utils.ml:Predictions made with classifier: XGBClassifier12
# INFO:utils.ml:Predictions made with classifier: XGBClassifier13
# INFO:utils.ml:Predictions made with classifier: XGBClassifier14
# INFO:utils.ml:Predictions made with classifier: XGBClassifier15
# INFO:utils.ml:Predictions made with classifier: XGBClassifier16
# INFO:utils.ml:Predictions made with classifier: XGBClassifier17
# INFO:utils.ml:Predictions made with classifier: XGBClassifier18
# {'GT': array([0, 0, 0, ..., 2, 2, 2]),
#  'RandomForestClassifier0': array([0, 0, 2, ..., 0, 0, 0]),
#  'RandomForestClassifier1': array([0, 0, 2, ..., 1, 0, 0]),
#  'RandomForestClassifier2': array([0, 0, 2, ..., 1, 0, 0]),
#  'RandomForestClassifier3': array([0, 0, 2, ..., 1, 0, 0]),
#  'RandomForestClassifier4': array([0, 0, 2, ..., 1, 0, 0]),
#  'RandomForestClassifier5': array([0, 0, 2, ..., 1, 0, 0]),
#  'RandomForestClassifier6': array([0, 0, 2, ..., 1, 0, 0]),
#  'RandomForestClassifier7': array([0, 0, 2, ..., 1, 0, 0]),
#  'XGBClassifier8': array([2, 0, 0, ..., 0, 0, 0], dtype=int64),
#  'XGBClassifier9': array([2, 0, 0, ..., 0, 2, 0], dtype=int64),
#  'XGBClassifier10': array([2, 0, 0, ..., 0, 0, 0], dtype=int64),
#  'XGBClassifier11': array([0, 0, 2, ..., 0, 0, 0], dtype=int64),
#  'XGBClassifier12': array([0, 0, 2, ..., 0, 0, 0], dtype=int64),
#  'XGBClassifier13': array([0, 0, 2, ..., 0, 0, 0], dtype=int64),
#  'XGBClassifier14': array([0, 0, 2, ..., 0, 2, 0], dtype=int64),
#  'XGBClassifier15': array([0, 0, 2, ..., 0, 0, 0], dtype=int64),
#  'XGBClassifier16': array([0, 0, 2, ..., 1, 0, 0], dtype=int64),
#  'XGBClassifier17': array([0, 0, 2, ..., 0, 0, 0], dtype=int64),
#  'XGBClassifier18': array([0, 0, 2, ..., 0, 0, 0], dtype=int64)}

# %%
df_borderline_smote = pd.DataFrame(data=pipeline.calculate_metrics(
    ["accuracy", "precision", "recall", "f1", "kappa"],))
df_borderline_smote = df_borderline_smote.T
df_borderline_smote
# Out:
# INFO:utils.ml:Metrics for classifier GT: {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'kappa': 1.0}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier0: {'accuracy': 0.8362204724409449, 'precision': 0.7448201814653773, 'recall': 0.7320433431460103, 'f1': 0.7374251057008433, 'kappa': 0.7051430306331566}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier1: {'accuracy': 0.8322834645669291, 'precision': 0.7353491657082506, 'recall': 0.7256421657256026, 'f1': 0.7298646703907566, 'kappa': 0.6980241125251172}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier2: {'accuracy': 0.8354330708661417, 'precision': 0.7319176474355581, 'recall': 0.7277864360221278, 'f1': 0.7295407770706291, 'kappa': 0.7042878978961582}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier3: {'accuracy': 0.8456692913385827, 'precision': 0.7487613870790913, 'recall': 0.7205048147148312, 'f1': 0.7316176553392993, 'kappa': 0.720090679285001}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier4: {'accuracy': 0.8409448818897638, 'precision': 0.7454586597429635, 'recall': 0.7409244081075448, 'f1': 0.7428333658250953, 'kappa': 0.7143067143601691}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier5: {'accuracy': 0.8496062992125984, 'precision': 0.7619291089819592, 'recall': 0.7258397803855855, 'f1': 0.7398156439799415, 'kappa': 0.726526387943125}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier6: {'accuracy': 0.8385826771653543, 'precision': 0.7449200026548425, 'recall': 0.7356842168145374, 'f1': 0.7398268892710739, 'kappa': 0.7092633704231455}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier7: {'accuracy': 0.8456692913385827, 'precision': 0.754719334173493, 'recall': 0.7199717088400045, 'f1': 0.7333426965235615, 'kappa': 0.7194812454077056}
# INFO:utils.ml:Metrics for classifier XGBClassifier8: {'accuracy': 0.8748031496062992, 'precision': 0.781291439661142, 'recall': 0.7593324405385302, 'f1': 0.768635979084687, 'kappa': 0.7735022410861304}
# INFO:utils.ml:Metrics for classifier XGBClassifier9: {'accuracy': 0.8740157480314961, 'precision': 0.7790045017893119, 'recall': 0.7591962023705189, 'f1': 0.7675892959724303, 'kappa': 0.7723188074525253}
# INFO:utils.ml:Metrics for classifier XGBClassifier10: {'accuracy': 0.8755905511811024, 'precision': 0.7819913119542868, 'recall': 0.7601794865396437, 'f1': 0.7693917297348606, 'kappa': 0.7749721883298644}
# INFO:utils.ml:Metrics for classifier XGBClassifier11: {'accuracy': 0.8181102362204724, 'precision': 0.7022591275878605, 'recall': 0.7214799069497092, 'f1': 0.7104448866211376, 'kappa': 0.6776607246453246}
# INFO:utils.ml:Metrics for classifier XGBClassifier12: {'accuracy': 0.8748031496062992, 'precision': 0.7812906135804166, 'recall': 0.7586216327054278, 'f1': 0.7683758267201481, 'kappa': 0.7731816793069983}
# INFO:utils.ml:Metrics for classifier XGBClassifier13: {'accuracy': 0.8669291338582678, 'precision': 0.7650706988323219, 'recall': 0.7501176487787591, 'f1': 0.756748416094661, 'kappa': 0.7594988055058783}
# INFO:utils.ml:Metrics for classifier XGBClassifier14: {'accuracy': 0.8614173228346457, 'precision': 0.7622752996110523, 'recall': 0.7376904845264445, 'f1': 0.747770119649223, 'kappa': 0.748842644613241}
# INFO:utils.ml:Metrics for classifier XGBClassifier15: {'accuracy': 0.8700787401574803, 'precision': 0.7833759118296518, 'recall': 0.7614252906939375, 'f1': 0.7709425119443106, 'kappa': 0.7648718155867937}
# INFO:utils.ml:Metrics for classifier XGBClassifier16: {'accuracy': 0.8677165354330708, 'precision': 0.7762500676504547, 'recall': 0.7594172585654234, 'f1': 0.7669641484089325, 'kappa': 0.760777137936602}
# INFO:utils.ml:Metrics for classifier XGBClassifier17: {'accuracy': 0.8732283464566929, 'precision': 0.7862238924787253, 'recall': 0.7606928057425207, 'f1': 0.7716257252723343, 'kappa': 0.7701313535122787}
# INFO:utils.ml:Metrics for classifier XGBClassifier18: {'accuracy': 0.8748031496062992, 'precision': 0.788558653434755, 'recall': 0.7681404082406322, 'f1': 0.7770445560865707, 'kappa': 0.7736160003587524}
#                          accuracy  precision    recall        f1     kappa
# GT                       1.000000   1.000000  1.000000  1.000000  1.000000
# RandomForestClassifier0  0.836220   0.744820  0.732043  0.737425  0.705143
# RandomForestClassifier1  0.832283   0.735349  0.725642  0.729865  0.698024
# RandomForestClassifier2  0.835433   0.731918  0.727786  0.729541  0.704288
# RandomForestClassifier3  0.845669   0.748761  0.720505  0.731618  0.720091
# RandomForestClassifier4  0.840945   0.745459  0.740924  0.742833  0.714307
# RandomForestClassifier5  0.849606   0.761929  0.725840  0.739816  0.726526
# RandomForestClassifier6  0.838583   0.744920  0.735684  0.739827  0.709263
# RandomForestClassifier7  0.845669   0.754719  0.719972  0.733343  0.719481
# XGBClassifier8           0.874803   0.781291  0.759332  0.768636  0.773502
# XGBClassifier9           0.874016   0.779005  0.759196  0.767589  0.772319
# XGBClassifier10          0.875591   0.781991  0.760179  0.769392  0.774972
# XGBClassifier11          0.818110   0.702259  0.721480  0.710445  0.677661
# XGBClassifier12          0.874803   0.781291  0.758622  0.768376  0.773182
# XGBClassifier13          0.866929   0.765071  0.750118  0.756748  0.759499
# XGBClassifier14          0.861417   0.762275  0.737690  0.747770  0.748843
# XGBClassifier15          0.870079   0.783376  0.761425  0.770943  0.764872
# XGBClassifier16          0.867717   0.776250  0.759417  0.766964  0.760777
# XGBClassifier17          0.873228   0.786224  0.760693  0.771626  0.770131
# XGBClassifier18          0.874803   0.788559  0.768140  0.777045  0.773616

# %%
highest = df_borderline_smote[df_borderline_smote["kappa"] == df_borderline_smote.iloc[1:]["kappa"].max()]
idx = highest.index[0]

confusion_matrix(pipeline.predictions["GT"], pipeline.predictions[idx])
# Out:
# array([[445,  30,  23],
#        [ 44, 623,  11],
#        [ 35,  15,  44]], dtype=int64)

# %% [markdown]
# ___
# # PCA

# %%
from sklearn.decomposition import PCA
from imblearn.over_sampling import BorderlineSMOTE
smote = BorderlineSMOTE(sampling_strategy='auto', random_state=42)

pipeline.feature_matrix, pipeline.labels = smote.fit_resample(
    np.nan_to_num(pipeline.backup_feature_matrix), pipeline.backup_labels)

pca = PCA(n_components=100)

pipeline.feature_matrix = pca.fit_transform(pipeline.feature_matrix, pipeline.labels)

print(pipeline.backup_feature_matrix.shape)
print(pipeline.feature_matrix.shape)

print(pipeline.backup_labels.shape)
print(pipeline.labels.shape)

print(pca.get_feature_names_out())

pipeline.fitted_classifiers = {}
pipeline.fit_classifiers()
# Out:
# INFO:utils.ml:Fitting classifiers...
# INFO:utils.ml:Fitting classifier: RandomForestClassifier0
# (5082, 189)
# (8139, 100)
# (5082,)
# (8139,)
# ['pca0' 'pca1' 'pca2' 'pca3' 'pca4' 'pca5' 'pca6' 'pca7' 'pca8' 'pca9'
#  'pca10' 'pca11' 'pca12' 'pca13' 'pca14' 'pca15' 'pca16' 'pca17' 'pca18'
#  'pca19' 'pca20' 'pca21' 'pca22' 'pca23' 'pca24' 'pca25' 'pca26' 'pca27'
#  'pca28' 'pca29' 'pca30' 'pca31' 'pca32' 'pca33' 'pca34' 'pca35' 'pca36'
#  'pca37' 'pca38' 'pca39' 'pca40' 'pca41' 'pca42' 'pca43' 'pca44' 'pca45'
#  'pca46' 'pca47' 'pca48' 'pca49' 'pca50' 'pca51' 'pca52' 'pca53' 'pca54'
#  'pca55' 'pca56' 'pca57' 'pca58' 'pca59' 'pca60' 'pca61' 'pca62' 'pca63'
#  'pca64' 'pca65' 'pca66' 'pca67' 'pca68' 'pca69' 'pca70' 'pca71' 'pca72'
#  'pca73' 'pca74' 'pca75' 'pca76' 'pca77' 'pca78' 'pca79' 'pca80' 'pca81'
#  'pca82' 'pca83' 'pca84' 'pca85' 'pca86' 'pca87' 'pca88' 'pca89' 'pca90'
#  'pca91' 'pca92' 'pca93' 'pca94' 'pca95' 'pca96' 'pca97' 'pca98' 'pca99']
# INFO:utils.ml:Top 10 features for RandomForestClassifier0: [('gradient_magnitude_std', 0.04170418579194047), ('color_moments_rgb_R_median', 0.03078526332404313), ('color_moments_rgb_R_mean', 0.028379020849434906), ('gradient_direction_mean', 0.028183303417517146), ('color_moments_lab_L_var', 0.025870378483579856), ('color_moments_rgb_R_skew', 0.020136574229036325), ('color_moments_rgb_G_entropy', 0.019541009969340606), ('color_moments_lab_A_mean', 0.017727507043115064), ('gradient_direction_std', 0.01768926130506994), ('color_moments_lab_L_kurtosis', 0.01565686943456985)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier0; Done in 8.598012447357178 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier1
# INFO:utils.ml:Top 10 features for RandomForestClassifier1: [('gradient_magnitude_std', 0.04385974818488469), ('color_moments_rgb_R_median', 0.033100391477724006), ('gradient_direction_mean', 0.02817613634741616), ('color_moments_rgb_R_mean', 0.02603996110317474), ('color_moments_lab_L_var', 0.025564876578843515), ('color_moments_rgb_G_entropy', 0.019743478687863823), ('color_moments_lab_A_mean', 0.019078560947289745), ('gradient_direction_std', 0.018885834616327604), ('color_moments_rgb_R_skew', 0.01835462432187318), ('color_moments_rgb_B_max', 0.0172017258228069)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier1; Done in 12.777026414871216 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier2
# INFO:utils.ml:Top 10 features for RandomForestClassifier2: [('gradient_magnitude_std', 0.04180382379360141), ('color_moments_rgb_R_median', 0.03249498945009758), ('gradient_direction_mean', 0.028240346789737185), ('color_moments_lab_L_var', 0.02597858205867157), ('color_moments_rgb_R_mean', 0.02365174939733963), ('color_moments_rgb_G_entropy', 0.019502823892719623), ('color_moments_lab_A_mean', 0.019293756759375114), ('gradient_direction_std', 0.01868659554085149), ('color_moments_rgb_R_skew', 0.018440826093963792), ('color_moments_rgb_B_max', 0.01716585502522743)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier2; Done in 8.606124639511108 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier3
# INFO:utils.ml:Top 10 features for RandomForestClassifier3: [('gradient_magnitude_std', 0.043001829287262955), ('color_moments_rgb_R_median', 0.03359466560367149), ('gradient_direction_mean', 0.028606805104624412), ('color_moments_lab_L_var', 0.026052562570451628), ('color_moments_rgb_R_mean', 0.02417453497859827), ('color_moments_rgb_G_entropy', 0.020808269686322052), ('gradient_direction_std', 0.020131023231848334), ('color_moments_rgb_R_skew', 0.019268562737329208), ('color_moments_lab_A_mean', 0.01763484379128332), ('color_moments_rgb_B_max', 0.017477745407639512)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier3; Done in 11.902443408966064 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier4
# INFO:utils.ml:Top 10 features for RandomForestClassifier4: [('gradient_magnitude_std', 0.042524536494470355), ('color_moments_rgb_R_median', 0.033706441603286785), ('gradient_direction_mean', 0.028518544622469635), ('color_moments_lab_L_var', 0.025538368153271113), ('color_moments_rgb_R_mean', 0.022611711720581996), ('color_moments_rgb_G_entropy', 0.020689206633402287), ('color_moments_lab_A_mean', 0.018902166322351668), ('gradient_direction_std', 0.01872249751518573), ('color_moments_rgb_R_skew', 0.018002490234657335), ('color_moments_rgb_B_max', 0.017324042418970405)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier4; Done in 12.90610957145691 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier5
# INFO:utils.ml:Top 10 features for RandomForestClassifier5: [('gradient_magnitude_std', 0.04335595553674151), ('color_moments_rgb_R_median', 0.03469449829177612), ('gradient_direction_mean', 0.028760431681371296), ('color_moments_lab_L_var', 0.026153578663056988), ('color_moments_rgb_R_mean', 0.023296516384091987), ('color_moments_rgb_G_entropy', 0.021027315563656074), ('gradient_direction_std', 0.01945543839967241), ('color_moments_rgb_R_skew', 0.018877883857560483), ('color_moments_lab_A_mean', 0.018401214981049994), ('color_moments_rgb_B_max', 0.01746354779779526)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier5; Done in 18.212929010391235 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier6
# INFO:utils.ml:Top 10 features for RandomForestClassifier6: [('gradient_magnitude_std', 0.04313001087851922), ('color_moments_rgb_R_median', 0.033178046357857226), ('gradient_direction_mean', 0.03010620604212093), ('color_moments_lab_L_var', 0.02601220212867304), ('color_moments_rgb_R_mean', 0.02180993032912845), ('color_moments_rgb_G_entropy', 0.021031183183915572), ('gradient_direction_std', 0.018767446728531395), ('color_moments_rgb_R_skew', 0.018576315988877767), ('color_moments_lab_A_mean', 0.018546221495434643), ('color_moments_rgb_B_max', 0.017104147653972782)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier6; Done in 16.361222505569458 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier7
# INFO:utils.ml:Top 10 features for RandomForestClassifier7: [('gradient_magnitude_std', 0.04406900941442611), ('color_moments_rgb_R_median', 0.034380054337381026), ('gradient_direction_mean', 0.029829911730841055), ('color_moments_lab_L_var', 0.02687254393374334), ('color_moments_rgb_R_mean', 0.02359014239529249), ('color_moments_rgb_G_entropy', 0.02114915170600247), ('gradient_direction_std', 0.018622705293533815), ('color_moments_lab_A_mean', 0.018601770522010886), ('color_moments_rgb_R_skew', 0.01840417449579684), ('color_moments_rgb_B_max', 0.017323648612488026)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier7; Done in 22.856998920440674 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier8
# INFO:utils.ml:Top 10 features for XGBClassifier8: [('gradient_magnitude_std', 0.05140053), ('gradient_direction_mean', 0.033548247), ('color_moments_rgb_R_median', 0.0292442), ('color_moments_lab_L_var', 0.026498793), ('color_moments_rgb_R_mean', 0.024109546), ('color_moments_rgb_G_entropy', 0.02034164), ('lbp_rad1_bins8_2', 0.020341426), ('color_moments_rgb_R_skew', 0.018980855), ('color_moments_lab_A_mean', 0.018381216), ('color_moments_lab_L_kurtosis', 0.017980048)]
# INFO:utils.ml:Fitted classifier: XGBClassifier8; Done in 3.732297420501709 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier9
# INFO:utils.ml:Top 10 features for XGBClassifier9: [('gradient_magnitude_std', 0.05199924), ('gradient_direction_mean', 0.033253808), ('color_moments_rgb_R_median', 0.029029245), ('color_moments_lab_L_var', 0.026444409), ('color_moments_rgb_R_mean', 0.024071306), ('lbp_rad1_bins8_2', 0.020573486), ('color_moments_rgb_G_entropy', 0.020352341), ('color_moments_rgb_R_skew', 0.01915649), ('color_moments_lab_A_mean', 0.018294921), ('color_moments_lab_B_min', 0.018063877)]
# INFO:utils.ml:Fitted classifier: XGBClassifier9; Done in 4.244760751724243 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier10
# INFO:utils.ml:Top 10 features for XGBClassifier10: [('gradient_magnitude_std', 0.052247573), ('gradient_direction_mean', 0.032808453), ('color_moments_rgb_R_median', 0.029027933), ('color_moments_lab_L_var', 0.026424062), ('color_moments_rgb_R_mean', 0.02395195), ('color_moments_rgb_G_entropy', 0.020371525), ('lbp_rad1_bins8_2', 0.019923547), ('color_moments_rgb_R_skew', 0.019172907), ('color_moments_lab_A_mean', 0.01854427), ('color_moments_lab_B_min', 0.018128917)]
# INFO:utils.ml:Fitted classifier: XGBClassifier10; Done in 5.110948085784912 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier11
# INFO:utils.ml:Top 10 features for XGBClassifier11: [('gradient_magnitude_std', 0.041918267), ('gradient_direction_mean', 0.026597587), ('color_moments_lab_L_var', 0.022672044), ('color_moments_rgb_R_median', 0.022498768), ('lbp_rad1_bins8_2', 0.020474864), ('color_moments_rgb_G_entropy', 0.020026544), ('color_moments_rgb_R_mean', 0.019835358), ('color_moments_lab_L_kurtosis', 0.01812056), ('color_moments_lab_A_mean', 0.017252624), ('color_moments_rgb_G_std', 0.01706126)]
# INFO:utils.ml:Fitted classifier: XGBClassifier11; Done in 1.9220545291900635 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier12
# INFO:utils.ml:Top 10 features for XGBClassifier12: [('gradient_magnitude_std', 0.037000015), ('gradient_direction_mean', 0.026095524), ('color_moments_rgb_R_median', 0.025044037), ('color_moments_lab_L_var', 0.022503179), ('color_moments_rgb_R_mean', 0.020462127), ('color_moments_rgb_G_entropy', 0.019459601), ('lbp_rad1_bins8_2', 0.017414086), ('color_moments_lab_A_mean', 0.017089132), ('gradient_direction_std', 0.016157702), ('color_moments_rgb_R_skew', 0.015884671)]
# INFO:utils.ml:Fitted classifier: XGBClassifier12; Done in 5.077910423278809 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier13
# INFO:utils.ml:Top 10 features for XGBClassifier13: [('gradient_magnitude_std', 0.04198157), ('color_moments_rgb_R_median', 0.026262317), ('gradient_direction_mean', 0.026146999), ('color_moments_lab_L_var', 0.023663437), ('color_moments_rgb_R_mean', 0.021751808), ('color_moments_rgb_G_entropy', 0.02004218), ('lbp_rad1_bins8_2', 0.019780995), ('color_moments_lab_L_kurtosis', 0.017182766), ('color_moments_rgb_R_skew', 0.01694482), ('color_moments_lab_B_min', 0.016283162)]
# INFO:utils.ml:Fitted classifier: XGBClassifier13; Done in 3.3468000888824463 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier14
# INFO:utils.ml:Top 10 features for XGBClassifier14: [('gradient_magnitude_std', 0.04109678), ('color_moments_rgb_R_median', 0.028556382), ('gradient_direction_mean', 0.026857434), ('color_moments_lab_L_var', 0.023799777), ('color_moments_rgb_R_mean', 0.023439936), ('lbp_rad1_bins8_2', 0.02178016), ('color_moments_rgb_G_entropy', 0.020662695), ('color_moments_lab_A_mean', 0.017167851), ('color_moments_rgb_R_skew', 0.016881486), ('color_moments_lab_L_kurtosis', 0.016810033)]
# INFO:utils.ml:Fitted classifier: XGBClassifier14; Done in 3.7041237354278564 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier15
# INFO:utils.ml:Top 10 features for XGBClassifier15: [('gradient_magnitude_std', 0.038180064), ('gradient_direction_mean', 0.027926484), ('color_moments_rgb_R_median', 0.027734311), ('color_moments_lab_L_var', 0.02441772), ('lbp_rad1_bins8_2', 0.020866994), ('color_moments_rgb_R_mean', 0.019326631), ('color_moments_rgb_G_entropy', 0.019150568), ('color_moments_lab_L_kurtosis', 0.017821351), ('color_moments_lab_A_mean', 0.01697), ('color_moments_rgb_R_skew', 0.016285287)]
# INFO:utils.ml:Fitted classifier: XGBClassifier15; Done in 9.125596523284912 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier16
# INFO:utils.ml:Top 10 features for XGBClassifier16: [('gradient_magnitude_std', 0.037145864), ('gradient_direction_mean', 0.027798666), ('color_moments_rgb_R_median', 0.02749256), ('color_moments_lab_L_var', 0.024332397), ('lbp_rad1_bins8_2', 0.020665482), ('color_moments_rgb_G_entropy', 0.019444155), ('color_moments_rgb_R_mean', 0.019113949), ('color_moments_lab_L_kurtosis', 0.017607171), ('color_moments_lab_A_mean', 0.017289776), ('color_moments_rgb_R_skew', 0.016162213)]
# INFO:utils.ml:Fitted classifier: XGBClassifier16; Done in 7.824019908905029 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier17
# INFO:utils.ml:Top 10 features for XGBClassifier17: [('gradient_magnitude_std', 0.03842706), ('color_moments_rgb_R_median', 0.027332993), ('gradient_direction_mean', 0.027142743), ('color_moments_lab_L_var', 0.02331493), ('color_moments_rgb_R_mean', 0.02287376), ('color_moments_rgb_G_entropy', 0.020329941), ('lbp_rad1_bins8_2', 0.019793298), ('color_moments_rgb_R_skew', 0.0181358), ('color_moments_lab_L_kurtosis', 0.016712496), ('color_moments_lab_A_mean', 0.016675552)]
# INFO:utils.ml:Fitted classifier: XGBClassifier17; Done in 5.564953327178955 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier18
# INFO:utils.ml:Top 10 features for XGBClassifier18: [('gradient_magnitude_std', 0.03929547), ('color_moments_rgb_R_median', 0.027330931), ('gradient_direction_mean', 0.026997248), ('color_moments_lab_L_var', 0.023446864), ('color_moments_rgb_R_mean', 0.023097249), ('color_moments_rgb_G_entropy', 0.020447467), ('lbp_rad1_bins8_2', 0.019691069), ('color_moments_rgb_R_skew', 0.018212587), ('color_moments_lab_A_mean', 0.016582364), ('color_moments_lab_L_kurtosis', 0.016575826)]
# INFO:utils.ml:Fitted classifier: XGBClassifier18; Done in 6.409698009490967 seconds
# INFO:utils.ml:Fitting completed in 168.32 seconds.

# %%
# Load and extract features from the new dataset
new_loader = FactoryLoader(path=VAL_PATH, factory=pipeline.loader.get_factory(),
                           percentage=percent, batch_size=pipeline.batch_size)
new_feature_matrix, new_labels = pipeline.feature_strategy.run(new_loader.get_loader())

new_feature_matrix = np.nan_to_num(new_feature_matrix) # Impute nans
new_feature_matrix = pca.transform(new_feature_matrix) # Impute nans

# Store predictions in the class attribute
pipeline.predictions = {"GT": new_labels, }
for clf_name, clf in pipeline.fitted_classifiers.items():

    pipeline.predictions[clf_name] = clf.predict(new_feature_matrix)
    if pipeline.verbose:
        logger.info("Predictions made with classifier: %s", clf_name)
# Out:
# Processed 5/53 batches.
# Processed 10/53 batches.
# Processed 15/53 batches.
# Processed 20/53 batches.
# Processed 25/53 batches.
# Processed 30/53 batches.
# Processed 35/53 batches.
# Processed 40/53 batches.
# Processed 45/53 batches.
# Processed 50/53 batches.
# INFO:utils.utils:Predictions made with classifier: RandomForestClassifier0
# INFO:utils.utils:Predictions made with classifier: RandomForestClassifier1
# INFO:utils.utils:Predictions made with classifier: RandomForestClassifier2
# INFO:utils.utils:Predictions made with classifier: RandomForestClassifier3
# INFO:utils.utils:Predictions made with classifier: RandomForestClassifier4
# Processed 53/53 batches.
# INFO:utils.utils:Predictions made with classifier: RandomForestClassifier5
# INFO:utils.utils:Predictions made with classifier: RandomForestClassifier6
# INFO:utils.utils:Predictions made with classifier: RandomForestClassifier7
# INFO:utils.utils:Predictions made with classifier: XGBClassifier8
# INFO:utils.utils:Predictions made with classifier: XGBClassifier9
# INFO:utils.utils:Predictions made with classifier: XGBClassifier10
# INFO:utils.utils:Predictions made with classifier: XGBClassifier11
# INFO:utils.utils:Predictions made with classifier: XGBClassifier12
# INFO:utils.utils:Predictions made with classifier: XGBClassifier13
# INFO:utils.utils:Predictions made with classifier: XGBClassifier14
# INFO:utils.utils:Predictions made with classifier: XGBClassifier15
# INFO:utils.utils:Predictions made with classifier: XGBClassifier16
# INFO:utils.utils:Predictions made with classifier: XGBClassifier17
# INFO:utils.utils:Predictions made with classifier: XGBClassifier18

# %%
df_pca = pd.DataFrame(data=pipeline.calculate_metrics(avg="macro"))
df_pca = df_pca.T
df_pca
# Out:
# INFO:utils.ml:Metrics for classifier GT: {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'kappa': 1.0}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier0: {'accuracy': 0.8023622047244094, 'precision': 0.6830837716214333, 'recall': 0.6356410390195691, 'f1': 0.6471530680864929, 'kappa': 0.6360857037175722}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier1: {'accuracy': 0.8070866141732284, 'precision': 0.686342664995935, 'recall': 0.6337258908224374, 'f1': 0.6443746921173038, 'kappa': 0.6441836636675099}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier2: {'accuracy': 0.8086614173228347, 'precision': 0.7018946467475881, 'recall': 0.640284983529171, 'f1': 0.6537751540479665, 'kappa': 0.6470156287173106}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier3: {'accuracy': 0.805511811023622, 'precision': 0.7022589889285316, 'recall': 0.632564904695037, 'f1': 0.645377420306688, 'kappa': 0.6403742886360614}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier4: {'accuracy': 0.8196850393700787, 'precision': 0.7137745107983887, 'recall': 0.6516440455854674, 'f1': 0.6657532810451726, 'kappa': 0.6675058191912124}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier5: {'accuracy': 0.8118110236220473, 'precision': 0.7151148489723024, 'recall': 0.6339766900401456, 'f1': 0.6472040074009021, 'kappa': 0.6507986544134228}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier6: {'accuracy': 0.8173228346456692, 'precision': 0.7229722557997222, 'recall': 0.65610033178594, 'f1': 0.6721918975352462, 'kappa': 0.6635131492994806}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier7: {'accuracy': 0.815748031496063, 'precision': 0.7278667285240626, 'recall': 0.6369680063377845, 'f1': 0.6508567897236012, 'kappa': 0.6579986742528863}
# INFO:utils.ml:Metrics for classifier XGBClassifier8: {'accuracy': 0.8559055118110236, 'precision': 0.7697063345101224, 'recall': 0.7096356303264901, 'f1': 0.7289084912789318, 'kappa': 0.7354889374487845}
# INFO:utils.ml:Metrics for classifier XGBClassifier9: {'accuracy': 0.8551181102362204, 'precision': 0.7665136507190771, 'recall': 0.70608953103571, 'f1': 0.7250390690194446, 'kappa': 0.7339757017176373}
# INFO:utils.ml:Metrics for classifier XGBClassifier10: {'accuracy': 0.8574803149606299, 'precision': 0.7748228390538706, 'recall': 0.7075644572893974, 'f1': 0.7281973454743933, 'kappa': 0.7377493930598908}
# INFO:utils.ml:Metrics for classifier XGBClassifier11: {'accuracy': 0.7889763779527559, 'precision': 0.6563962327329597, 'recall': 0.6727781016742549, 'f1': 0.662871987008714, 'kappa': 0.6266738035485513}
# INFO:utils.ml:Metrics for classifier XGBClassifier12: {'accuracy': 0.8606299212598425, 'precision': 0.7925125928455562, 'recall': 0.7165284498314604, 'f1': 0.7395939466613717, 'kappa': 0.7436900244463094}
# INFO:utils.ml:Metrics for classifier XGBClassifier13: {'accuracy': 0.8511811023622047, 'precision': 0.7549717260853654, 'recall': 0.7068634797773911, 'f1': 0.7228920601350799, 'kappa': 0.7279299416482665}
# INFO:utils.ml:Metrics for classifier XGBClassifier14: {'accuracy': 0.8551181102362204, 'precision': 0.7678209297422846, 'recall': 0.718662763777132, 'f1': 0.7358493316059738, 'kappa': 0.735207999057228}
# INFO:utils.ml:Metrics for classifier XGBClassifier15: {'accuracy': 0.852755905511811, 'precision': 0.7537643007759361, 'recall': 0.7055031145734006, 'f1': 0.7211878564752937, 'kappa': 0.7307406248441064}
# INFO:utils.ml:Metrics for classifier XGBClassifier16: {'accuracy': 0.8535433070866142, 'precision': 0.7568362131379808, 'recall': 0.7092269158224563, 'f1': 0.7249245992311111, 'kappa': 0.73246684999026}
# INFO:utils.ml:Metrics for classifier XGBClassifier17: {'accuracy': 0.8519685039370078, 'precision': 0.7730869763392322, 'recall': 0.6980140482850249, 'f1': 0.7193147489797888, 'kappa': 0.7270478272202229}
# INFO:utils.ml:Metrics for classifier XGBClassifier18: {'accuracy': 0.8606299212598425, 'precision': 0.7844576058026966, 'recall': 0.7102418334607495, 'f1': 0.732332680701108, 'kappa': 0.7432027965636996}
#                          accuracy  precision    recall        f1     kappa
# GT                       1.000000   1.000000  1.000000  1.000000  1.000000
# RandomForestClassifier0  0.802362   0.683084  0.635641  0.647153  0.636086
# RandomForestClassifier1  0.807087   0.686343  0.633726  0.644375  0.644184
# RandomForestClassifier2  0.808661   0.701895  0.640285  0.653775  0.647016
# RandomForestClassifier3  0.805512   0.702259  0.632565  0.645377  0.640374
# RandomForestClassifier4  0.819685   0.713775  0.651644  0.665753  0.667506
# RandomForestClassifier5  0.811811   0.715115  0.633977  0.647204  0.650799
# RandomForestClassifier6  0.817323   0.722972  0.656100  0.672192  0.663513
# RandomForestClassifier7  0.815748   0.727867  0.636968  0.650857  0.657999
# XGBClassifier8           0.855906   0.769706  0.709636  0.728908  0.735489
# XGBClassifier9           0.855118   0.766514  0.706090  0.725039  0.733976
# XGBClassifier10          0.857480   0.774823  0.707564  0.728197  0.737749
# XGBClassifier11          0.788976   0.656396  0.672778  0.662872  0.626674
# XGBClassifier12          0.860630   0.792513  0.716528  0.739594  0.743690
# XGBClassifier13          0.851181   0.754972  0.706863  0.722892  0.727930
# XGBClassifier14          0.855118   0.767821  0.718663  0.735849  0.735208
# XGBClassifier15          0.852756   0.753764  0.705503  0.721188  0.730741
# XGBClassifier16          0.853543   0.756836  0.709227  0.724925  0.732467
# XGBClassifier17          0.851969   0.773087  0.698014  0.719315  0.727048
# XGBClassifier18          0.860630   0.784458  0.710242  0.732333  0.743203

# %%
highest = df_pca[df_pca["kappa"] == df_pca.iloc[1:]["kappa"].max()]
idx = highest.index[0]

confusion_matrix(pipeline.predictions["GT"], pipeline.predictions[idx])
# Out:
# array([[441,  46,  11],
#        [ 52, 619,   7],
#        [ 37,  24,  33]], dtype=int64)
