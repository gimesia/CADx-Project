# %%
import numpy as np
from sklearn.metrics import confusion_matrix, recall_score, cohen_kappa_score

from utils.loader import FactoryLoader
from utils.ml import MLPipeline
from utils.preprocessing import PreprocessingFactory
from utils.feature_extraction import *
from utils.utils import *

VAL_PATH = r"C:\Users\gimes\Src\repos\CADx-Project\dataset\multiclass\val"
TRAIN_PATH = r"C:\Users\gimes\Src\repos\CADx-Project\dataset\multiclass\train"
# Out:
# INFO:numexpr.utils:Note: NumExpr detected 16 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.

# %%
percent = 100
random = False
batch_size = 24
th = 0.1

# Initialize the FactoryLoader
factory = PreprocessingFactory()
factory.gaussian_smoothing(5)
factory.clahe(clip_limit=1.5)
factory.pad2square(fill=np.nan)
factory.resize((150,150))
factory.hair_removal()
factory.normalize2float()

factory_loader = FactoryLoader(path=VAL_PATH, batch_size=batch_size, factory=factory, percentage=percent, shuffle=random)

# Create the feature extraction pipeline strategy and add desired features
strategy = FeatureExtractionStrategy()

strategy.add_extractor(GradientExtractor(threshold=th)) # Add gradient feature

strategy.add_extractor(ColorMomentsExtractor("rgb", threshold=th))   # Add color moments feature
strategy.add_extractor(ColorMomentsExtractor("lab", threshold=th))   # Add color moments feature
strategy.add_extractor(ColorMomentsExtractor("hsv", threshold=th))   # Add color moments feature

strategy.add_extractor(LBPExtractor(radius=1, n_points=8))
strategy.add_extractor(LBPExtractor(radius=2, n_points=16))
strategy.add_extractor(LBPExtractor(radius=3, n_points=24))
strategy.add_extractor(LBPExtractor(radius=4, n_points=32))

strategy.add_extractor(FourierTransformExtractor())

strategy.add_extractor(GLCMExtractor(properties=['contrast', 'dissimilarity', 'homogeneity', 'energy', 'correlation',]))

pipeline = MLPipeline(dataset_path=TRAIN_PATH, preprocessing_factory=factory, feature_strategy=strategy, classifiers=[], percentage=percent, verbose=True, shuffle=random, batch_size=batch_size)
# Out:
# INFO:utils.ml:MLPipeline initialized with dataset path: C:\Users\gimes\Src\repos\CADx-Project\dataset\multiclass\train
# INFO:utils.ml:Preprocessing steps

# %%
pipeline.feature_matrix = None
pipeline.run_feature_extraction()
# Out:
# INFO:utils.ml:Running feature extraction...
# Processed 5/212 batches.
# Processed 10/212 batches.
# Processed 15/212 batches.
# Processed 20/212 batches.
# Processed 25/212 batches.
# Processed 30/212 batches.
# Processed 35/212 batches.
# Processed 40/212 batches.
# Processed 45/212 batches.
# Processed 50/212 batches.
# Processed 55/212 batches.
# Processed 60/212 batches.
# Processed 65/212 batches.
# Processed 70/212 batches.
# Processed 75/212 batches.
# Processed 80/212 batches.
# Processed 85/212 batches.
# Processed 90/212 batches.
# Processed 95/212 batches.
# Processed 100/212 batches.
# Processed 105/212 batches.
# Processed 110/212 batches.
# Processed 115/212 batches.
# Processed 120/212 batches.
# Processed 125/212 batches.
# Processed 130/212 batches.
# Processed 135/212 batches.
# Processed 140/212 batches.
# Processed 145/212 batches.
# Processed 150/212 batches.
# Processed 155/212 batches.
# Processed 160/212 batches.
# Processed 165/212 batches.
# Processed 170/212 batches.
# Processed 175/212 batches.
# Processed 180/212 batches.
# Processed 185/212 batches.
# Processed 190/212 batches.
# Processed 195/212 batches.
# Processed 200/212 batches.
# Processed 205/212 batches.
# Processed 210/212 batches.
# INFO:utils.ml:Feature extraction completed. Extracted 5082 features.
# Processed 212/212 batches.

# %%
from xgboost import XGBClassifier
from sklearn.ensemble import RandomForestClassifier

rf1 = RandomForestClassifier(n_estimators=100)
rf2 = RandomForestClassifier(n_estimators=150)
# Random Forest with Out-of-Bag Error (OOB)
rf3 = RandomForestClassifier(n_estimators=100, oob_score=True, random_state=42)
# Random Forest with Bootstrap Disabled
rf4 = RandomForestClassifier(n_estimators=100, bootstrap=False, random_state=42)
# Random Forest with Out-of-Bag Error (OOB)
rf5 = RandomForestClassifier(n_estimators=150, oob_score=True, random_state=42)
# Random Forest with Bootstrap Disabled
rf6 = RandomForestClassifier(n_estimators=150, bootstrap=False, random_state=42)
# Random Forest with Out-of-Bag Error (OOB)
rf7 = RandomForestClassifier(n_estimators=200, oob_score=True, random_state=42)
# Random Forest with Bootstrap Disabled
rf8 = RandomForestClassifier(n_estimators=200, bootstrap=False, random_state=42)


xgb1 = XGBClassifier(n_estimators=350)
xgb2 = XGBClassifier(n_estimators=450)
xgb3 = XGBClassifier(n_estimators=550)
xgb4 = XGBClassifier(learning_rate=0.05, n_estimators=400, max_depth=3, min_child_weight=4, subsample=0.8, colsample_bytree=0.8)
xgb5 = XGBClassifier(learning_rate=0.1, n_estimators=400, max_depth=7, min_child_weight=3, subsample=0.7, colsample_bytree=0.7) # 2ND
xgb6 = XGBClassifier(learning_rate=0.1, n_estimators=400, max_depth=5, min_child_weight=5, gamma=0.2, subsample=0.8, colsample_bytree=0.8) # THIS
xgb7 = XGBClassifier(learning_rate=0.1, n_estimators=400, max_depth=5, min_child_weight=1, subsample=0.8, colsample_bytree=0.8, reg_alpha=0.1, reg_lambda=0.1)
xgb8 = XGBClassifier(learning_rate=0.05, n_estimators=500, max_depth=7, min_child_weight=1, subsample=0.8, colsample_bytree=0.8)
xgb9 = XGBClassifier(learning_rate=0.05, n_estimators=400, max_depth=7, min_child_weight=1, subsample=0.8, colsample_bytree=0.8)
xgb10 = XGBClassifier(learning_rate=0.1, n_estimators=400, max_depth=7, min_child_weight=1, subsample=0.8, colsample_bytree=0.8)
xgb11 = XGBClassifier(learning_rate=0.1, n_estimators=500, max_depth=7, min_child_weight=1, subsample=0.8, colsample_bytree=0.8)


pipeline.classifiers = [rf1, rf2, rf3, rf4, rf5, rf6, rf7, rf8,
                        # svm1, svm2, svm3, svm6, svm7, svm8,
                        xgb1, xgb2, xgb3, xgb4, xgb5, xgb6, xgb7, xgb8, xgb9, xgb10, xgb11]
pipeline.fitted_classifiers = {}

# %%
pipeline.fit_classifiers()
# Out:
# INFO:utils.ml:Fitting classifiers...
# INFO:utils.ml:Fitting classifier: RandomForestClassifier0
# INFO:utils.ml:Top 10 features for RandomForestClassifier0: [('color_moments_lab_B_std', 0.033071220905978756), ('color_moments_lab_B_var', 0.03165348992107507), ('color_moments_rgb_B_var', 0.02246862783734352), ('color_moments_rgb_B_std', 0.022084762468461087), ('color_moments_rgb_B_kurtosis', 0.020980529703660242), ('color_moments_rgb_R_iqr', 0.01888405850826889), ('color_moments_rgb_B_iqr', 0.01711785769692506), ('color_moments_lab_L_iqr', 0.015508001339587721), ('color_moments_rgb_R_var', 0.015248961147097093), ('color_moments_rgb_R_skew', 0.014130282153650434)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier0; Done in 3.9026951789855957 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier1
# INFO:utils.ml:Top 10 features for RandomForestClassifier1: [('color_moments_lab_B_std', 0.03733678482876494), ('color_moments_lab_B_var', 0.0328963441167115), ('color_moments_rgb_B_var', 0.022233345733075716), ('color_moments_rgb_B_std', 0.02065816931749865), ('color_moments_rgb_R_iqr', 0.01961169034643951), ('color_moments_rgb_B_kurtosis', 0.01815570583030492), ('color_moments_rgb_R_kurtosis', 0.017915847258582716), ('color_moments_lab_L_iqr', 0.01702891465906365), ('color_moments_rgb_B_iqr', 0.014067185044178835), ('color_moments_rgb_G_kurtosis', 0.011548830355249113)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier1; Done in 5.815764427185059 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier2
# INFO:utils.ml:Top 10 features for RandomForestClassifier2: [('color_moments_lab_B_std', 0.039775770187648087), ('color_moments_lab_B_var', 0.032615813644042674), ('color_moments_rgb_B_std', 0.024712082064091367), ('color_moments_rgb_B_var', 0.022073095257360113), ('color_moments_rgb_B_iqr', 0.01889408467506961), ('color_moments_lab_L_iqr', 0.0173114822671313), ('color_moments_rgb_R_iqr', 0.015515290184411177), ('color_moments_rgb_R_skew', 0.013185087024937451), ('color_moments_rgb_R_kurtosis', 0.01256931835490681), ('color_moments_rgb_R_var', 0.011655163294254426)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier2; Done in 3.954937219619751 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier3
# INFO:utils.ml:Top 10 features for RandomForestClassifier3: [('color_moments_lab_B_std', 0.03941968299810914), ('color_moments_lab_B_var', 0.034380673062582565), ('color_moments_rgb_B_std', 0.024397710475564303), ('color_moments_rgb_B_var', 0.01999522560706916), ('color_moments_rgb_R_iqr', 0.019427987746216634), ('color_moments_lab_L_iqr', 0.017503527884389938), ('color_moments_rgb_B_iqr', 0.016388551373682832), ('color_moments_rgb_R_skew', 0.015029650110944927), ('color_moments_rgb_R_kurtosis', 0.013695580150625958), ('color_moments_lab_B_skew', 0.012149897283101126)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier3; Done in 7.118231773376465 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier4
# INFO:utils.ml:Top 10 features for RandomForestClassifier4: [('color_moments_lab_B_std', 0.041479178302798736), ('color_moments_lab_B_var', 0.03152521771523977), ('color_moments_rgb_B_var', 0.022505440299566956), ('color_moments_rgb_B_std', 0.022222367150516502), ('color_moments_lab_L_iqr', 0.018027582975993342), ('color_moments_rgb_B_iqr', 0.017506822993653602), ('color_moments_rgb_R_iqr', 0.016654282174583958), ('color_moments_rgb_R_skew', 0.014168209906273809), ('color_moments_lab_L_var', 0.011781094356014892), ('color_moments_rgb_B_kurtosis', 0.011749717238690253)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier4; Done in 9.066188097000122 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier5
# INFO:utils.ml:Top 10 features for RandomForestClassifier5: [('color_moments_lab_B_std', 0.03860369199789483), ('color_moments_lab_B_var', 0.03377103549280053), ('color_moments_rgb_B_std', 0.023384313129953267), ('color_moments_rgb_B_var', 0.02078767538907162), ('color_moments_rgb_R_iqr', 0.018500837648412042), ('color_moments_lab_L_iqr', 0.017986768015518104), ('color_moments_rgb_B_iqr', 0.015314992755363856), ('color_moments_rgb_R_skew', 0.015121236514797414), ('color_moments_lab_B_skew', 0.012675055625532223), ('color_moments_rgb_B_kurtosis', 0.012668077048708844)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier5; Done in 13.473827362060547 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier6
# INFO:utils.ml:Top 10 features for RandomForestClassifier6: [('color_moments_lab_B_std', 0.04027424548967768), ('color_moments_lab_B_var', 0.03187646980511495), ('color_moments_rgb_R_iqr', 0.021544002409106033), ('color_moments_rgb_B_var', 0.020882002701001247), ('color_moments_rgb_B_std', 0.020136734826743784), ('color_moments_rgb_B_iqr', 0.019243929418056537), ('color_moments_lab_L_iqr', 0.017609134528577007), ('color_moments_rgb_R_skew', 0.013754293561697646), ('color_moments_rgb_B_kurtosis', 0.013359250505940088), ('color_moments_rgb_R_kurtosis', 0.012532662668918927)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier6; Done in 12.424557209014893 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier7
# INFO:utils.ml:Top 10 features for RandomForestClassifier7: [('color_moments_lab_B_std', 0.03633887444941163), ('color_moments_lab_B_var', 0.033502973781494895), ('color_moments_rgb_B_std', 0.021312582107052874), ('color_moments_rgb_R_iqr', 0.02123109182018882), ('color_moments_rgb_B_var', 0.02053325189367344), ('color_moments_lab_L_iqr', 0.018819773664976603), ('color_moments_rgb_B_iqr', 0.017188974159974647), ('color_moments_rgb_B_kurtosis', 0.014723500499237345), ('color_moments_rgb_R_skew', 0.014445051996209738), ('color_moments_lab_B_skew', 0.01289770885079117)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier7; Done in 19.08513045310974 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier8
# INFO:utils.ml:Top 10 features for XGBClassifier8: [('color_moments_rgb_R_iqr', 0.080779865), ('color_moments_lab_B_std', 0.03173205), ('color_moments_rgb_B_std', 0.02523185), ('color_moments_hsv_H_min', 0.022839699), ('lbp_rad2_bins16_8', 0.02128484), ('lbp_rad2_bins16_12', 0.016479649), ('color_moments_rgb_R_std', 0.015377874), ('lbp_rad1_bins8_4', 0.013491593), ('color_moments_rgb_B_iqr', 0.0125239), ('lbp_rad2_bins16_6', 0.012372141)]
# INFO:utils.ml:Fitted classifier: XGBClassifier8; Done in 10.713488340377808 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier9
# INFO:utils.ml:Top 10 features for XGBClassifier9: [('color_moments_rgb_R_iqr', 0.0826787), ('color_moments_lab_B_std', 0.03168296), ('color_moments_rgb_B_std', 0.024997022), ('color_moments_hsv_H_min', 0.024664627), ('lbp_rad2_bins16_8', 0.0211234), ('lbp_rad2_bins16_12', 0.016649745), ('color_moments_rgb_R_std', 0.015780928), ('lbp_rad1_bins8_4', 0.013425932), ('lbp_rad2_bins16_6', 0.012620499), ('color_moments_rgb_B_iqr', 0.012210978)]
# INFO:utils.ml:Fitted classifier: XGBClassifier9; Done in 12.63760232925415 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier10
# INFO:utils.ml:Top 10 features for XGBClassifier10: [('color_moments_rgb_R_iqr', 0.08321732), ('color_moments_lab_B_std', 0.03182119), ('color_moments_hsv_H_min', 0.026121836), ('color_moments_rgb_B_std', 0.024906589), ('lbp_rad2_bins16_8', 0.02002815), ('lbp_rad2_bins16_12', 0.017083075), ('color_moments_rgb_R_std', 0.015921295), ('lbp_rad1_bins8_4', 0.013047528), ('lbp_rad2_bins16_6', 0.012664773), ('color_moments_rgb_B_iqr', 0.012385023)]
# INFO:utils.ml:Fitted classifier: XGBClassifier10; Done in 13.920022249221802 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier11
# INFO:utils.ml:Top 10 features for XGBClassifier11: [('color_moments_rgb_R_iqr', 0.03589486), ('color_moments_lab_B_var', 0.02732463), ('color_moments_lab_B_std', 0.02711095), ('color_moments_rgb_B_var', 0.020782266), ('color_moments_lab_L_iqr', 0.02043232), ('color_moments_rgb_B_std', 0.018067867), ('lbp_rad1_bins8_4', 0.014468297), ('lbp_rad2_bins16_8', 0.014112227), ('color_moments_rgb_B_iqr', 0.013292445), ('lbp_rad1_bins8_3', 0.012193551)]
# INFO:utils.ml:Fitted classifier: XGBClassifier11; Done in 5.862924337387085 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier12
# INFO:utils.ml:Top 10 features for XGBClassifier12: [('color_moments_rgb_R_iqr', 0.038503505), ('color_moments_lab_B_var', 0.027049689), ('color_moments_rgb_B_iqr', 0.023211166), ('color_moments_lab_B_std', 0.019603439), ('color_moments_rgb_B_std', 0.017240517), ('color_moments_rgb_B_var', 0.016042508), ('color_moments_rgb_R_std', 0.012951906), ('lbp_rad3_bins24_11', 0.0122732185), ('lbp_rad1_bins8_4', 0.011898042), ('color_moments_lab_L_iqr', 0.009831115)]
# INFO:utils.ml:Fitted classifier: XGBClassifier12; Done in 10.998588562011719 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier13
# INFO:utils.ml:Top 10 features for XGBClassifier13: [('color_moments_rgb_R_iqr', 0.050323676), ('color_moments_lab_B_var', 0.025965378), ('color_moments_lab_B_std', 0.022519875), ('color_moments_rgb_B_var', 0.016272163), ('color_moments_rgb_B_std', 0.015906379), ('lbp_rad2_bins16_8', 0.013457115), ('color_moments_rgb_R_std', 0.011311523), ('color_moments_rgb_R_var', 0.010543081), ('fourier_transform_magnitude_std', 0.010357868), ('lbp_rad1_bins8_4', 0.010018044)]
# INFO:utils.ml:Fitted classifier: XGBClassifier13; Done in 8.737492561340332 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier14
# INFO:utils.ml:Top 10 features for XGBClassifier14: [('color_moments_rgb_R_iqr', 0.048261814), ('color_moments_lab_B_var', 0.029739002), ('color_moments_lab_B_std', 0.022884723), ('color_moments_rgb_B_std', 0.02171024), ('color_moments_rgb_B_var', 0.017219236), ('lbp_rad2_bins16_8', 0.014189747), ('color_moments_hsv_H_min', 0.011788813), ('lbp_rad1_bins8_4', 0.0115247425), ('color_moments_rgb_R_std', 0.011463119), ('color_moments_rgb_R_var', 0.01074832)]
# INFO:utils.ml:Fitted classifier: XGBClassifier14; Done in 8.85382342338562 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier15
# INFO:utils.ml:Top 10 features for XGBClassifier15: [('color_moments_rgb_R_iqr', 0.04168604), ('color_moments_lab_B_var', 0.026613466), ('color_moments_lab_B_std', 0.022988595), ('color_moments_rgb_B_var', 0.018516244), ('color_moments_rgb_B_std', 0.017634535), ('color_moments_rgb_B_iqr', 0.016348405), ('lbp_rad2_bins16_8', 0.012075941), ('color_moments_rgb_R_std', 0.011742219), ('lbp_rad1_bins8_4', 0.010774676), ('fourier_transform_magnitude_std', 0.0098642865)]
# INFO:utils.ml:Fitted classifier: XGBClassifier15; Done in 19.509336948394775 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier16
# INFO:utils.ml:Top 10 features for XGBClassifier16: [('color_moments_rgb_R_iqr', 0.04074417), ('color_moments_lab_B_var', 0.0274903), ('color_moments_lab_B_std', 0.022102784), ('color_moments_rgb_B_var', 0.018444717), ('color_moments_rgb_B_std', 0.017106658), ('color_moments_rgb_B_iqr', 0.016254362), ('lbp_rad2_bins16_8', 0.011856895), ('color_moments_rgb_R_std', 0.0111782), ('lbp_rad1_bins8_4', 0.010862433), ('fourier_transform_magnitude_std', 0.010289151)]
# INFO:utils.ml:Fitted classifier: XGBClassifier16; Done in 16.39028000831604 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier17
# INFO:utils.ml:Top 10 features for XGBClassifier17: [('color_moments_rgb_R_iqr', 0.049551576), ('color_moments_lab_B_var', 0.03206826), ('color_moments_rgb_B_var', 0.023516439), ('color_moments_lab_B_std', 0.022314467), ('color_moments_rgb_B_std', 0.018005522), ('lbp_rad2_bins16_8', 0.012139267), ('lbp_rad3_bins24_11', 0.011513417), ('color_moments_rgb_R_std', 0.011096491), ('color_moments_rgb_B_iqr', 0.01069666), ('lbp_rad1_bins8_4', 0.010633491)]
# INFO:utils.ml:Fitted classifier: XGBClassifier17; Done in 10.901308059692383 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier18
# INFO:utils.ml:Top 10 features for XGBClassifier18: [('color_moments_rgb_R_iqr', 0.050203655), ('color_moments_lab_B_var', 0.030814352), ('color_moments_rgb_B_var', 0.023625253), ('color_moments_lab_B_std', 0.022592358), ('color_moments_rgb_B_std', 0.018064335), ('lbp_rad2_bins16_8', 0.011865728), ('lbp_rad3_bins24_11', 0.01153286), ('color_moments_rgb_R_std', 0.011331905), ('color_moments_rgb_B_iqr', 0.010761923), ('lbp_rad1_bins8_4', 0.010665083)]
# INFO:utils.ml:Fitted classifier: XGBClassifier18; Done in 11.948188781738281 seconds
# INFO:utils.ml:Fitting completed in 205.32 seconds.

# %%
pipeline.predict_with_classifiers(VAL_PATH, percent)
# Out:
# INFO:utils.ml:Predicting with classifiers on dataset: C:\Users\gimes\Src\repos\CADx-Project\dataset\multiclass\val
# Processed 5/53 batches.
# Processed 10/53 batches.
# Processed 15/53 batches.
# Processed 20/53 batches.
# Processed 25/53 batches.
# Processed 30/53 batches.
# Processed 35/53 batches.
# Processed 40/53 batches.
# Processed 45/53 batches.
# Processed 50/53 batches.
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier0
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier1
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier2
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier3
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier4
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier5
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier6
# Processed 53/53 batches.
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier7
# INFO:utils.ml:Predictions made with classifier: XGBClassifier8
# INFO:utils.ml:Predictions made with classifier: XGBClassifier9
# INFO:utils.ml:Predictions made with classifier: XGBClassifier10
# INFO:utils.ml:Predictions made with classifier: XGBClassifier11
# INFO:utils.ml:Predictions made with classifier: XGBClassifier12
# INFO:utils.ml:Predictions made with classifier: XGBClassifier13
# INFO:utils.ml:Predictions made with classifier: XGBClassifier14
# INFO:utils.ml:Predictions made with classifier: XGBClassifier15
# INFO:utils.ml:Predictions made with classifier: XGBClassifier16
# INFO:utils.ml:Predictions made with classifier: XGBClassifier17
# INFO:utils.ml:Predictions made with classifier: XGBClassifier18
# {'GT': array([0, 0, 0, ..., 2, 2, 2]),
#  'RandomForestClassifier0': array([0, 0, 0, ..., 1, 0, 0]),
#  'RandomForestClassifier1': array([0, 0, 1, ..., 1, 0, 0]),
#  'RandomForestClassifier2': array([0, 0, 0, ..., 1, 0, 0]),
#  'RandomForestClassifier3': array([0, 0, 0, ..., 1, 0, 0]),
#  'RandomForestClassifier4': array([0, 0, 0, ..., 1, 0, 0]),
#  'RandomForestClassifier5': array([0, 0, 0, ..., 1, 0, 0]),
#  'RandomForestClassifier6': array([0, 0, 0, ..., 1, 0, 0]),
#  'RandomForestClassifier7': array([0, 0, 0, ..., 1, 0, 0]),
#  'XGBClassifier8': array([0, 0, 0, ..., 1, 0, 0], dtype=int64),
#  'XGBClassifier9': array([0, 0, 0, ..., 1, 0, 0], dtype=int64),
#  'XGBClassifier10': array([0, 0, 0, ..., 1, 0, 0], dtype=int64),
#  'XGBClassifier11': array([0, 0, 0, ..., 1, 0, 0], dtype=int64),
#  'XGBClassifier12': array([0, 0, 0, ..., 1, 0, 0], dtype=int64),
#  'XGBClassifier13': array([0, 0, 0, ..., 1, 0, 0], dtype=int64),
#  'XGBClassifier14': array([0, 0, 0, ..., 1, 0, 0], dtype=int64),
#  'XGBClassifier15': array([0, 0, 0, ..., 1, 0, 0], dtype=int64),
#  'XGBClassifier16': array([0, 0, 0, ..., 1, 0, 0], dtype=int64),
#  'XGBClassifier17': array([0, 0, 0, ..., 1, 0, 0], dtype=int64),
#  'XGBClassifier18': array([0, 0, 0, ..., 1, 0, 0], dtype=int64)}

# %%
import pandas as pd

df = pd.DataFrame(data=pipeline.calculate_metrics())
df.T
# Out:
# INFO:utils.ml:Metrics for classifier GT: {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'kappa': 1.0}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier0: {'accuracy': 0.8204724409448819, 'precision': 0.8763192628816191, 'recall': 0.6111503063657379, 'f1': 0.6094727712952976, 'kappa': 0.6630076532037317}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier1: {'accuracy': 0.8275590551181102, 'precision': 0.8808885166998676, 'recall': 0.6188072442912931, 'f1': 0.620086183620821, 'kappa': 0.6760551240897676}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier2: {'accuracy': 0.8251968503937008, 'precision': 0.7472660773744392, 'recall': 0.6024154359230683, 'f1': 0.5883178871783148, 'kappa': 0.6714292373671452}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier3: {'accuracy': 0.8401574803149606, 'precision': 0.8296230327150272, 'recall': 0.6309718885584389, 'f1': 0.6339928687330764, 'kappa': 0.7001456179691644}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier4: {'accuracy': 0.8259842519685039, 'precision': 0.806645353555376, 'recall': 0.614591800957675, 'f1': 0.6126945323394476, 'kappa': 0.6733189316026426}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier5: {'accuracy': 0.8362204724409449, 'precision': 0.8109398481738906, 'recall': 0.6310350294670176, 'f1': 0.6362481888857424, 'kappa': 0.6931768553879891}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier6: {'accuracy': 0.8251968503937008, 'precision': 0.7969051549895135, 'recall': 0.6110457016668948, 'f1': 0.6063059760294208, 'kappa': 0.6717551564035336}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier7: {'accuracy': 0.8385826771653543, 'precision': 0.8607280781899007, 'recall': 0.6353867109686471, 'f1': 0.6439619542851255, 'kappa': 0.6970800541730466}
# INFO:utils.ml:Metrics for classifier XGBClassifier8: {'accuracy': 0.8551181102362204, 'precision': 0.8128004871520722, 'recall': 0.6947602120022172, 'f1': 0.7212062507037963, 'kappa': 0.731546708207539}
# INFO:utils.ml:Metrics for classifier XGBClassifier9: {'accuracy': 0.8559055118110236, 'precision': 0.8108905254918705, 'recall': 0.6923750988388374, 'f1': 0.7179900421495325, 'kappa': 0.7328817190459552}
# INFO:utils.ml:Metrics for classifier XGBClassifier10: {'accuracy': 0.8559055118110236, 'precision': 0.8074088119595609, 'recall': 0.695074152128504, 'f1': 0.7208764219356062, 'kappa': 0.7330191887073354}
# INFO:utils.ml:Metrics for classifier XGBClassifier11: {'accuracy': 0.8283464566929134, 'precision': 0.7547436811172054, 'recall': 0.628284556036233, 'f1': 0.6347034484789587, 'kappa': 0.6791115355728843}
# INFO:utils.ml:Metrics for classifier XGBClassifier12: {'accuracy': 0.8566929133858268, 'precision': 0.8286234616621356, 'recall': 0.6781275607671381, 'f1': 0.7016040746472134, 'kappa': 0.7328935873197835}
# INFO:utils.ml:Metrics for classifier XGBClassifier13: {'accuracy': 0.8503937007874016, 'precision': 0.8311405075314567, 'recall': 0.6580336282681721, 'f1': 0.6758178996389854, 'kappa': 0.7197119293762342}
# INFO:utils.ml:Metrics for classifier XGBClassifier14: {'accuracy': 0.8543307086614174, 'precision': 0.8116952215366907, 'recall': 0.6710768259758421, 'f1': 0.6906288217374869, 'kappa': 0.7289280341138791}
# INFO:utils.ml:Metrics for classifier XGBClassifier15: {'accuracy': 0.8503937007874016, 'precision': 0.8312895437895437, 'recall': 0.6587444361012745, 'f1': 0.6761756096080479, 'kappa': 0.7200046414481318}
# INFO:utils.ml:Metrics for classifier XGBClassifier16: {'accuracy': 0.8503937007874016, 'precision': 0.8344315563104674, 'recall': 0.6616211913492166, 'f1': 0.680847224175761, 'kappa': 0.7200773992371442}
# INFO:utils.ml:Metrics for classifier XGBClassifier17: {'accuracy': 0.8606299212598425, 'precision': 0.8409754625775264, 'recall': 0.6816519829396038, 'f1': 0.7054209423296901, 'kappa': 0.7403265008132486}
# INFO:utils.ml:Metrics for classifier XGBClassifier18: {'accuracy': 0.8614173228346457, 'precision': 0.8437646304312971, 'recall': 0.6853757841886594, 'f1': 0.7102270301862732, 'kappa': 0.7420748481435666}
#                          accuracy  precision    recall        f1     kappa
# GT                       1.000000   1.000000  1.000000  1.000000  1.000000
# RandomForestClassifier0  0.820472   0.876319  0.611150  0.609473  0.663008
# RandomForestClassifier1  0.827559   0.880889  0.618807  0.620086  0.676055
# RandomForestClassifier2  0.825197   0.747266  0.602415  0.588318  0.671429
# RandomForestClassifier3  0.840157   0.829623  0.630972  0.633993  0.700146
# RandomForestClassifier4  0.825984   0.806645  0.614592  0.612695  0.673319
# RandomForestClassifier5  0.836220   0.810940  0.631035  0.636248  0.693177
# RandomForestClassifier6  0.825197   0.796905  0.611046  0.606306  0.671755
# RandomForestClassifier7  0.838583   0.860728  0.635387  0.643962  0.697080
# XGBClassifier8           0.855118   0.812800  0.694760  0.721206  0.731547
# XGBClassifier9           0.855906   0.810891  0.692375  0.717990  0.732882
# XGBClassifier10          0.855906   0.807409  0.695074  0.720876  0.733019
# XGBClassifier11          0.828346   0.754744  0.628285  0.634703  0.679112
# XGBClassifier12          0.856693   0.828623  0.678128  0.701604  0.732894
# XGBClassifier13          0.850394   0.831141  0.658034  0.675818  0.719712
# XGBClassifier14          0.854331   0.811695  0.671077  0.690629  0.728928
# XGBClassifier15          0.850394   0.831290  0.658744  0.676176  0.720005
# XGBClassifier16          0.850394   0.834432  0.661621  0.680847  0.720077
# XGBClassifier17          0.860630   0.840975  0.681652  0.705421  0.740327
# XGBClassifier18          0.861417   0.843765  0.685376  0.710227  0.742075

# %% [markdown]
# ___
# # Balance the data

# %%
# Backup
pipeline.backup_feature_matrix = pipeline.feature_matrix.copy()
pipeline.backup_labels = pipeline.labels.copy()

# %%
print(pipeline.backup_feature_matrix.shape)
print(pipeline.feature_matrix.shape)

print(pipeline.backup_labels.shape)
print(pipeline.labels.shape)
# Out:
# (5082, 189)
# (5082, 189)
# (5082,)
# (5082,)

# %%
pipeline.get_feature_names()
# Out:
# ['gradient_magnitude_mean',
#  'gradient_magnitude_std',
#  'gradient_direction_mean',
#  'gradient_direction_std',
#  'color_moments_rgb_R_mean',
#  'color_moments_rgb_R_std',
#  'color_moments_rgb_R_skew',
#  'color_moments_rgb_R_kurtosis',
#  'color_moments_rgb_R_median',
#  'color_moments_rgb_R_var',
#  'color_moments_rgb_R_min',
#  'color_moments_rgb_R_max',
#  'color_moments_rgb_R_iqr',
#  'color_moments_rgb_R_entropy',
#  'color_moments_rgb_G_mean',
#  'color_moments_rgb_G_std',
#  'color_moments_rgb_G_skew',
#  'color_moments_rgb_G_kurtosis',
#  'color_moments_rgb_G_median',
#  'color_moments_rgb_G_var',
#  'color_moments_rgb_G_min',
#  'color_moments_rgb_G_max',
#  'color_moments_rgb_G_iqr',
#  'color_moments_rgb_G_entropy',
#  'color_moments_rgb_B_mean',
#  'color_moments_rgb_B_std',
#  'color_moments_rgb_B_skew',
#  'color_moments_rgb_B_kurtosis',
#  'color_moments_rgb_B_median',
#  'color_moments_rgb_B_var',
#  'color_moments_rgb_B_min',
#  'color_moments_rgb_B_max',
#  'color_moments_rgb_B_iqr',
#  'color_moments_rgb_B_entropy',
#  'color_moments_lab_L_mean',
#  'color_moments_lab_L_std',
#  'color_moments_lab_L_skew',
#  'color_moments_lab_L_kurtosis',
#  'color_moments_lab_L_median',
#  'color_moments_lab_L_var',
#  'color_moments_lab_L_min',
#  'color_moments_lab_L_max',
#  'color_moments_lab_L_iqr',
#  'color_moments_lab_L_entropy',
#  'color_moments_lab_A_mean',
#  'color_moments_lab_A_std',
#  'color_moments_lab_A_skew',
#  'color_moments_lab_A_kurtosis',
#  'color_moments_lab_A_median',
#  'color_moments_lab_A_var',
#  'color_moments_lab_A_min',
#  'color_moments_lab_A_max',
#  'color_moments_lab_A_iqr',
#  'color_moments_lab_A_entropy',
#  'color_moments_lab_B_mean',
#  'color_moments_lab_B_std',
#  'color_moments_lab_B_skew',
#  'color_moments_lab_B_kurtosis',
#  'color_moments_lab_B_median',
#  'color_moments_lab_B_var',
#  'color_moments_lab_B_min',
#  'color_moments_lab_B_max',
#  'color_moments_lab_B_iqr',
#  'color_moments_lab_B_entropy',
#  'color_moments_hsv_H_mean',
#  'color_moments_hsv_H_std',
#  'color_moments_hsv_H_skew',
#  'color_moments_hsv_H_kurtosis',
#  'color_moments_hsv_H_median',
#  'color_moments_hsv_H_var',
#  'color_moments_hsv_H_min',
#  'color_moments_hsv_H_max',
#  'color_moments_hsv_H_iqr',
#  'color_moments_hsv_H_entropy',
#  'color_moments_hsv_S_mean',
#  'color_moments_hsv_S_std',
#  'color_moments_hsv_S_skew',
#  'color_moments_hsv_S_kurtosis',
#  'color_moments_hsv_S_median',
#  'color_moments_hsv_S_var',
#  'color_moments_hsv_S_min',
#  'color_moments_hsv_S_max',
#  'color_moments_hsv_S_iqr',
#  'color_moments_hsv_S_entropy',
#  'color_moments_hsv_V_mean',
#  'color_moments_hsv_V_std',
#  'color_moments_hsv_V_skew',
#  'color_moments_hsv_V_kurtosis',
#  'color_moments_hsv_V_median',
#  'color_moments_hsv_V_var',
#  'color_moments_hsv_V_min',
#  'color_moments_hsv_V_max',
#  'color_moments_hsv_V_iqr',
#  'color_moments_hsv_V_entropy',
#  'lbp_rad1_bins8_0',
#  'lbp_rad1_bins8_1',
#  'lbp_rad1_bins8_2',
#  'lbp_rad1_bins8_3',
#  'lbp_rad1_bins8_4',
#  'lbp_rad1_bins8_5',
#  'lbp_rad1_bins8_6',
#  'lbp_rad1_bins8_7',
#  'lbp_rad1_bins8_8',
#  'lbp_rad1_bins8_9',
#  'lbp_rad2_bins16_0',
#  'lbp_rad2_bins16_1',
#  'lbp_rad2_bins16_2',
#  'lbp_rad2_bins16_3',
#  'lbp_rad2_bins16_4',
#  'lbp_rad2_bins16_5',
#  'lbp_rad2_bins16_6',
#  'lbp_rad2_bins16_7',
#  'lbp_rad2_bins16_8',
#  'lbp_rad2_bins16_9',
#  'lbp_rad2_bins16_10',
#  'lbp_rad2_bins16_11',
#  'lbp_rad2_bins16_12',
#  'lbp_rad2_bins16_13',
#  'lbp_rad2_bins16_14',
#  'lbp_rad2_bins16_15',
#  'lbp_rad2_bins16_16',
#  'lbp_rad2_bins16_17',
#  'lbp_rad3_bins24_0',
#  'lbp_rad3_bins24_1',
#  'lbp_rad3_bins24_2',
#  'lbp_rad3_bins24_3',
#  'lbp_rad3_bins24_4',
#  'lbp_rad3_bins24_5',
#  'lbp_rad3_bins24_6',
#  'lbp_rad3_bins24_7',
#  'lbp_rad3_bins24_8',
#  'lbp_rad3_bins24_9',
#  'lbp_rad3_bins24_10',
#  'lbp_rad3_bins24_11',
#  'lbp_rad3_bins24_12',
#  'lbp_rad3_bins24_13',
#  'lbp_rad3_bins24_14',
#  'lbp_rad3_bins24_15',
#  'lbp_rad3_bins24_16',
#  'lbp_rad3_bins24_17',
#  'lbp_rad3_bins24_18',
#  'lbp_rad3_bins24_19',
#  'lbp_rad3_bins24_20',
#  'lbp_rad3_bins24_21',
#  'lbp_rad3_bins24_22',
#  'lbp_rad3_bins24_23',
#  'lbp_rad3_bins24_24',
#  'lbp_rad3_bins24_25',
#  'lbp_rad4_bins32_0',
#  'lbp_rad4_bins32_1',
#  'lbp_rad4_bins32_2',
#  'lbp_rad4_bins32_3',
#  'lbp_rad4_bins32_4',
#  'lbp_rad4_bins32_5',
#  'lbp_rad4_bins32_6',
#  'lbp_rad4_bins32_7',
#  'lbp_rad4_bins32_8',
#  'lbp_rad4_bins32_9',
#  'lbp_rad4_bins32_10',
#  'lbp_rad4_bins32_11',
#  'lbp_rad4_bins32_12',
#  'lbp_rad4_bins32_13',
#  'lbp_rad4_bins32_14',
#  'lbp_rad4_bins32_15',
#  'lbp_rad4_bins32_16',
#  'lbp_rad4_bins32_17',
#  'lbp_rad4_bins32_18',
#  'lbp_rad4_bins32_19',
#  'lbp_rad4_bins32_20',
#  'lbp_rad4_bins32_21',
#  'lbp_rad4_bins32_22',
#  'lbp_rad4_bins32_23',
#  'lbp_rad4_bins32_24',
#  'lbp_rad4_bins32_25',
#  'lbp_rad4_bins32_26',
#  'lbp_rad4_bins32_27',
#  'lbp_rad4_bins32_28',
#  'lbp_rad4_bins32_29',
#  'lbp_rad4_bins32_30',
#  'lbp_rad4_bins32_31',
#  'lbp_rad4_bins32_32',
#  'lbp_rad4_bins32_33',
#  'fourier_transform_magnitude_mean',
#  'fourier_transform_magnitude_std',
#  'glcm_contrast_dist_1_angle_0',
#  'glcm_dissimilarity_dist_1_angle_0',
#  'glcm_homogeneity_dist_1_angle_0',
#  'glcm_energy_dist_1_angle_0',
#  'glcm_correlation_dist_1_angle_0']

# %%
from imblearn.over_sampling import SMOTE

smote = SMOTE(random_state=42)


pipeline.feature_matrix, pipeline.labels = smote.fit_resample(np.nan_to_num(pipeline.feature_matrix), pipeline.labels)

# %%
pipeline.fitted_classifiers = {}
pipeline.fit_classifiers()
# Out:
# INFO:utils.ml:Fitting classifiers...
# INFO:utils.ml:Fitting classifier: RandomForestClassifier0
# INFO:utils.ml:Top 10 features for RandomForestClassifier0: [('color_moments_rgb_B_var', 0.022482653796038025), ('color_moments_lab_B_std', 0.02067179953719284), ('color_moments_rgb_B_std', 0.01912795106460723), ('color_moments_lab_B_var', 0.017548587014674287), ('color_moments_rgb_R_iqr', 0.015988778961347802), ('color_moments_rgb_R_kurtosis', 0.01396702663751318), ('color_moments_rgb_B_kurtosis', 0.013908125825641573), ('color_moments_lab_L_iqr', 0.013862418123590813), ('color_moments_rgb_G_iqr', 0.01325629545804817), ('color_moments_rgb_B_iqr', 0.01284753199993297)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier0; Done in 7.15999436378479 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier1
# INFO:utils.ml:Top 10 features for RandomForestClassifier1: [('color_moments_rgb_B_var', 0.02154319053598528), ('color_moments_rgb_B_std', 0.020606043105425773), ('color_moments_lab_B_var', 0.02015629096829908), ('color_moments_rgb_R_iqr', 0.01870556040769395), ('color_moments_lab_B_std', 0.017435916183123918), ('color_moments_rgb_B_kurtosis', 0.01513390583536661), ('color_moments_rgb_B_iqr', 0.014367740900911518), ('color_moments_lab_L_iqr', 0.011705757331913539), ('color_moments_rgb_R_kurtosis', 0.011529733017779159), ('gradient_direction_std', 0.010833315507018831)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier1; Done in 11.122355699539185 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier2
# INFO:utils.ml:Top 10 features for RandomForestClassifier2: [('color_moments_rgb_B_std', 0.02382087775745314), ('color_moments_lab_B_std', 0.023178964225387885), ('color_moments_lab_B_var', 0.01788213971120074), ('color_moments_rgb_R_iqr', 0.017592810477467916), ('color_moments_rgb_B_var', 0.017565212023480374), ('color_moments_lab_L_iqr', 0.014314192110085893), ('color_moments_rgb_B_iqr', 0.01295136201270785), ('gradient_direction_std', 0.011740629435067127), ('fourier_transform_magnitude_std', 0.01172567647461072), ('color_moments_rgb_R_kurtosis', 0.011504355993106556)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier2; Done in 7.4989893436431885 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier3
# INFO:utils.ml:Top 10 features for RandomForestClassifier3: [('color_moments_lab_B_std', 0.025322778779177567), ('color_moments_rgb_B_std', 0.02326024744628155), ('color_moments_rgb_B_var', 0.01954589024154153), ('color_moments_rgb_R_iqr', 0.016713933015124714), ('color_moments_lab_L_iqr', 0.016565245245857695), ('color_moments_lab_B_var', 0.016329285674074424), ('gradient_direction_std', 0.01356583705523459), ('fourier_transform_magnitude_std', 0.01301259046461848), ('color_moments_rgb_B_kurtosis', 0.011728786322109674), ('color_moments_rgb_B_skew', 0.011568676954080441)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier3; Done in 11.1514413356781 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier4
# INFO:utils.ml:Top 10 features for RandomForestClassifier4: [('color_moments_lab_B_std', 0.023533585758128864), ('color_moments_rgb_B_std', 0.02167488935550672), ('color_moments_rgb_B_var', 0.018446423239663917), ('color_moments_rgb_R_iqr', 0.01760175921397611), ('color_moments_lab_B_var', 0.016686988619487735), ('color_moments_lab_L_iqr', 0.01621703161004763), ('color_moments_rgb_B_iqr', 0.012791037606154037), ('fourier_transform_magnitude_std', 0.012419507310830403), ('color_moments_rgb_B_kurtosis', 0.011527280188002134), ('color_moments_rgb_R_kurtosis', 0.011169140559937115)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier4; Done in 11.455266952514648 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier5
# INFO:utils.ml:Top 10 features for RandomForestClassifier5: [('color_moments_lab_B_std', 0.024253428858483556), ('color_moments_rgb_B_std', 0.02218841095123418), ('color_moments_rgb_B_var', 0.01974703044272028), ('color_moments_rgb_R_iqr', 0.017503049468672243), ('color_moments_lab_L_iqr', 0.016864392364793857), ('color_moments_lab_B_var', 0.01568306218262415), ('gradient_direction_std', 0.013634287762264104), ('fourier_transform_magnitude_std', 0.012956107529248915), ('color_moments_rgb_B_kurtosis', 0.01236148781108179), ('color_moments_rgb_B_iqr', 0.011420047800733935)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier5; Done in 16.832905769348145 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier6
# INFO:utils.ml:Top 10 features for RandomForestClassifier6: [('color_moments_lab_B_std', 0.022990861432873003), ('color_moments_rgb_B_std', 0.020026861485082988), ('color_moments_rgb_R_iqr', 0.01968832662451835), ('color_moments_rgb_B_var', 0.018438532365627775), ('color_moments_lab_B_var', 0.01671761376963928), ('color_moments_lab_L_iqr', 0.016456029361626278), ('color_moments_rgb_B_iqr', 0.014072364312727107), ('color_moments_rgb_B_kurtosis', 0.012863163118494263), ('color_moments_rgb_R_kurtosis', 0.012085658051677665), ('fourier_transform_magnitude_std', 0.011833578974189093)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier6; Done in 17.735275268554688 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier7
# INFO:utils.ml:Top 10 features for RandomForestClassifier7: [('color_moments_lab_B_std', 0.023856769321591097), ('color_moments_rgb_B_std', 0.020834215140261847), ('color_moments_rgb_R_iqr', 0.020062878738816008), ('color_moments_rgb_B_var', 0.01962503425674978), ('color_moments_lab_L_iqr', 0.016410119433797145), ('color_moments_lab_B_var', 0.01578265545306614), ('gradient_direction_std', 0.013702177690458242), ('color_moments_rgb_B_iqr', 0.013307618710495133), ('color_moments_rgb_B_kurtosis', 0.012907762823433979), ('fourier_transform_magnitude_std', 0.012657321020462105)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier7; Done in 35.38604712486267 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier8
# INFO:utils.ml:Top 10 features for XGBClassifier8: [('color_moments_rgb_R_iqr', 0.04929907), ('color_moments_rgb_B_std', 0.044500604), ('color_moments_hsv_H_min', 0.033705946), ('gradient_magnitude_mean', 0.030012295), ('fourier_transform_magnitude_std', 0.018125327), ('gradient_direction_std', 0.017893491), ('lbp_rad2_bins16_8', 0.015510216), ('color_moments_lab_B_std', 0.014478368), ('color_moments_lab_B_var', 0.014244828), ('color_moments_hsv_S_min', 0.013594864)]
# INFO:utils.ml:Fitted classifier: XGBClassifier8; Done in 13.922507286071777 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier9
# INFO:utils.ml:Top 10 features for XGBClassifier9: [('color_moments_rgb_R_iqr', 0.049156807), ('color_moments_rgb_B_std', 0.045904092), ('color_moments_hsv_H_min', 0.036546238), ('gradient_magnitude_mean', 0.029480116), ('gradient_direction_std', 0.018420108), ('fourier_transform_magnitude_std', 0.01766053), ('lbp_rad2_bins16_8', 0.015175318), ('color_moments_lab_B_std', 0.01449174), ('color_moments_lab_B_var', 0.014486033), ('color_moments_hsv_S_min', 0.0139372805)]
# INFO:utils.ml:Fitted classifier: XGBClassifier9; Done in 17.096457719802856 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier10
# INFO:utils.ml:Top 10 features for XGBClassifier10: [('color_moments_rgb_R_iqr', 0.050109357), ('color_moments_rgb_B_std', 0.045709934), ('color_moments_hsv_H_min', 0.03875165), ('gradient_magnitude_mean', 0.028571049), ('gradient_direction_std', 0.019408954), ('fourier_transform_magnitude_std', 0.017461685), ('lbp_rad2_bins16_8', 0.015071914), ('color_moments_lab_B_std', 0.01462935), ('color_moments_lab_B_var', 0.014322144), ('color_moments_hsv_S_min', 0.013894794)]
# INFO:utils.ml:Fitted classifier: XGBClassifier10; Done in 22.32380175590515 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier11
# INFO:utils.ml:Top 10 features for XGBClassifier11: [('color_moments_rgb_R_iqr', 0.04292911), ('color_moments_rgb_B_std', 0.02833124), ('color_moments_rgb_B_iqr', 0.02679801), ('gradient_direction_std', 0.01934137), ('color_moments_lab_B_std', 0.01853298), ('color_moments_rgb_B_var', 0.01850098), ('lbp_rad1_bins8_4', 0.015178885), ('fourier_transform_magnitude_std', 0.015082443), ('color_moments_lab_B_var', 0.013767453), ('color_moments_lab_L_skew', 0.013162224)]
# INFO:utils.ml:Fitted classifier: XGBClassifier11; Done in 8.256771087646484 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier12
# INFO:utils.ml:Top 10 features for XGBClassifier12: [('color_moments_rgb_R_iqr', 0.03605024), ('color_moments_rgb_B_var', 0.023652412), ('color_moments_rgb_B_std', 0.021865215), ('gradient_direction_std', 0.020431405), ('gradient_magnitude_mean', 0.019821078), ('color_moments_rgb_B_iqr', 0.017983746), ('fourier_transform_magnitude_std', 0.015656633), ('color_moments_lab_B_std', 0.0126858065), ('color_moments_lab_B_var', 0.012659316), ('lbp_rad4_bins32_32', 0.01187552)]
# INFO:utils.ml:Fitted classifier: XGBClassifier12; Done in 19.993404388427734 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier13
# INFO:utils.ml:Top 10 features for XGBClassifier13: [('color_moments_rgb_R_iqr', 0.038229372), ('color_moments_rgb_B_std', 0.036696456), ('gradient_magnitude_mean', 0.021636175), ('fourier_transform_magnitude_std', 0.017823128), ('gradient_direction_std', 0.017587496), ('color_moments_lab_B_var', 0.014649949), ('color_moments_rgb_B_var', 0.013435388), ('lbp_rad1_bins8_4', 0.013273415), ('color_moments_lab_B_std', 0.0125405425), ('lbp_rad1_bins8_0', 0.011304803)]
# INFO:utils.ml:Fitted classifier: XGBClassifier13; Done in 14.832592487335205 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier14
# INFO:utils.ml:Top 10 features for XGBClassifier14: [('color_moments_rgb_R_iqr', 0.037859667), ('color_moments_rgb_B_std', 0.037198402), ('gradient_magnitude_mean', 0.022178119), ('fourier_transform_magnitude_std', 0.019325119), ('gradient_direction_std', 0.017152604), ('color_moments_lab_B_var', 0.015395398), ('color_moments_rgb_B_var', 0.014248772), ('color_moments_lab_B_std', 0.012640271), ('lbp_rad1_bins8_4', 0.01253694), ('color_moments_rgb_B_iqr', 0.012309156)]
# INFO:utils.ml:Fitted classifier: XGBClassifier14; Done in 16.470607042312622 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier15
# INFO:utils.ml:Top 10 features for XGBClassifier15: [('color_moments_rgb_R_iqr', 0.038999297), ('color_moments_rgb_B_std', 0.02855382), ('gradient_direction_std', 0.019990362), ('color_moments_rgb_B_var', 0.019929813), ('gradient_magnitude_mean', 0.018661829), ('fourier_transform_magnitude_std', 0.017055323), ('color_moments_lab_B_var', 0.0147121465), ('color_moments_lab_B_std', 0.0123108765), ('lbp_rad2_bins16_8', 0.012159958), ('color_moments_hsv_S_min', 0.010714533)]
# INFO:utils.ml:Fitted classifier: XGBClassifier15; Done in 25.733678817749023 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier16
# INFO:utils.ml:Top 10 features for XGBClassifier16: [('color_moments_rgb_R_iqr', 0.039141703), ('color_moments_rgb_B_std', 0.027279258), ('gradient_direction_std', 0.02021747), ('color_moments_rgb_B_var', 0.020161346), ('gradient_magnitude_mean', 0.018413516), ('fourier_transform_magnitude_std', 0.017279152), ('color_moments_lab_B_var', 0.014871748), ('lbp_rad2_bins16_8', 0.01209889), ('color_moments_lab_B_std', 0.011903159), ('lbp_rad1_bins8_4', 0.0104374355)]
# INFO:utils.ml:Fitted classifier: XGBClassifier16; Done in 18.928086042404175 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier17
# INFO:utils.ml:Top 10 features for XGBClassifier17: [('color_moments_rgb_B_std', 0.04025082), ('color_moments_rgb_R_iqr', 0.03744847), ('gradient_magnitude_mean', 0.019422635), ('gradient_direction_std', 0.018392246), ('fourier_transform_magnitude_std', 0.01736754), ('color_moments_lab_B_var', 0.015232394), ('color_moments_rgb_B_var', 0.014659252), ('lbp_rad1_bins8_4', 0.01287833), ('color_moments_lab_B_std', 0.01234038), ('color_moments_hsv_S_min', 0.011433914)]
# INFO:utils.ml:Fitted classifier: XGBClassifier17; Done in 15.910525560379028 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier18
# INFO:utils.ml:Top 10 features for XGBClassifier18: [('color_moments_rgb_B_std', 0.04032471), ('color_moments_rgb_R_iqr', 0.03780151), ('gradient_magnitude_mean', 0.020365082), ('gradient_direction_std', 0.018310549), ('fourier_transform_magnitude_std', 0.0175811), ('color_moments_lab_B_var', 0.01522738), ('color_moments_rgb_B_var', 0.014322204), ('color_moments_lab_B_std', 0.012560357), ('lbp_rad1_bins8_4', 0.012536733), ('color_moments_hsv_S_min', 0.011546126)]
# INFO:utils.ml:Fitted classifier: XGBClassifier18; Done in 13.534822225570679 seconds
# INFO:utils.ml:Fitting completed in 305.36 seconds.

# %%
pipeline.predict_with_classifiers(VAL_PATH, percent)
# Out:
# INFO:utils.ml:Predicting with classifiers on dataset: C:\Users\gimes\Src\repos\CADx-Project\dataset\multiclass\val
# Processed 5/53 batches.
# Processed 10/53 batches.
# Processed 15/53 batches.
# Processed 20/53 batches.
# Processed 25/53 batches.
# Processed 30/53 batches.
# Processed 35/53 batches.
# Processed 40/53 batches.
# Processed 45/53 batches.
# Processed 50/53 batches.
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier0
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier1
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier2
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier3
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier4
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier5
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier6
# Processed 53/53 batches.
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier7
# INFO:utils.ml:Predictions made with classifier: XGBClassifier8
# INFO:utils.ml:Predictions made with classifier: XGBClassifier9
# INFO:utils.ml:Predictions made with classifier: XGBClassifier10
# INFO:utils.ml:Predictions made with classifier: XGBClassifier11
# INFO:utils.ml:Predictions made with classifier: XGBClassifier12
# INFO:utils.ml:Predictions made with classifier: XGBClassifier13
# INFO:utils.ml:Predictions made with classifier: XGBClassifier14
# INFO:utils.ml:Predictions made with classifier: XGBClassifier15
# INFO:utils.ml:Predictions made with classifier: XGBClassifier16
# INFO:utils.ml:Predictions made with classifier: XGBClassifier17
# INFO:utils.ml:Predictions made with classifier: XGBClassifier18
# {'GT': array([0, 0, 0, ..., 2, 2, 2]),
#  'RandomForestClassifier0': array([0, 0, 2, ..., 1, 2, 0]),
#  'RandomForestClassifier1': array([0, 0, 2, ..., 1, 2, 0]),
#  'RandomForestClassifier2': array([0, 0, 2, ..., 1, 2, 0]),
#  'RandomForestClassifier3': array([0, 0, 2, ..., 1, 2, 0]),
#  'RandomForestClassifier4': array([0, 0, 2, ..., 1, 0, 0]),
#  'RandomForestClassifier5': array([0, 0, 2, ..., 1, 2, 0]),
#  'RandomForestClassifier6': array([0, 0, 2, ..., 1, 0, 0]),
#  'RandomForestClassifier7': array([0, 0, 2, ..., 1, 2, 0]),
#  'XGBClassifier8': array([0, 0, 1, ..., 1, 2, 0], dtype=int64),
#  'XGBClassifier9': array([0, 0, 0, ..., 1, 2, 0], dtype=int64),
#  'XGBClassifier10': array([0, 0, 1, ..., 1, 2, 0], dtype=int64),
#  'XGBClassifier11': array([0, 0, 2, ..., 1, 0, 0], dtype=int64),
#  'XGBClassifier12': array([0, 0, 0, ..., 1, 2, 0], dtype=int64),
#  'XGBClassifier13': array([0, 0, 0, ..., 0, 2, 0], dtype=int64),
#  'XGBClassifier14': array([0, 0, 0, ..., 1, 2, 0], dtype=int64),
#  'XGBClassifier15': array([0, 0, 0, ..., 1, 2, 0], dtype=int64),
#  'XGBClassifier16': array([0, 0, 0, ..., 1, 2, 0], dtype=int64),
#  'XGBClassifier17': array([0, 0, 0, ..., 1, 2, 0], dtype=int64),
#  'XGBClassifier18': array([0, 0, 0, ..., 1, 2, 0], dtype=int64)}

# %%
import pandas as pd

df_smote = pd.DataFrame(data=pipeline.calculate_metrics())
df_smote = df_smote.T
df_smote
# Out:
# INFO:utils.ml:Metrics for classifier GT: {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'kappa': 1.0}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier0: {'accuracy': 0.8196850393700787, 'precision': 0.7034075883156138, 'recall': 0.6942287445142398, 'f1': 0.6974402556208337, 'kappa': 0.6760738136926003}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier1: {'accuracy': 0.8204724409448819, 'precision': 0.7059499112813171, 'recall': 0.6923767372256869, 'f1': 0.6972283051667559, 'kappa': 0.6767769676241164}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier2: {'accuracy': 0.8204724409448819, 'precision': 0.7061756849960362, 'recall': 0.7013624068860643, 'f1': 0.7026848226019619, 'kappa': 0.6783252829484405}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier3: {'accuracy': 0.8338582677165355, 'precision': 0.7278467737484132, 'recall': 0.6892276316714797, 'f1': 0.7017012689619054, 'kappa': 0.6976477066042037}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier4: {'accuracy': 0.8181102362204724, 'precision': 0.6912677041942384, 'recall': 0.6878473537657818, 'f1': 0.688351394099075, 'kappa': 0.6743531908658607}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier5: {'accuracy': 0.8330708661417323, 'precision': 0.7262013199192525, 'recall': 0.6946672020410771, 'f1': 0.7054792351382974, 'kappa': 0.6972123382260988}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier6: {'accuracy': 0.8259842519685039, 'precision': 0.7007921525960796, 'recall': 0.6925860726531305, 'f1': 0.6954720915732956, 'kappa': 0.6871391181440808}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier7: {'accuracy': 0.8346456692913385, 'precision': 0.729422943468745, 'recall': 0.6960058901267532, 'f1': 0.7073276012603419, 'kappa': 0.6999324932493249}
# INFO:utils.ml:Metrics for classifier XGBClassifier8: {'accuracy': 0.8535433070866142, 'precision': 0.7568456508704638, 'recall': 0.7300750103911535, 'f1': 0.7405986378214443, 'kappa': 0.7347070794194148}
# INFO:utils.ml:Metrics for classifier XGBClassifier9: {'accuracy': 0.8519685039370078, 'precision': 0.751513712215588, 'recall': 0.7231605137678688, 'f1': 0.7339534619843059, 'kappa': 0.7316652131303777}
# INFO:utils.ml:Metrics for classifier XGBClassifier10: {'accuracy': 0.8519685039370078, 'precision': 0.7496022864122992, 'recall': 0.7229828118095932, 'f1': 0.7332802353029235, 'kappa': 0.7316784816841008}
# INFO:utils.ml:Metrics for classifier XGBClassifier11: {'accuracy': 0.7992125984251969, 'precision': 0.663616582018315, 'recall': 0.675726063735265, 'f1': 0.6686302355492214, 'kappa': 0.6439784705090827}
# INFO:utils.ml:Metrics for classifier XGBClassifier12: {'accuracy': 0.8519685039370078, 'precision': 0.7454676616494013, 'recall': 0.7197506526451, 'f1': 0.729712037480887, 'kappa': 0.7315698822217326}
# INFO:utils.ml:Metrics for classifier XGBClassifier13: {'accuracy': 0.8519685039370078, 'precision': 0.7490700980783348, 'recall': 0.7346675347596373, 'f1': 0.7407111366777522, 'kappa': 0.7329856047524894}
# INFO:utils.ml:Metrics for classifier XGBClassifier14: {'accuracy': 0.8511811023622047, 'precision': 0.7471452604113024, 'recall': 0.7223134677667552, 'f1': 0.7320187982513673, 'kappa': 0.7303736554066805}
# INFO:utils.ml:Metrics for classifier XGBClassifier15: {'accuracy': 0.8496062992125984, 'precision': 0.7407909090605788, 'recall': 0.7213301835976303, 'f1': 0.7290401455933582, 'kappa': 0.7281105267641375}
# INFO:utils.ml:Metrics for classifier XGBClassifier16: {'accuracy': 0.8480314960629921, 'precision': 0.7348145050010978, 'recall': 0.7199914955119544, 'f1': 0.7259543131073872, 'kappa': 0.7257467529561302}
# INFO:utils.ml:Metrics for classifier XGBClassifier17: {'accuracy': 0.8559055118110236, 'precision': 0.7505361371489631, 'recall': 0.7259741281072323, 'f1': 0.7354963001177985, 'kappa': 0.7390387517516439}
# INFO:utils.ml:Metrics for classifier XGBClassifier18: {'accuracy': 0.8543307086614174, 'precision': 0.7510230688211267, 'recall': 0.7219363867318895, 'f1': 0.7328588873928185, 'kappa': 0.7357737291947819}
#                          accuracy  precision    recall        f1     kappa
# GT                       1.000000   1.000000  1.000000  1.000000  1.000000
# RandomForestClassifier0  0.819685   0.703408  0.694229  0.697440  0.676074
# RandomForestClassifier1  0.820472   0.705950  0.692377  0.697228  0.676777
# RandomForestClassifier2  0.820472   0.706176  0.701362  0.702685  0.678325
# RandomForestClassifier3  0.833858   0.727847  0.689228  0.701701  0.697648
# RandomForestClassifier4  0.818110   0.691268  0.687847  0.688351  0.674353
# RandomForestClassifier5  0.833071   0.726201  0.694667  0.705479  0.697212
# RandomForestClassifier6  0.825984   0.700792  0.692586  0.695472  0.687139
# RandomForestClassifier7  0.834646   0.729423  0.696006  0.707328  0.699932
# XGBClassifier8           0.853543   0.756846  0.730075  0.740599  0.734707
# XGBClassifier9           0.851969   0.751514  0.723161  0.733953  0.731665
# XGBClassifier10          0.851969   0.749602  0.722983  0.733280  0.731678
# XGBClassifier11          0.799213   0.663617  0.675726  0.668630  0.643978
# XGBClassifier12          0.851969   0.745468  0.719751  0.729712  0.731570
# XGBClassifier13          0.851969   0.749070  0.734668  0.740711  0.732986
# XGBClassifier14          0.851181   0.747145  0.722313  0.732019  0.730374
# XGBClassifier15          0.849606   0.740791  0.721330  0.729040  0.728111
# XGBClassifier16          0.848031   0.734815  0.719991  0.725954  0.725747
# XGBClassifier17          0.855906   0.750536  0.725974  0.735496  0.739039
# XGBClassifier18          0.854331   0.751023  0.721936  0.732859  0.735774

# %%
highest = df_smote[df_smote["kappa"] == df_smote.iloc[1:]["kappa"].max()]
idx = highest.index[0]

confusion_matrix(pipeline.predictions["GT"], pipeline.predictions[idx])
# Out:
# array([[442,  35,  21],
#        [ 55, 608,  15],
#        [ 37,  20,  37]], dtype=int64)

# %% [markdown]
# ___
# # Borderline SMOTE

# %%
from imblearn.over_sampling import BorderlineSMOTE
smote = BorderlineSMOTE(sampling_strategy='auto', random_state=42)

pipeline.feature_matrix, pipeline.labels = smote.fit_resample(
    np.nan_to_num(pipeline.backup_feature_matrix), pipeline.backup_labels)

print(pipeline.backup_feature_matrix.shape)
print(pipeline.feature_matrix.shape)

print(pipeline.backup_labels.shape)
print(pipeline.labels.shape)
# Out:
# (5082, 189)
# (8139, 189)
# (5082,)
# (8139,)

# %%
pipeline.fitted_classifiers = {}

pipeline.fit_classifiers()
# Out:
# INFO:utils.ml:Fitting classifiers...
# INFO:utils.ml:Fitting classifier: RandomForestClassifier0
# INFO:utils.ml:Top 10 features for RandomForestClassifier0: [('color_moments_lab_B_std', 0.021698979202988786), ('color_moments_lab_B_var', 0.0168173759164938), ('color_moments_rgb_B_std', 0.016627362842674794), ('color_moments_rgb_R_iqr', 0.01661610195647723), ('color_moments_rgb_B_iqr', 0.015572656580080503), ('color_moments_rgb_G_iqr', 0.014344673863501517), ('color_moments_rgb_B_kurtosis', 0.014177283628515764), ('color_moments_rgb_B_var', 0.013795092593743181), ('color_moments_rgb_R_kurtosis', 0.01377432258748903), ('color_moments_hsv_H_mean', 0.013571152964386829)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier0; Done in 10.456933498382568 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier1
# INFO:utils.ml:Top 10 features for RandomForestClassifier1: [('color_moments_lab_B_std', 0.020365080048209777), ('color_moments_rgb_B_std', 0.020026888419821556), ('color_moments_rgb_R_iqr', 0.017953062391548934), ('color_moments_lab_B_var', 0.017540671261835703), ('color_moments_rgb_B_var', 0.016700042776633218), ('color_moments_rgb_B_kurtosis', 0.014670775546411961), ('color_moments_rgb_B_iqr', 0.014285649421931583), ('color_moments_lab_L_iqr', 0.013229573969306418), ('fourier_transform_magnitude_std', 0.013134032878803608), ('color_moments_hsv_H_skew', 0.012183505975531887)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier1; Done in 17.617527723312378 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier2
# INFO:utils.ml:Top 10 features for RandomForestClassifier2: [('color_moments_rgb_B_std', 0.025123627973207562), ('color_moments_lab_B_std', 0.02303216528439549), ('color_moments_lab_B_var', 0.018458641235941528), ('color_moments_rgb_R_iqr', 0.017342832657124066), ('color_moments_rgb_B_var', 0.015955597716778215), ('color_moments_lab_L_iqr', 0.014975030063570111), ('color_moments_rgb_B_iqr', 0.013741861326751986), ('color_moments_rgb_R_kurtosis', 0.01341361493921638), ('color_moments_hsv_H_median', 0.012129713275533159), ('color_moments_hsv_H_skew', 0.01115172783570132)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier2; Done in 13.679443597793579 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier3
# INFO:utils.ml:Top 10 features for RandomForestClassifier3: [('color_moments_lab_B_std', 0.024657311062526235), ('color_moments_rgb_B_std', 0.023336368764216974), ('color_moments_lab_B_var', 0.017801464094646367), ('color_moments_rgb_B_var', 0.017311118630719522), ('color_moments_rgb_R_iqr', 0.015974705225742417), ('color_moments_lab_L_iqr', 0.015108058304130804), ('color_moments_rgb_B_iqr', 0.013765010536722917), ('fourier_transform_magnitude_std', 0.01327505142710197), ('color_moments_rgb_R_kurtosis', 0.011697136449779887), ('color_moments_rgb_B_skew', 0.011672655751356412)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier3; Done in 20.426664113998413 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier4
# INFO:utils.ml:Top 10 features for RandomForestClassifier4: [('color_moments_lab_B_std', 0.022761461808804246), ('color_moments_rgb_B_std', 0.022700447723463732), ('color_moments_lab_B_var', 0.017259730677405088), ('color_moments_rgb_B_var', 0.01691589050017853), ('color_moments_rgb_R_iqr', 0.016443780411792654), ('color_moments_lab_L_iqr', 0.015816098581105352), ('color_moments_rgb_B_iqr', 0.013320049843174924), ('color_moments_rgb_R_kurtosis', 0.012775548917245732), ('color_moments_hsv_H_median', 0.012150068314753796), ('fourier_transform_magnitude_std', 0.011886486320236679)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier4; Done in 21.104616165161133 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier5
# INFO:utils.ml:Top 10 features for RandomForestClassifier5: [('color_moments_lab_B_std', 0.02448531684852437), ('color_moments_rgb_B_std', 0.022197265777664323), ('color_moments_rgb_B_var', 0.018132288759181832), ('color_moments_rgb_R_iqr', 0.01723609849239787), ('color_moments_lab_B_var', 0.01660667161259868), ('color_moments_lab_L_iqr', 0.01585712949310218), ('fourier_transform_magnitude_std', 0.01352509247580409), ('color_moments_rgb_B_iqr', 0.012067530807894817), ('color_moments_hsv_H_median', 0.012026435817970667), ('color_moments_rgb_B_kurtosis', 0.0119538543729776)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier5; Done in 27.742567777633667 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier6
# INFO:utils.ml:Top 10 features for RandomForestClassifier6: [('color_moments_lab_B_std', 0.022430173709094548), ('color_moments_rgb_B_std', 0.0207456374999646), ('color_moments_rgb_R_iqr', 0.01939539200732473), ('color_moments_lab_B_var', 0.017291684495367343), ('color_moments_rgb_B_var', 0.01664862436077449), ('color_moments_lab_L_iqr', 0.015397235271457185), ('color_moments_rgb_B_iqr', 0.014263943218770957), ('color_moments_rgb_R_kurtosis', 0.014062995864924717), ('color_moments_hsv_H_median', 0.012883485539980836), ('color_moments_rgb_B_kurtosis', 0.012307488818796073)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier6; Done in 24.615400552749634 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier7
# INFO:utils.ml:Top 10 features for RandomForestClassifier7: [('color_moments_lab_B_std', 0.02381015888488123), ('color_moments_rgb_B_std', 0.02032384775502665), ('color_moments_rgb_R_iqr', 0.019939832673224408), ('color_moments_rgb_B_var', 0.017483808685032708), ('color_moments_lab_L_iqr', 0.015922090995292685), ('color_moments_lab_B_var', 0.015684622443083572), ('color_moments_rgb_B_iqr', 0.013541254390081834), ('color_moments_rgb_B_kurtosis', 0.012910066201001071), ('color_moments_rgb_R_kurtosis', 0.012696133348333758), ('color_moments_hsv_H_median', 0.01255671498850114)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier7; Done in 29.99170470237732 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier8
# INFO:utils.ml:Top 10 features for XGBClassifier8: [('color_moments_rgb_R_iqr', 0.050435066), ('color_moments_rgb_B_std', 0.03159462), ('color_moments_hsv_H_mean', 0.022447187), ('fourier_transform_magnitude_std', 0.02180722), ('lbp_rad2_bins16_8', 0.021643182), ('gradient_direction_std', 0.017990328), ('gradient_magnitude_mean', 0.016819645), ('color_moments_lab_B_std', 0.016326593), ('color_moments_lab_B_var', 0.014901393), ('color_moments_hsv_H_median', 0.013620852)]
# INFO:utils.ml:Fitted classifier: XGBClassifier8; Done in 7.894384860992432 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier9
# INFO:utils.ml:Top 10 features for XGBClassifier9: [('color_moments_rgb_R_iqr', 0.050834004), ('color_moments_rgb_B_std', 0.032313082), ('color_moments_hsv_H_mean', 0.022380827), ('lbp_rad2_bins16_8', 0.02098623), ('fourier_transform_magnitude_std', 0.020812495), ('gradient_direction_std', 0.018350031), ('gradient_magnitude_mean', 0.017100355), ('color_moments_lab_B_std', 0.01637925), ('color_moments_lab_B_var', 0.015273583), ('color_moments_hsv_H_median', 0.013681781)]
# INFO:utils.ml:Fitted classifier: XGBClassifier9; Done in 8.402470111846924 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier10
# INFO:utils.ml:Top 10 features for XGBClassifier10: [('color_moments_rgb_R_iqr', 0.05097637), ('color_moments_rgb_B_std', 0.03283614), ('color_moments_hsv_H_mean', 0.0228911), ('lbp_rad2_bins16_8', 0.020799918), ('fourier_transform_magnitude_std', 0.02026824), ('gradient_direction_std', 0.018684305), ('gradient_magnitude_mean', 0.016909061), ('color_moments_lab_B_std', 0.016567161), ('color_moments_lab_B_var', 0.015645182), ('color_moments_hsv_H_median', 0.013422912)]
# INFO:utils.ml:Fitted classifier: XGBClassifier10; Done in 9.612653017044067 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier11
# INFO:utils.ml:Top 10 features for XGBClassifier11: [('color_moments_rgb_R_iqr', 0.03884673), ('color_moments_hsv_H_mean', 0.0330806), ('color_moments_rgb_B_std', 0.026331255), ('color_moments_rgb_B_var', 0.022167707), ('fourier_transform_magnitude_std', 0.018403929), ('color_moments_hsv_H_median', 0.018006774), ('color_moments_lab_B_std', 0.01765281), ('gradient_direction_std', 0.014964069), ('lbp_rad2_bins16_8', 0.014915596), ('color_moments_rgb_B_kurtosis', 0.013466532)]
# INFO:utils.ml:Fitted classifier: XGBClassifier11; Done in 3.5102100372314453 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier12
# INFO:utils.ml:Top 10 features for XGBClassifier12: [('color_moments_rgb_B_std', 0.0314179), ('color_moments_rgb_R_iqr', 0.020980196), ('color_moments_hsv_H_mean', 0.0187311), ('fourier_transform_magnitude_std', 0.015347815), ('gradient_direction_std', 0.014831363), ('color_moments_rgb_B_var', 0.014566776), ('color_moments_rgb_B_iqr', 0.0142753245), ('color_moments_lab_B_var', 0.013688873), ('color_moments_hsv_H_median', 0.012631085), ('lbp_rad2_bins16_8', 0.011914786)]
# INFO:utils.ml:Fitted classifier: XGBClassifier12; Done in 9.55941390991211 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier13
# INFO:utils.ml:Top 10 features for XGBClassifier13: [('color_moments_rgb_R_iqr', 0.031787504), ('color_moments_rgb_B_std', 0.03013558), ('color_moments_hsv_H_mean', 0.021865774), ('fourier_transform_magnitude_std', 0.021430066), ('gradient_direction_std', 0.015509559), ('color_moments_lab_B_var', 0.013449891), ('lbp_rad2_bins16_8', 0.0130341025), ('color_moments_hsv_H_median', 0.01281467), ('color_moments_lab_B_std', 0.012789648), ('color_moments_rgb_B_var', 0.0120479595)]
# INFO:utils.ml:Fitted classifier: XGBClassifier13; Done in 6.101983308792114 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier14
# INFO:utils.ml:Top 10 features for XGBClassifier14: [('color_moments_rgb_R_iqr', 0.035775345), ('color_moments_rgb_B_std', 0.033539936), ('color_moments_hsv_H_mean', 0.021512695), ('fourier_transform_magnitude_std', 0.020871393), ('color_moments_lab_B_var', 0.014661922), ('gradient_direction_std', 0.014043753), ('color_moments_rgb_B_var', 0.013405332), ('color_moments_hsv_H_median', 0.013260502), ('color_moments_lab_B_std', 0.012560607), ('lbp_rad1_bins8_4', 0.01221259)]
# INFO:utils.ml:Fitted classifier: XGBClassifier14; Done in 7.0244340896606445 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier15
# INFO:utils.ml:Top 10 features for XGBClassifier15: [('color_moments_rgb_R_iqr', 0.03451925), ('color_moments_rgb_B_std', 0.033420403), ('fourier_transform_magnitude_std', 0.019984702), ('color_moments_hsv_H_mean', 0.018050611), ('color_moments_rgb_B_var', 0.015864098), ('gradient_direction_std', 0.015523849), ('color_moments_hsv_H_median', 0.014789169), ('color_moments_lab_B_var', 0.013801639), ('lbp_rad2_bins16_8', 0.012474365), ('color_moments_lab_B_std', 0.012343096)]
# INFO:utils.ml:Fitted classifier: XGBClassifier15; Done in 16.02384305000305 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier16
# INFO:utils.ml:Top 10 features for XGBClassifier16: [('color_moments_rgb_R_iqr', 0.033923887), ('color_moments_rgb_B_std', 0.032419212), ('fourier_transform_magnitude_std', 0.02033694), ('color_moments_hsv_H_mean', 0.017926179), ('color_moments_rgb_B_var', 0.01672943), ('gradient_direction_std', 0.015272263), ('color_moments_hsv_H_median', 0.014583362), ('color_moments_lab_B_var', 0.013840747), ('lbp_rad2_bins16_8', 0.012301157), ('color_moments_lab_B_std', 0.0120798545)]
# INFO:utils.ml:Fitted classifier: XGBClassifier16; Done in 13.723048448562622 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier17
# INFO:utils.ml:Top 10 features for XGBClassifier17: [('color_moments_rgb_R_iqr', 0.03424179), ('color_moments_rgb_B_std', 0.03401028), ('fourier_transform_magnitude_std', 0.019432599), ('color_moments_hsv_H_mean', 0.018949697), ('gradient_direction_std', 0.016737679), ('color_moments_rgb_B_var', 0.014212657), ('color_moments_lab_B_var', 0.013580649), ('color_moments_hsv_H_median', 0.0132869985), ('lbp_rad2_bins16_8', 0.012660043), ('color_moments_lab_B_std', 0.012119376)]
# INFO:utils.ml:Fitted classifier: XGBClassifier17; Done in 11.240845441818237 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier18
# INFO:utils.ml:Top 10 features for XGBClassifier18: [('color_moments_rgb_B_std', 0.0345225), ('color_moments_rgb_R_iqr', 0.03406496), ('color_moments_hsv_H_mean', 0.01979669), ('fourier_transform_magnitude_std', 0.01893677), ('gradient_direction_std', 0.016486814), ('color_moments_rgb_B_var', 0.014041196), ('color_moments_lab_B_var', 0.013595139), ('color_moments_hsv_H_median', 0.013137537), ('lbp_rad2_bins16_8', 0.012839227), ('color_moments_lab_B_std', 0.0123546915)]
# INFO:utils.ml:Fitted classifier: XGBClassifier18; Done in 13.088696002960205 seconds
# INFO:utils.ml:Fitting completed in 271.83 seconds.

# %%
pipeline.predict_with_classifiers(VAL_PATH, percent)
# Out:
# INFO:utils.ml:Predicting with classifiers on dataset: C:\Users\gimes\Src\repos\CADx-Project\dataset\multiclass\val
# Processed 5/53 batches.
# Processed 10/53 batches.
# Processed 15/53 batches.
# Processed 20/53 batches.
# Processed 25/53 batches.
# Processed 30/53 batches.
# Processed 35/53 batches.
# Processed 40/53 batches.
# Processed 45/53 batches.
# Processed 50/53 batches.
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier0
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier1
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier2
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier3
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier4
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier5
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier6
# Processed 53/53 batches.
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier7
# INFO:utils.ml:Predictions made with classifier: XGBClassifier8
# INFO:utils.ml:Predictions made with classifier: XGBClassifier9
# INFO:utils.ml:Predictions made with classifier: XGBClassifier10
# INFO:utils.ml:Predictions made with classifier: XGBClassifier11
# INFO:utils.ml:Predictions made with classifier: XGBClassifier12
# INFO:utils.ml:Predictions made with classifier: XGBClassifier13
# INFO:utils.ml:Predictions made with classifier: XGBClassifier14
# INFO:utils.ml:Predictions made with classifier: XGBClassifier15
# INFO:utils.ml:Predictions made with classifier: XGBClassifier16
# INFO:utils.ml:Predictions made with classifier: XGBClassifier17
# INFO:utils.ml:Predictions made with classifier: XGBClassifier18
# {'GT': array([0, 0, 0, ..., 2, 2, 2]),
#  'RandomForestClassifier0': array([0, 0, 2, ..., 1, 0, 0]),
#  'RandomForestClassifier1': array([0, 0, 2, ..., 1, 0, 0]),
#  'RandomForestClassifier2': array([0, 0, 2, ..., 1, 0, 0]),
#  'RandomForestClassifier3': array([0, 0, 2, ..., 1, 0, 0]),
#  'RandomForestClassifier4': array([0, 0, 2, ..., 1, 0, 0]),
#  'RandomForestClassifier5': array([0, 0, 2, ..., 1, 0, 0]),
#  'RandomForestClassifier6': array([0, 0, 2, ..., 1, 0, 0]),
#  'RandomForestClassifier7': array([0, 0, 2, ..., 1, 0, 0]),
#  'XGBClassifier8': array([0, 0, 0, ..., 1, 0, 0], dtype=int64),
#  'XGBClassifier9': array([0, 0, 0, ..., 1, 0, 0], dtype=int64),
#  'XGBClassifier10': array([0, 0, 0, ..., 1, 0, 0], dtype=int64),
#  'XGBClassifier11': array([0, 0, 2, ..., 1, 0, 0], dtype=int64),
#  'XGBClassifier12': array([0, 0, 0, ..., 1, 2, 0], dtype=int64),
#  'XGBClassifier13': array([0, 0, 2, ..., 1, 0, 0], dtype=int64),
#  'XGBClassifier14': array([0, 0, 2, ..., 1, 0, 0], dtype=int64),
#  'XGBClassifier15': array([0, 0, 0, ..., 1, 0, 0], dtype=int64),
#  'XGBClassifier16': array([0, 0, 0, ..., 1, 0, 0], dtype=int64),
#  'XGBClassifier17': array([0, 0, 2, ..., 1, 0, 0], dtype=int64),
#  'XGBClassifier18': array([0, 0, 0, ..., 1, 2, 0], dtype=int64)}

# %%
df_borderline_smote = pd.DataFrame(data=pipeline.calculate_metrics(
    ["accuracy", "precision", "recall", "f1", "kappa"],))
df_borderline_smote = df_borderline_smote.T
df_borderline_smote
# Out:
# INFO:utils.ml:Metrics for classifier GT: {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'kappa': 1.0}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier0: {'accuracy': 0.8228346456692913, 'precision': 0.7022596077353963, 'recall': 0.6936739615210986, 'f1': 0.6967017373361784, 'kappa': 0.6815403749966567}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier1: {'accuracy': 0.8181102362204724, 'precision': 0.7030043657223022, 'recall': 0.6909018109719995, 'f1': 0.694863575798989, 'kappa': 0.6732622322013284}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier2: {'accuracy': 0.8181102362204724, 'precision': 0.6929302193687885, 'recall': 0.6813830354367951, 'f1': 0.6852551855087133, 'kappa': 0.6726555770286495}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier3: {'accuracy': 0.8322834645669291, 'precision': 0.7256799595121489, 'recall': 0.6939978579982391, 'f1': 0.7050061993946178, 'kappa': 0.6955375673619333}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier4: {'accuracy': 0.8196850393700787, 'precision': 0.7012753804701273, 'recall': 0.6915296912245732, 'f1': 0.6949005752581936, 'kappa': 0.6759279894453458}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier5: {'accuracy': 0.8283464566929134, 'precision': 0.7103317390786102, 'recall': 0.6850753292464403, 'f1': 0.6938371426621414, 'kappa': 0.6887366887321917}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier6: {'accuracy': 0.815748031496063, 'precision': 0.6903316383892552, 'recall': 0.6802635130996592, 'f1': 0.6833756028058975, 'kappa': 0.6688861257069512}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier7: {'accuracy': 0.8307086614173228, 'precision': 0.708159497742912, 'recall': 0.6807967450042435, 'f1': 0.6897657364996768, 'kappa': 0.6926012653952671}
# INFO:utils.ml:Metrics for classifier XGBClassifier8: {'accuracy': 0.8535433070866142, 'precision': 0.7525419775473648, 'recall': 0.721089340730776, 'f1': 0.7329445227634213, 'kappa': 0.7339553281014893}
# INFO:utils.ml:Metrics for classifier XGBClassifier9: {'accuracy': 0.8559055118110236, 'precision': 0.7606458582068338, 'recall': 0.7227419689427389, 'f1': 0.7366179088244649, 'kappa': 0.7377821203081492}
# INFO:utils.ml:Metrics for classifier XGBClassifier10: {'accuracy': 0.8559055118110236, 'precision': 0.7584505701159276, 'recall': 0.7227419689427389, 'f1': 0.7359630862124306, 'kappa': 0.7379015887622811}
# INFO:utils.ml:Metrics for classifier XGBClassifier11: {'accuracy': 0.8023622047244094, 'precision': 0.6667465297952765, 'recall': 0.6812801951545592, 'f1': 0.672621618667591, 'kappa': 0.6503227250189774}
# INFO:utils.ml:Metrics for classifier XGBClassifier12: {'accuracy': 0.8464566929133859, 'precision': 0.7373903006720356, 'recall': 0.7206410528828425, 'f1': 0.7277934825219835, 'kappa': 0.7221212366025744}
# INFO:utils.ml:Metrics for classifier XGBClassifier13: {'accuracy': 0.8401574803149606, 'precision': 0.72574605898262, 'recall': 0.7163525122897919, 'f1': 0.7204595597740546, 'kappa': 0.7117238202156733}
# INFO:utils.ml:Metrics for classifier XGBClassifier14: {'accuracy': 0.8456692913385827, 'precision': 0.7281177109382767, 'recall': 0.7145736022606713, 'f1': 0.7202742639984381, 'kappa': 0.7211042889795186}
# INFO:utils.ml:Metrics for classifier XGBClassifier15: {'accuracy': 0.8464566929133859, 'precision': 0.7336549575355545, 'recall': 0.7098448397241763, 'f1': 0.719055733696524, 'kappa': 0.721406008135642}
# INFO:utils.ml:Metrics for classifier XGBClassifier16: {'accuracy': 0.8433070866141732, 'precision': 0.7251081389674564, 'recall': 0.7078782713859266, 'f1': 0.7146953815606086, 'kappa': 0.7164936888912821}
# INFO:utils.ml:Metrics for classifier XGBClassifier17: {'accuracy': 0.8433070866141732, 'precision': 0.7264153677101355, 'recall': 0.7127432720904329, 'f1': 0.7185241163358644, 'kappa': 0.716778358024968}
# INFO:utils.ml:Metrics for classifier XGBClassifier18: {'accuracy': 0.8488188976377953, 'precision': 0.7395506875468708, 'recall': 0.7167178725571968, 'f1': 0.7258921021478099, 'kappa': 0.7258302450257259}
#                          accuracy  precision    recall        f1     kappa
# GT                       1.000000   1.000000  1.000000  1.000000  1.000000
# RandomForestClassifier0  0.822835   0.702260  0.693674  0.696702  0.681540
# RandomForestClassifier1  0.818110   0.703004  0.690902  0.694864  0.673262
# RandomForestClassifier2  0.818110   0.692930  0.681383  0.685255  0.672656
# RandomForestClassifier3  0.832283   0.725680  0.693998  0.705006  0.695538
# RandomForestClassifier4  0.819685   0.701275  0.691530  0.694901  0.675928
# RandomForestClassifier5  0.828346   0.710332  0.685075  0.693837  0.688737
# RandomForestClassifier6  0.815748   0.690332  0.680264  0.683376  0.668886
# RandomForestClassifier7  0.830709   0.708159  0.680797  0.689766  0.692601
# XGBClassifier8           0.853543   0.752542  0.721089  0.732945  0.733955
# XGBClassifier9           0.855906   0.760646  0.722742  0.736618  0.737782
# XGBClassifier10          0.855906   0.758451  0.722742  0.735963  0.737902
# XGBClassifier11          0.802362   0.666747  0.681280  0.672622  0.650323
# XGBClassifier12          0.846457   0.737390  0.720641  0.727793  0.722121
# XGBClassifier13          0.840157   0.725746  0.716353  0.720460  0.711724
# XGBClassifier14          0.845669   0.728118  0.714574  0.720274  0.721104
# XGBClassifier15          0.846457   0.733655  0.709845  0.719056  0.721406
# XGBClassifier16          0.843307   0.725108  0.707878  0.714695  0.716494
# XGBClassifier17          0.843307   0.726415  0.712743  0.718524  0.716778
# XGBClassifier18          0.848819   0.739551  0.716718  0.725892  0.725830

# %%
highest = df_borderline_smote[df_borderline_smote["kappa"] == df_borderline_smote.iloc[1:]["kappa"].max()]
idx = highest.index[0]

confusion_matrix(pipeline.predictions["GT"], pipeline.predictions[idx])
# Out:
# array([[441,  38,  19],
#        [ 56, 610,  12],
#        [ 35,  23,  36]], dtype=int64)

# %% [markdown]
# ___
# # PCA

# %%
from sklearn.decomposition import PCA
from imblearn.over_sampling import BorderlineSMOTE
smote = BorderlineSMOTE(sampling_strategy='auto', random_state=42)

pipeline.feature_matrix, pipeline.labels = smote.fit_resample(
    np.nan_to_num(pipeline.backup_feature_matrix), pipeline.backup_labels)

pca = PCA(n_components=100)

pipeline.feature_matrix = pca.fit_transform(pipeline.feature_matrix, pipeline.labels)

print(pipeline.backup_feature_matrix.shape)
print(pipeline.feature_matrix.shape)

print(pipeline.backup_labels.shape)
print(pipeline.labels.shape)

print(pca.get_feature_names_out())

pipeline.fitted_classifiers = {}
pipeline.fit_classifiers()
# Out:
# INFO:utils.ml:Fitting classifiers...
# INFO:utils.ml:Fitting classifier: RandomForestClassifier0
# (5082, 189)
# (8139, 100)
# (5082,)
# (8139,)
# ['pca0' 'pca1' 'pca2' 'pca3' 'pca4' 'pca5' 'pca6' 'pca7' 'pca8' 'pca9'
#  'pca10' 'pca11' 'pca12' 'pca13' 'pca14' 'pca15' 'pca16' 'pca17' 'pca18'
#  'pca19' 'pca20' 'pca21' 'pca22' 'pca23' 'pca24' 'pca25' 'pca26' 'pca27'
#  'pca28' 'pca29' 'pca30' 'pca31' 'pca32' 'pca33' 'pca34' 'pca35' 'pca36'
#  'pca37' 'pca38' 'pca39' 'pca40' 'pca41' 'pca42' 'pca43' 'pca44' 'pca45'
#  'pca46' 'pca47' 'pca48' 'pca49' 'pca50' 'pca51' 'pca52' 'pca53' 'pca54'
#  'pca55' 'pca56' 'pca57' 'pca58' 'pca59' 'pca60' 'pca61' 'pca62' 'pca63'
#  'pca64' 'pca65' 'pca66' 'pca67' 'pca68' 'pca69' 'pca70' 'pca71' 'pca72'
#  'pca73' 'pca74' 'pca75' 'pca76' 'pca77' 'pca78' 'pca79' 'pca80' 'pca81'
#  'pca82' 'pca83' 'pca84' 'pca85' 'pca86' 'pca87' 'pca88' 'pca89' 'pca90'
#  'pca91' 'pca92' 'pca93' 'pca94' 'pca95' 'pca96' 'pca97' 'pca98' 'pca99']
# INFO:utils.ml:Top 10 features for RandomForestClassifier0: [('gradient_magnitude_std', 0.047907252324980415), ('color_moments_rgb_R_var', 0.03362100886265028), ('gradient_direction_mean', 0.028770474576938192), ('color_moments_rgb_R_median', 0.024306964718643645), ('gradient_direction_std', 0.022762841982708504), ('color_moments_rgb_R_std', 0.020735503538865826), ('color_moments_lab_L_skew', 0.01668086724291248), ('color_moments_rgb_R_kurtosis', 0.01637594869653363), ('color_moments_lab_L_mean', 0.016085704907514042), ('color_moments_lab_B_mean', 0.016033009490347267)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier0; Done in 7.393419027328491 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier1
# INFO:utils.ml:Top 10 features for RandomForestClassifier1: [('gradient_magnitude_std', 0.051428252743307784), ('color_moments_rgb_R_var', 0.029569093975270324), ('gradient_direction_mean', 0.027604787882320826), ('color_moments_rgb_R_median', 0.02726726146924474), ('gradient_direction_std', 0.02291925766232148), ('color_moments_rgb_R_std', 0.020342057359606504), ('color_moments_lab_L_skew', 0.016805972110097826), ('color_moments_lab_L_mean', 0.01623337635100562), ('color_moments_lab_B_mean', 0.015942200526653183), ('color_moments_rgb_R_skew', 0.015769321447706045)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier1; Done in 10.819075345993042 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier2
# INFO:utils.ml:Top 10 features for RandomForestClassifier2: [('gradient_magnitude_std', 0.05166466276259309), ('color_moments_rgb_R_var', 0.031463030117161936), ('gradient_direction_mean', 0.02735573747172126), ('color_moments_rgb_R_median', 0.024450217382816275), ('color_moments_rgb_R_std', 0.021711448313782907), ('gradient_direction_std', 0.020625675351272924), ('color_moments_rgb_R_kurtosis', 0.018807488076966198), ('color_moments_lab_L_mean', 0.017037536925756113), ('color_moments_lab_B_mean', 0.015940202636518554), ('color_moments_rgb_B_mean', 0.015678763202502086)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier2; Done in 7.406255722045898 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier3
# INFO:utils.ml:Top 10 features for RandomForestClassifier3: [('gradient_magnitude_std', 0.054980331340202165), ('color_moments_rgb_R_var', 0.03332659795919618), ('gradient_direction_mean', 0.027559745521420757), ('color_moments_rgb_R_median', 0.024753219317905216), ('color_moments_rgb_R_std', 0.021514548467425055), ('gradient_direction_std', 0.020997005327616867), ('color_moments_lab_L_mean', 0.016630903059730903), ('color_moments_lab_B_mean', 0.016150610655470788), ('color_moments_rgb_R_kurtosis', 0.015799735222598546), ('color_moments_rgb_B_mean', 0.015712623170030936)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier3; Done in 10.75977897644043 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier4
# INFO:utils.ml:Top 10 features for RandomForestClassifier4: [('gradient_magnitude_std', 0.05255514253617958), ('color_moments_rgb_R_var', 0.029771222187611853), ('color_moments_rgb_R_median', 0.026795171551007187), ('gradient_direction_mean', 0.026178505536230693), ('color_moments_rgb_R_std', 0.021707692173624196), ('gradient_direction_std', 0.02136787163086906), ('color_moments_rgb_R_kurtosis', 0.016996155906792248), ('color_moments_lab_L_mean', 0.016974279506174972), ('color_moments_lab_B_mean', 0.01601007462818554), ('color_moments_lab_L_skew', 0.015613232308587946)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier4; Done in 10.901846647262573 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier5
# INFO:utils.ml:Top 10 features for RandomForestClassifier5: [('gradient_magnitude_std', 0.05479105796942631), ('color_moments_rgb_R_var', 0.030964494789628472), ('gradient_direction_mean', 0.027709269689535018), ('color_moments_rgb_R_median', 0.026298648455913266), ('color_moments_rgb_R_std', 0.021910224837096422), ('gradient_direction_std', 0.020882877086020515), ('color_moments_lab_L_mean', 0.01691144042608571), ('color_moments_lab_L_iqr', 0.015668185533401532), ('color_moments_rgb_R_kurtosis', 0.015643503792337768), ('color_moments_lab_B_mean', 0.015613922830154165)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier5; Done in 15.97140622138977 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier6
# INFO:utils.ml:Top 10 features for RandomForestClassifier6: [('gradient_magnitude_std', 0.050852646750889456), ('color_moments_rgb_R_var', 0.031147540480114096), ('gradient_direction_mean', 0.027675120543143226), ('color_moments_rgb_R_median', 0.026303327185774064), ('color_moments_rgb_R_std', 0.021643788925984182), ('gradient_direction_std', 0.021413697937214864), ('color_moments_lab_L_mean', 0.01693742428101415), ('color_moments_rgb_R_kurtosis', 0.01661266781541866), ('color_moments_lab_B_mean', 0.0158579284885211), ('color_moments_lab_L_skew', 0.015253310042775588)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier6; Done in 14.89791488647461 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier7
# INFO:utils.ml:Top 10 features for RandomForestClassifier7: [('gradient_magnitude_std', 0.053445088153690715), ('color_moments_rgb_R_var', 0.03284961311780335), ('gradient_direction_mean', 0.027990782242781873), ('color_moments_rgb_R_median', 0.025140928062573363), ('color_moments_rgb_R_std', 0.021590375937628793), ('gradient_direction_std', 0.021473324126606633), ('color_moments_lab_L_mean', 0.016922601436997933), ('color_moments_lab_B_mean', 0.01593286904492687), ('color_moments_rgb_R_kurtosis', 0.015848812956479986), ('color_moments_lab_L_iqr', 0.01548206992230896)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier7; Done in 31.735867023468018 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier8
# INFO:utils.ml:Top 10 features for XGBClassifier8: [('gradient_magnitude_std', 0.054504674), ('color_moments_rgb_R_var', 0.031497885), ('color_moments_rgb_R_std', 0.030143825), ('color_moments_rgb_R_median', 0.026068522), ('gradient_direction_mean', 0.023917079), ('color_moments_rgb_B_mean', 0.018429266), ('color_moments_rgb_G_min', 0.018415228), ('color_moments_rgb_R_max', 0.017691955), ('color_moments_lab_L_skew', 0.017611567), ('color_moments_lab_B_mean', 0.017492684)]
# INFO:utils.ml:Fitted classifier: XGBClassifier8; Done in 5.757129430770874 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier9
# INFO:utils.ml:Top 10 features for XGBClassifier9: [('gradient_magnitude_std', 0.05367216), ('color_moments_rgb_R_var', 0.031212179), ('color_moments_rgb_R_std', 0.030114418), ('color_moments_rgb_R_median', 0.026346257), ('gradient_direction_mean', 0.0239003), ('color_moments_rgb_G_min', 0.019098034), ('color_moments_rgb_B_mean', 0.018443812), ('color_moments_rgb_R_max', 0.017747773), ('color_moments_lab_B_mean', 0.017615167), ('color_moments_lab_L_skew', 0.017534977)]
# INFO:utils.ml:Fitted classifier: XGBClassifier9; Done in 8.028255462646484 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier10
# INFO:utils.ml:Top 10 features for XGBClassifier10: [('gradient_magnitude_std', 0.053180072), ('color_moments_rgb_R_var', 0.031381104), ('color_moments_rgb_R_std', 0.029784143), ('color_moments_rgb_R_median', 0.026562525), ('gradient_direction_mean', 0.02391973), ('color_moments_rgb_G_min', 0.019186493), ('color_moments_rgb_B_mean', 0.01854718), ('color_moments_rgb_R_max', 0.018073615), ('color_moments_lab_B_mean', 0.01783349), ('color_moments_lab_L_skew', 0.017556127)]
# INFO:utils.ml:Fitted classifier: XGBClassifier10; Done in 10.222292184829712 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier11
# INFO:utils.ml:Top 10 features for XGBClassifier11: [('gradient_magnitude_std', 0.040732946), ('color_moments_rgb_R_var', 0.02999222), ('gradient_direction_std', 0.028038999), ('color_moments_rgb_R_std', 0.022542737), ('color_moments_rgb_R_median', 0.021348938), ('gradient_direction_mean', 0.019337012), ('color_moments_lab_B_mean', 0.018341107), ('color_moments_lab_L_skew', 0.017475264), ('color_moments_rgb_R_max', 0.017274674), ('color_moments_lab_B_entropy', 0.017031882)]
# INFO:utils.ml:Fitted classifier: XGBClassifier11; Done in 4.746795177459717 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier12
# INFO:utils.ml:Top 10 features for XGBClassifier12: [('gradient_magnitude_std', 0.041565653), ('color_moments_rgb_R_var', 0.0279542), ('color_moments_rgb_R_median', 0.021601954), ('color_moments_rgb_R_std', 0.021381026), ('gradient_direction_mean', 0.020323718), ('gradient_direction_std', 0.019418495), ('color_moments_lab_B_mean', 0.017100837), ('color_moments_rgb_R_max', 0.016478518), ('color_moments_lab_L_iqr', 0.016140914), ('color_moments_rgb_B_mean', 0.015817566)]
# INFO:utils.ml:Fitted classifier: XGBClassifier12; Done in 11.070945978164673 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier13
# INFO:utils.ml:Top 10 features for XGBClassifier13: [('gradient_magnitude_std', 0.04318633), ('color_moments_rgb_R_var', 0.028740268), ('color_moments_rgb_R_median', 0.025046926), ('color_moments_rgb_R_std', 0.02374285), ('gradient_direction_mean', 0.022521889), ('gradient_direction_std', 0.021188565), ('color_moments_rgb_B_mean', 0.01905903), ('color_moments_lab_B_mean', 0.017617187), ('color_moments_rgb_R_max', 0.017114814), ('color_moments_lab_L_iqr', 0.016222898)]
# INFO:utils.ml:Fitted classifier: XGBClassifier13; Done in 6.444795846939087 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier14
# INFO:utils.ml:Top 10 features for XGBClassifier14: [('gradient_magnitude_std', 0.047688957), ('color_moments_rgb_R_var', 0.028189147), ('color_moments_rgb_R_median', 0.025603876), ('gradient_direction_mean', 0.024376746), ('color_moments_rgb_R_std', 0.023476617), ('gradient_direction_std', 0.019921722), ('color_moments_rgb_B_mean', 0.01849718), ('color_moments_lab_B_mean', 0.018045409), ('color_moments_lab_L_skew', 0.017601429), ('color_moments_lab_L_mean', 0.017314726)]
# INFO:utils.ml:Fitted classifier: XGBClassifier14; Done in 6.756205320358276 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier15
# INFO:utils.ml:Top 10 features for XGBClassifier15: [('gradient_magnitude_std', 0.043208595), ('color_moments_rgb_R_var', 0.02533018), ('color_moments_rgb_R_median', 0.02407832), ('gradient_direction_mean', 0.023702495), ('color_moments_rgb_R_std', 0.022592362), ('gradient_direction_std', 0.01903682), ('color_moments_rgb_B_mean', 0.017306987), ('color_moments_lab_B_mean', 0.01665096), ('color_moments_lab_L_mean', 0.016093213), ('color_moments_lab_L_iqr', 0.015495897)]
# INFO:utils.ml:Fitted classifier: XGBClassifier15; Done in 13.63063931465149 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier16
# INFO:utils.ml:Top 10 features for XGBClassifier16: [('gradient_magnitude_std', 0.04209663), ('color_moments_rgb_R_var', 0.025197659), ('gradient_direction_mean', 0.023824), ('color_moments_rgb_R_median', 0.023617825), ('color_moments_rgb_R_std', 0.02237632), ('gradient_direction_std', 0.018757014), ('color_moments_rgb_B_mean', 0.017195148), ('color_moments_lab_B_mean', 0.016557693), ('color_moments_lab_L_mean', 0.01590121), ('color_moments_lab_B_entropy', 0.015715048)]
# INFO:utils.ml:Fitted classifier: XGBClassifier16; Done in 12.089404106140137 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier17
# INFO:utils.ml:Top 10 features for XGBClassifier17: [('gradient_magnitude_std', 0.043605257), ('color_moments_rgb_R_var', 0.026802056), ('color_moments_rgb_R_median', 0.024903731), ('gradient_direction_mean', 0.024131298), ('color_moments_rgb_R_std', 0.022244131), ('gradient_direction_std', 0.019101962), ('color_moments_lab_B_mean', 0.018204559), ('color_moments_rgb_B_mean', 0.018153468), ('color_moments_lab_L_mean', 0.016207248), ('color_moments_rgb_G_min', 0.016068952)]
# INFO:utils.ml:Fitted classifier: XGBClassifier17; Done in 10.02042818069458 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier18
# INFO:utils.ml:Top 10 features for XGBClassifier18: [('gradient_magnitude_std', 0.043942466), ('color_moments_rgb_R_var', 0.026618185), ('color_moments_rgb_R_median', 0.02520681), ('gradient_direction_mean', 0.024187148), ('color_moments_rgb_R_std', 0.02225517), ('gradient_direction_std', 0.019280106), ('color_moments_lab_B_mean', 0.018434288), ('color_moments_rgb_B_mean', 0.018294476), ('color_moments_lab_L_mean', 0.016234819), ('color_moments_rgb_G_min', 0.016177626)]
# INFO:utils.ml:Fitted classifier: XGBClassifier18; Done in 12.29373836517334 seconds
# INFO:utils.ml:Fitting completed in 210.95 seconds.

# %%
# Load and extract features from the new dataset
new_loader = FactoryLoader(path=VAL_PATH, factory=pipeline.loader.get_factory(),
                           percentage=percent, batch_size=pipeline.batch_size)
new_feature_matrix, new_labels = pipeline.feature_strategy.run(new_loader.get_loader())

new_feature_matrix = np.nan_to_num(new_feature_matrix) # Impute nans
new_feature_matrix = pca.transform(new_feature_matrix) # Impute nans

# Store predictions in the class attribute
pipeline.predictions = {"GT": new_labels, }
for clf_name, clf in pipeline.fitted_classifiers.items():

    pipeline.predictions[clf_name] = clf.predict(new_feature_matrix)
    if pipeline.verbose:
        logger.info("Predictions made with classifier: %s", clf_name)
# Out:
# Processed 5/53 batches.
# Processed 10/53 batches.
# Processed 15/53 batches.
# Processed 20/53 batches.
# Processed 25/53 batches.
# Processed 30/53 batches.
# Processed 35/53 batches.
# Processed 40/53 batches.
# Processed 45/53 batches.
# Processed 50/53 batches.
# INFO:utils.utils:Predictions made with classifier: RandomForestClassifier0
# INFO:utils.utils:Predictions made with classifier: RandomForestClassifier1
# INFO:utils.utils:Predictions made with classifier: RandomForestClassifier2
# INFO:utils.utils:Predictions made with classifier: RandomForestClassifier3
# INFO:utils.utils:Predictions made with classifier: RandomForestClassifier4
# INFO:utils.utils:Predictions made with classifier: RandomForestClassifier5
# INFO:utils.utils:Predictions made with classifier: RandomForestClassifier6
# Processed 53/53 batches.
# INFO:utils.utils:Predictions made with classifier: RandomForestClassifier7
# INFO:utils.utils:Predictions made with classifier: XGBClassifier8
# INFO:utils.utils:Predictions made with classifier: XGBClassifier9
# INFO:utils.utils:Predictions made with classifier: XGBClassifier10
# INFO:utils.utils:Predictions made with classifier: XGBClassifier11
# INFO:utils.utils:Predictions made with classifier: XGBClassifier12
# INFO:utils.utils:Predictions made with classifier: XGBClassifier13
# INFO:utils.utils:Predictions made with classifier: XGBClassifier14
# INFO:utils.utils:Predictions made with classifier: XGBClassifier15
# INFO:utils.utils:Predictions made with classifier: XGBClassifier16
# INFO:utils.utils:Predictions made with classifier: XGBClassifier17
# INFO:utils.utils:Predictions made with classifier: XGBClassifier18

# %%
df_pca = pd.DataFrame(data=pipeline.calculate_metrics(avg="macro"))
df_pca = df_pca.T
df_pca
# Out:
# INFO:utils.ml:Metrics for classifier GT: {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'kappa': 1.0}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier0: {'accuracy': 0.8062992125984252, 'precision': 0.6710106176707596, 'recall': 0.6476180249775857, 'f1': 0.6549816382608759, 'kappa': 0.6470277207856181}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier1: {'accuracy': 0.8070866141732284, 'precision': 0.6828970558279727, 'recall': 0.6545739853911346, 'f1': 0.6636090028252618, 'kappa': 0.6484450912246291}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier2: {'accuracy': 0.8102362204724409, 'precision': 0.6805816866022797, 'recall': 0.6550854141476469, 'f1': 0.6625307858891067, 'kappa': 0.6550966410039125}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier3: {'accuracy': 0.8141732283464567, 'precision': 0.6950427364362993, 'recall': 0.6471363392438768, 'f1': 0.6591212419840576, 'kappa': 0.658131746799405}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier4: {'accuracy': 0.815748031496063, 'precision': 0.6844590215930432, 'recall': 0.6617590679040772, 'f1': 0.6689205445117165, 'kappa': 0.6652322804487902}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier5: {'accuracy': 0.8204724409448819, 'precision': 0.7043292077842483, 'recall': 0.657533794249363, 'f1': 0.6704102148788507, 'kappa': 0.6700411593912239}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier6: {'accuracy': 0.8125984251968504, 'precision': 0.6835030427138733, 'recall': 0.6617807450223917, 'f1': 0.6690701162211791, 'kappa': 0.6596125172862697}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier7: {'accuracy': 0.8188976377952756, 'precision': 0.6996889456692253, 'recall': 0.6534960528740205, 'f1': 0.6657617687250096, 'kappa': 0.6669934789548086}
# INFO:utils.ml:Metrics for classifier XGBClassifier8: {'accuracy': 0.8393700787401575, 'precision': 0.7260246742572148, 'recall': 0.7011216900489675, 'f1': 0.7107336005599033, 'kappa': 0.7081788322647791}
# INFO:utils.ml:Metrics for classifier XGBClassifier9: {'accuracy': 0.841732283464567, 'precision': 0.7300034451888063, 'recall': 0.7058287754671482, 'f1': 0.7152595335043879, 'kappa': 0.7127175410323127}
# INFO:utils.ml:Metrics for classifier XGBClassifier10: {'accuracy': 0.8440944881889764, 'precision': 0.7335294470915574, 'recall': 0.7078368075956623, 'f1': 0.7177121682187163, 'kappa': 0.716933980530065}
# INFO:utils.ml:Metrics for classifier XGBClassifier11: {'accuracy': 0.7811023622047244, 'precision': 0.64245590637204, 'recall': 0.6599422229179065, 'f1': 0.6484369612249645, 'kappa': 0.6156994387770651}
# INFO:utils.ml:Metrics for classifier XGBClassifier12: {'accuracy': 0.8385826771653543, 'precision': 0.7275493942872644, 'recall': 0.7006300479644052, 'f1': 0.7109986753173102, 'kappa': 0.706376595840664}
# INFO:utils.ml:Metrics for classifier XGBClassifier13: {'accuracy': 0.8362204724409449, 'precision': 0.7185535176526292, 'recall': 0.7113729505355887, 'f1': 0.714384911149012, 'kappa': 0.7051127483813351}
# INFO:utils.ml:Metrics for classifier XGBClassifier14: {'accuracy': 0.8409448818897638, 'precision': 0.7175084175084177, 'recall': 0.6968845695970348, 'f1': 0.7047188760827637, 'kappa': 0.7114051981712805}
# INFO:utils.ml:Metrics for classifier XGBClassifier15: {'accuracy': 0.841732283464567, 'precision': 0.7162807664638704, 'recall': 0.7004306688878151, 'f1': 0.7067049837208286, 'kappa': 0.7134708116699442}
# INFO:utils.ml:Metrics for classifier XGBClassifier16: {'accuracy': 0.8409448818897638, 'precision': 0.719470986884251, 'recall': 0.7026380800929193, 'f1': 0.709377671347556, 'kappa': 0.7119871026266273}
# INFO:utils.ml:Metrics for classifier XGBClassifier17: {'accuracy': 0.8488188976377953, 'precision': 0.7491930568167743, 'recall': 0.7114974679361392, 'f1': 0.7252120395974372, 'kappa': 0.7243686840141975}
# INFO:utils.ml:Metrics for classifier XGBClassifier18: {'accuracy': 0.8480314960629921, 'precision': 0.7486748843226958, 'recall': 0.7111835278098524, 'f1': 0.7247637400032853, 'kappa': 0.723045806874421}
#                          accuracy  precision    recall        f1     kappa
# GT                       1.000000   1.000000  1.000000  1.000000  1.000000
# RandomForestClassifier0  0.806299   0.671011  0.647618  0.654982  0.647028
# RandomForestClassifier1  0.807087   0.682897  0.654574  0.663609  0.648445
# RandomForestClassifier2  0.810236   0.680582  0.655085  0.662531  0.655097
# RandomForestClassifier3  0.814173   0.695043  0.647136  0.659121  0.658132
# RandomForestClassifier4  0.815748   0.684459  0.661759  0.668921  0.665232
# RandomForestClassifier5  0.820472   0.704329  0.657534  0.670410  0.670041
# RandomForestClassifier6  0.812598   0.683503  0.661781  0.669070  0.659613
# RandomForestClassifier7  0.818898   0.699689  0.653496  0.665762  0.666993
# XGBClassifier8           0.839370   0.726025  0.701122  0.710734  0.708179
# XGBClassifier9           0.841732   0.730003  0.705829  0.715260  0.712718
# XGBClassifier10          0.844094   0.733529  0.707837  0.717712  0.716934
# XGBClassifier11          0.781102   0.642456  0.659942  0.648437  0.615699
# XGBClassifier12          0.838583   0.727549  0.700630  0.710999  0.706377
# XGBClassifier13          0.836220   0.718554  0.711373  0.714385  0.705113
# XGBClassifier14          0.840945   0.717508  0.696885  0.704719  0.711405
# XGBClassifier15          0.841732   0.716281  0.700431  0.706705  0.713471
# XGBClassifier16          0.840945   0.719471  0.702638  0.709378  0.711987
# XGBClassifier17          0.848819   0.749193  0.711497  0.725212  0.724369
# XGBClassifier18          0.848031   0.748675  0.711184  0.724764  0.723046

# %%
highest = df_pca[df_pca["kappa"] == df_pca.iloc[1:]["kappa"].max()]
idx = highest.index[0]

confusion_matrix(pipeline.predictions["GT"], pipeline.predictions[idx])
# Out:
# array([[437,  44,  17],
#        [ 57, 607,  14],
#        [ 33,  27,  34]], dtype=int64)
