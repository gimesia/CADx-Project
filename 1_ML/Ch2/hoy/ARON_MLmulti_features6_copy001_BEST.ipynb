# %%
import numpy as np
from sklearn.metrics import confusion_matrix, recall_score, cohen_kappa_score

from utils.loader import FactoryLoader
from utils.ml import MLPipeline
from utils.preprocessing import PreprocessingFactory
from utils.feature_extraction import *
from utils.utils import *

VAL_PATH = r"C:\Users\gimes\Src\repos\CADx-Project\dataset\multiclass\val"
TRAIN_PATH = r"C:\Users\gimes\Src\repos\CADx-Project\dataset\multiclass\train"
TEST_PATH = r"C:\Users\gimes\Src\repos\CADx-Project\dataset\multiclass\test"

# %%
percent = 100
random = False
batch_size = 24
th = 0.01

# Initialize the FactoryLoader
factory = PreprocessingFactory()
factory.pad2square(fill=np.nan)
factory.resize((200,200))
factory.normalize2float()

# Create the feature extraction pipeline strategy and add desired features
strategy = FeatureExtractionStrategy()

strategy.add_extractor(GradientExtractor(threshold=th)) # Add gradient feature

strategy.add_extractor(ColorMomentsExtractor("rgb", threshold=th))   # Add color moments feature
strategy.add_extractor(ColorMomentsExtractor("lab", threshold=th))   # Add color moments feature
strategy.add_extractor(ColorMomentsExtractor("hsv", threshold=th))   # Add color moments feature

strategy.add_extractor(LBPExtractor(radius=1, n_points=8))
strategy.add_extractor(LBPExtractor(radius=2, n_points=16))
strategy.add_extractor(LBPExtractor(radius=3, n_points=24))
strategy.add_extractor(LBPExtractor(radius=4, n_points=32))
strategy.add_extractor(LBPExtractor(radius=5, n_points=40))

strategy.add_extractor(FourierTransformExtractor())
strategy.add_extractor(FFTExtractor())

strategy.add_extractor(GLCMExtractor(properties=['contrast', 'dissimilarity', 'homogeneity', 'energy', 'correlation', 'ASM']))

pipeline = MLPipeline(dataset_path=TRAIN_PATH, preprocessing_factory=factory, feature_strategy=strategy, classifiers=[], percentage=percent, verbose=True, shuffle=random, batch_size=batch_size)
# Out:
# INFO:utils.ml:MLPipeline initialized with dataset path: C:\Users\gimes\Src\repos\CADx-Project\dataset\multiclass\train
# INFO:utils.ml:Preprocessing steps

# %%
pipeline.feature_matrix = None
pipeline.run_feature_extraction()
# Out:
# INFO:utils.ml:Running feature extraction...
# Processed 5/212 batches.
# Processed 10/212 batches.
# Processed 15/212 batches.
# Processed 20/212 batches.
# Processed 25/212 batches.
# Processed 30/212 batches.
# Processed 35/212 batches.
# Processed 40/212 batches.
# Processed 45/212 batches.
# Processed 50/212 batches.
# Processed 55/212 batches.
# Processed 60/212 batches.
# Processed 65/212 batches.
# Processed 70/212 batches.
# Processed 75/212 batches.
# Processed 80/212 batches.
# Processed 85/212 batches.
# Processed 90/212 batches.
# Processed 95/212 batches.
# Processed 100/212 batches.
# Processed 105/212 batches.
# Processed 110/212 batches.
# Processed 115/212 batches.
# Processed 120/212 batches.
# Processed 125/212 batches.
# Processed 130/212 batches.
# Processed 135/212 batches.
# Processed 140/212 batches.
# Processed 145/212 batches.
# Processed 150/212 batches.
# Processed 155/212 batches.
# Processed 160/212 batches.
# Processed 165/212 batches.
# Processed 170/212 batches.
# Processed 175/212 batches.
# Processed 180/212 batches.
# Processed 185/212 batches.
# Processed 190/212 batches.
# Processed 195/212 batches.
# Processed 200/212 batches.
# Processed 205/212 batches.
# Processed 210/212 batches.
# INFO:utils.ml:Feature extraction completed. Extracted 5082 features.
# Processed 212/212 batches.

# %%
from xgboost import XGBClassifier
from sklearn.ensemble import RandomForestClassifier

xgb0 = XGBClassifier(learning_rate=0.1, n_estimators=400, max_depth=7, min_child_weight=3, subsample=0.7, colsample_bytree=0.7)
xgb1 = XGBClassifier(learning_rate=0.1, n_estimators=400, max_depth=5, min_child_weight=5, gamma=0.2, subsample=0.8, colsample_bytree=0.8)
xgb2 = XGBClassifier(learning_rate=0.1, n_estimators=400, max_depth=5, min_child_weight=1, subsample=0.8, colsample_bytree=0.8, reg_alpha=0.1, reg_lambda=0.1)
xgb3 = XGBClassifier(learning_rate=0.1, n_estimators=400, max_depth=7, min_child_weight=1, subsample=0.8, colsample_bytree=0.8) # THIS!!
xgb4 = XGBClassifier(learning_rate=0.1, n_estimators=500, max_depth=7, min_child_weight=1, subsample=0.8, colsample_bytree=0.8)
xgb5 = XGBClassifier(learning_rate=0.1, n_estimators=750, max_depth=7, min_child_weight=3, subsample=0.7, colsample_bytree=0.7)
xgb6 = XGBClassifier(learning_rate=0.1, n_estimators=750, max_depth=5, min_child_weight=5, gamma=0.2, subsample=0.8, colsample_bytree=0.8) # THIS
xgb7 = XGBClassifier(learning_rate=0.1, n_estimators=750, max_depth=5, min_child_weight=1, subsample=0.8, colsample_bytree=0.8, reg_alpha=0.1, reg_lambda=0.1) # THIS
xgb8 = XGBClassifier(learning_rate=0.1, n_estimators=1000, max_depth=7, min_child_weight=3, subsample=0.7, colsample_bytree=0.7)
xgb9 = XGBClassifier(learning_rate=0.1, n_estimators=1000, max_depth=5, min_child_weight=5, gamma=0.2, subsample=0.8, colsample_bytree=0.8)
xgb10 = XGBClassifier(learning_rate=0.1, n_estimators=1000, max_depth=5, min_child_weight=1, subsample=0.8, colsample_bytree=0.8, reg_alpha=0.1, reg_lambda=0.1)
xgb11 = XGBClassifier(learning_rate=0.1, n_estimators=1000, max_depth=7, min_child_weight=1, subsample=0.8, colsample_bytree=0.8)
xgb12 = XGBClassifier(learning_rate=0.1, n_estimators=1000, max_depth=9, min_child_weight=1, subsample=0.8, colsample_bytree=0.8)
xgb13 = XGBClassifier(learning_rate=0.1, n_estimators=1000, max_depth=5, min_child_weight=5, gamma=0.2, subsample=0.8, colsample_bytree=0.8)
xgb14 = XGBClassifier(learning_rate=0.1, n_estimators=1000, max_depth=5, min_child_weight=1, subsample=0.8, colsample_bytree=0.8, reg_alpha=0.1, reg_lambda=0.1)
xgb15 = XGBClassifier(learning_rate=0.1, n_estimators=1000, max_depth=7, min_child_weight=1, subsample=0.8, colsample_bytree=0.8)
xgb16 = XGBClassifier(learning_rate=0.1, n_estimators=1000, max_depth=9, min_child_weight=1, subsample=0.8, colsample_bytree=0.8)

CLFS = [xgb0, xgb1, xgb2, xgb3, xgb4, xgb5, xgb6, xgb7, xgb8, xgb9, xgb10, xgb11, xgb12, xgb13, xgb14, xgb15, xgb16]

pipeline.classifiers = CLFS.copy()
pipeline.fitted_classifiers = {}

# %% [markdown]
# ___
# # Balance the data

# %%
# Backup
pipeline.backup_feature_matrix = pipeline.feature_matrix.copy()
pipeline.backup_labels = pipeline.labels.copy()

# %%
from imblearn.over_sampling import SMOTE

smote = SMOTE(random_state=42)

pipeline.feature_matrix, pipeline.labels = smote.fit_resample(np.nan_to_num(pipeline.feature_matrix), pipeline.labels)

# %%
print(pipeline.backup_feature_matrix.shape)
print(pipeline.feature_matrix.shape)

print(pipeline.backup_labels.shape)
print(pipeline.labels.shape)
# Out:
# (5082, 519)
# (8139, 519)
# (5082,)
# (8139,)

# %%
pipeline.fitted_classifiers = {}
pipeline.classifiers = CLFS.copy()
pipeline.fit_classifiers()
# Out:
# INFO:utils.ml:Fitting classifiers...
# INFO:utils.ml:Fitting classifier: XGBClassifier0
# INFO:utils.ml:Top 10 features for XGBClassifier0: [('color_moments_rgb_B_iqr', 0.027694887), ('color_moments_lab_L_iqr', 0.017617349), ('color_moments_lab_B_var', 0.010725688), ('fft_radial_variance_53', 0.0070006726), ('lbp_rad1_bins8_4', 0.006842836), ('fft_radial_variance_19', 0.0068394733), ('color_moments_hsv_H_median', 0.006804766), ('color_moments_rgb_B_var', 0.006408653), ('fft_high_freq_energy', 0.0063838223), ('color_moments_lab_B_std', 0.0061635687)]
# INFO:utils.ml:Fitted classifier: XGBClassifier0; Done in 64.39511275291443 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier1
# INFO:utils.ml:Top 10 features for XGBClassifier1: [('color_moments_rgb_B_iqr', 0.029252732), ('color_moments_lab_L_iqr', 0.018102674), ('fft_radial_mean_92', 0.012822518), ('fft_radial_variance_91', 0.012702556), ('color_moments_lab_B_var', 0.010444425), ('fft_radial_variance_28', 0.009813966), ('lbp_rad4_bins32_6', 0.008392285), ('lbp_rad1_bins8_4', 0.008091538), ('color_moments_rgb_B_std', 0.0076210774), ('color_moments_hsv_H_median', 0.007493651)]
# INFO:utils.ml:Fitted classifier: XGBClassifier1; Done in 45.89455485343933 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier2
# INFO:utils.ml:Top 10 features for XGBClassifier2: [('color_moments_rgb_B_iqr', 0.02756393), ('color_moments_lab_L_iqr', 0.015827805), ('fft_radial_variance_91', 0.015456772), ('color_moments_lab_B_var', 0.012041912), ('lbp_rad1_bins8_4', 0.00880348), ('color_moments_hsv_H_median', 0.008406768), ('color_moments_rgb_B_std', 0.0080258725), ('fft_radial_mean_24', 0.0075927945), ('color_moments_lab_B_std', 0.007372356), ('fft_radial_variance_84', 0.007288214)]
# INFO:utils.ml:Fitted classifier: XGBClassifier2; Done in 43.79967284202576 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier3
# INFO:utils.ml:Top 10 features for XGBClassifier3: [('color_moments_rgb_B_iqr', 0.026758086), ('fft_radial_variance_82', 0.019456495), ('color_moments_lab_L_iqr', 0.01747135), ('fft_radial_variance_114', 0.014617277), ('fft_radial_variance_32', 0.014058141), ('color_moments_lab_B_var', 0.011304971), ('fft_radial_mean_126', 0.010535569), ('fft_radial_variance_34', 0.01049932), ('fft_radial_variance_28', 0.009153655), ('lbp_rad1_bins8_4', 0.008662635)]
# INFO:utils.ml:Fitted classifier: XGBClassifier3; Done in 68.06642198562622 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier4
# INFO:utils.ml:Top 10 features for XGBClassifier4: [('color_moments_rgb_B_iqr', 0.026950214), ('fft_radial_variance_82', 0.020974793), ('color_moments_lab_L_iqr', 0.017939746), ('fft_radial_variance_114', 0.015757944), ('fft_radial_variance_32', 0.015155175), ('fft_radial_mean_126', 0.011357717), ('fft_radial_variance_34', 0.01131864), ('color_moments_lab_B_var', 0.01113796), ('fft_radial_variance_28', 0.009867964), ('lbp_rad1_bins8_4', 0.008636259)]
# INFO:utils.ml:Fitted classifier: XGBClassifier4; Done in 80.40131187438965 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier5
# INFO:utils.ml:Top 10 features for XGBClassifier5: [('color_moments_rgb_B_iqr', 0.025522169), ('color_moments_lab_L_iqr', 0.01797122), ('color_moments_lab_B_var', 0.010711074), ('fft_radial_variance_53', 0.008523218), ('lbp_rad1_bins8_4', 0.0069972617), ('color_moments_hsv_H_median', 0.0069457116), ('fft_radial_mean_94', 0.006612889), ('color_moments_rgb_B_std', 0.0065007885), ('color_moments_lab_B_std', 0.006310658), ('fft_radial_variance_19', 0.006069903)]
# INFO:utils.ml:Fitted classifier: XGBClassifier5; Done in 103.86578941345215 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier6
# INFO:utils.ml:Top 10 features for XGBClassifier6: [('color_moments_rgb_B_iqr', 0.030405171), ('color_moments_lab_L_iqr', 0.01696589), ('fft_radial_mean_92', 0.0138123315), ('fft_radial_variance_91', 0.01368311), ('color_moments_lab_B_var', 0.010275356), ('lbp_rad4_bins32_6', 0.008397436), ('color_moments_rgb_B_std', 0.007865889), ('lbp_rad1_bins8_4', 0.0077049257), ('fft_radial_variance_42', 0.007610873), ('color_moments_hsv_H_median', 0.00743456)]
# INFO:utils.ml:Fitted classifier: XGBClassifier6; Done in 54.27316904067993 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier7
# INFO:utils.ml:Top 10 features for XGBClassifier7: [('color_moments_rgb_B_iqr', 0.02646872), ('fft_radial_variance_91', 0.023360439), ('color_moments_lab_L_iqr', 0.015504509), ('color_moments_lab_B_var', 0.011509793), ('fft_radial_variance_84', 0.01101497), ('lbp_rad1_bins8_4', 0.008954266), ('fft_radial_mean_24', 0.008785663), ('color_moments_rgb_B_std', 0.008663012), ('fft_radial_mean_116', 0.008219312), ('color_moments_hsv_H_median', 0.008083145)]
# INFO:utils.ml:Fitted classifier: XGBClassifier7; Done in 82.70642900466919 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier8
# INFO:utils.ml:Top 10 features for XGBClassifier8: [('color_moments_rgb_B_iqr', 0.02526195), ('color_moments_lab_L_iqr', 0.018077947), ('color_moments_lab_B_var', 0.010724377), ('fft_radial_variance_53', 0.0091922935), ('fft_radial_mean_94', 0.007132003), ('color_moments_hsv_H_median', 0.007129994), ('color_moments_rgb_B_std', 0.006847327), ('lbp_rad1_bins8_4', 0.006832147), ('fft_radial_variance_19', 0.006546392), ('color_moments_lab_B_std', 0.006356291)]
# INFO:utils.ml:Fitted classifier: XGBClassifier8; Done in 122.21436858177185 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier9
# INFO:utils.ml:Top 10 features for XGBClassifier9: [('color_moments_rgb_B_iqr', 0.030407693), ('color_moments_lab_L_iqr', 0.017115917), ('fft_radial_mean_92', 0.013934472), ('fft_radial_variance_91', 0.013804106), ('color_moments_lab_B_var', 0.010323943), ('lbp_rad4_bins32_6', 0.008471693), ('color_moments_rgb_B_std', 0.007935446), ('lbp_rad1_bins8_4', 0.0077288817), ('color_moments_hsv_H_median', 0.00740221), ('fft_radial_variance_79', 0.007071854)]
# INFO:utils.ml:Fitted classifier: XGBClassifier9; Done in 63.202964544296265 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier10
# INFO:utils.ml:Top 10 features for XGBClassifier10: [('fft_radial_variance_91', 0.027067628), ('color_moments_rgb_B_iqr', 0.026878715), ('color_moments_lab_L_iqr', 0.01598169), ('fft_radial_variance_84', 0.012762993), ('color_moments_lab_B_var', 0.011502823), ('lbp_rad1_bins8_4', 0.008885902), ('color_moments_rgb_B_std', 0.008793436), ('color_moments_hsv_H_median', 0.008333641), ('fft_radial_mean_133', 0.0082551), ('fft_radial_mean_24', 0.008242947)]
# INFO:utils.ml:Fitted classifier: XGBClassifier10; Done in 113.46659398078918 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier11
# INFO:utils.ml:Top 10 features for XGBClassifier11: [('color_moments_rgb_B_iqr', 0.026742), ('fft_radial_variance_114', 0.019080017), ('fft_radial_variance_32', 0.018350173), ('color_moments_lab_L_iqr', 0.016968684), ('fft_radial_variance_82', 0.012699049), ('color_moments_lab_B_var', 0.010906763), ('fft_radial_variance_28', 0.010622599), ('fft_radial_mean_126', 0.0103189675), ('fft_radial_variance_34', 0.010280626), ('fft_radial_variance_112', 0.009530858)]
# INFO:utils.ml:Fitted classifier: XGBClassifier11; Done in 125.19273114204407 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier12
# INFO:utils.ml:Top 10 features for XGBClassifier12: [('color_moments_rgb_B_iqr', 0.02943276), ('color_moments_lab_L_iqr', 0.018281925), ('fft_radial_variance_114', 0.016892275), ('fft_radial_variance_72', 0.015599513), ('color_moments_lab_B_var', 0.011617476), ('fft_radial_mean_117', 0.010837005), ('fft_radial_mean_50', 0.009801051), ('fft_radial_mean_75', 0.008624695), ('fft_radial_variance_28', 0.0085840905), ('lbp_rad1_bins8_4', 0.008179566)]
# INFO:utils.ml:Fitted classifier: XGBClassifier12; Done in 108.00357580184937 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier13
# INFO:utils.ml:Top 10 features for XGBClassifier13: [('color_moments_rgb_B_iqr', 0.030407693), ('color_moments_lab_L_iqr', 0.017115917), ('fft_radial_mean_92', 0.013934472), ('fft_radial_variance_91', 0.013804106), ('color_moments_lab_B_var', 0.010323943), ('lbp_rad4_bins32_6', 0.008471693), ('color_moments_rgb_B_std', 0.007935446), ('lbp_rad1_bins8_4', 0.0077288817), ('color_moments_hsv_H_median', 0.00740221), ('fft_radial_variance_79', 0.007071854)]
# INFO:utils.ml:Fitted classifier: XGBClassifier13; Done in 30.68656325340271 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier14
# INFO:utils.ml:Top 10 features for XGBClassifier14: [('fft_radial_variance_91', 0.027067628), ('color_moments_rgb_B_iqr', 0.026878715), ('color_moments_lab_L_iqr', 0.01598169), ('fft_radial_variance_84', 0.012762993), ('color_moments_lab_B_var', 0.011502823), ('lbp_rad1_bins8_4', 0.008885902), ('color_moments_rgb_B_std', 0.008793436), ('color_moments_hsv_H_median', 0.008333641), ('fft_radial_mean_133', 0.0082551), ('fft_radial_mean_24', 0.008242947)]
# INFO:utils.ml:Fitted classifier: XGBClassifier14; Done in 42.966071128845215 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier15
# INFO:utils.ml:Top 10 features for XGBClassifier15: [('color_moments_rgb_B_iqr', 0.026742), ('fft_radial_variance_114', 0.019080017), ('fft_radial_variance_32', 0.018350173), ('color_moments_lab_L_iqr', 0.016968684), ('fft_radial_variance_82', 0.012699049), ('color_moments_lab_B_var', 0.010906763), ('fft_radial_variance_28', 0.010622599), ('fft_radial_mean_126', 0.0103189675), ('fft_radial_variance_34', 0.010280626), ('fft_radial_variance_112', 0.009530858)]
# INFO:utils.ml:Fitted classifier: XGBClassifier15; Done in 55.2317841053009 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier16
# INFO:utils.ml:Top 10 features for XGBClassifier16: [('color_moments_rgb_B_iqr', 0.02943276), ('color_moments_lab_L_iqr', 0.018281925), ('fft_radial_variance_114', 0.016892275), ('fft_radial_variance_72', 0.015599513), ('color_moments_lab_B_var', 0.011617476), ('fft_radial_mean_117', 0.010837005), ('fft_radial_mean_50', 0.009801051), ('fft_radial_mean_75', 0.008624695), ('fft_radial_variance_28', 0.0085840905), ('lbp_rad1_bins8_4', 0.008179566)]
# INFO:utils.ml:Fitted classifier: XGBClassifier16; Done in 67.84888219833374 seconds
# INFO:utils.ml:Fitting completed in 1272.22 seconds.

# %%
pipeline.predict_with_classifiers(VAL_PATH, percent)
# Out:
# INFO:utils.ml:Predicting with classifiers on dataset: C:\Users\gimes\Src\repos\CADx-Project\dataset\multiclass\val
# Processed 5/53 batches.
# Processed 10/53 batches.
# Processed 15/53 batches.
# Processed 20/53 batches.
# Processed 25/53 batches.
# Processed 30/53 batches.
# Processed 35/53 batches.
# Processed 40/53 batches.
# Processed 45/53 batches.
# Processed 50/53 batches.
# INFO:utils.ml:Predictions made with classifier: XGBClassifier0
# INFO:utils.ml:Predictions made with classifier: XGBClassifier1
# INFO:utils.ml:Predictions made with classifier: XGBClassifier2
# INFO:utils.ml:Predictions made with classifier: XGBClassifier3
# INFO:utils.ml:Predictions made with classifier: XGBClassifier4
# INFO:utils.ml:Predictions made with classifier: XGBClassifier5
# INFO:utils.ml:Predictions made with classifier: XGBClassifier6
# INFO:utils.ml:Predictions made with classifier: XGBClassifier7
# INFO:utils.ml:Predictions made with classifier: XGBClassifier8
# INFO:utils.ml:Predictions made with classifier: XGBClassifier9
# INFO:utils.ml:Predictions made with classifier: XGBClassifier10
# INFO:utils.ml:Predictions made with classifier: XGBClassifier11
# INFO:utils.ml:Predictions made with classifier: XGBClassifier12
# Processed 53/53 batches.
# INFO:utils.ml:Predictions made with classifier: XGBClassifier13
# INFO:utils.ml:Predictions made with classifier: XGBClassifier14
# INFO:utils.ml:Predictions made with classifier: XGBClassifier15
# INFO:utils.ml:Predictions made with classifier: XGBClassifier16
# {'GT': array([0, 0, 0, ..., 2, 2, 2]),
#  'XGBClassifier0': array([0, 0, 2, ..., 0, 2, 0], dtype=int64),
#  'XGBClassifier1': array([0, 0, 2, ..., 0, 2, 0], dtype=int64),
#  'XGBClassifier2': array([0, 0, 2, ..., 1, 2, 0], dtype=int64),
#  'XGBClassifier3': array([0, 0, 2, ..., 1, 2, 0], dtype=int64),
#  'XGBClassifier4': array([0, 0, 2, ..., 1, 2, 0], dtype=int64),
#  'XGBClassifier5': array([0, 0, 2, ..., 0, 2, 0], dtype=int64),
#  'XGBClassifier6': array([0, 0, 2, ..., 0, 2, 0], dtype=int64),
#  'XGBClassifier7': array([0, 0, 2, ..., 1, 2, 0], dtype=int64),
#  'XGBClassifier8': array([0, 0, 2, ..., 0, 2, 0], dtype=int64),
#  'XGBClassifier9': array([0, 0, 2, ..., 0, 2, 0], dtype=int64),
#  'XGBClassifier10': array([0, 0, 2, ..., 1, 2, 0], dtype=int64),
#  'XGBClassifier11': array([0, 0, 2, ..., 1, 2, 0], dtype=int64),
#  'XGBClassifier12': array([0, 0, 2, ..., 1, 2, 0], dtype=int64),
#  'XGBClassifier13': array([0, 0, 2, ..., 0, 2, 0], dtype=int64),
#  'XGBClassifier14': array([0, 0, 2, ..., 1, 2, 0], dtype=int64),
#  'XGBClassifier15': array([0, 0, 2, ..., 1, 2, 0], dtype=int64),
#  'XGBClassifier16': array([0, 0, 2, ..., 1, 2, 0], dtype=int64)}

# %%
import pandas as pd

smote_classifiers = pipeline.fitted_classifiers.copy()
smote_predictions = pipeline.predictions.copy()

df_smote = pd.DataFrame(data=pipeline.calculate_metrics())
df_smote = df_smote.T
df_smote
# Out:
# INFO:utils.ml:Metrics for classifier GT: {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'kappa': 1.0}
# INFO:utils.ml:Metrics for classifier XGBClassifier0: {'accuracy': 0.8771653543307086, 'precision': 0.7851080132258205, 'recall': 0.7743026332405503, 'f1': 0.7794268266389786, 'kappa': 0.7779640654138574}
# INFO:utils.ml:Metrics for classifier XGBClassifier1: {'accuracy': 0.8740157480314961, 'precision': 0.7836436139111725, 'recall': 0.7752128201502426, 'f1': 0.7792100598423314, 'kappa': 0.7727862312034279}
# INFO:utils.ml:Metrics for classifier XGBClassifier2: {'accuracy': 0.8803149606299212, 'precision': 0.7952996666205242, 'recall': 0.78379973165744, 'f1': 0.7891138002689159, 'kappa': 0.7841256776825494}
# INFO:utils.ml:Metrics for classifier XGBClassifier3: {'accuracy': 0.8842519685039371, 'precision': 0.804822140527382, 'recall': 0.7948882078240785, 'f1': 0.7996358195033691, 'kappa': 0.7910370579307195}
# INFO:utils.ml:Metrics for classifier XGBClassifier4: {'accuracy': 0.8811023622047244, 'precision': 0.7993899732240232, 'recall': 0.7896894803213356, 'f1': 0.7943243682758032, 'kappa': 0.7853509914798549}
# INFO:utils.ml:Metrics for classifier XGBClassifier5: {'accuracy': 0.8779527559055118, 'precision': 0.7906366562400834, 'recall': 0.7780264344896058, 'f1': 0.7839578651510886, 'kappa': 0.7793319761810812}
# INFO:utils.ml:Metrics for classifier XGBClassifier6: {'accuracy': 0.8748031496062992, 'precision': 0.782622491727354, 'recall': 0.7726500050285874, 'f1': 0.7773519188843938, 'kappa': 0.7740132595003291}
# INFO:utils.ml:Metrics for classifier XGBClassifier7: {'accuracy': 0.8874015748031496, 'precision': 0.8078887957920217, 'recall': 0.7912789676247197, 'f1': 0.798954041685301, 'kappa': 0.7963136596920647}
# INFO:utils.ml:Metrics for classifier XGBClassifier8: {'accuracy': 0.8771653543307086, 'precision': 0.7901299286285658, 'recall': 0.7744803351988258, 'f1': 0.7817134528975345, 'kappa': 0.7777069663486137}
# INFO:utils.ml:Metrics for classifier XGBClassifier9: {'accuracy': 0.8755905511811024, 'precision': 0.78479563508881, 'recall': 0.7733193490714254, 'f1': 0.7786750952086635, 'kappa': 0.7753782502205246}
# INFO:utils.ml:Metrics for classifier XGBClassifier10: {'accuracy': 0.8889763779527559, 'precision': 0.8131338016453439, 'recall': 0.7927953576686714, 'f1': 0.8020195031265507, 'kappa': 0.7990208622338348}
# INFO:utils.ml:Metrics for classifier XGBClassifier11: {'accuracy': 0.8834645669291339, 'precision': 0.8085058661145618, 'recall': 0.7916975124498496, 'f1': 0.7994539797927428, 'kappa': 0.7892768415293685}
# INFO:utils.ml:Metrics for classifier XGBClassifier12: {'accuracy': 0.8755905511811024, 'precision': 0.7855322215197044, 'recall': 0.7734970510297009, 'f1': 0.7791481481481481, 'kappa': 0.7751517216031841}
# INFO:utils.ml:Metrics for classifier XGBClassifier13: {'accuracy': 0.8755905511811024, 'precision': 0.78479563508881, 'recall': 0.7733193490714254, 'f1': 0.7786750952086635, 'kappa': 0.7753782502205246}
# INFO:utils.ml:Metrics for classifier XGBClassifier14: {'accuracy': 0.8889763779527559, 'precision': 0.8131338016453439, 'recall': 0.7927953576686714, 'f1': 0.8020195031265507, 'kappa': 0.7990208622338348}
# INFO:utils.ml:Metrics for classifier XGBClassifier15: {'accuracy': 0.8834645669291339, 'precision': 0.8085058661145618, 'recall': 0.7916975124498496, 'f1': 0.7994539797927428, 'kappa': 0.7892768415293685}
# INFO:utils.ml:Metrics for classifier XGBClassifier16: {'accuracy': 0.8755905511811024, 'precision': 0.7855322215197044, 'recall': 0.7734970510297009, 'f1': 0.7791481481481481, 'kappa': 0.7751517216031841}
#                  accuracy  precision    recall        f1     kappa
# GT               1.000000   1.000000  1.000000  1.000000  1.000000
# XGBClassifier0   0.877165   0.785108  0.774303  0.779427  0.777964
# XGBClassifier1   0.874016   0.783644  0.775213  0.779210  0.772786
# XGBClassifier2   0.880315   0.795300  0.783800  0.789114  0.784126
# XGBClassifier3   0.884252   0.804822  0.794888  0.799636  0.791037
# XGBClassifier4   0.881102   0.799390  0.789689  0.794324  0.785351
# XGBClassifier5   0.877953   0.790637  0.778026  0.783958  0.779332
# XGBClassifier6   0.874803   0.782622  0.772650  0.777352  0.774013
# XGBClassifier7   0.887402   0.807889  0.791279  0.798954  0.796314
# XGBClassifier8   0.877165   0.790130  0.774480  0.781713  0.777707
# XGBClassifier9   0.875591   0.784796  0.773319  0.778675  0.775378
# XGBClassifier10  0.888976   0.813134  0.792795  0.802020  0.799021
# XGBClassifier11  0.883465   0.808506  0.791698  0.799454  0.789277
# XGBClassifier12  0.875591   0.785532  0.773497  0.779148  0.775152
# XGBClassifier13  0.875591   0.784796  0.773319  0.778675  0.775378
# XGBClassifier14  0.888976   0.813134  0.792795  0.802020  0.799021
# XGBClassifier15  0.883465   0.808506  0.791698  0.799454  0.789277
# XGBClassifier16  0.875591   0.785532  0.773497  0.779148  0.775152

# %%
# BEST
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=5, max_leaves=None,
#               min_child_weight=1, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=1000, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softprob', ...)

# %%
highest = df_smote[df_smote["kappa"] == df_smote.iloc[1:]["kappa"].max()]
idx = highest.index[0]

confusion_matrix(pipeline.predictions["GT"], pipeline.predictions[idx])
# Out:
# array([[442,  32,  24],
#        [ 37, 631,  10],
#        [ 31,  11,  52]], dtype=int64)

# %% [markdown]
# ___
# # Borderline SMOTE

# %%
from imblearn.over_sampling import BorderlineSMOTE
smote = BorderlineSMOTE(sampling_strategy='auto', random_state=42)

pipeline.feature_matrix, pipeline.labels = smote.fit_resample(pipeline.backup_feature_matrix, pipeline.backup_labels)

print(pipeline.backup_feature_matrix.shape)
print(pipeline.feature_matrix.shape)

print(pipeline.backup_labels.shape)
print(pipeline.labels.shape)
# Out:
# (5082, 519)
# (8139, 519)
# (5082,)
# (8139,)

# %%
pipeline.fitted_classifiers = {}
pipeline.classifiers = CLFS.copy()
pipeline.fit_classifiers()
# Out:
# INFO:utils.ml:Fitting classifiers...
# INFO:utils.ml:Fitting classifier: XGBClassifier0
# INFO:utils.ml:Top 10 features for XGBClassifier0: [('color_moments_rgb_B_iqr', 0.029166298), ('color_moments_lab_L_iqr', 0.015084127), ('fft_radial_mean_121', 0.010826645), ('color_moments_lab_B_var', 0.010617831), ('fft_radial_mean_126', 0.009657436), ('fft_radial_mean_38', 0.008333238), ('fft_radial_variance_83', 0.00769103), ('color_moments_lab_A_iqr', 0.007254932), ('fft_radial_mean_75', 0.0072412686), ('fft_radial_variance_19', 0.0070487214)]
# INFO:utils.ml:Fitted classifier: XGBClassifier0; Done in 63.23371648788452 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier1
# INFO:utils.ml:Top 10 features for XGBClassifier1: [('color_moments_rgb_B_iqr', 0.032402284), ('color_moments_lab_L_iqr', 0.013204501), ('color_moments_lab_B_var', 0.012107884), ('lbp_rad4_bins32_8', 0.011022263), ('color_moments_rgb_B_std', 0.009752075), ('lbp_rad1_bins8_4', 0.008528293), ('color_moments_lab_B_std', 0.0077431262), ('color_moments_rgb_B_var', 0.0072002495), ('color_moments_lab_A_iqr', 0.007176), ('color_moments_lab_L_std', 0.007139207)]
# INFO:utils.ml:Fitted classifier: XGBClassifier1; Done in 47.16432785987854 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier2
# INFO:utils.ml:Top 10 features for XGBClassifier2: [('color_moments_rgb_B_iqr', 0.031923234), ('color_moments_lab_L_iqr', 0.014719035), ('color_moments_lab_B_var', 0.013394059), ('color_moments_rgb_B_std', 0.009659543), ('fft_radial_mean_57', 0.009230607), ('lbp_rad4_bins32_8', 0.0089549925), ('fft_radial_mean_70', 0.008798426), ('lbp_rad1_bins8_4', 0.008720371), ('color_moments_rgb_B_var', 0.008540261), ('color_moments_lab_L_std', 0.008161294)]
# INFO:utils.ml:Fitted classifier: XGBClassifier2; Done in 49.758546113967896 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier3
# INFO:utils.ml:Top 10 features for XGBClassifier3: [('color_moments_rgb_B_iqr', 0.030999385), ('fft_radial_variance_57', 0.018076604), ('color_moments_lab_L_iqr', 0.014886562), ('fft_radial_variance_133', 0.014135001), ('color_moments_lab_B_var', 0.010155191), ('fft_radial_mean_110', 0.009693703), ('fft_radial_mean_105', 0.008832169), ('fft_radial_variance_97', 0.008613771), ('fft_radial_mean_34', 0.007999211), ('lbp_rad1_bins8_4', 0.00797851)]
# INFO:utils.ml:Fitted classifier: XGBClassifier3; Done in 76.46027779579163 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier4
# INFO:utils.ml:Top 10 features for XGBClassifier4: [('color_moments_rgb_B_iqr', 0.031634957), ('fft_radial_variance_57', 0.019723114), ('fft_radial_variance_133', 0.015422489), ('color_moments_lab_L_iqr', 0.014932277), ('fft_radial_mean_110', 0.010576653), ('color_moments_lab_B_var', 0.009916037), ('fft_radial_mean_105', 0.009636647), ('fft_radial_variance_97', 0.009398356), ('lbp_rad1_bins8_4', 0.007937125), ('color_moments_lab_A_iqr', 0.0073524737)]
# INFO:utils.ml:Fitted classifier: XGBClassifier4; Done in 87.34648251533508 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier5
# INFO:utils.ml:Top 10 features for XGBClassifier5: [('color_moments_rgb_B_iqr', 0.029954664), ('color_moments_lab_L_iqr', 0.014936512), ('color_moments_lab_B_var', 0.0105343), ('fft_radial_mean_126', 0.009867952), ('fft_radial_variance_83', 0.009418111), ('fft_radial_mean_38', 0.008753343), ('fft_radial_variance_43', 0.00805391), ('fft_radial_variance_19', 0.007774541), ('color_moments_rgb_B_std', 0.0077039776), ('color_moments_lab_A_iqr', 0.00760187)]
# INFO:utils.ml:Fitted classifier: XGBClassifier5; Done in 110.38316321372986 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier6
# INFO:utils.ml:Top 10 features for XGBClassifier6: [('color_moments_rgb_B_iqr', 0.0334038), ('color_moments_lab_L_iqr', 0.013521654), ('color_moments_lab_B_var', 0.012223191), ('color_moments_rgb_B_std', 0.0098379105), ('lbp_rad4_bins32_8', 0.009622442), ('lbp_rad1_bins8_4', 0.008406389), ('color_moments_lab_B_std', 0.007594047), ('fft_radial_mean_79', 0.0072925873), ('color_moments_rgb_B_var', 0.007177001), ('color_moments_lab_L_std', 0.0071343295)]
# INFO:utils.ml:Fitted classifier: XGBClassifier6; Done in 61.74359059333801 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier7
# INFO:utils.ml:Top 10 features for XGBClassifier7: [('color_moments_rgb_B_iqr', 0.03364819), ('color_moments_lab_L_iqr', 0.014708812), ('color_moments_lab_B_var', 0.012119868), ('color_moments_rgb_B_std', 0.010505255), ('lbp_rad4_bins32_8', 0.009418675), ('fft_radial_mean_70', 0.00898773), ('fft_radial_variance_90', 0.008932492), ('color_moments_lab_L_std', 0.008683197), ('fft_radial_variance_65', 0.008416488), ('lbp_rad1_bins8_4', 0.008260672)]
# INFO:utils.ml:Fitted classifier: XGBClassifier7; Done in 96.05713772773743 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier8
# INFO:utils.ml:Top 10 features for XGBClassifier8: [('color_moments_rgb_B_iqr', 0.029874252), ('color_moments_lab_L_iqr', 0.014746654), ('color_moments_lab_B_var', 0.010666323), ('fft_radial_mean_126', 0.009249283), ('fft_radial_variance_19', 0.008497453), ('color_moments_rgb_B_std', 0.008136955), ('color_moments_lab_A_iqr', 0.0076929433), ('color_moments_rgb_G_entropy', 0.007381343), ('color_moments_lab_B_std', 0.007048312), ('lbp_rad1_bins8_4', 0.006900676)]
# INFO:utils.ml:Fitted classifier: XGBClassifier8; Done in 135.12462162971497 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier9
# INFO:utils.ml:Top 10 features for XGBClassifier9: [('color_moments_rgb_B_iqr', 0.03357423), ('color_moments_lab_L_iqr', 0.013590643), ('color_moments_lab_B_var', 0.0120760845), ('color_moments_rgb_B_std', 0.009888105), ('lbp_rad4_bins32_8', 0.009671537), ('lbp_rad1_bins8_4', 0.008401224), ('color_moments_lab_B_std', 0.007539205), ('fft_radial_mean_79', 0.007329795), ('color_moments_rgb_B_var', 0.007213619), ('color_moments_lab_L_std', 0.00717073)]
# INFO:utils.ml:Fitted classifier: XGBClassifier9; Done in 54.848698139190674 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier10
# INFO:utils.ml:Top 10 features for XGBClassifier10: [('color_moments_rgb_B_iqr', 0.034470625), ('color_moments_lab_L_iqr', 0.013597988), ('color_moments_lab_B_var', 0.012039227), ('color_moments_rgb_B_std', 0.010793202), ('fft_radial_mean_70', 0.010534553), ('fft_radial_variance_90', 0.010469808), ('fft_radial_variance_65', 0.009864997), ('lbp_rad4_bins32_8', 0.009201978), ('color_moments_lab_L_std', 0.008782499), ('lbp_rad1_bins8_4', 0.008451394)]
# INFO:utils.ml:Fitted classifier: XGBClassifier10; Done in 60.395002603530884 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier11
# INFO:utils.ml:Top 10 features for XGBClassifier11: [('color_moments_rgb_B_iqr', 0.03299492), ('fft_radial_variance_57', 0.019538354), ('color_moments_lab_L_iqr', 0.014942944), ('fft_radial_mean_110', 0.013093514), ('color_moments_lab_B_var', 0.009747068), ('fft_radial_variance_133', 0.009559399), ('fft_radial_mean_105', 0.009546851), ('lbp_rad1_bins8_4', 0.008020168), ('color_moments_rgb_B_std', 0.007938724), ('color_moments_lab_A_iqr', 0.0074799354)]
# INFO:utils.ml:Fitted classifier: XGBClassifier11; Done in 51.28921461105347 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier12
# INFO:utils.ml:Top 10 features for XGBClassifier12: [('color_moments_rgb_B_iqr', 0.033389226), ('fft_radial_variance_133', 0.018813804), ('fft_radial_variance_57', 0.015676731), ('color_moments_lab_L_iqr', 0.012843528), ('fft_radial_variance_76', 0.0092602065), ('color_moments_lab_B_var', 0.009066114), ('fft_radial_variance_72', 0.00900378), ('fft_radial_variance_46', 0.008631263), ('fft_radial_mean_96', 0.0074005057), ('color_moments_lab_A_iqr', 0.007329729)]
# INFO:utils.ml:Fitted classifier: XGBClassifier12; Done in 55.92332220077515 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier13
# INFO:utils.ml:Top 10 features for XGBClassifier13: [('color_moments_rgb_B_iqr', 0.03357423), ('color_moments_lab_L_iqr', 0.013590643), ('color_moments_lab_B_var', 0.0120760845), ('color_moments_rgb_B_std', 0.009888105), ('lbp_rad4_bins32_8', 0.009671537), ('lbp_rad1_bins8_4', 0.008401224), ('color_moments_lab_B_std', 0.007539205), ('fft_radial_mean_79', 0.007329795), ('color_moments_rgb_B_var', 0.007213619), ('color_moments_lab_L_std', 0.00717073)]
# INFO:utils.ml:Fitted classifier: XGBClassifier13; Done in 22.87097454071045 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier14
# INFO:utils.ml:Top 10 features for XGBClassifier14: [('color_moments_rgb_B_iqr', 0.034470625), ('color_moments_lab_L_iqr', 0.013597988), ('color_moments_lab_B_var', 0.012039227), ('color_moments_rgb_B_std', 0.010793202), ('fft_radial_mean_70', 0.010534553), ('fft_radial_variance_90', 0.010469808), ('fft_radial_variance_65', 0.009864997), ('lbp_rad4_bins32_8', 0.009201978), ('color_moments_lab_L_std', 0.008782499), ('lbp_rad1_bins8_4', 0.008451394)]
# INFO:utils.ml:Fitted classifier: XGBClassifier14; Done in 40.849536180496216 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier15
# INFO:utils.ml:Top 10 features for XGBClassifier15: [('color_moments_rgb_B_iqr', 0.03299492), ('fft_radial_variance_57', 0.019538354), ('color_moments_lab_L_iqr', 0.014942944), ('fft_radial_mean_110', 0.013093514), ('color_moments_lab_B_var', 0.009747068), ('fft_radial_variance_133', 0.009559399), ('fft_radial_mean_105', 0.009546851), ('lbp_rad1_bins8_4', 0.008020168), ('color_moments_rgb_B_std', 0.007938724), ('color_moments_lab_A_iqr', 0.0074799354)]
# INFO:utils.ml:Fitted classifier: XGBClassifier15; Done in 50.60902285575867 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier16
# INFO:utils.ml:Top 10 features for XGBClassifier16: [('color_moments_rgb_B_iqr', 0.033389226), ('fft_radial_variance_133', 0.018813804), ('fft_radial_variance_57', 0.015676731), ('color_moments_lab_L_iqr', 0.012843528), ('fft_radial_variance_76', 0.0092602065), ('color_moments_lab_B_var', 0.009066114), ('fft_radial_variance_72', 0.00900378), ('fft_radial_variance_46', 0.008631263), ('fft_radial_mean_96', 0.0074005057), ('color_moments_lab_A_iqr', 0.007329729)]
# INFO:utils.ml:Fitted classifier: XGBClassifier16; Done in 55.56303000450134 seconds
# INFO:utils.ml:Fitting completed in 1119.63 seconds.

# %%
pipeline.predict_with_classifiers(VAL_PATH, percent)
# Out:
# INFO:utils.ml:Predicting with classifiers on dataset: C:\Users\gimes\Src\repos\CADx-Project\dataset\multiclass\val
# Processed 5/53 batches.
# Processed 10/53 batches.
# Processed 15/53 batches.
# Processed 20/53 batches.
# Processed 25/53 batches.
# Processed 30/53 batches.
# Processed 35/53 batches.
# Processed 40/53 batches.
# Processed 45/53 batches.
# Processed 50/53 batches.
# INFO:utils.ml:Predictions made with classifier: XGBClassifier0
# INFO:utils.ml:Predictions made with classifier: XGBClassifier1
# INFO:utils.ml:Predictions made with classifier: XGBClassifier2
# INFO:utils.ml:Predictions made with classifier: XGBClassifier3
# INFO:utils.ml:Predictions made with classifier: XGBClassifier4
# INFO:utils.ml:Predictions made with classifier: XGBClassifier5
# INFO:utils.ml:Predictions made with classifier: XGBClassifier6
# INFO:utils.ml:Predictions made with classifier: XGBClassifier7
# INFO:utils.ml:Predictions made with classifier: XGBClassifier8
# INFO:utils.ml:Predictions made with classifier: XGBClassifier9
# INFO:utils.ml:Predictions made with classifier: XGBClassifier10
# INFO:utils.ml:Predictions made with classifier: XGBClassifier11
# INFO:utils.ml:Predictions made with classifier: XGBClassifier12
# INFO:utils.ml:Predictions made with classifier: XGBClassifier13
# INFO:utils.ml:Predictions made with classifier: XGBClassifier14
# Processed 53/53 batches.
# INFO:utils.ml:Predictions made with classifier: XGBClassifier15
# INFO:utils.ml:Predictions made with classifier: XGBClassifier16
# {'GT': array([0, 0, 0, ..., 2, 2, 2]),
#  'XGBClassifier0': array([0, 0, 0, ..., 1, 2, 0], dtype=int64),
#  'XGBClassifier1': array([0, 0, 0, ..., 0, 2, 0], dtype=int64),
#  'XGBClassifier2': array([0, 0, 2, ..., 0, 2, 0], dtype=int64),
#  'XGBClassifier3': array([0, 0, 2, ..., 0, 2, 0], dtype=int64),
#  'XGBClassifier4': array([0, 0, 2, ..., 0, 2, 0], dtype=int64),
#  'XGBClassifier5': array([0, 0, 0, ..., 1, 2, 0], dtype=int64),
#  'XGBClassifier6': array([0, 0, 0, ..., 1, 2, 0], dtype=int64),
#  'XGBClassifier7': array([0, 0, 0, ..., 0, 2, 0], dtype=int64),
#  'XGBClassifier8': array([0, 0, 0, ..., 1, 2, 0], dtype=int64),
#  'XGBClassifier9': array([0, 0, 0, ..., 1, 2, 0], dtype=int64),
#  'XGBClassifier10': array([0, 0, 0, ..., 0, 2, 0], dtype=int64),
#  'XGBClassifier11': array([0, 0, 0, ..., 0, 2, 0], dtype=int64),
#  'XGBClassifier12': array([0, 0, 0, ..., 0, 2, 0], dtype=int64),
#  'XGBClassifier13': array([0, 0, 0, ..., 1, 2, 0], dtype=int64),
#  'XGBClassifier14': array([0, 0, 0, ..., 0, 2, 0], dtype=int64),
#  'XGBClassifier15': array([0, 0, 0, ..., 0, 2, 0], dtype=int64),
#  'XGBClassifier16': array([0, 0, 0, ..., 0, 2, 0], dtype=int64)}

# %%
borderline_smote_classifiers = pipeline.fitted_classifiers.copy()
borderline_smote_predictions = pipeline.predictions.copy()

df_borderline_smote = pd.DataFrame(data=pipeline.calculate_metrics(
    ["accuracy", "precision", "recall", "f1", "kappa"],))
df_borderline_smote = df_borderline_smote.T
df_borderline_smote
# Out:
# INFO:utils.ml:Metrics for classifier GT: {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'kappa': 1.0}
# INFO:utils.ml:Metrics for classifier XGBClassifier0: {'accuracy': 0.8811023622047244, 'precision': 0.8092041929515471, 'recall': 0.795798394733771, 'f1': 0.8020747023390632, 'kappa': 0.7853298467297419}
# INFO:utils.ml:Metrics for classifier XGBClassifier1: {'accuracy': 0.8700787401574803, 'precision': 0.7829068418859334, 'recall': 0.7695224505629371, 'f1': 0.7757337884218414, 'kappa': 0.7652258671685936}
# INFO:utils.ml:Metrics for classifier XGBClassifier2: {'accuracy': 0.8771653543307086, 'precision': 0.7908593371987128, 'recall': 0.7841768126923058, 'f1': 0.7873272694679564, 'kappa': 0.7787891239102472}
# INFO:utils.ml:Metrics for classifier XGBClassifier3: {'accuracy': 0.8748031496062992, 'precision': 0.7918684807256237, 'recall': 0.7755267602765294, 'f1': 0.7830929578026526, 'kappa': 0.773340547044773}
# INFO:utils.ml:Metrics for classifier XGBClassifier4: {'accuracy': 0.8763779527559055, 'precision': 0.7946493397169464, 'recall': 0.7795645016518721, 'f1': 0.7866121247221066, 'kappa': 0.7762478678516923}
# INFO:utils.ml:Metrics for classifier XGBClassifier5: {'accuracy': 0.8834645669291339, 'precision': 0.8150072652335095, 'recall': 0.7978064268622851, 'f1': 0.8057127191278188, 'kappa': 0.7894467993583482}
# INFO:utils.ml:Metrics for classifier XGBClassifier6: {'accuracy': 0.8732283464566929, 'precision': 0.7889924055141293, 'recall': 0.7716667208594625, 'f1': 0.7795995368176377, 'kappa': 0.7705245153933865}
# INFO:utils.ml:Metrics for classifier XGBClassifier7: {'accuracy': 0.8826771653543307, 'precision': 0.7966131106710491, 'recall': 0.788329115117345, 'f1': 0.792207140221049, 'kappa': 0.7886199023248125}
# INFO:utils.ml:Metrics for classifier XGBClassifier8: {'accuracy': 0.8803149606299212, 'precision': 0.8087726699169216, 'recall': 0.795129050690933, 'f1': 0.8015334030115772, 'kappa': 0.7838210722940678}
# INFO:utils.ml:Metrics for classifier XGBClassifier9: {'accuracy': 0.8724409448818897, 'precision': 0.7864992272624901, 'recall': 0.7708196748583488, 'f1': 0.778067833710065, 'kappa': 0.7691572342850987}
# INFO:utils.ml:Metrics for classifier XGBClassifier10: {'accuracy': 0.8858267716535433, 'precision': 0.8025065366242649, 'recall': 0.7904733854138705, 'f1': 0.7960646191415423, 'kappa': 0.7939843197622904}
# INFO:utils.ml:Metrics for classifier XGBClassifier11: {'accuracy': 0.8795275590551181, 'precision': 0.800646122569247, 'recall': 0.7824195797814997, 'f1': 0.7907735092917898, 'kappa': 0.781927023945268}
# INFO:utils.ml:Metrics for classifier XGBClassifier12: {'accuracy': 0.8716535433070867, 'precision': 0.7917459560820408, 'recall': 0.7706834366903377, 'f1': 0.7801565328204694, 'kappa': 0.7674630205431442}
# INFO:utils.ml:Metrics for classifier XGBClassifier13: {'accuracy': 0.8724409448818897, 'precision': 0.7864992272624901, 'recall': 0.7708196748583488, 'f1': 0.778067833710065, 'kappa': 0.7691572342850987}
# INFO:utils.ml:Metrics for classifier XGBClassifier14: {'accuracy': 0.8858267716535433, 'precision': 0.8025065366242649, 'recall': 0.7904733854138705, 'f1': 0.7960646191415423, 'kappa': 0.7939843197622904}
# INFO:utils.ml:Metrics for classifier XGBClassifier15: {'accuracy': 0.8795275590551181, 'precision': 0.800646122569247, 'recall': 0.7824195797814997, 'f1': 0.7907735092917898, 'kappa': 0.781927023945268}
# INFO:utils.ml:Metrics for classifier XGBClassifier16: {'accuracy': 0.8716535433070867, 'precision': 0.7917459560820408, 'recall': 0.7706834366903377, 'f1': 0.7801565328204694, 'kappa': 0.7674630205431442}
#                  accuracy  precision    recall        f1     kappa
# GT               1.000000   1.000000  1.000000  1.000000  1.000000
# XGBClassifier0   0.881102   0.809204  0.795798  0.802075  0.785330
# XGBClassifier1   0.870079   0.782907  0.769522  0.775734  0.765226
# XGBClassifier2   0.877165   0.790859  0.784177  0.787327  0.778789
# XGBClassifier3   0.874803   0.791868  0.775527  0.783093  0.773341
# XGBClassifier4   0.876378   0.794649  0.779565  0.786612  0.776248
# XGBClassifier5   0.883465   0.815007  0.797806  0.805713  0.789447
# XGBClassifier6   0.873228   0.788992  0.771667  0.779600  0.770525
# XGBClassifier7   0.882677   0.796613  0.788329  0.792207  0.788620
# XGBClassifier8   0.880315   0.808773  0.795129  0.801533  0.783821
# XGBClassifier9   0.872441   0.786499  0.770820  0.778068  0.769157
# XGBClassifier10  0.885827   0.802507  0.790473  0.796065  0.793984
# XGBClassifier11  0.879528   0.800646  0.782420  0.790774  0.781927
# XGBClassifier12  0.871654   0.791746  0.770683  0.780157  0.767463
# XGBClassifier13  0.872441   0.786499  0.770820  0.778068  0.769157
# XGBClassifier14  0.885827   0.802507  0.790473  0.796065  0.793984
# XGBClassifier15  0.879528   0.800646  0.782420  0.790774  0.781927
# XGBClassifier16  0.871654   0.791746  0.770683  0.780157  0.767463

# %%
highest = df_borderline_smote[df_borderline_smote["kappa"] == df_borderline_smote.iloc[1:]["kappa"].max()]
idx = highest.index[0]

confusion_matrix(pipeline.predictions["GT"], pipeline.predictions[idx])
# Out:
# array([[442,  32,  24],
#        [ 37, 631,  10],
#        [ 31,  11,  52]], dtype=int64)

# %% [markdown]
# ___
# # TEST SET

# %%
test_loader = FactoryLoader(TEST_PATH, pipeline.batch_size, factory, shuffle=False)

# test_loader.show_images(100)

test_feature_matrix, _ = pipeline.feature_strategy.run(test_loader.get_loader())
# Out:
# Processed 5/89 batches.
# Processed 10/89 batches.
# Processed 15/89 batches.
# Processed 20/89 batches.
# Processed 25/89 batches.
# Processed 30/89 batches.
# Processed 35/89 batches.
# Processed 40/89 batches.
# Processed 45/89 batches.
# Processed 50/89 batches.
# Processed 55/89 batches.
# Processed 60/89 batches.
# Processed 65/89 batches.
# Processed 70/89 batches.
# Processed 75/89 batches.
# Processed 80/89 batches.
# Processed 85/89 batches.
# Processed 89/89 batches.

# %%
test_predictions = smote_classifiers["XGBClassifier14"].predict(test_feature_matrix)
test_predictions.shape

np.histogram(test_predictions, bins=3)
# Out:
# (array([ 886, 1110,  125], dtype=int64),
#  array([0.        , 0.66666667, 1.33333333, 2.        ]))
