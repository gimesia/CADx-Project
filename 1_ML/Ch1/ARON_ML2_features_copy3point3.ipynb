# %%
from utils.loader import FactoryLoader
from utils.ml import MLPipeline
from utils.preprocessing import PreprocessingFactory
from utils.feature_extraction import *
from utils.utils import *

VAL_PATH = r"C:\Users\gimes\Src\repos\CADx-Project\dataset\binary\val"
TRAIN_PATH = r"C:\Users\gimes\Src\repos\CADx-Project\dataset\binary\train"

# %%
percent = 100
random = False
batch_size = 48

# Initialize the FactoryLoader
factory = PreprocessingFactory()
factory.gaussian_smoothing(5)
factory.clahe(clip_limit=1.5)
factory.pad2square(fill=np.nan)
factory.resize((150,150))
factory.hair_removal()
factory.normalize2float()

factory_loader = FactoryLoader(path=VAL_PATH, batch_size=batch_size, factory=factory, percentage=percent, shuffle=random)

# Create the feature extraction pipeline strategy and add desired features
strategy = FeatureExtractionStrategy()

strategy.add_extractor(GradientExtractor())   # Add variance feature

# strategy.add_extractor(MeanExtractor())  # Add mean feature
# strategy.add_extractor(StdExtractor())   # Add standard deviation feature
strategy.add_extractor(VarExtractor(threshold=0.01))   # Add variance feature
strategy.add_extractor(ColorMomentsExtractor(threshold=0.01))   # Add color moments feature


# strategy.add_extractor(MeanExtractor("lab"))  # Add mean feature
# strategy.add_extractor(StdExtractor("lab"))   # Add standard deviation feature
strategy.add_extractor(VarExtractor("lab", threshold=0.01))   # Add variance feature
strategy.add_extractor(ColorMomentsExtractor("lab", threshold=0.01))   # Add color moments feature

# strategy.add_extractor(MeanExtractor("hsv"))  # Add mean feature
# strategy.add_extractor(StdExtractor("hsv"))   # Add standard deviation feature
strategy.add_extractor(VarExtractor("hsv", threshold=0.01))   # Add variance feature
strategy.add_extractor(ColorMomentsExtractor("hsv", threshold=0.01))   # Add color moments feature

strategy.add_extractor(LBPExtractor(radius=1, n_points=16))
strategy.add_extractor(LBPExtractor(radius=2, n_points=16))
strategy.add_extractor(LBPExtractor(radius=3, n_points=16))
strategy.add_extractor(LBPExtractor(radius=1, n_points=32))
strategy.add_extractor(LBPExtractor(radius=2, n_points=32))
strategy.add_extractor(LBPExtractor(radius=3, n_points=32))
strategy.add_extractor(LBPExtractor(radius=1, n_points=64))
strategy.add_extractor(LBPExtractor(radius=2, n_points=64))
strategy.add_extractor(LBPExtractor(radius=3, n_points=64))

strategy.add_extractor(GLCMExtractor(properties=['contrast', 'dissimilarity', 'homogeneity', 'energy', 'correlation',]))

pipeline = MLPipeline(dataset_path=TRAIN_PATH, preprocessing_factory=factory, feature_strategy=strategy, classifiers=[], percentage=percent, verbose=True, shuffle=random, batch_size=batch_size)
# Out:
# INFO:utils.ml:MLPipeline initialized with dataset path: C:\Users\gimes\Src\repos\CADx-Project\dataset\binary\train
# INFO:utils.ml:Preprocessing steps

# %%
pipeline.run_feature_extraction()
# Out:
# INFO:utils.ml:Running feature extraction...
# Processed 5/317 batches.
# Processed 10/317 batches.
# Processed 15/317 batches.
# Processed 20/317 batches.
# Processed 25/317 batches.
# Processed 30/317 batches.
# Processed 35/317 batches.
# Processed 40/317 batches.
# Processed 45/317 batches.
# Processed 50/317 batches.
# Processed 55/317 batches.
# Processed 60/317 batches.
# Processed 65/317 batches.
# Processed 70/317 batches.
# Processed 75/317 batches.
# Processed 80/317 batches.
# Processed 85/317 batches.
# Processed 90/317 batches.
# Processed 95/317 batches.
# Processed 100/317 batches.
# Processed 105/317 batches.
# Processed 110/317 batches.
# Processed 115/317 batches.
# Processed 120/317 batches.
# Processed 125/317 batches.
# Processed 130/317 batches.
# Processed 135/317 batches.
# Processed 140/317 batches.
# Processed 145/317 batches.
# Processed 150/317 batches.
# Processed 155/317 batches.
# Processed 160/317 batches.
# Processed 165/317 batches.
# Processed 170/317 batches.
# Processed 175/317 batches.
# Processed 180/317 batches.
# Processed 185/317 batches.
# Processed 190/317 batches.
# Processed 195/317 batches.
# Processed 200/317 batches.
# Processed 205/317 batches.
# Processed 210/317 batches.
# Processed 215/317 batches.
# Processed 220/317 batches.
# Processed 225/317 batches.
# Processed 230/317 batches.
# Processed 235/317 batches.
# Processed 240/317 batches.
# Processed 245/317 batches.
# Processed 250/317 batches.
# Processed 255/317 batches.
# Processed 260/317 batches.
# Processed 265/317 batches.
# Processed 270/317 batches.
# Processed 275/317 batches.
# Processed 280/317 batches.
# Processed 285/317 batches.
# Processed 290/317 batches.
# Processed 295/317 batches.
# Processed 300/317 batches.
# Processed 305/317 batches.
# Processed 310/317 batches.
# Processed 315/317 batches.
# INFO:utils.ml:Feature extraction completed. Extracted 15195 features.
# Processed 317/317 batches.

# %%
from xgboost import XGBClassifier
from sklearn.ensemble import RandomForestClassifier

rf1 = RandomForestClassifier(n_estimators=100)
rf2 = RandomForestClassifier(n_estimators=150)
rf3 = RandomForestClassifier(n_estimators=250)

# Random Forest with Class Weight Balancing
rf4 = RandomForestClassifier(n_estimators=100, class_weight="balanced", random_state=42)
# Random Forest with Feature Selection via max_features
rf5 = RandomForestClassifier(n_estimators=100, max_features='sqrt', random_state=42)
# Random Forest with Min Samples per Leaf
rf6 = RandomForestClassifier(n_estimators=100, min_samples_leaf=5, random_state=42)
# Random Forest with Out-of-Bag Error (OOB)
rf7 = RandomForestClassifier(n_estimators=100, oob_score=True, random_state=42)
# Random Forest with Bootstrap Disabled
rf8 = RandomForestClassifier(n_estimators=100, bootstrap=False, random_state=42)
# Random Forest with High Number of Trees and Limited Depth
rf9 = RandomForestClassifier(n_estimators=100, max_depth=5, random_state=42)

xgb1 = XGBClassifier(n_estimators=350)
xgb2 = XGBClassifier(n_estimators=450)
xgb3 = XGBClassifier(n_estimators=550)
xgb4 = XGBClassifier(learning_rate=0.05, n_estimators=400, max_depth=3, min_child_weight=1, subsample=0.8, colsample_bytree=0.8)
xgb5 = XGBClassifier(learning_rate=0.1, n_estimators=400, max_depth=7, min_child_weight=3, subsample=0.7, colsample_bytree=0.7)
xgb6 = XGBClassifier(learning_rate=0.1, n_estimators=400, max_depth=5, min_child_weight=5, gamma=0.2, subsample=0.8, colsample_bytree=0.8)
xgb7 = XGBClassifier(learning_rate=0.1, n_estimators=400, max_depth=5, min_child_weight=1, subsample=0.8, colsample_bytree=0.8, reg_alpha=0.1, reg_lambda=0.1)
xgb8 = XGBClassifier(learning_rate=0.05, n_estimators=500, max_depth=7, min_child_weight=1, subsample=0.8, colsample_bytree=0.8)
xgb9 = XGBClassifier(learning_rate=0.05, n_estimators=400, max_depth=7, min_child_weight=1, subsample=0.8, colsample_bytree=0.8)
xgb10 = XGBClassifier(learning_rate=0.1, n_estimators=400, max_depth=7, min_child_weight=1, subsample=0.8, colsample_bytree=0.8)
xgb11 = XGBClassifier(learning_rate=0.1, n_estimators=500, max_depth=7, min_child_weight=1, subsample=0.8, colsample_bytree=0.8)


pipeline.classifiers = [rf1, rf2, rf3, rf4, rf5, rf6, rf7, rf8, rf9,
                        # svm1, svm2, svm3, svm6, svm7, svm8,
                        xgb1, xgb2, xgb3, xgb4, xgb5, xgb6, xgb7, xgb8, xgb9, xgb10, xgb11]
pipeline.fitted_classifiers = {}

# %%
pipeline.fit_classifiers()
# Out:
# INFO:utils.ml:Fitting classifiers...
# INFO:utils.ml:Fitting classifier: RandomForestClassifier0
# INFO:utils.ml:Top 10 features for RandomForestClassifier0: [('lbp_rad1_bins32_10', 0.025958034422447464), ('lbp_rad1_bins64_10', 0.024542230580040566), ('color_moments_lab_channel_2_std', 0.022459768313233038), ('lbp_rad2_bins64_10', 0.01992772343644558), ('lbp_rad1_bins16_10', 0.018259649891025825), ('lbp_rad2_bins32_2', 0.011201865049065271), ('lbp_rad1_bins64_63', 0.010217743405219604), ('gradient_magnitude_mean', 0.009359238230689832), ('lbp_rad1_bins64_40', 0.009277590026524434), ('color_moments_hsv_channel_0_std', 0.009153976810407626)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier0; Done in 17.727558612823486 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier1
# INFO:utils.ml:Top 10 features for RandomForestClassifier1: [('lbp_rad1_bins16_10', 0.023952119622661135), ('color_moments_lab_channel_2_std', 0.023046817411005394), ('lbp_rad1_bins64_10', 0.022479556673835815), ('lbp_rad1_bins32_10', 0.021228482019391797), ('lbp_rad1_bins64_63', 0.013678411017078377), ('lbp_rad2_bins64_10', 0.011941874487033844), ('lbp_rad2_bins32_10', 0.010304330230653191), ('lbp_rad2_bins32_2', 0.010088821267337319), ('lbp_rad1_bins64_41', 0.009928878782305825), ('color_moments_hsv_channel_0_std', 0.009371536756809608)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier1; Done in 26.6156485080719 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier2
# INFO:utils.ml:Top 10 features for RandomForestClassifier2: [('lbp_rad1_bins32_10', 0.024077373999258935), ('lbp_rad1_bins16_10', 0.0202465962227464), ('color_moments_lab_channel_2_std', 0.02019289998201983), ('lbp_rad1_bins64_10', 0.019938923192630364), ('lbp_rad1_bins64_41', 0.013959704899326214), ('lbp_rad2_bins16_4', 0.012697514934849788), ('lbp_rad2_bins64_10', 0.011652138579039501), ('gradient_magnitude_mean', 0.01158906462863039), ('lbp_rad2_bins32_10', 0.01096093173917618), ('color_moments_rgb_channel_0_mean', 0.010473441646038676)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier2; Done in 44.57444787025452 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier3
# INFO:utils.ml:Top 10 features for RandomForestClassifier3: [('lbp_rad1_bins64_10', 0.02329042198203945), ('lbp_rad1_bins32_10', 0.02265964158142113), ('lbp_rad1_bins16_10', 0.020434071823666237), ('color_moments_lab_channel_2_std', 0.019270603901527128), ('lbp_rad2_bins64_10', 0.012308430070857055), ('lbp_rad1_bins64_41', 0.01226639571159652), ('lbp_rad1_bins64_63', 0.011470304863059179), ('gradient_magnitude_mean', 0.011321810038925939), ('lbp_rad2_bins16_4', 0.01039725692187197), ('lbp_rad1_bins64_40', 0.010166933204130119)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier3; Done in 18.02952551841736 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier4
# INFO:utils.ml:Top 10 features for RandomForestClassifier4: [('lbp_rad1_bins32_10', 0.023308696332481227), ('lbp_rad1_bins64_10', 0.023057483207927585), ('lbp_rad1_bins16_10', 0.02089697684088914), ('color_moments_lab_channel_2_std', 0.016073560805385374), ('lbp_rad1_bins64_41', 0.012961669523956554), ('lbp_rad1_bins64_63', 0.01128729600852764), ('lbp_rad2_bins64_10', 0.011149578612025328), ('color_moments_rgb_channel_0_mean', 0.01087822101137026), ('lbp_rad1_bins64_40', 0.010574971597858354), ('gradient_magnitude_mean', 0.010139212710297638)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier4; Done in 17.786221027374268 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier5
# INFO:utils.ml:Top 10 features for RandomForestClassifier5: [('lbp_rad1_bins64_10', 0.03210493042065674), ('lbp_rad1_bins32_10', 0.02833313974726265), ('color_moments_lab_channel_2_std', 0.02320405650701505), ('lbp_rad1_bins16_10', 0.02280173340963775), ('lbp_rad2_bins64_10', 0.015391352396656904), ('lbp_rad1_bins64_63', 0.014340125867137132), ('lbp_rad1_bins64_41', 0.014280048975882276), ('color_moments_rgb_channel_0_mean', 0.013007189944426062), ('gradient_magnitude_mean', 0.012908108526540592), ('lbp_rad1_bins64_40', 0.011728143663462792)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier5; Done in 14.684466361999512 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier6
# INFO:utils.ml:Top 10 features for RandomForestClassifier6: [('lbp_rad1_bins32_10', 0.023308696332481227), ('lbp_rad1_bins64_10', 0.023057483207927585), ('lbp_rad1_bins16_10', 0.02089697684088914), ('color_moments_lab_channel_2_std', 0.016073560805385374), ('lbp_rad1_bins64_41', 0.012961669523956554), ('lbp_rad1_bins64_63', 0.01128729600852764), ('lbp_rad2_bins64_10', 0.011149578612025328), ('color_moments_rgb_channel_0_mean', 0.01087822101137026), ('lbp_rad1_bins64_40', 0.010574971597858354), ('gradient_magnitude_mean', 0.010139212710297638)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier6; Done in 18.11970806121826 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier7
# INFO:utils.ml:Top 10 features for RandomForestClassifier7: [('lbp_rad1_bins64_10', 0.02480385999270894), ('lbp_rad1_bins32_10', 0.023702762937032343), ('lbp_rad1_bins16_10', 0.018504336594906003), ('color_moments_lab_channel_2_std', 0.017598443786033268), ('lbp_rad2_bins64_10', 0.014203924777094493), ('lbp_rad1_bins64_41', 0.01237759175817438), ('lbp_rad1_bins64_63', 0.012310091057542199), ('lbp_rad1_bins64_40', 0.010244680683226193), ('color_moments_rgb_channel_0_mean', 0.010209002985531852), ('gradient_magnitude_mean', 0.009868630502379717)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier7; Done in 26.018622875213623 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier8
# INFO:utils.ml:Top 10 features for RandomForestClassifier8: [('lbp_rad1_bins32_10', 0.06568498953661049), ('lbp_rad1_bins64_10', 0.05819220377138287), ('lbp_rad1_bins16_10', 0.05595158782054197), ('lbp_rad1_bins64_41', 0.035644652893716204), ('lbp_rad2_bins64_10', 0.03374910989347752), ('color_moments_lab_channel_2_std', 0.030695117774323048), ('lbp_rad1_bins64_63', 0.03021290351906787), ('lbp_rad2_bins16_4', 0.025020502424458323), ('lbp_rad1_bins64_40', 0.024628597691861112), ('gradient_magnitude_mean', 0.02241988207101534)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier8; Done in 6.428148984909058 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier9
# INFO:utils.ml:Top 10 features for XGBClassifier9: [('lbp_rad1_bins32_10', 0.14135484), ('lbp_rad1_bins16_10', 0.035069417), ('color_moments_lab_channel_2_std', 0.019701686), ('lbp_rad1_bins64_10', 0.012724745), ('lbp_rad1_bins64_41', 0.008866034), ('color_moments_hsv_channel_0_std', 0.005726421), ('var_rgb_channel_0', 0.005660588), ('lbp_rad1_bins16_3', 0.0055678138), ('color_moments_lab_channel_1_std', 0.0053862706), ('lbp_rad2_bins16_16', 0.0051384484)]
# INFO:utils.ml:Fitted classifier: XGBClassifier9; Done in 10.775882959365845 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier10
# INFO:utils.ml:Top 10 features for XGBClassifier10: [('lbp_rad1_bins32_10', 0.14130977), ('lbp_rad1_bins16_10', 0.03309693), ('color_moments_lab_channel_2_std', 0.020472439), ('lbp_rad1_bins64_10', 0.01327953), ('lbp_rad1_bins64_41', 0.008784383), ('color_moments_lab_channel_1_std', 0.0063505173), ('var_rgb_channel_0', 0.0058323406), ('color_moments_hsv_channel_0_std', 0.005655442), ('lbp_rad2_bins16_16', 0.0056336178), ('lbp_rad1_bins16_3', 0.0054503228)]
# INFO:utils.ml:Fitted classifier: XGBClassifier10; Done in 15.452726602554321 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier11
# INFO:utils.ml:Top 10 features for XGBClassifier11: [('lbp_rad1_bins32_10', 0.13765638), ('lbp_rad1_bins16_10', 0.03278203), ('color_moments_lab_channel_2_std', 0.020429991), ('lbp_rad1_bins64_10', 0.012508235), ('lbp_rad1_bins64_41', 0.009554061), ('color_moments_lab_channel_1_std', 0.007127428), ('lbp_rad2_bins16_16', 0.006322824), ('var_rgb_channel_0', 0.0058608963), ('color_moments_hsv_channel_0_std', 0.005800989), ('lbp_rad1_bins16_3', 0.00552746)]
# INFO:utils.ml:Fitted classifier: XGBClassifier11; Done in 19.397326469421387 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier12
# INFO:utils.ml:Top 10 features for XGBClassifier12: [('lbp_rad1_bins16_10', 0.085244186), ('lbp_rad1_bins32_10', 0.061312325), ('lbp_rad1_bins64_10', 0.030222371), ('lbp_rad2_bins64_7', 0.02966498), ('color_moments_lab_channel_2_std', 0.014521206), ('lbp_rad1_bins64_41', 0.012523723), ('lbp_rad2_bins16_7', 0.011080801), ('lbp_rad1_bins32_25', 0.008091689), ('lbp_rad1_bins16_3', 0.0063063162), ('color_moments_lab_channel_1_std', 0.006108712)]
# INFO:utils.ml:Fitted classifier: XGBClassifier12; Done in 6.759764194488525 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier13
# INFO:utils.ml:Top 10 features for XGBClassifier13: [('lbp_rad1_bins32_10', 0.055371348), ('lbp_rad1_bins64_10', 0.03459651), ('lbp_rad2_bins64_7', 0.029271383), ('lbp_rad1_bins16_10', 0.018876698), ('color_moments_lab_channel_2_std', 0.016328711), ('var_rgb_channel_0', 0.0044952985), ('lbp_rad1_bins32_25', 0.0043025254), ('lbp_rad1_bins64_40', 0.0042745033), ('color_moments_hsv_channel_0_std', 0.0042513967), ('color_moments_rgb_channel_1_skew', 0.0042262473)]
# INFO:utils.ml:Fitted classifier: XGBClassifier13; Done in 16.846480131149292 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier14
# INFO:utils.ml:Top 10 features for XGBClassifier14: [('lbp_rad1_bins32_10', 0.05633432), ('lbp_rad1_bins64_10', 0.039262652), ('lbp_rad1_bins16_10', 0.03684124), ('color_moments_lab_channel_2_std', 0.016253594), ('lbp_rad2_bins64_7', 0.011217556), ('lbp_rad1_bins64_41', 0.0055779815), ('lbp_rad1_bins32_25', 0.005127808), ('lbp_rad3_bins16_16', 0.0050156936), ('lbp_rad3_bins16_4', 0.004892753), ('color_moments_hsv_channel_2_std', 0.004888126)]
# INFO:utils.ml:Fitted classifier: XGBClassifier14; Done in 10.473657369613647 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier15
# INFO:utils.ml:Top 10 features for XGBClassifier15: [('lbp_rad1_bins32_10', 0.053435076), ('lbp_rad1_bins64_10', 0.033041157), ('lbp_rad1_bins16_10', 0.030234857), ('lbp_rad2_bins64_7', 0.023248676), ('color_moments_lab_channel_2_std', 0.015958387), ('lbp_rad1_bins64_41', 0.006533944), ('lbp_rad1_bins16_3', 0.005149541), ('lbp_rad1_bins32_25', 0.0049447473), ('color_moments_hsv_channel_2_std', 0.0048144157), ('lbp_rad2_bins32_7', 0.0043784925)]
# INFO:utils.ml:Fitted classifier: XGBClassifier15; Done in 11.239698648452759 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier16
# INFO:utils.ml:Top 10 features for XGBClassifier16: [('lbp_rad1_bins32_10', 0.08117876), ('lbp_rad1_bins64_10', 0.026468018), ('lbp_rad1_bins16_10', 0.02072313), ('color_moments_lab_channel_2_std', 0.017052094), ('lbp_rad2_bins64_7', 0.010188489), ('lbp_rad1_bins32_25', 0.0063224775), ('color_moments_hsv_channel_2_std', 0.0046113627), ('lbp_rad2_bins32_7', 0.0046026767), ('color_moments_lab_channel_2_skew', 0.004474849), ('color_moments_rgb_channel_1_mean', 0.0044335807)]
# INFO:utils.ml:Fitted classifier: XGBClassifier16; Done in 24.790193796157837 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier17
# INFO:utils.ml:Top 10 features for XGBClassifier17: [('lbp_rad1_bins32_10', 0.08252458), ('lbp_rad1_bins64_10', 0.026585357), ('lbp_rad1_bins16_10', 0.020812137), ('color_moments_lab_channel_2_std', 0.017325846), ('lbp_rad2_bins64_7', 0.009475767), ('lbp_rad1_bins32_25', 0.0061812093), ('lbp_rad1_bins16_3', 0.0045019994), ('color_moments_hsv_channel_2_std', 0.004468202), ('color_moments_lab_channel_2_skew', 0.004456208), ('lbp_rad1_bins64_41', 0.0044006594)]
# INFO:utils.ml:Fitted classifier: XGBClassifier17; Done in 20.660072803497314 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier18
# INFO:utils.ml:Top 10 features for XGBClassifier18: [('lbp_rad1_bins32_10', 0.067388035), ('lbp_rad1_bins64_10', 0.039333377), ('lbp_rad1_bins16_10', 0.01852051), ('color_moments_lab_channel_2_std', 0.017294362), ('lbp_rad2_bins64_7', 0.012951348), ('lbp_rad1_bins32_25', 0.005162949), ('lbp_rad1_bins64_40', 0.005049508), ('var_lab_channel_1', 0.0045960597), ('color_moments_rgb_channel_1_mean', 0.0045721284), ('color_moments_hsv_channel_0_std', 0.0045696353)]
# INFO:utils.ml:Fitted classifier: XGBClassifier18; Done in 19.94131875038147 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier19
# INFO:utils.ml:Top 10 features for XGBClassifier19: [('lbp_rad1_bins32_10', 0.06818918), ('lbp_rad1_bins64_10', 0.039296158), ('lbp_rad1_bins16_10', 0.019016907), ('color_moments_lab_channel_2_std', 0.017610628), ('lbp_rad2_bins64_7', 0.0119695), ('lbp_rad1_bins64_40', 0.005199647), ('lbp_rad1_bins32_25', 0.005125885), ('var_lab_channel_1', 0.0047996086), ('var_lab_channel_0', 0.00477092), ('color_moments_hsv_channel_0_std', 0.004713638)]
# INFO:utils.ml:Fitted classifier: XGBClassifier19; Done in 23.322709321975708 seconds
# INFO:utils.ml:Fitting completed in 369.66 seconds.

# %%
pipeline.predict_with_classifiers(VAL_PATH)
# Out:
# INFO:utils.ml:Predicting with classifiers on dataset: C:\Users\gimes\Src\repos\CADx-Project\dataset\binary\val
# Processed 5/80 batches.
# Processed 10/80 batches.
# Processed 15/80 batches.
# Processed 20/80 batches.
# Processed 25/80 batches.
# Processed 30/80 batches.
# Processed 35/80 batches.
# Processed 40/80 batches.
# Processed 45/80 batches.
# Processed 50/80 batches.
# Processed 55/80 batches.
# Processed 60/80 batches.
# Processed 65/80 batches.
# Processed 70/80 batches.
# Processed 75/80 batches.
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier0
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier1
# Processed 80/80 batches.
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier2
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier3
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier4
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier5
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier6
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier7
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier8
# INFO:utils.ml:Predictions made with classifier: XGBClassifier9
# INFO:utils.ml:Predictions made with classifier: XGBClassifier10
# INFO:utils.ml:Predictions made with classifier: XGBClassifier11
# INFO:utils.ml:Predictions made with classifier: XGBClassifier12
# INFO:utils.ml:Predictions made with classifier: XGBClassifier13
# INFO:utils.ml:Predictions made with classifier: XGBClassifier14
# INFO:utils.ml:Predictions made with classifier: XGBClassifier15
# INFO:utils.ml:Predictions made with classifier: XGBClassifier16
# INFO:utils.ml:Predictions made with classifier: XGBClassifier17
# INFO:utils.ml:Predictions made with classifier: XGBClassifier18
# INFO:utils.ml:Predictions made with classifier: XGBClassifier19
# {'GT': array([0, 0, 0, ..., 1, 1, 1]),
#  'RandomForestClassifier0': array([0, 0, 1, ..., 0, 0, 1]),
#  'RandomForestClassifier1': array([0, 0, 1, ..., 0, 0, 1]),
#  'RandomForestClassifier2': array([0, 0, 0, ..., 0, 0, 1]),
#  'RandomForestClassifier3': array([0, 0, 0, ..., 0, 0, 1]),
#  'RandomForestClassifier4': array([0, 0, 1, ..., 0, 0, 1]),
#  'RandomForestClassifier5': array([0, 0, 0, ..., 0, 0, 1]),
#  'RandomForestClassifier6': array([0, 0, 1, ..., 0, 0, 1]),
#  'RandomForestClassifier7': array([0, 0, 1, ..., 0, 0, 1]),
#  'RandomForestClassifier8': array([0, 0, 1, ..., 0, 0, 1]),
#  'XGBClassifier9': array([0, 0, 0, ..., 0, 0, 1]),
#  'XGBClassifier10': array([0, 0, 0, ..., 0, 0, 1]),
#  'XGBClassifier11': array([0, 0, 0, ..., 0, 0, 1]),
#  'XGBClassifier12': array([0, 0, 1, ..., 0, 0, 1]),
#  'XGBClassifier13': array([0, 0, 1, ..., 0, 0, 1]),
#  'XGBClassifier14': array([0, 0, 0, ..., 0, 0, 1]),
#  'XGBClassifier15': array([0, 0, 0, ..., 1, 0, 1]),
#  'XGBClassifier16': array([0, 0, 0, ..., 0, 0, 1]),
#  'XGBClassifier17': array([0, 0, 0, ..., 0, 0, 1]),
#  'XGBClassifier18': array([0, 0, 0, ..., 0, 0, 1]),
#  'XGBClassifier19': array([0, 0, 0, ..., 0, 0, 1])}

# %%
import pandas as pd

df = pd.DataFrame(data=pipeline.calculate_metrics(["report"]))
df = df.T
df
# Out:
# INFO:utils.ml:Metrics for classifier GT: {}
# INFO:utils.ml:Classification report
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1931
#            1       1.00      1.00      1.00      1865
#
#     accuracy                           1.00      3796
#    macro avg       1.00      1.00      1.00      3796
# weighted avg       1.00      1.00      1.00      3796
#
# INFO:utils.ml:Metrics for classifier RandomForestClassifier0: {}
# INFO:utils.ml:Classification report
#               precision    recall  f1-score   support
#
#            0       0.80      0.80      0.80      1931
#            1       0.79      0.80      0.79      1865
#
#     accuracy                           0.80      3796
#    macro avg       0.80      0.80      0.80      3796
# weighted avg       0.80      0.80      0.80      3796
#
# INFO:utils.ml:Metrics for classifier RandomForestClassifier1: {}
# INFO:utils.ml:Classification report
#               precision    recall  f1-score   support
#
#            0       0.80      0.79      0.80      1931
#            1       0.79      0.80      0.79      1865
#
#     accuracy                           0.80      3796
#    macro avg       0.80      0.80      0.80      3796
# weighted avg       0.80      0.80      0.80      3796
#
# INFO:utils.ml:Metrics for classifier RandomForestClassifier2: {}
# INFO:utils.ml:Classification report
#               precision    recall  f1-score   support
#
#            0       0.81      0.80      0.80      1931
#            1       0.79      0.81      0.80      1865
#
#     accuracy                           0.80      3796
#    macro avg       0.80      0.80      0.80      3796
# weighted avg       0.80      0.80      0.80      3796
#
# INFO:utils.ml:Metrics for classifier RandomForestClassifier3: {}
# INFO:utils.ml:Classification report
#               precision    recall  f1-score   support
#
#            0       0.80      0.80      0.80      1931
#            1       0.79      0.80      0.80      1865
#
#     accuracy                           0.80      3796
#    macro avg       0.80      0.80      0.80      3796
# weighted avg       0.80      0.80      0.80      3796
#
# INFO:utils.ml:Metrics for classifier RandomForestClassifier4: {}
# INFO:utils.ml:Classification report
#               precision    recall  f1-score   support
#
#            0       0.80      0.80      0.80      1931
#            1       0.79      0.80      0.79      1865
#
#     accuracy                           0.80      3796
#    macro avg       0.80      0.80      0.80      3796
# weighted avg       0.80      0.80      0.80      3796
#
# INFO:utils.ml:Metrics for classifier RandomForestClassifier5: {}
# INFO:utils.ml:Classification report
#               precision    recall  f1-score   support
#
#            0       0.80      0.79      0.79      1931
#            1       0.78      0.80      0.79      1865
#
#     accuracy                           0.79      3796
#    macro avg       0.79      0.79      0.79      3796
# weighted avg       0.79      0.79      0.79      3796
#
# INFO:utils.ml:Metrics for classifier RandomForestClassifier6: {}
# INFO:utils.ml:Classification report
#               precision    recall  f1-score   support
#
#            0       0.80      0.80      0.80      1931
#            1       0.79      0.80      0.79      1865
#
#     accuracy                           0.80      3796
#    macro avg       0.80      0.80      0.80      3796
# weighted avg       0.80      0.80      0.80      3796
#
# INFO:utils.ml:Metrics for classifier RandomForestClassifier7: {}
# INFO:utils.ml:Classification report
#               precision    recall  f1-score   support
#
#            0       0.81      0.81      0.81      1931
#            1       0.80      0.80      0.80      1865
#
#     accuracy                           0.81      3796
#    macro avg       0.81      0.81      0.81      3796
# weighted avg       0.81      0.81      0.81      3796
#
# INFO:utils.ml:Metrics for classifier RandomForestClassifier8: {}
# INFO:utils.ml:Classification report
#               precision    recall  f1-score   support
#
#            0       0.77      0.75      0.76      1931
#            1       0.74      0.77      0.75      1865
#
#     accuracy                           0.76      3796
#    macro avg       0.76      0.76      0.76      3796
# weighted avg       0.76      0.76      0.76      3796
#
# INFO:utils.ml:Metrics for classifier XGBClassifier9: {}
# INFO:utils.ml:Classification report
#               precision    recall  f1-score   support
#
#            0       0.82      0.82      0.82      1931
#            1       0.81      0.82      0.82      1865
#
#     accuracy                           0.82      3796
#    macro avg       0.82      0.82      0.82      3796
# weighted avg       0.82      0.82      0.82      3796
#
# INFO:utils.ml:Metrics for classifier XGBClassifier10: {}
# INFO:utils.ml:Classification report
#               precision    recall  f1-score   support
#
#            0       0.82      0.82      0.82      1931
#            1       0.81      0.82      0.81      1865
#
#     accuracy                           0.82      3796
#    macro avg       0.82      0.82      0.82      3796
# weighted avg       0.82      0.82      0.82      3796
#
# INFO:utils.ml:Metrics for classifier XGBClassifier11: {}
# INFO:utils.ml:Classification report
#               precision    recall  f1-score   support
#
#            0       0.82      0.82      0.82      1931
#            1       0.81      0.81      0.81      1865
#
#     accuracy                           0.81      3796
#    macro avg       0.81      0.81      0.81      3796
# weighted avg       0.81      0.81      0.81      3796
#
# INFO:utils.ml:Metrics for classifier XGBClassifier12: {}
# INFO:utils.ml:Classification report
#               precision    recall  f1-score   support
#
#            0       0.82      0.81      0.81      1931
#            1       0.80      0.82      0.81      1865
#
#     accuracy                           0.81      3796
#    macro avg       0.81      0.81      0.81      3796
# weighted avg       0.81      0.81      0.81      3796
#
# INFO:utils.ml:Metrics for classifier XGBClassifier13: {}
# INFO:utils.ml:Classification report
#               precision    recall  f1-score   support
#
#            0       0.83      0.83      0.83      1931
#            1       0.82      0.82      0.82      1865
#
#     accuracy                           0.82      3796
#    macro avg       0.82      0.82      0.82      3796
# weighted avg       0.82      0.82      0.82      3796
#
# INFO:utils.ml:Metrics for classifier XGBClassifier14: {}
# INFO:utils.ml:Classification report
#               precision    recall  f1-score   support
#
#            0       0.83      0.82      0.82      1931
#            1       0.81      0.82      0.82      1865
#
#     accuracy                           0.82      3796
#    macro avg       0.82      0.82      0.82      3796
# weighted avg       0.82      0.82      0.82      3796
#
# INFO:utils.ml:Metrics for classifier XGBClassifier15: {}
# INFO:utils.ml:Classification report
#               precision    recall  f1-score   support
#
#            0       0.82      0.82      0.82      1931
#            1       0.81      0.82      0.81      1865
#
#     accuracy                           0.82      3796
#    macro avg       0.82      0.82      0.82      3796
# weighted avg       0.82      0.82      0.82      3796
#
# INFO:utils.ml:Metrics for classifier XGBClassifier16: {}
# INFO:utils.ml:Classification report
#               precision    recall  f1-score   support
#
#            0       0.83      0.82      0.82      1931
#            1       0.81      0.83      0.82      1865
#
#     accuracy                           0.82      3796
#    macro avg       0.82      0.82      0.82      3796
# weighted avg       0.82      0.82      0.82      3796
#
# INFO:utils.ml:Metrics for classifier XGBClassifier17: {}
# INFO:utils.ml:Classification report
#               precision    recall  f1-score   support
#
#            0       0.83      0.81      0.82      1931
#            1       0.81      0.82      0.82      1865
#
#     accuracy                           0.82      3796
#    macro avg       0.82      0.82      0.82      3796
# weighted avg       0.82      0.82      0.82      3796
#
# INFO:utils.ml:Metrics for classifier XGBClassifier18: {}
# INFO:utils.ml:Classification report
#               precision    recall  f1-score   support
#
#            0       0.84      0.82      0.83      1931
#            1       0.82      0.83      0.83      1865
#
#     accuracy                           0.83      3796
#    macro avg       0.83      0.83      0.83      3796
# weighted avg       0.83      0.83      0.83      3796
#
# INFO:utils.ml:Metrics for classifier XGBClassifier19: {}
# INFO:utils.ml:Classification report
#               precision    recall  f1-score   support
#
#            0       0.83      0.82      0.83      1931
#            1       0.82      0.83      0.82      1865
#
#     accuracy                           0.83      3796
#    macro avg       0.83      0.83      0.83      3796
# weighted avg       0.83      0.83      0.83      3796
# Empty DataFrame
# Columns: []
# Index: [GT, RandomForestClassifier0, RandomForestClassifier1, RandomForestClassifier2, RandomForestClassifier3, RandomForestClassifier4, RandomForestClassifier5, RandomForestClassifier6, RandomForestClassifier7, RandomForestClassifier8, XGBClassifier9, XGBClassifier10, XGBClassifier11, XGBClassifier12, XGBClassifier13, XGBClassifier14, XGBClassifier15, XGBClassifier16, XGBClassifier17, XGBClassifier18, XGBClassifier19]
