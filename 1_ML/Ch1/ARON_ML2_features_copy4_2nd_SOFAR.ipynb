# %%
from sklearn.metrics import confusion_matrix, recall_score

from utils.loader import FactoryLoader
from utils.ml import MLPipeline
from utils.preprocessing import PreprocessingFactory
from utils.feature_extraction import *
from utils.utils import *

VAL_PATH = r"C:\Users\gimes\Src\repos\CADx-Project\dataset\binary\val"
TRAIN_PATH = r"C:\Users\gimes\Src\repos\CADx-Project\dataset\binary\train"

# %%
percent = 100
random = False


# Initialize the FactoryLoader
factory = PreprocessingFactory()
factory.gaussian_smoothing(5)
factory.clahe(clip_limit=1.5)
factory.pad2square(fill=np.nan)
factory.resize((150,150))
factory.hair_removal()
factory.normalize2float()

factory_loader = FactoryLoader(path=VAL_PATH, batch_size=32, factory=factory, percentage=percent, shuffle=random)

# Create the feature extraction pipeline strategy and add desired features
strategy = FeatureExtractionStrategy()

strategy.add_extractor(MeanExtractor())  # Add mean feature
strategy.add_extractor(StdExtractor())   # Add standard deviation feature
strategy.add_extractor(VarExtractor())   # Add variance feature

strategy.add_extractor(MeanExtractor("lab"))  # Add mean feature
strategy.add_extractor(StdExtractor("lab"))   # Add standard deviation feature
strategy.add_extractor(VarExtractor("lab"))   # Add variance feature

strategy.add_extractor(MeanExtractor("hsv"))  # Add mean feature
strategy.add_extractor(StdExtractor("hsv"))   # Add standard deviation feature
strategy.add_extractor(VarExtractor("hsv"))   # Add variance feature

strategy.add_extractor(LBPExtractor(radius=1, n_points=8))
strategy.add_extractor(LBPExtractor(radius=2, n_points=8))
strategy.add_extractor(LBPExtractor(radius=1, n_points=16))
strategy.add_extractor(LBPExtractor(radius=2, n_points=16))

strategy.add_extractor(GLCMExtractor(properties=['contrast', 'dissimilarity', 'homogeneity', 'energy', 'correlation',]))

pipeline = MLPipeline(dataset_path=TRAIN_PATH, preprocessing_factory=factory, feature_strategy=strategy, classifiers=[], percentage=percent, verbose=True, shuffle=random)
# Out:
# INFO:utils.ml:MLPipeline initialized with dataset path: C:\Users\gimes\Src\repos\CADx-Project\dataset\binary\train
# INFO:utils.ml:Preprocessing steps

# %%
pipeline.run_feature_extraction()
# Out:
# INFO:utils.ml:Running feature extraction...
# Processed 5/634 batches.
# Processed 10/634 batches.
# Processed 15/634 batches.
# Processed 20/634 batches.
# Processed 25/634 batches.
# Processed 30/634 batches.
# Processed 35/634 batches.
# Processed 40/634 batches.
# Processed 45/634 batches.
# Processed 50/634 batches.
# Processed 55/634 batches.
# Processed 60/634 batches.
# Processed 65/634 batches.
# Processed 70/634 batches.
# Processed 75/634 batches.
# Processed 80/634 batches.
# Processed 85/634 batches.
# Processed 90/634 batches.
# Processed 95/634 batches.
# Processed 100/634 batches.
# Processed 105/634 batches.
# Processed 110/634 batches.
# Processed 115/634 batches.
# Processed 120/634 batches.
# Processed 125/634 batches.
# Processed 130/634 batches.
# Processed 135/634 batches.
# Processed 140/634 batches.
# Processed 145/634 batches.
# Processed 150/634 batches.
# Processed 155/634 batches.
# Processed 160/634 batches.
# Processed 165/634 batches.
# Processed 170/634 batches.
# Processed 175/634 batches.
# Processed 180/634 batches.
# Processed 185/634 batches.
# Processed 190/634 batches.
# Processed 195/634 batches.
# Processed 200/634 batches.
# Processed 205/634 batches.
# Processed 210/634 batches.
# Processed 215/634 batches.
# Processed 220/634 batches.
# Processed 225/634 batches.
# Processed 230/634 batches.
# Processed 235/634 batches.
# Processed 240/634 batches.
# Processed 245/634 batches.
# Processed 250/634 batches.
# Processed 255/634 batches.
# Processed 260/634 batches.
# Processed 265/634 batches.
# Processed 270/634 batches.
# Processed 275/634 batches.
# Processed 280/634 batches.
# Processed 285/634 batches.
# Processed 290/634 batches.
# Processed 295/634 batches.
# Processed 300/634 batches.
# Processed 305/634 batches.
# Processed 310/634 batches.
# Processed 315/634 batches.
# Processed 320/634 batches.
# Processed 325/634 batches.
# Processed 330/634 batches.
# Processed 335/634 batches.
# Processed 340/634 batches.
# Processed 345/634 batches.
# Processed 350/634 batches.
# Processed 355/634 batches.
# Processed 360/634 batches.
# Processed 365/634 batches.
# Processed 370/634 batches.
# Processed 375/634 batches.
# Processed 380/634 batches.
# Processed 385/634 batches.
# Processed 390/634 batches.
# Processed 395/634 batches.
# Processed 400/634 batches.
# Processed 405/634 batches.
# Processed 410/634 batches.
# Processed 415/634 batches.
# Processed 420/634 batches.
# Processed 425/634 batches.
# Processed 430/634 batches.
# Processed 435/634 batches.
# Processed 440/634 batches.
# Processed 445/634 batches.
# Processed 450/634 batches.
# Processed 455/634 batches.
# Processed 460/634 batches.
# Processed 465/634 batches.
# Processed 470/634 batches.
# Processed 475/634 batches.
# Processed 480/634 batches.
# Processed 485/634 batches.
# Processed 490/634 batches.
# Processed 495/634 batches.
# Processed 500/634 batches.
# Processed 505/634 batches.
# Processed 510/634 batches.
# Processed 515/634 batches.
# Processed 520/634 batches.
# Processed 525/634 batches.
# Processed 530/634 batches.
# Processed 535/634 batches.
# Processed 540/634 batches.
# Processed 545/634 batches.
# Processed 550/634 batches.
# Processed 555/634 batches.
# Processed 560/634 batches.
# Processed 565/634 batches.
# Processed 570/634 batches.
# Processed 575/634 batches.
# Processed 580/634 batches.
# Processed 585/634 batches.
# Processed 590/634 batches.
# Processed 595/634 batches.
# Processed 600/634 batches.
# Processed 605/634 batches.
# Processed 610/634 batches.
# Processed 615/634 batches.
# Processed 620/634 batches.
# Processed 625/634 batches.
# Processed 630/634 batches.
# INFO:utils.ml:Feature extraction completed. Extracted 15195 features.
# Processed 634/634 batches.

# %%
from xgboost import XGBClassifier
from sklearn.ensemble import RandomForestClassifier

rf1 = RandomForestClassifier(n_estimators=100)
rf2 = RandomForestClassifier(n_estimators=150)
rf3 = RandomForestClassifier(n_estimators=250)

# Random Forest with Class Weight Balancing
rf4 = RandomForestClassifier(n_estimators=100, class_weight="balanced", random_state=42)
# Random Forest with Feature Selection via max_features
rf5 = RandomForestClassifier(n_estimators=100, max_features='sqrt', random_state=42)
# Random Forest with Min Samples per Leaf
rf6 = RandomForestClassifier(n_estimators=100, min_samples_leaf=5, random_state=42)
# Random Forest with Out-of-Bag Error (OOB)
rf7 = RandomForestClassifier(n_estimators=100, oob_score=True, random_state=42)
# Random Forest with Bootstrap Disabled
rf8 = RandomForestClassifier(n_estimators=100, bootstrap=False, random_state=42)
# Random Forest with High Number of Trees and Limited Depth
rf9 = RandomForestClassifier(n_estimators=100, max_depth=5, random_state=42)

xgb1 = XGBClassifier(n_estimators=350)
xgb2 = XGBClassifier(n_estimators=450)
xgb3 = XGBClassifier(n_estimators=550)
xgb4 = XGBClassifier(learning_rate=0.05, n_estimators=400, max_depth=3, min_child_weight=1, subsample=0.8, colsample_bytree=0.8)
xgb5 = XGBClassifier(learning_rate=0.1, n_estimators=400, max_depth=7, min_child_weight=3, subsample=0.7, colsample_bytree=0.7)
xgb6 = XGBClassifier(learning_rate=0.1, n_estimators=400, max_depth=5, min_child_weight=5, gamma=0.2, subsample=0.8, colsample_bytree=0.8)
xgb7 = XGBClassifier(learning_rate=0.1, n_estimators=400, max_depth=5, min_child_weight=1, subsample=0.8, colsample_bytree=0.8, reg_alpha=0.1, reg_lambda=0.1)
xgb8 = XGBClassifier(learning_rate=0.05, n_estimators=500, max_depth=7, min_child_weight=1, subsample=0.8, colsample_bytree=0.8)
xgb9 = XGBClassifier(learning_rate=0.05, n_estimators=400, max_depth=7, min_child_weight=1, subsample=0.8, colsample_bytree=0.8)
xgb10 = XGBClassifier(learning_rate=0.1, n_estimators=400, max_depth=7, min_child_weight=1, subsample=0.8, colsample_bytree=0.8)
xgb11 = XGBClassifier(learning_rate=0.1, n_estimators=500, max_depth=7, min_child_weight=1, subsample=0.8, colsample_bytree=0.8)


pipeline.classifiers = [rf1, rf2, rf3, rf4, rf5, rf6, rf7, rf8, rf9,
                        # svm1, svm2, svm3, svm6, svm7, svm8,
                        xgb1, xgb2, xgb3, xgb4, xgb5, xgb6, xgb7, xgb8, xgb9, xgb10, xgb11]
pipeline.fitted_classifiers = {}

# %%
pipeline.fit_classifiers()
# Out:
# INFO:utils.ml:Fitting classifiers...
# INFO:utils.ml:Fitting classifier: RandomForestClassifier0
# INFO:utils.ml:Top 10 features for RandomForestClassifier0: [('lbp_rad1_bins16_1', 0.047772364921728545), ('mean_lab_channel_1', 0.04592974285918344), ('mean_rgb_channel_0', 0.027536616832237525), ('lbp_rad1_bins8_7', 0.026862743553692926), ('lbp_rad1_bins16_13', 0.023638927724753782), ('lbp_rad1_bins8_1', 0.021311058161512016), ('glcm_homogeneity_dist_1_angle_0', 0.021173541361305528), ('lbp_rad1_bins8_9', 0.01789549065537687), ('lbp_rad1_bins16_17', 0.017790964514762465), ('glcm_energy_dist_1_angle_0', 0.017522916734825845)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier0; Done in 9.604954242706299 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier1
# INFO:utils.ml:Top 10 features for RandomForestClassifier1: [('lbp_rad1_bins16_1', 0.04894770390738203), ('mean_lab_channel_1', 0.04082149240785899), ('lbp_rad1_bins8_7', 0.033601019962713904), ('lbp_rad1_bins16_13', 0.03356078770894945), ('mean_rgb_channel_0', 0.026260124896690166), ('lbp_rad1_bins16_17', 0.020080689630570105), ('glcm_correlation_dist_1_angle_0', 0.018149412899142785), ('glcm_homogeneity_dist_1_angle_0', 0.018028942961291865), ('lbp_rad1_bins8_1', 0.017749330824165462), ('lbp_rad1_bins8_9', 0.01627951905828108)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier1; Done in 14.261799335479736 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier2
# INFO:utils.ml:Top 10 features for RandomForestClassifier2: [('lbp_rad1_bins16_1', 0.049505775985307386), ('lbp_rad1_bins8_7', 0.03803056595015415), ('mean_lab_channel_1', 0.034864198328852875), ('mean_rgb_channel_0', 0.030049590496766383), ('lbp_rad1_bins16_13', 0.026631931509463563), ('lbp_rad1_bins8_1', 0.024463943623392426), ('glcm_correlation_dist_1_angle_0', 0.01853930852924477), ('glcm_energy_dist_1_angle_0', 0.01842558407969395), ('glcm_homogeneity_dist_1_angle_0', 0.018039924777021064), ('lbp_rad1_bins8_9', 0.017951647268261577)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier2; Done in 23.939627647399902 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier3
# INFO:utils.ml:Top 10 features for RandomForestClassifier3: [('lbp_rad1_bins16_1', 0.04904169499190337), ('mean_lab_channel_1', 0.04023059832539546), ('lbp_rad1_bins16_13', 0.02640833713078337), ('lbp_rad1_bins8_7', 0.02588203256044506), ('lbp_rad1_bins8_1', 0.02485017266467393), ('mean_rgb_channel_0', 0.023860637024243177), ('lbp_rad1_bins8_9', 0.02303128888204258), ('glcm_homogeneity_dist_1_angle_0', 0.02209437698428941), ('glcm_correlation_dist_1_angle_0', 0.018087112125008502), ('glcm_energy_dist_1_angle_0', 0.01795464446329844)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier3; Done in 9.826649904251099 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier4
# INFO:utils.ml:Top 10 features for RandomForestClassifier4: [('lbp_rad1_bins16_1', 0.04535173001120488), ('mean_lab_channel_1', 0.037428660044988946), ('mean_rgb_channel_0', 0.02702972098341634), ('lbp_rad1_bins8_1', 0.026720909005463048), ('lbp_rad1_bins8_7', 0.02668227908106331), ('lbp_rad1_bins16_13', 0.026070914554331498), ('lbp_rad1_bins8_9', 0.02237193488313073), ('glcm_homogeneity_dist_1_angle_0', 0.01922293130648263), ('glcm_energy_dist_1_angle_0', 0.019021027872359927), ('glcm_correlation_dist_1_angle_0', 0.017600660949153673)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier4; Done in 9.811657667160034 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier5
# INFO:utils.ml:Top 10 features for RandomForestClassifier5: [('lbp_rad1_bins16_1', 0.057591510517542785), ('mean_lab_channel_1', 0.05151638390771012), ('lbp_rad1_bins8_7', 0.03224198063121833), ('lbp_rad1_bins16_13', 0.031982746926262004), ('lbp_rad1_bins8_1', 0.029923945100777925), ('mean_rgb_channel_0', 0.029403232944941755), ('lbp_rad1_bins8_9', 0.0280230721382273), ('glcm_energy_dist_1_angle_0', 0.01955897509609095), ('glcm_correlation_dist_1_angle_0', 0.018249242063489445), ('lbp_rad1_bins16_8', 0.016584387473142646)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier5; Done in 8.437282085418701 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier6
# INFO:utils.ml:Top 10 features for RandomForestClassifier6: [('lbp_rad1_bins16_1', 0.04535173001120488), ('mean_lab_channel_1', 0.037428660044988946), ('mean_rgb_channel_0', 0.02702972098341634), ('lbp_rad1_bins8_1', 0.026720909005463048), ('lbp_rad1_bins8_7', 0.02668227908106331), ('lbp_rad1_bins16_13', 0.026070914554331498), ('lbp_rad1_bins8_9', 0.02237193488313073), ('glcm_homogeneity_dist_1_angle_0', 0.01922293130648263), ('glcm_energy_dist_1_angle_0', 0.019021027872359927), ('glcm_correlation_dist_1_angle_0', 0.017600660949153673)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier6; Done in 9.953997373580933 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier7
# INFO:utils.ml:Top 10 features for RandomForestClassifier7: [('lbp_rad1_bins16_1', 0.046728955904536455), ('mean_lab_channel_1', 0.04252578085265363), ('lbp_rad1_bins8_7', 0.028932024043348922), ('lbp_rad1_bins8_1', 0.025723761252251884), ('lbp_rad1_bins16_13', 0.02536913993528066), ('lbp_rad1_bins8_9', 0.023888308435867932), ('mean_rgb_channel_0', 0.022302787729903063), ('glcm_homogeneity_dist_1_angle_0', 0.02138576580717535), ('glcm_correlation_dist_1_angle_0', 0.019174160591821227), ('glcm_energy_dist_1_angle_0', 0.017373752689925703)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier7; Done in 14.312341928482056 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier8
# INFO:utils.ml:Top 10 features for RandomForestClassifier8: [('lbp_rad1_bins16_1', 0.10513652715751998), ('mean_lab_channel_1', 0.09739105257380169), ('lbp_rad1_bins8_7', 0.07279183895263681), ('lbp_rad1_bins16_13', 0.06406724328699487), ('lbp_rad1_bins8_1', 0.06094314657276455), ('lbp_rad1_bins8_9', 0.05371704718013313), ('mean_rgb_channel_0', 0.04212050956919287), ('glcm_energy_dist_1_angle_0', 0.0351017292779935), ('glcm_homogeneity_dist_1_angle_0', 0.03351569376368768), ('lbp_rad1_bins16_17', 0.028086770896789362)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier8; Done in 3.3802835941314697 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier9
# INFO:utils.ml:Top 10 features for XGBClassifier9: [('lbp_rad1_bins16_1', 0.1699806), ('mean_lab_channel_1', 0.04842506), ('glcm_correlation_dist_1_angle_0', 0.019287651), ('glcm_energy_dist_1_angle_0', 0.017485505), ('glcm_homogeneity_dist_1_angle_0', 0.016152905), ('std_rgb_channel_0', 0.015004306), ('std_rgb_channel_2', 0.014831153), ('std_lab_channel_1', 0.014744252), ('lbp_rad1_bins8_7', 0.013894011), ('lbp_rad2_bins16_9', 0.013579517)]
# INFO:utils.ml:Fitted classifier: XGBClassifier9; Done in 1.3100223541259766 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier10
# INFO:utils.ml:Top 10 features for XGBClassifier10: [('lbp_rad1_bins16_1', 0.17140989), ('mean_lab_channel_1', 0.04807551), ('glcm_correlation_dist_1_angle_0', 0.019247882), ('glcm_energy_dist_1_angle_0', 0.017758373), ('glcm_homogeneity_dist_1_angle_0', 0.016309744), ('std_rgb_channel_0', 0.015543265), ('std_rgb_channel_2', 0.015104548), ('std_lab_channel_1', 0.014659143), ('lbp_rad2_bins16_9', 0.0141681535), ('lbp_rad2_bins16_14', 0.013284586)]
# INFO:utils.ml:Fitted classifier: XGBClassifier10; Done in 1.6717019081115723 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier11
# INFO:utils.ml:Top 10 features for XGBClassifier11: [('lbp_rad1_bins16_1', 0.17052044), ('mean_lab_channel_1', 0.048385717), ('glcm_correlation_dist_1_angle_0', 0.019336049), ('glcm_energy_dist_1_angle_0', 0.017803919), ('std_rgb_channel_0', 0.016262049), ('glcm_homogeneity_dist_1_angle_0', 0.016159352), ('std_rgb_channel_2', 0.014714421), ('std_lab_channel_1', 0.014549566), ('lbp_rad2_bins16_9', 0.014191977), ('lbp_rad1_bins8_7', 0.0132556865)]
# INFO:utils.ml:Fitted classifier: XGBClassifier11; Done in 1.9529263973236084 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier12
# INFO:utils.ml:Top 10 features for XGBClassifier12: [('lbp_rad1_bins16_1', 0.15614286), ('lbp_rad1_bins16_13', 0.058250025), ('lbp_rad1_bins8_7', 0.05247951), ('mean_lab_channel_1', 0.051944286), ('glcm_energy_dist_1_angle_0', 0.028131215), ('std_hsv_channel_0', 0.016064301), ('glcm_homogeneity_dist_1_angle_0', 0.015646406), ('glcm_contrast_dist_1_angle_0', 0.015231257), ('var_lab_channel_1', 0.014369123), ('glcm_correlation_dist_1_angle_0', 0.014077462)]
# INFO:utils.ml:Fitted classifier: XGBClassifier12; Done in 0.6806802749633789 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier13
# INFO:utils.ml:Top 10 features for XGBClassifier13: [('lbp_rad1_bins16_1', 0.09629041), ('lbp_rad1_bins8_7', 0.040631533), ('mean_lab_channel_1', 0.03966035), ('lbp_rad1_bins16_13', 0.021364262), ('glcm_correlation_dist_1_angle_0', 0.015028497), ('var_rgb_channel_2', 0.014245842), ('var_rgb_channel_0', 0.013625433), ('glcm_homogeneity_dist_1_angle_0', 0.013548129), ('glcm_energy_dist_1_angle_0', 0.013364001), ('lbp_rad1_bins8_8', 0.012805206)]
# INFO:utils.ml:Fitted classifier: XGBClassifier13; Done in 1.637169361114502 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier14
# INFO:utils.ml:Top 10 features for XGBClassifier14: [('lbp_rad1_bins16_1', 0.15760317), ('mean_lab_channel_1', 0.04631701), ('var_lab_channel_0', 0.01825287), ('lbp_rad1_bins8_7', 0.017633006), ('glcm_energy_dist_1_angle_0', 0.01420979), ('var_hsv_channel_0', 0.013524572), ('glcm_correlation_dist_1_angle_0', 0.013524172), ('var_rgb_channel_2', 0.013404063), ('var_lab_channel_1', 0.013023837), ('std_rgb_channel_2', 0.012692083)]
# INFO:utils.ml:Fitted classifier: XGBClassifier14; Done in 0.9993994235992432 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier15
# INFO:utils.ml:Top 10 features for XGBClassifier15: [('lbp_rad1_bins16_1', 0.14230987), ('mean_lab_channel_1', 0.04282102), ('lbp_rad1_bins8_7', 0.019698873), ('var_lab_channel_0', 0.015287591), ('glcm_energy_dist_1_angle_0', 0.014602222), ('glcm_correlation_dist_1_angle_0', 0.014324812), ('var_lab_channel_1', 0.013849958), ('var_hsv_channel_0', 0.013446829), ('lbp_rad2_bins16_14', 0.013325646), ('std_rgb_channel_2', 0.013079458)]
# INFO:utils.ml:Fitted classifier: XGBClassifier15; Done in 1.0567476749420166 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier16
# INFO:utils.ml:Top 10 features for XGBClassifier16: [('lbp_rad1_bins16_1', 0.13242163), ('mean_lab_channel_1', 0.041319326), ('lbp_rad1_bins8_7', 0.026783371), ('glcm_correlation_dist_1_angle_0', 0.014976586), ('var_rgb_channel_2', 0.014558042), ('glcm_energy_dist_1_angle_0', 0.014295709), ('lbp_rad2_bins16_14', 0.013330702), ('var_rgb_channel_0', 0.013037815), ('var_lab_channel_1', 0.012946645), ('var_lab_channel_0', 0.012693583)]
# INFO:utils.ml:Fitted classifier: XGBClassifier16; Done in 2.439995527267456 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier17
# INFO:utils.ml:Top 10 features for XGBClassifier17: [('lbp_rad1_bins16_1', 0.14239083), ('mean_lab_channel_1', 0.042785894), ('lbp_rad1_bins8_7', 0.028322011), ('glcm_energy_dist_1_angle_0', 0.0154896835), ('glcm_correlation_dist_1_angle_0', 0.015176648), ('var_rgb_channel_2', 0.013522918), ('lbp_rad2_bins16_14', 0.013330693), ('var_lab_channel_0', 0.013016872), ('lbp_rad1_bins16_16', 0.012545119), ('glcm_homogeneity_dist_1_angle_0', 0.0124988295)]
# INFO:utils.ml:Fitted classifier: XGBClassifier17; Done in 1.9857730865478516 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier18
# INFO:utils.ml:Top 10 features for XGBClassifier18: [('lbp_rad1_bins16_1', 0.14357989), ('mean_lab_channel_1', 0.042056963), ('var_rgb_channel_0', 0.016193636), ('lbp_rad1_bins8_7', 0.01582594), ('var_rgb_channel_2', 0.014949381), ('glcm_correlation_dist_1_angle_0', 0.014576532), ('var_lab_channel_0', 0.0142333945), ('glcm_energy_dist_1_angle_0', 0.013896659), ('std_rgb_channel_2', 0.013820427), ('var_lab_channel_1', 0.013433601)]
# INFO:utils.ml:Fitted classifier: XGBClassifier18; Done in 1.9089128971099854 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier19
# INFO:utils.ml:Top 10 features for XGBClassifier19: [('lbp_rad1_bins16_1', 0.14296663), ('mean_lab_channel_1', 0.041285694), ('var_rgb_channel_0', 0.01615666), ('var_rgb_channel_2', 0.015715256), ('lbp_rad1_bins8_7', 0.015713783), ('glcm_correlation_dist_1_angle_0', 0.014617975), ('lbp_rad2_bins16_14', 0.0139550045), ('std_rgb_channel_2', 0.013952511), ('var_lab_channel_1', 0.013886182), ('glcm_energy_dist_1_angle_0', 0.013740798)]
# INFO:utils.ml:Fitted classifier: XGBClassifier19; Done in 2.369260311126709 seconds
# INFO:utils.ml:Fitting completed in 121.56 seconds.

# %%
pipeline.predict_with_classifiers(VAL_PATH)
# Out:
# INFO:utils.ml:Predicting with classifiers on dataset: C:\Users\gimes\Src\repos\CADx-Project\dataset\binary\val
# Processed 5/159 batches.
# Processed 10/159 batches.
# Processed 15/159 batches.
# Processed 20/159 batches.
# Processed 25/159 batches.
# Processed 30/159 batches.
# Processed 35/159 batches.
# Processed 40/159 batches.
# Processed 45/159 batches.
# Processed 50/159 batches.
# Processed 55/159 batches.
# Processed 60/159 batches.
# Processed 65/159 batches.
# Processed 70/159 batches.
# Processed 75/159 batches.
# Processed 80/159 batches.
# Processed 85/159 batches.
# Processed 90/159 batches.
# Processed 95/159 batches.
# Processed 100/159 batches.
# Processed 105/159 batches.
# Processed 110/159 batches.
# Processed 115/159 batches.
# Processed 120/159 batches.
# Processed 125/159 batches.
# Processed 130/159 batches.
# Processed 135/159 batches.
# Processed 140/159 batches.
# Processed 145/159 batches.
# Processed 150/159 batches.
# Processed 155/159 batches.
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier0
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier1
# Processed 159/159 batches.
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier2
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier3
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier4
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier5
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier6
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier7
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier8
# INFO:utils.ml:Predictions made with classifier: XGBClassifier9
# INFO:utils.ml:Predictions made with classifier: XGBClassifier10
# INFO:utils.ml:Predictions made with classifier: XGBClassifier11
# INFO:utils.ml:Predictions made with classifier: XGBClassifier12
# INFO:utils.ml:Predictions made with classifier: XGBClassifier13
# INFO:utils.ml:Predictions made with classifier: XGBClassifier14
# INFO:utils.ml:Predictions made with classifier: XGBClassifier15
# INFO:utils.ml:Predictions made with classifier: XGBClassifier16
# INFO:utils.ml:Predictions made with classifier: XGBClassifier17
# INFO:utils.ml:Predictions made with classifier: XGBClassifier18
# INFO:utils.ml:Predictions made with classifier: XGBClassifier19
# {'GT': array([0, 0, 0, ..., 1, 1, 1]),
#  'RandomForestClassifier0': array([0, 0, 1, ..., 0, 0, 1]),
#  'RandomForestClassifier1': array([0, 0, 1, ..., 0, 0, 1]),
#  'RandomForestClassifier2': array([0, 0, 1, ..., 0, 0, 1]),
#  'RandomForestClassifier3': array([0, 0, 0, ..., 0, 0, 1]),
#  'RandomForestClassifier4': array([0, 0, 0, ..., 0, 0, 1]),
#  'RandomForestClassifier5': array([0, 0, 1, ..., 0, 0, 1]),
#  'RandomForestClassifier6': array([0, 0, 0, ..., 0, 0, 1]),
#  'RandomForestClassifier7': array([0, 0, 1, ..., 0, 0, 1]),
#  'RandomForestClassifier8': array([0, 0, 1, ..., 0, 0, 1]),
#  'XGBClassifier9': array([0, 0, 0, ..., 0, 0, 1]),
#  'XGBClassifier10': array([0, 0, 0, ..., 0, 0, 1]),
#  'XGBClassifier11': array([0, 0, 0, ..., 0, 0, 1]),
#  'XGBClassifier12': array([0, 0, 1, ..., 0, 0, 1]),
#  'XGBClassifier13': array([0, 0, 0, ..., 0, 0, 1]),
#  'XGBClassifier14': array([0, 0, 1, ..., 0, 0, 1]),
#  'XGBClassifier15': array([0, 0, 1, ..., 0, 0, 1]),
#  'XGBClassifier16': array([0, 0, 0, ..., 0, 0, 1]),
#  'XGBClassifier17': array([0, 0, 0, ..., 0, 0, 1]),
#  'XGBClassifier18': array([0, 0, 0, ..., 0, 0, 1]),
#  'XGBClassifier19': array([0, 0, 0, ..., 0, 0, 1])}

# %%
import pandas as pd

df = pd.DataFrame(data=pipeline.calculate_metrics())
df = df.T
df
# Out:
# INFO:utils.ml:Metrics for classifier GT: {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'kappa': 1.0}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier0: {'accuracy': 0.7984720758693361, 'precision': 0.7985025405511041, 'recall': 0.7985898206627302, 'f1': 0.7984618798107029, 'kappa': 0.5969663037993096}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier1: {'accuracy': 0.8016332982086407, 'precision': 0.8016163167321233, 'recall': 0.8017061823250674, 'f1': 0.8016144503908074, 'kappa': 0.6032520587007311}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier2: {'accuracy': 0.8000526870389885, 'precision': 0.8000946606927719, 'recall': 0.8001800731121826, 'f1': 0.8000440141853098, 'kappa': 0.6001346779664405}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier3: {'accuracy': 0.7984720758693361, 'precision': 0.7984550803522552, 'recall': 0.7985440040651818, 'f1': 0.798452927687872, 'kappa': 0.5969293823453643}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier4: {'accuracy': 0.8047945205479452, 'precision': 0.8047332447777373, 'recall': 0.8047492374313272, 'f1': 0.8047407381285964, 'kappa': 0.6094817202354409}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier5: {'accuracy': 0.7924130663856691, 'precision': 0.7927374585604058, 'recall': 0.7926893370893688, 'f1': 0.7924121443886666, 'kappa': 0.5849820062784478}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier6: {'accuracy': 0.8047945205479452, 'precision': 0.8047332447777373, 'recall': 0.8047492374313272, 'f1': 0.8047407381285964, 'kappa': 0.6094817202354409}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier7: {'accuracy': 0.8100632244467861, 'precision': 0.8100041089196872, 'recall': 0.8100561878091752, 'f1': 0.8100233427880337, 'kappa': 0.6200498767518918}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier8: {'accuracy': 0.7505268703898841, 'precision': 0.7516466265865063, 'recall': 0.7510516297519101, 'f1': 0.7504537016732139, 'kappa': 0.5015012599711896}
# INFO:utils.ml:Metrics for classifier XGBClassifier9: {'accuracy': 0.8169125395152792, 'precision': 0.8168585928130414, 'recall': 0.8169259006779468, 'f1': 0.8168794854451114, 'kappa': 0.6337646905305944}
# INFO:utils.ml:Metrics for classifier XGBClassifier10: {'accuracy': 0.8184931506849316, 'precision': 0.8184338184338185, 'recall': 0.8184703365298509, 'f1': 0.8184492926104052, 'kappa': 0.6368998202438619}
# INFO:utils.ml:Metrics for classifier XGBClassifier11: {'accuracy': 0.8242887249736565, 'precision': 0.8242331213402317, 'recall': 0.8242951532981703, 'f1': 0.824254465267703, 'kappa': 0.6485130536762191}
# INFO:utils.ml:Metrics for classifier XGBClassifier12: {'accuracy': 0.7968914646996839, 'precision': 0.796882633799689, 'recall': 0.7969720782547486, 'f1': 0.7968741964317876, 'kappa': 0.5937754869198837}
# INFO:utils.ml:Metrics for classifier XGBClassifier13: {'accuracy': 0.8174394099051633, 'precision': 0.8174591409920309, 'recall': 0.8175537269025341, 'f1': 0.8174287543528163, 'kappa': 0.6348921981626277}
# INFO:utils.ml:Metrics for classifier XGBClassifier14: {'accuracy': 0.8069020021074815, 'precision': 0.8068405328713191, 'recall': 0.8068665195907605, 'f1': 0.8068521254666927, 'kappa': 0.613704921310128}
# INFO:utils.ml:Metrics for classifier XGBClassifier15: {'accuracy': 0.8134878819810326, 'precision': 0.8134537075104037, 'recall': 0.8135414425008642, 'f1': 0.8134650466981477, 'kappa': 0.6269450074636872}
# INFO:utils.ml:Metrics for classifier XGBClassifier16: {'accuracy': 0.8177028451001054, 'precision': 0.8176751042026674, 'recall': 0.8177668435002214, 'f1': 0.8176826011298155, 'kappa': 0.6353823095115088}
# INFO:utils.ml:Metrics for classifier XGBClassifier17: {'accuracy': 0.8166491043203372, 'precision': 0.8165966383638501, 'recall': 0.8166669674827112, 'f1': 0.8166172882900367, 'kappa': 0.6332410935179573}
# INFO:utils.ml:Metrics for classifier XGBClassifier18: {'accuracy': 0.821917808219178, 'precision': 0.82186303717085, 'recall': 0.8219281012630109, 'f1': 0.8218843843843844, 'kappa': 0.6437736150794455}
# INFO:utils.ml:Metrics for classifier XGBClassifier19: {'accuracy': 0.8266596417281349, 'precision': 0.8266113371934043, 'recall': 0.8266896952918587, 'f1': 0.8266319213466051, 'kappa': 0.6532716401219465}
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
#                          accuracy  precision    recall        f1     kappa
# GT                       1.000000   1.000000  1.000000  1.000000  1.000000
# RandomForestClassifier0  0.798472   0.798503  0.798590  0.798462  0.596966
# RandomForestClassifier1  0.801633   0.801616  0.801706  0.801614  0.603252
# RandomForestClassifier2  0.800053   0.800095  0.800180  0.800044  0.600135
# RandomForestClassifier3  0.798472   0.798455  0.798544  0.798453  0.596929
# RandomForestClassifier4  0.804795   0.804733  0.804749  0.804741  0.609482
# RandomForestClassifier5  0.792413   0.792737  0.792689  0.792412  0.584982
# RandomForestClassifier6  0.804795   0.804733  0.804749  0.804741  0.609482
# RandomForestClassifier7  0.810063   0.810004  0.810056  0.810023  0.620050
# RandomForestClassifier8  0.750527   0.751647  0.751052  0.750454  0.501501
# XGBClassifier9           0.816913   0.816859  0.816926  0.816879  0.633765
# XGBClassifier10          0.818493   0.818434  0.818470  0.818449  0.636900
# XGBClassifier11          0.824289   0.824233  0.824295  0.824254  0.648513
# XGBClassifier12          0.796891   0.796883  0.796972  0.796874  0.593775
# XGBClassifier13          0.817439   0.817459  0.817554  0.817429  0.634892
# XGBClassifier14          0.806902   0.806841  0.806867  0.806852  0.613705
# XGBClassifier15          0.813488   0.813454  0.813541  0.813465  0.626945
# XGBClassifier16          0.817703   0.817675  0.817767  0.817683  0.635382
# XGBClassifier17          0.816649   0.816597  0.816667  0.816617  0.633241
# XGBClassifier18          0.821918   0.821863  0.821928  0.821884  0.643774
# XGBClassifier19          0.826660   0.826611  0.826690  0.826632  0.653272
