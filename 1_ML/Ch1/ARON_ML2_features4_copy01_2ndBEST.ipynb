# %%
from utils.loader import FactoryLoader
from utils.ml import MLPipeline
from utils.preprocessing import PreprocessingFactory
from utils.feature_extraction import *
from utils.utils import *

VAL_PATH = r"C:\Users\gimes\Src\repos\CADx-Project\dataset\binary\val"
TRAIN_PATH = r"C:\Users\gimes\Src\repos\CADx-Project\dataset\binary\train"
# Out:
# INFO:numexpr.utils:Note: NumExpr detected 16 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.

# %%
percent = 100
random = False
batch_size = 24
th = 0.1

# Initialize the FactoryLoader
factory = PreprocessingFactory()
factory.gaussian_smoothing(5)
factory.clahe(clip_limit=1.5)
factory.pad2square(fill=np.nan)
factory.resize((150,150))
factory.hair_removal()
factory.normalize2float()

factory_loader = FactoryLoader(path=VAL_PATH, batch_size=batch_size, factory=factory, percentage=percent, shuffle=random)


# Create the feature extraction pipeline strategy and add desired features
strategy = FeatureExtractionStrategy()

strategy.add_extractor(GradientExtractor(threshold=th)) # Add gradient feature

strategy.add_extractor(ColorMomentsExtractor("rgb", threshold=th))   # Add color moments feature
strategy.add_extractor(ColorMomentsExtractor("lab", threshold=th))   # Add color moments feature
strategy.add_extractor(ColorMomentsExtractor("hsv", threshold=th))   # Add color moments feature

strategy.add_extractor(LBPExtractor(radius=1, n_points=8))
strategy.add_extractor(LBPExtractor(radius=2, n_points=16))
strategy.add_extractor(LBPExtractor(radius=3, n_points=24))
strategy.add_extractor(LBPExtractor(radius=4, n_points=32))

strategy.add_extractor(FourierTransformExtractor())

strategy.add_extractor(GLCMExtractor(properties=['contrast', 'dissimilarity', 'homogeneity', 'energy', 'correlation',]))

pipeline = MLPipeline(dataset_path=TRAIN_PATH, preprocessing_factory=factory, feature_strategy=strategy, classifiers=[], percentage=percent, verbose=True, shuffle=random, batch_size=batch_size)
# Out:
# INFO:utils.ml:MLPipeline initialized with dataset path: C:\Users\gimes\Src\repos\CADx-Project\dataset\binary\train
# INFO:utils.ml:Preprocessing steps

# %%
pipeline.run_feature_extraction()
# Out:
# INFO:utils.ml:Running feature extraction...
# Processed 5/634 batches.
# Processed 10/634 batches.
# Processed 15/634 batches.
# Processed 20/634 batches.
# Processed 25/634 batches.
# Processed 30/634 batches.
# Processed 35/634 batches.
# Processed 40/634 batches.
# Processed 45/634 batches.
# Processed 50/634 batches.
# Processed 55/634 batches.
# Processed 60/634 batches.
# Processed 65/634 batches.
# Processed 70/634 batches.
# Processed 75/634 batches.
# Processed 80/634 batches.
# Processed 85/634 batches.
# Processed 90/634 batches.
# Processed 95/634 batches.
# Processed 100/634 batches.
# Processed 105/634 batches.
# Processed 110/634 batches.
# Processed 115/634 batches.
# Processed 120/634 batches.
# Processed 125/634 batches.
# Processed 130/634 batches.
# Processed 135/634 batches.
# Processed 140/634 batches.
# Processed 145/634 batches.
# Processed 150/634 batches.
# Processed 155/634 batches.
# Processed 160/634 batches.
# Processed 165/634 batches.
# Processed 170/634 batches.
# Processed 175/634 batches.
# Processed 180/634 batches.
# Processed 185/634 batches.
# Processed 190/634 batches.
# Processed 195/634 batches.
# Processed 200/634 batches.
# Processed 205/634 batches.
# Processed 210/634 batches.
# Processed 215/634 batches.
# Processed 220/634 batches.
# Processed 225/634 batches.
# Processed 230/634 batches.
# Processed 235/634 batches.
# Processed 240/634 batches.
# Processed 245/634 batches.
# Processed 250/634 batches.
# Processed 255/634 batches.
# Processed 260/634 batches.
# Processed 265/634 batches.
# Processed 270/634 batches.
# Processed 275/634 batches.
# Processed 280/634 batches.
# Processed 285/634 batches.
# Processed 290/634 batches.
# Processed 295/634 batches.
# Processed 300/634 batches.
# Processed 305/634 batches.
# Processed 310/634 batches.
# Processed 315/634 batches.
# Processed 320/634 batches.
# Processed 325/634 batches.
# Processed 330/634 batches.
# Processed 335/634 batches.
# Processed 340/634 batches.
# Processed 345/634 batches.
# Processed 350/634 batches.
# Processed 355/634 batches.
# Processed 360/634 batches.
# Processed 365/634 batches.
# Processed 370/634 batches.
# Processed 375/634 batches.
# Processed 380/634 batches.
# Processed 385/634 batches.
# Processed 390/634 batches.
# Processed 395/634 batches.
# Processed 400/634 batches.
# Processed 405/634 batches.
# Processed 410/634 batches.
# Processed 415/634 batches.
# Processed 420/634 batches.
# Processed 425/634 batches.
# Processed 430/634 batches.
# Processed 435/634 batches.
# Processed 440/634 batches.
# Processed 445/634 batches.
# Processed 450/634 batches.
# Processed 455/634 batches.
# Processed 460/634 batches.
# Processed 465/634 batches.
# Processed 470/634 batches.
# Processed 475/634 batches.
# Processed 480/634 batches.
# Processed 485/634 batches.
# Processed 490/634 batches.
# Processed 495/634 batches.
# Processed 500/634 batches.
# Processed 505/634 batches.
# Processed 510/634 batches.
# Processed 515/634 batches.
# Processed 520/634 batches.
# Processed 525/634 batches.
# Processed 530/634 batches.
# Processed 535/634 batches.
# Processed 540/634 batches.
# Processed 545/634 batches.
# Processed 550/634 batches.
# Processed 555/634 batches.
# Processed 560/634 batches.
# Processed 565/634 batches.
# Processed 570/634 batches.
# Processed 575/634 batches.
# Processed 580/634 batches.
# Processed 585/634 batches.
# Processed 590/634 batches.
# Processed 595/634 batches.
# Processed 600/634 batches.
# Processed 605/634 batches.
# Processed 610/634 batches.
# Processed 615/634 batches.
# Processed 620/634 batches.
# Processed 625/634 batches.
# Processed 630/634 batches.
# INFO:utils.ml:Feature extraction completed. Extracted 15195 features.
# Processed 634/634 batches.

# %%
from xgboost import XGBClassifier
from sklearn.ensemble import RandomForestClassifier

rf1 = RandomForestClassifier(n_estimators=100)
rf2 = RandomForestClassifier(n_estimators=150)
rf3 = RandomForestClassifier(n_estimators=250)

rf4 = RandomForestClassifier(n_estimators=100, max_features='sqrt', random_state=42) # Random Forest with Feature Selection via max_features

rf5 = RandomForestClassifier(n_estimators=100, oob_score=True, random_state=42) # Random Forest with Out-of-Bag Error (OOB)

rf6 = RandomForestClassifier(n_estimators=100, bootstrap=False, random_state=42) # Random Forest with Bootstrap Disabled

xgb1 = XGBClassifier(n_estimators=350)
xgb2 = XGBClassifier(n_estimators=450)
xgb3 = XGBClassifier(n_estimators=550)
xgb4 = XGBClassifier(learning_rate=0.05, n_estimators=400, max_depth=3, min_child_weight=1, subsample=0.8, colsample_bytree=0.8)
xgb5 = XGBClassifier(learning_rate=0.1, n_estimators=400, max_depth=7, min_child_weight=3, subsample=0.7, colsample_bytree=0.7)
xgb6 = XGBClassifier(learning_rate=0.1, n_estimators=400, max_depth=5, min_child_weight=5, gamma=0.2, subsample=0.8, colsample_bytree=0.8)
xgb7 = XGBClassifier(learning_rate=0.1, n_estimators=400, max_depth=5, min_child_weight=1, subsample=0.8, colsample_bytree=0.8, reg_alpha=0.1, reg_lambda=0.1)
xgb8 = XGBClassifier(learning_rate=0.05, n_estimators=500, max_depth=7, min_child_weight=1, subsample=0.8, colsample_bytree=0.8)
xgb9 = XGBClassifier(learning_rate=0.05, n_estimators=400, max_depth=7, min_child_weight=1, subsample=0.8, colsample_bytree=0.8)
xgb10 = XGBClassifier(learning_rate=0.1, n_estimators=400, max_depth=7, min_child_weight=1, subsample=0.8, colsample_bytree=0.8)
xgb11 = XGBClassifier(learning_rate=0.1, n_estimators=500, max_depth=7, min_child_weight=1, subsample=0.8, colsample_bytree=0.8)

pipeline.classifiers = [rf1, rf2, rf3, rf4, rf5, rf6,# rf7, rf8, rf9,
                        # svm1, svm2, svm3, svm6, svm7, svm8,
                        xgb1, xgb2, xgb3, xgb4, xgb5, xgb6, xgb7, xgb8, xgb9, xgb10, xgb11]
pipeline.fitted_classifiers = {}

# %%
pipeline.fit_classifiers()
# Out:
# INFO:utils.ml:Fitting classifiers...
# INFO:utils.ml:Fitting classifier: RandomForestClassifier0
# INFO:utils.ml:Top 10 features for RandomForestClassifier0: [('lbp_rad2_bins16_1', 0.02040152972418565), ('lbp_rad1_bins8_4', 0.01759584356072889), ('color_moments_hsv_S_min', 0.015446892627852014), ('color_moments_lab_B_skew', 0.015004235016111733), ('color_moments_hsv_H_max', 0.01499114797637519), ('color_moments_rgb_G_max', 0.014243423671658963), ('color_moments_lab_L_median', 0.013394467120554665), ('color_moments_lab_A_mean', 0.013262361544389367), ('lbp_rad2_bins16_8', 0.012688590086352354), ('color_moments_hsv_S_iqr', 0.011518116668290604)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier0; Done in 13.393831014633179 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier1
# INFO:utils.ml:Top 10 features for RandomForestClassifier1: [('lbp_rad2_bins16_1', 0.017174236522841425), ('lbp_rad1_bins8_4', 0.015010755826093973), ('color_moments_lab_A_mean', 0.014766293015098061), ('color_moments_rgb_G_max', 0.0139930918158822), ('color_moments_lab_B_skew', 0.01378075905966971), ('color_moments_hsv_H_max', 0.01363987027308583), ('color_moments_hsv_S_min', 0.013424914572537725), ('color_moments_lab_A_median', 0.012929305785995462), ('color_moments_lab_A_min', 0.012327791527307685), ('color_moments_hsv_V_median', 0.011810845890488697)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier1; Done in 19.85888409614563 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier2
# INFO:utils.ml:Top 10 features for RandomForestClassifier2: [('lbp_rad2_bins16_1', 0.01973468513687504), ('lbp_rad1_bins8_4', 0.016375816594002748), ('color_moments_rgb_G_max', 0.015344868028167657), ('color_moments_lab_B_skew', 0.013811516435283125), ('color_moments_hsv_S_min', 0.013600046993658058), ('color_moments_lab_A_median', 0.01344730355836652), ('color_moments_lab_A_mean', 0.01321304007353871), ('color_moments_hsv_V_median', 0.013174813297424632), ('color_moments_hsv_H_max', 0.012705166637301342), ('color_moments_lab_L_max', 0.012090063774745282)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier2; Done in 34.83949947357178 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier3
# INFO:utils.ml:Top 10 features for RandomForestClassifier3: [('lbp_rad2_bins16_1', 0.021613755502420312), ('color_moments_hsv_S_min', 0.01984156993687339), ('lbp_rad1_bins8_4', 0.017085182284783375), ('color_moments_lab_B_skew', 0.016579729520172577), ('color_moments_rgb_G_max', 0.016332250884157327), ('color_moments_lab_A_mean', 0.016069549798976512), ('color_moments_hsv_H_max', 0.014461702026700598), ('color_moments_lab_A_median', 0.014393502497115528), ('glcm_correlation_dist_1_angle_0', 0.010536275486584033), ('color_moments_lab_A_iqr', 0.01050455537962727)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier3; Done in 15.003019094467163 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier4
# INFO:utils.ml:Top 10 features for RandomForestClassifier4: [('lbp_rad2_bins16_1', 0.021613755502420312), ('color_moments_hsv_S_min', 0.01984156993687339), ('lbp_rad1_bins8_4', 0.017085182284783375), ('color_moments_lab_B_skew', 0.016579729520172577), ('color_moments_rgb_G_max', 0.016332250884157327), ('color_moments_lab_A_mean', 0.016069549798976512), ('color_moments_hsv_H_max', 0.014461702026700598), ('color_moments_lab_A_median', 0.014393502497115528), ('glcm_correlation_dist_1_angle_0', 0.010536275486584033), ('color_moments_lab_A_iqr', 0.01050455537962727)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier4; Done in 15.701600074768066 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier5
# INFO:utils.ml:Top 10 features for RandomForestClassifier5: [('lbp_rad2_bins16_1', 0.022701394697977287), ('lbp_rad1_bins8_4', 0.022132562838811033), ('color_moments_hsv_S_min', 0.020964834377026828), ('color_moments_lab_A_mean', 0.01700141173379697), ('color_moments_lab_B_skew', 0.015821219062835103), ('color_moments_hsv_H_max', 0.015472122088763524), ('color_moments_rgb_G_max', 0.014353421811696234), ('color_moments_lab_A_median', 0.0139909626584384), ('color_moments_lab_L_median', 0.01235872162864412), ('glcm_correlation_dist_1_angle_0', 0.011373200395712166)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier5; Done in 27.324405670166016 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier6
# INFO:utils.ml:Top 10 features for XGBClassifier6: [('color_moments_hsv_S_min', 0.1131283), ('lbp_rad2_bins16_1', 0.06485581), ('glcm_correlation_dist_1_angle_0', 0.031397376), ('color_moments_lab_B_skew', 0.01908764), ('lbp_rad1_bins8_3', 0.019085504), ('color_moments_lab_A_mean', 0.018253502), ('color_moments_lab_L_median', 0.017052159), ('lbp_rad1_bins8_4', 0.01508129), ('color_moments_hsv_H_max', 0.012977758), ('color_moments_hsv_H_min', 0.010805926)]
# INFO:utils.ml:Fitted classifier: XGBClassifier6; Done in 10.630807638168335 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier7
# INFO:utils.ml:Top 10 features for XGBClassifier7: [('color_moments_hsv_S_min', 0.11765575), ('lbp_rad2_bins16_1', 0.066496514), ('glcm_correlation_dist_1_angle_0', 0.030477831), ('color_moments_lab_A_mean', 0.018935664), ('color_moments_lab_B_skew', 0.018731192), ('lbp_rad1_bins8_3', 0.018439488), ('color_moments_lab_L_median', 0.015464175), ('lbp_rad1_bins8_4', 0.014245041), ('color_moments_hsv_H_max', 0.013224921), ('color_moments_hsv_H_min', 0.011927771)]
# INFO:utils.ml:Fitted classifier: XGBClassifier7; Done in 14.998483896255493 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier8
# INFO:utils.ml:Top 10 features for XGBClassifier8: [('color_moments_hsv_S_min', 0.11459335), ('lbp_rad2_bins16_1', 0.062937915), ('glcm_correlation_dist_1_angle_0', 0.0314727), ('color_moments_lab_A_mean', 0.019486068), ('lbp_rad1_bins8_3', 0.019238103), ('color_moments_lab_B_skew', 0.01885561), ('color_moments_lab_L_median', 0.016089529), ('lbp_rad1_bins8_4', 0.01537676), ('color_moments_hsv_H_max', 0.013907016), ('color_moments_hsv_H_min', 0.012637345)]
# INFO:utils.ml:Fitted classifier: XGBClassifier8; Done in 16.553621768951416 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier9
# INFO:utils.ml:Top 10 features for XGBClassifier9: [('color_moments_hsv_S_min', 0.06789381), ('lbp_rad2_bins16_1', 0.0424138), ('lbp_rad1_bins8_4', 0.040998172), ('glcm_correlation_dist_1_angle_0', 0.027533798), ('color_moments_lab_L_median', 0.022802552), ('color_moments_rgb_G_median', 0.021387566), ('color_moments_lab_A_mean', 0.017420437), ('color_moments_lab_B_skew', 0.017089078), ('color_moments_hsv_V_median', 0.0165187), ('color_moments_rgb_B_median', 0.015511074)]
# INFO:utils.ml:Fitted classifier: XGBClassifier9; Done in 5.991645574569702 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier10
# INFO:utils.ml:Top 10 features for XGBClassifier10: [('color_moments_hsv_S_min', 0.08933723), ('lbp_rad2_bins16_1', 0.023902444), ('lbp_rad1_bins8_4', 0.019224357), ('glcm_correlation_dist_1_angle_0', 0.014746856), ('color_moments_lab_A_mean', 0.0139786685), ('color_moments_lab_L_median', 0.013467026), ('color_moments_rgb_G_median', 0.012804778), ('color_moments_lab_B_skew', 0.012074271), ('lbp_rad1_bins8_3', 0.01090475), ('color_moments_hsv_H_max', 0.009834109)]
# INFO:utils.ml:Fitted classifier: XGBClassifier10; Done in 14.60257601737976 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier11
# INFO:utils.ml:Top 10 features for XGBClassifier11: [('color_moments_hsv_S_min', 0.11035376), ('lbp_rad2_bins16_1', 0.033507284), ('lbp_rad1_bins8_4', 0.020052673), ('glcm_correlation_dist_1_angle_0', 0.018713089), ('color_moments_lab_A_mean', 0.018559787), ('color_moments_rgb_G_median', 0.016040768), ('lbp_rad1_bins8_3', 0.0147054205), ('color_moments_lab_B_skew', 0.013661792), ('lbp_rad3_bins24_6', 0.012403573), ('color_moments_lab_L_median', 0.012081106)]
# INFO:utils.ml:Fitted classifier: XGBClassifier11; Done in 8.911911249160767 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier12
# INFO:utils.ml:Top 10 features for XGBClassifier12: [('color_moments_hsv_S_min', 0.094307184), ('lbp_rad2_bins16_1', 0.037477575), ('lbp_rad1_bins8_4', 0.019283371), ('glcm_correlation_dist_1_angle_0', 0.017753884), ('color_moments_lab_A_mean', 0.017092858), ('color_moments_lab_L_median', 0.016620785), ('color_moments_rgb_G_median', 0.014532266), ('lbp_rad1_bins8_3', 0.014400651), ('color_moments_lab_B_skew', 0.014335787), ('color_moments_hsv_H_max', 0.0131244445)]
# INFO:utils.ml:Fitted classifier: XGBClassifier12; Done in 9.456392288208008 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier13
# INFO:utils.ml:Top 10 features for XGBClassifier13: [('color_moments_hsv_S_min', 0.09806796), ('lbp_rad2_bins16_1', 0.039796535), ('lbp_rad1_bins8_4', 0.01892015), ('glcm_correlation_dist_1_angle_0', 0.017572353), ('color_moments_lab_A_mean', 0.01580747), ('color_moments_lab_L_median', 0.014414298), ('lbp_rad1_bins8_3', 0.014003713), ('color_moments_lab_B_skew', 0.013857921), ('color_moments_hsv_H_max', 0.011943058), ('color_moments_rgb_G_median', 0.009944333)]
# INFO:utils.ml:Fitted classifier: XGBClassifier13; Done in 24.73633337020874 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier14
# INFO:utils.ml:Top 10 features for XGBClassifier14: [('color_moments_hsv_S_min', 0.10252626), ('lbp_rad2_bins16_1', 0.040087804), ('lbp_rad1_bins8_4', 0.019025562), ('glcm_correlation_dist_1_angle_0', 0.017276715), ('color_moments_lab_A_mean', 0.015909526), ('color_moments_lab_L_median', 0.014878837), ('lbp_rad1_bins8_3', 0.01403912), ('color_moments_lab_B_skew', 0.013763208), ('color_moments_hsv_H_max', 0.011595327), ('color_moments_rgb_G_median', 0.010300168)]
# INFO:utils.ml:Fitted classifier: XGBClassifier14; Done in 18.6564724445343 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier15
# INFO:utils.ml:Top 10 features for XGBClassifier15: [('color_moments_hsv_S_min', 0.09209363), ('lbp_rad2_bins16_1', 0.033440325), ('lbp_rad1_bins8_4', 0.019887144), ('color_moments_lab_A_mean', 0.017913286), ('glcm_correlation_dist_1_angle_0', 0.01647141), ('lbp_rad1_bins8_3', 0.015264629), ('color_moments_lab_L_median', 0.014735607), ('color_moments_lab_B_skew', 0.014053978), ('color_moments_hsv_H_max', 0.011268743), ('color_moments_rgb_B_median', 0.008909569)]
# INFO:utils.ml:Fitted classifier: XGBClassifier15; Done in 17.597819566726685 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier16
# INFO:utils.ml:Top 10 features for XGBClassifier16: [('color_moments_hsv_S_min', 0.09032273), ('lbp_rad2_bins16_1', 0.033763338), ('lbp_rad1_bins8_4', 0.020780414), ('color_moments_lab_A_mean', 0.018241998), ('glcm_correlation_dist_1_angle_0', 0.016552348), ('lbp_rad1_bins8_3', 0.015151567), ('color_moments_lab_L_median', 0.01457546), ('color_moments_lab_B_skew', 0.014192121), ('color_moments_hsv_H_max', 0.011691867), ('color_moments_rgb_B_median', 0.009243264)]
# INFO:utils.ml:Fitted classifier: XGBClassifier16; Done in 19.99379587173462 seconds
# INFO:utils.ml:Fitting completed in 288.27 seconds.

# %%
pipeline.predict_with_classifiers(VAL_PATH)
# Out:
# INFO:utils.ml:Predicting with classifiers on dataset: C:\Users\gimes\Src\repos\CADx-Project\dataset\binary\val
# Processed 5/159 batches.
# Processed 10/159 batches.
# Processed 15/159 batches.
# Processed 20/159 batches.
# Processed 25/159 batches.
# Processed 30/159 batches.
# Processed 35/159 batches.
# Processed 40/159 batches.
# Processed 45/159 batches.
# Processed 50/159 batches.
# Processed 55/159 batches.
# Processed 60/159 batches.
# Processed 65/159 batches.
# Processed 70/159 batches.
# Processed 75/159 batches.
# Processed 80/159 batches.
# Processed 85/159 batches.
# Processed 90/159 batches.
# Processed 95/159 batches.
# Processed 100/159 batches.
# Processed 105/159 batches.
# Processed 110/159 batches.
# Processed 115/159 batches.
# Processed 120/159 batches.
# Processed 125/159 batches.
# Processed 130/159 batches.
# Processed 135/159 batches.
# Processed 140/159 batches.
# Processed 145/159 batches.
# Processed 150/159 batches.
# Processed 155/159 batches.
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier0
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier1
# Processed 159/159 batches.
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier2
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier3
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier4
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier5
# INFO:utils.ml:Predictions made with classifier: XGBClassifier6
# INFO:utils.ml:Predictions made with classifier: XGBClassifier7
# INFO:utils.ml:Predictions made with classifier: XGBClassifier8
# INFO:utils.ml:Predictions made with classifier: XGBClassifier9
# INFO:utils.ml:Predictions made with classifier: XGBClassifier10
# INFO:utils.ml:Predictions made with classifier: XGBClassifier11
# INFO:utils.ml:Predictions made with classifier: XGBClassifier12
# INFO:utils.ml:Predictions made with classifier: XGBClassifier13
# INFO:utils.ml:Predictions made with classifier: XGBClassifier14
# INFO:utils.ml:Predictions made with classifier: XGBClassifier15
# INFO:utils.ml:Predictions made with classifier: XGBClassifier16
# {'GT': array([0, 0, 0, ..., 1, 1, 1]),
#  'RandomForestClassifier0': array([0, 0, 0, ..., 0, 0, 1]),
#  'RandomForestClassifier1': array([0, 0, 0, ..., 0, 0, 1]),
#  'RandomForestClassifier2': array([0, 0, 0, ..., 0, 0, 1]),
#  'RandomForestClassifier3': array([0, 0, 0, ..., 0, 0, 1]),
#  'RandomForestClassifier4': array([0, 0, 0, ..., 0, 0, 1]),
#  'RandomForestClassifier5': array([0, 0, 0, ..., 0, 0, 1]),
#  'XGBClassifier6': array([0, 0, 1, ..., 0, 0, 1]),
#  'XGBClassifier7': array([0, 0, 1, ..., 0, 0, 1]),
#  'XGBClassifier8': array([0, 0, 1, ..., 0, 0, 1]),
#  'XGBClassifier9': array([0, 0, 1, ..., 0, 0, 1]),
#  'XGBClassifier10': array([0, 0, 1, ..., 0, 0, 1]),
#  'XGBClassifier11': array([0, 0, 1, ..., 0, 0, 1]),
#  'XGBClassifier12': array([0, 0, 1, ..., 0, 0, 1]),
#  'XGBClassifier13': array([0, 0, 1, ..., 1, 0, 1]),
#  'XGBClassifier14': array([0, 0, 1, ..., 1, 0, 1]),
#  'XGBClassifier15': array([0, 0, 1, ..., 0, 0, 1]),
#  'XGBClassifier16': array([0, 0, 1, ..., 0, 0, 1])}

# %%
import pandas as pd

df = pd.DataFrame(data=pipeline.calculate_metrics())
df = df.T
df
# Out:
# INFO:utils.ml:Metrics for classifier GT: {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'kappa': 1.0}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier0: {'accuracy': 0.8258693361433087, 'precision': 0.8258500431076625, 'recall': 0.8257571192744873, 'f1': 0.8257938851137321, 'kappa': 0.6515918582260033}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier1: {'accuracy': 0.8269230769230769, 'precision': 0.8268811801480183, 'recall': 0.8269669551261136, 'f1': 0.8268987508043503, 'kappa': 0.6538080981496988}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier2: {'accuracy': 0.8319283456269758, 'precision': 0.8318745778437404, 'recall': 0.8319416657526487, 'f1': 0.8318968006468006, 'kappa': 0.66379817517853}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier3: {'accuracy': 0.8248155953635405, 'precision': 0.8247613414857637, 'recall': 0.8247672030910931, 'f1': 0.8247642150081174, 'kappa': 0.6495284543454285}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier4: {'accuracy': 0.8248155953635405, 'precision': 0.8247613414857637, 'recall': 0.8247672030910931, 'f1': 0.8247642150081174, 'kappa': 0.6495284543454285}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier5: {'accuracy': 0.8321917808219178, 'precision': 0.8322133592333132, 'recall': 0.8320448225162198, 'f1': 0.8321035891634015, 'kappa': 0.6642174602054867}
# INFO:utils.ml:Metrics for classifier XGBClassifier6: {'accuracy': 0.8234984193888304, 'precision': 0.8263012836983091, 'recall': 0.8226661649980631, 'f1': 0.822813558944177, 'kappa': 0.6463391740979864}
# INFO:utils.ml:Metrics for classifier XGBClassifier7: {'accuracy': 0.8258693361433087, 'precision': 0.8283499834527168, 'recall': 0.8250881969502806, 'f1': 0.8252554096593556, 'kappa': 0.6511250621512162}
# INFO:utils.ml:Metrics for classifier XGBClassifier8: {'accuracy': 0.8274499473129611, 'precision': 0.8297058075161101, 'recall': 0.8267059393582622, 'f1': 0.8268842244822238, 'kappa': 0.6543172321131642}
# INFO:utils.ml:Metrics for classifier XGBClassifier9: {'accuracy': 0.8134878819810326, 'precision': 0.8136514225734921, 'recall': 0.8132298896375352, 'f1': 0.8133311329537678, 'kappa': 0.6267124610019881}
# INFO:utils.ml:Metrics for classifier XGBClassifier10: {'accuracy': 0.8311380400421496, 'precision': 0.8318803504547887, 'recall': 0.8306975368719482, 'f1': 0.8308704185047212, 'kappa': 0.6619106241194272}
# INFO:utils.ml:Metrics for classifier XGBClassifier11: {'accuracy': 0.821917808219178, 'precision': 0.8230548694314035, 'recall': 0.8213691387729205, 'f1': 0.8215428524535897, 'kappa': 0.6433749862066608}
# INFO:utils.ml:Metrics for classifier XGBClassifier12: {'accuracy': 0.8221812434141201, 'precision': 0.8222990162067922, 'recall': 0.8219579514705045, 'f1': 0.8220502288803666, 'kappa': 0.6441342920490409}
# INFO:utils.ml:Metrics for classifier XGBClassifier13: {'accuracy': 0.8321917808219178, 'precision': 0.8327143870622131, 'recall': 0.8318157395284778, 'f1': 0.8319729200095033, 'kappa': 0.6640635159151003}
# INFO:utils.ml:Metrics for classifier XGBClassifier14: {'accuracy': 0.8319283456269758, 'precision': 0.8322052949241192, 'recall': 0.8316392762088293, 'f1': 0.8317657810406058, 'kappa': 0.6635947504152546}
# INFO:utils.ml:Metrics for classifier XGBClassifier15: {'accuracy': 0.8356164383561644, 'precision': 0.8360773511573641, 'recall': 0.8352643409421281, 'f1': 0.8354174263378366, 'kappa': 0.6709344490081928}
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# INFO:utils.ml:Metrics for classifier XGBClassifier16: {'accuracy': 0.8369336143308747, 'precision': 0.8373569654579721, 'recall': 0.8365956601963449, 'f1': 0.8367450787623822, 'kappa': 0.6735801709029361}
# cannot access local variable 'report' where it is not associated with a value
#                          accuracy  precision    recall        f1     kappa
# GT                       1.000000   1.000000  1.000000  1.000000  1.000000
# RandomForestClassifier0  0.825869   0.825850  0.825757  0.825794  0.651592
# RandomForestClassifier1  0.826923   0.826881  0.826967  0.826899  0.653808
# RandomForestClassifier2  0.831928   0.831875  0.831942  0.831897  0.663798
# RandomForestClassifier3  0.824816   0.824761  0.824767  0.824764  0.649528
# RandomForestClassifier4  0.824816   0.824761  0.824767  0.824764  0.649528
# RandomForestClassifier5  0.832192   0.832213  0.832045  0.832104  0.664217
# XGBClassifier6           0.823498   0.826301  0.822666  0.822814  0.646339
# XGBClassifier7           0.825869   0.828350  0.825088  0.825255  0.651125
# XGBClassifier8           0.827450   0.829706  0.826706  0.826884  0.654317
# XGBClassifier9           0.813488   0.813651  0.813230  0.813331  0.626712
# XGBClassifier10          0.831138   0.831880  0.830698  0.830870  0.661911
# XGBClassifier11          0.821918   0.823055  0.821369  0.821543  0.643375
# XGBClassifier12          0.822181   0.822299  0.821958  0.822050  0.644134
# XGBClassifier13          0.832192   0.832714  0.831816  0.831973  0.664064
# XGBClassifier14          0.831928   0.832205  0.831639  0.831766  0.663595
# XGBClassifier15          0.835616   0.836077  0.835264  0.835417  0.670934
# XGBClassifier16          0.836934   0.837357  0.836596  0.836745  0.673580

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

highest = df[df["accuracy"] == df.iloc[1:]["accuracy"].max()]
idx = highest.index[0]

print(classification_report(pipeline.predictions["GT"], pipeline.predictions[idx]))
print(confusion_matrix(pipeline.predictions["GT"], pipeline.predictions[idx]))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.86      0.84      1931
#            1       0.85      0.82      0.83      1865
#
#     accuracy                           0.84      3796
#    macro avg       0.84      0.84      0.84      3796
# weighted avg       0.84      0.84      0.84      3796
#
# [[1653  278]
#  [ 341 1524]]
