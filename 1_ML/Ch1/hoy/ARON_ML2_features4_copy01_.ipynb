# %%
from utils.loader import FactoryLoader
from utils.ml import MLPipeline
from utils.preprocessing import PreprocessingFactory
from utils.feature_extraction import *
from utils.utils import *

VAL_PATH = r"C:\Users\gimes\Src\repos\CADx-Project\dataset\binary\val"
TRAIN_PATH = r"C:\Users\gimes\Src\repos\CADx-Project\dataset\binary\train"

# %%
percent = 100
random = False
batch_size = 24
th = 0.1

# Initialize the FactoryLoader
factory = PreprocessingFactory()
factory.pad2square(fill=np.nan)
factory.resize((300,300))
factory.normalize2float()


# Create the feature extraction pipeline strategy and add desired features
strategy = FeatureExtractionStrategy()

strategy.add_extractor(GradientExtractor(threshold=th)) # Add gradient feature

strategy.add_extractor(ColorMomentsExtractor("rgb", threshold=th))   # Add color moments feature
strategy.add_extractor(ColorMomentsExtractor("lab", threshold=th))   # Add color moments feature
strategy.add_extractor(ColorMomentsExtractor("hsv", threshold=th))   # Add color moments feature

strategy.add_extractor(LBPExtractor(radius=1, n_points=8))
strategy.add_extractor(LBPExtractor(radius=2, n_points=16))
strategy.add_extractor(LBPExtractor(radius=3, n_points=24))
strategy.add_extractor(LBPExtractor(radius=4, n_points=32))

strategy.add_extractor(FourierTransformExtractor())
strategy.add_extractor(FFTExtractor())

strategy.add_extractor(GLCMExtractor(properties=['contrast', 'dissimilarity', 'homogeneity', 'energy', 'correlation',]))

pipeline = MLPipeline(dataset_path=TRAIN_PATH, preprocessing_factory=factory, feature_strategy=strategy, classifiers=[], percentage=percent, verbose=True, shuffle=random, batch_size=batch_size)
# Out:
# INFO:utils.ml:MLPipeline initialized with dataset path: C:\Users\gimes\Src\repos\CADx-Project\dataset\binary\train
# INFO:utils.ml:Preprocessing steps

# %%
pipeline.run_feature_extraction()
# Out:
# INFO:utils.ml:Running feature extraction...
# Processed 5/634 batches.
# Processed 10/634 batches.
# Processed 15/634 batches.
# Processed 20/634 batches.
# Processed 25/634 batches.
# Processed 30/634 batches.
# Processed 35/634 batches.
# Processed 40/634 batches.
# Processed 45/634 batches.
# Processed 50/634 batches.
# Processed 55/634 batches.
# Processed 60/634 batches.
# Processed 65/634 batches.
# Processed 70/634 batches.
# Processed 75/634 batches.
# Processed 80/634 batches.
# Processed 85/634 batches.
# Processed 90/634 batches.
# Processed 95/634 batches.
# Processed 100/634 batches.
# Processed 105/634 batches.
# Processed 110/634 batches.
# Processed 115/634 batches.
# Processed 120/634 batches.
# Processed 125/634 batches.
# Processed 130/634 batches.
# Processed 135/634 batches.
# Processed 140/634 batches.
# Processed 145/634 batches.
# Processed 150/634 batches.
# Processed 155/634 batches.
# Processed 160/634 batches.
# Processed 165/634 batches.
# Processed 170/634 batches.
# Processed 175/634 batches.
# Processed 180/634 batches.
# Processed 185/634 batches.
# Processed 190/634 batches.
# Processed 195/634 batches.
# Processed 200/634 batches.
# Processed 205/634 batches.
# Processed 210/634 batches.
# Processed 215/634 batches.
# Processed 220/634 batches.
# Processed 225/634 batches.
# Processed 230/634 batches.
# Processed 235/634 batches.
# Processed 240/634 batches.
# Processed 245/634 batches.
# Processed 250/634 batches.
# Processed 255/634 batches.
# Processed 260/634 batches.
# Processed 265/634 batches.
# Processed 270/634 batches.
# Processed 275/634 batches.
# Processed 280/634 batches.
# Processed 285/634 batches.
# Processed 290/634 batches.
# Processed 295/634 batches.
# Processed 300/634 batches.
# Processed 305/634 batches.
# Processed 310/634 batches.
# Processed 315/634 batches.
# Processed 320/634 batches.
# Processed 325/634 batches.
# Processed 330/634 batches.
# Processed 335/634 batches.
# Processed 340/634 batches.
# Processed 345/634 batches.
# Processed 350/634 batches.
# Processed 355/634 batches.
# Processed 360/634 batches.
# Processed 365/634 batches.
# Processed 370/634 batches.
# Processed 375/634 batches.
# Processed 380/634 batches.
# Processed 385/634 batches.
# Processed 390/634 batches.
# Processed 395/634 batches.
# Processed 400/634 batches.
# Processed 405/634 batches.
# Processed 410/634 batches.
# Processed 415/634 batches.
# Processed 420/634 batches.
# Processed 425/634 batches.
# Processed 430/634 batches.
# Processed 435/634 batches.
# Processed 440/634 batches.
# Processed 445/634 batches.
# Processed 450/634 batches.
# Processed 455/634 batches.
# Processed 460/634 batches.
# Processed 465/634 batches.
# Processed 470/634 batches.
# Processed 475/634 batches.
# Processed 480/634 batches.
# Processed 485/634 batches.
# Processed 490/634 batches.
# Processed 495/634 batches.
# Processed 500/634 batches.
# Processed 505/634 batches.
# Processed 510/634 batches.
# Processed 515/634 batches.
# Processed 520/634 batches.
# Processed 525/634 batches.
# Processed 530/634 batches.
# Processed 535/634 batches.
# Processed 540/634 batches.
# Processed 545/634 batches.
# Processed 550/634 batches.
# Processed 555/634 batches.
# Processed 560/634 batches.
# Processed 565/634 batches.
# Processed 570/634 batches.
# Processed 575/634 batches.
# Processed 580/634 batches.
# Processed 585/634 batches.
# Processed 590/634 batches.
# Processed 595/634 batches.
# Processed 600/634 batches.
# Processed 605/634 batches.
# Processed 610/634 batches.
# Processed 615/634 batches.
# Processed 620/634 batches.
# Processed 625/634 batches.
# Processed 630/634 batches.
# INFO:utils.ml:Feature extraction completed. Extracted 15195 features.
# Processed 634/634 batches.

# %%
from xgboost import XGBClassifier
from sklearn.ensemble import RandomForestClassifier

rf0 = RandomForestClassifier(n_estimators=300, max_features='sqrt', random_state=42) # Random Forest with Feature Selection via max_features
rf1 = RandomForestClassifier(n_estimators=300, oob_score=True, random_state=42) # Random Forest with Out-of-Bag Error (OOB)
rf2 = RandomForestClassifier(n_estimators=300, bootstrap=False, random_state=42) # Random Forest with Bootstrap Disabled
rf3 = RandomForestClassifier(n_estimators=100, max_features='sqrt', random_state=42) # Random Forest with Feature Selection via max_features
rf4 = RandomForestClassifier(n_estimators=100, oob_score=True, random_state=42) # Random Forest with Out-of-Bag Error (OOB)
rf5 = RandomForestClassifier(n_estimators=100, bootstrap=False, random_state=42) # Random Forest with Bootstrap Disabled

xgb6 = XGBClassifier(n_estimators=350)
xgb7 = XGBClassifier(n_estimators=450)
xgb8 = XGBClassifier(n_estimators=550)
xgb9 = XGBClassifier(learning_rate=0.1, n_estimators=400, max_depth=7, min_child_weight=3, subsample=0.7, colsample_bytree=0.7)
xgb10 = XGBClassifier(learning_rate=0.1, n_estimators=400, max_depth=7, min_child_weight=1, subsample=0.8, colsample_bytree=0.8)
xgb11 = XGBClassifier(learning_rate=0.1, n_estimators=500, max_depth=7, min_child_weight=1, subsample=0.8, colsample_bytree=0.8)
xgb12 = XGBClassifier(learning_rate=0.1, n_estimators=500, min_child_weight=1, subsample=0.8, colsample_bytree=0.8)
xgb13 = XGBClassifier(learning_rate=0.1, n_estimators=750, max_depth=7, min_child_weight=3, subsample=0.7, colsample_bytree=0.7)
xgb14 = XGBClassifier(learning_rate=0.1, n_estimators=750, max_depth=7, min_child_weight=1, subsample=0.8, colsample_bytree=0.8)
xgb15 = XGBClassifier(learning_rate=0.1, n_estimators=750, max_depth=7, min_child_weight=1, subsample=0.8, colsample_bytree=0.8)
xgb16 = XGBClassifier(learning_rate=0.1, n_estimators=750, min_child_weight=1, subsample=0.8, colsample_bytree=0.8)
xgb17 = XGBClassifier(learning_rate=0.1, n_estimators=1000, max_depth=7, min_child_weight=3, subsample=0.7, colsample_bytree=0.7)
xgb18 = XGBClassifier(learning_rate=0.1, n_estimators=1000, max_depth=7, min_child_weight=1, subsample=0.8, colsample_bytree=0.8)
xgb19 = XGBClassifier(learning_rate=0.1, n_estimators=1000, max_depth=7, min_child_weight=1, subsample=0.8, colsample_bytree=0.8)
xgb20 = XGBClassifier(learning_rate=0.1, n_estimators=1000, min_child_weight=1, subsample=0.8, colsample_bytree=0.8)



pipeline.classifiers = [rf0, rf1, rf2, rf3, rf4, rf5, 
                        # svm1, svm2, svm3, svm6, svm7, svm8,
                       xgb6, xgb7, xgb8, xgb9, xgb10, xgb11, xgb12, xgb13, xgb14, xgb15, xgb16, xgb17, xgb18, xgb19, xgb20 ]
pipeline.fitted_classifiers = {}

# %%
pipeline.fit_classifiers()
# Out:
# INFO:utils.ml:Fitting classifiers...
# INFO:utils.ml:Fitting classifier: RandomForestClassifier0
# INFO:utils.ml:Top 10 features for RandomForestClassifier0: [('color_moments_lab_A_min', 0.02282289525210082), ('color_moments_hsv_H_max', 0.019188947131887537), ('color_moments_lab_A_mean', 0.01849210921952182), ('color_moments_hsv_S_min', 0.018254125280471212), ('color_moments_lab_A_median', 0.017784948527625678), ('color_moments_lab_B_skew', 0.01586863306239568), ('color_moments_hsv_V_min', 0.014893593215073891), ('lbp_rad1_bins8_4', 0.013265645781796504), ('glcm_correlation_dist_1_angle_0', 0.012211291804825814), ('color_moments_lab_L_min', 0.011984387170728318)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier0; Done in 43.19293999671936 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier1
# INFO:utils.ml:Top 10 features for RandomForestClassifier1: [('color_moments_lab_A_min', 0.02282289525210082), ('color_moments_hsv_H_max', 0.019188947131887537), ('color_moments_lab_A_mean', 0.01849210921952182), ('color_moments_hsv_S_min', 0.018254125280471212), ('color_moments_lab_A_median', 0.017784948527625678), ('color_moments_lab_B_skew', 0.01586863306239568), ('color_moments_hsv_V_min', 0.014893593215073891), ('lbp_rad1_bins8_4', 0.013265645781796504), ('glcm_correlation_dist_1_angle_0', 0.012211291804825814), ('color_moments_lab_L_min', 0.011984387170728318)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier1; Done in 41.00695586204529 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier2
# INFO:utils.ml:Top 10 features for RandomForestClassifier2: [('color_moments_lab_A_min', 0.02302112476601101), ('color_moments_hsv_S_min', 0.019228845372494738), ('color_moments_hsv_H_max', 0.019019428758591108), ('color_moments_lab_A_mean', 0.018359624201356037), ('color_moments_lab_A_median', 0.017141502570638043), ('color_moments_lab_B_skew', 0.01667491530286551), ('color_moments_hsv_V_min', 0.014332119165293502), ('glcm_correlation_dist_1_angle_0', 0.012796644634949996), ('color_moments_lab_A_iqr', 0.01236352860870788), ('lbp_rad1_bins8_4', 0.012311858092424405)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier2; Done in 58.28363871574402 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier3
# INFO:utils.ml:Top 10 features for RandomForestClassifier3: [('color_moments_lab_A_median', 0.02144506612545378), ('color_moments_lab_A_min', 0.02128855589835461), ('color_moments_lab_A_mean', 0.020105972545896907), ('color_moments_hsv_S_min', 0.01965945016798059), ('color_moments_hsv_H_max', 0.01934105686085631), ('color_moments_lab_B_skew', 0.017735858652316836), ('lbp_rad1_bins8_4', 0.01709737664626151), ('color_moments_hsv_V_min', 0.01588119081431671), ('glcm_correlation_dist_1_angle_0', 0.012955117082545793), ('color_moments_lab_L_min', 0.01215278673337255)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier3; Done in 13.160383462905884 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier4
# INFO:utils.ml:Top 10 features for RandomForestClassifier4: [('color_moments_lab_A_median', 0.02144506612545378), ('color_moments_lab_A_min', 0.02128855589835461), ('color_moments_lab_A_mean', 0.020105972545896907), ('color_moments_hsv_S_min', 0.01965945016798059), ('color_moments_hsv_H_max', 0.01934105686085631), ('color_moments_lab_B_skew', 0.017735858652316836), ('lbp_rad1_bins8_4', 0.01709737664626151), ('color_moments_hsv_V_min', 0.01588119081431671), ('glcm_correlation_dist_1_angle_0', 0.012955117082545793), ('color_moments_lab_L_min', 0.01215278673337255)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier4; Done in 13.397649049758911 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier5
# INFO:utils.ml:Top 10 features for RandomForestClassifier5: [('color_moments_hsv_S_min', 0.021376990441713976), ('color_moments_lab_A_min', 0.02088511854284467), ('color_moments_lab_B_skew', 0.0194856671100518), ('color_moments_lab_A_median', 0.01937290846177319), ('color_moments_hsv_H_max', 0.01819738873439365), ('color_moments_lab_A_mean', 0.01798164046118561), ('color_moments_hsv_V_min', 0.015939761939829853), ('lbp_rad1_bins8_4', 0.015660657569800174), ('glcm_correlation_dist_1_angle_0', 0.01491171627449348), ('lbp_rad4_bins32_27', 0.012789124563733316)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier5; Done in 19.166048049926758 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier6
# INFO:utils.ml:Top 10 features for XGBClassifier6: [('color_moments_lab_A_min', 0.06912507), ('color_moments_hsv_H_max', 0.021972707), ('color_moments_hsv_V_min', 0.021372268), ('color_moments_lab_B_skew', 0.021163194), ('lbp_rad1_bins8_4', 0.019912923), ('lbp_rad4_bins32_28', 0.017199798), ('color_moments_lab_A_iqr', 0.015716517), ('color_moments_hsv_S_min', 0.013159305), ('color_moments_rgb_R_min', 0.013143072), ('lbp_rad4_bins32_27', 0.011877896)]
# INFO:utils.ml:Fitted classifier: XGBClassifier6; Done in 3.1803481578826904 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier7
# INFO:utils.ml:Top 10 features for XGBClassifier7: [('color_moments_lab_A_min', 0.069231965), ('color_moments_hsv_H_max', 0.022131825), ('color_moments_lab_B_skew', 0.021680376), ('color_moments_hsv_V_min', 0.020797146), ('lbp_rad1_bins8_4', 0.019194154), ('lbp_rad4_bins32_28', 0.018804872), ('color_moments_lab_A_iqr', 0.015175983), ('color_moments_rgb_R_min', 0.014264246), ('color_moments_hsv_S_min', 0.0130241765), ('color_moments_rgb_B_std', 0.011699338)]
# INFO:utils.ml:Fitted classifier: XGBClassifier7; Done in 3.7141363620758057 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier8
# INFO:utils.ml:Top 10 features for XGBClassifier8: [('color_moments_lab_A_min', 0.06884907), ('color_moments_hsv_H_max', 0.021539595), ('color_moments_lab_B_skew', 0.020516356), ('color_moments_hsv_V_min', 0.020418769), ('lbp_rad4_bins32_28', 0.019742003), ('lbp_rad1_bins8_4', 0.018649327), ('color_moments_lab_A_iqr', 0.015739495), ('color_moments_rgb_R_min', 0.014742675), ('color_moments_hsv_S_min', 0.013306124), ('lbp_rad4_bins32_5', 0.011702978)]
# INFO:utils.ml:Fitted classifier: XGBClassifier8; Done in 4.56759786605835 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier9
# INFO:utils.ml:Top 10 features for XGBClassifier9: [('color_moments_lab_A_min', 0.052118603), ('color_moments_hsv_S_min', 0.017483506), ('color_moments_lab_B_skew', 0.015812367), ('color_moments_hsv_H_max', 0.014905126), ('color_moments_hsv_V_min', 0.01461531), ('lbp_rad4_bins32_28', 0.013428944), ('color_moments_lab_A_iqr', 0.011693831), ('glcm_correlation_dist_1_angle_0', 0.01127032), ('lbp_rad1_bins8_4', 0.010284481), ('lbp_rad2_bins16_8', 0.010122721)]
# INFO:utils.ml:Fitted classifier: XGBClassifier9; Done in 4.668228626251221 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier10
# INFO:utils.ml:Top 10 features for XGBClassifier10: [('color_moments_lab_A_min', 0.059777524), ('color_moments_lab_B_skew', 0.017874643), ('color_moments_hsv_V_min', 0.017772257), ('color_moments_hsv_H_max', 0.016878791), ('color_moments_lab_A_iqr', 0.014456716), ('color_moments_hsv_S_min', 0.013342715), ('lbp_rad4_bins32_28', 0.012173456), ('lbp_rad1_bins8_4', 0.012171877), ('lbp_rad4_bins32_27', 0.010694768), ('glcm_correlation_dist_1_angle_0', 0.010442423)]
# INFO:utils.ml:Fitted classifier: XGBClassifier10; Done in 6.541273593902588 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier11
# INFO:utils.ml:Top 10 features for XGBClassifier11: [('color_moments_lab_A_min', 0.059383504), ('color_moments_hsv_V_min', 0.017985873), ('color_moments_lab_B_skew', 0.01794861), ('color_moments_hsv_H_max', 0.017320236), ('color_moments_lab_A_iqr', 0.014460575), ('color_moments_hsv_S_min', 0.0134602245), ('lbp_rad1_bins8_4', 0.013242616), ('lbp_rad4_bins32_28', 0.012878595), ('lbp_rad4_bins32_27', 0.010584464), ('glcm_correlation_dist_1_angle_0', 0.009927728)]
# INFO:utils.ml:Fitted classifier: XGBClassifier11; Done in 7.827049255371094 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier12
# INFO:utils.ml:Top 10 features for XGBClassifier12: [('color_moments_lab_A_min', 0.053909693), ('color_moments_hsv_H_max', 0.018354878), ('color_moments_lab_B_skew', 0.017006285), ('color_moments_hsv_S_min', 0.016973505), ('color_moments_hsv_V_min', 0.016245728), ('color_moments_lab_A_iqr', 0.0137327025), ('lbp_rad4_bins32_28', 0.012315188), ('lbp_rad4_bins32_27', 0.011753064), ('lbp_rad1_bins8_4', 0.011511798), ('lbp_rad4_bins32_29', 0.010654547)]
# INFO:utils.ml:Fitted classifier: XGBClassifier12; Done in 6.148449182510376 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier13
# INFO:utils.ml:Top 10 features for XGBClassifier13: [('color_moments_lab_A_min', 0.052204024), ('color_moments_lab_B_skew', 0.016041536), ('color_moments_hsv_S_min', 0.01577309), ('color_moments_hsv_H_max', 0.014620374), ('lbp_rad4_bins32_28', 0.013184643), ('color_moments_hsv_V_min', 0.013116203), ('glcm_correlation_dist_1_angle_0', 0.011652088), ('lbp_rad1_bins8_4', 0.010996356), ('color_moments_lab_A_iqr', 0.01085567), ('color_moments_rgb_R_min', 0.009991564)]
# INFO:utils.ml:Fitted classifier: XGBClassifier13; Done in 10.125802755355835 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier14
# INFO:utils.ml:Top 10 features for XGBClassifier14: [('color_moments_lab_A_min', 0.060563557), ('color_moments_lab_B_skew', 0.017859709), ('color_moments_hsv_V_min', 0.017499257), ('color_moments_hsv_H_max', 0.017279746), ('lbp_rad1_bins8_4', 0.014247302), ('color_moments_lab_A_iqr', 0.013800143), ('color_moments_hsv_S_min', 0.01340307), ('lbp_rad4_bins32_28', 0.013324304), ('lbp_rad4_bins32_27', 0.010703605), ('glcm_correlation_dist_1_angle_0', 0.0102249645)]
# INFO:utils.ml:Fitted classifier: XGBClassifier14; Done in 11.028130769729614 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier15
# INFO:utils.ml:Top 10 features for XGBClassifier15: [('color_moments_lab_A_min', 0.060563557), ('color_moments_lab_B_skew', 0.017859709), ('color_moments_hsv_V_min', 0.017499257), ('color_moments_hsv_H_max', 0.017279746), ('lbp_rad1_bins8_4', 0.014247302), ('color_moments_lab_A_iqr', 0.013800143), ('color_moments_hsv_S_min', 0.01340307), ('lbp_rad4_bins32_28', 0.013324304), ('lbp_rad4_bins32_27', 0.010703605), ('glcm_correlation_dist_1_angle_0', 0.0102249645)]
# INFO:utils.ml:Fitted classifier: XGBClassifier15; Done in 10.944925785064697 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier16
# INFO:utils.ml:Top 10 features for XGBClassifier16: [('color_moments_lab_A_min', 0.056900494), ('color_moments_hsv_H_max', 0.019179663), ('color_moments_hsv_S_min', 0.01718862), ('color_moments_lab_B_skew', 0.016447393), ('color_moments_hsv_V_min', 0.016198747), ('color_moments_lab_A_iqr', 0.013287773), ('lbp_rad4_bins32_28', 0.012780272), ('lbp_rad1_bins8_4', 0.012065087), ('lbp_rad4_bins32_27', 0.011452507), ('color_moments_hsv_S_iqr', 0.010309289)]
# INFO:utils.ml:Fitted classifier: XGBClassifier16; Done in 9.295635461807251 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier17
# INFO:utils.ml:Top 10 features for XGBClassifier17: [('color_moments_lab_A_min', 0.05233975), ('color_moments_lab_B_skew', 0.016017115), ('color_moments_hsv_S_min', 0.015846185), ('color_moments_hsv_H_max', 0.014464753), ('lbp_rad4_bins32_28', 0.01301424), ('color_moments_hsv_V_min', 0.012692759), ('glcm_correlation_dist_1_angle_0', 0.011039662), ('color_moments_lab_A_iqr', 0.010863261), ('lbp_rad1_bins8_4', 0.010459324), ('color_moments_rgb_R_min', 0.010303177)]
# INFO:utils.ml:Fitted classifier: XGBClassifier17; Done in 12.310884952545166 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier18
# INFO:utils.ml:Top 10 features for XGBClassifier18: [('color_moments_lab_A_min', 0.061361045), ('color_moments_hsv_V_min', 0.017748693), ('color_moments_hsv_H_max', 0.017708225), ('color_moments_lab_B_skew', 0.017540762), ('lbp_rad1_bins8_4', 0.01502302), ('color_moments_lab_A_iqr', 0.01392172), ('color_moments_hsv_S_min', 0.0135864625), ('lbp_rad4_bins32_28', 0.013268706), ('lbp_rad4_bins32_27', 0.010627783), ('glcm_correlation_dist_1_angle_0', 0.010162142)]
# INFO:utils.ml:Fitted classifier: XGBClassifier18; Done in 13.971061706542969 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier19
# INFO:utils.ml:Top 10 features for XGBClassifier19: [('color_moments_lab_A_min', 0.061361045), ('color_moments_hsv_V_min', 0.017748693), ('color_moments_hsv_H_max', 0.017708225), ('color_moments_lab_B_skew', 0.017540762), ('lbp_rad1_bins8_4', 0.01502302), ('color_moments_lab_A_iqr', 0.01392172), ('color_moments_hsv_S_min', 0.0135864625), ('lbp_rad4_bins32_28', 0.013268706), ('lbp_rad4_bins32_27', 0.010627783), ('glcm_correlation_dist_1_angle_0', 0.010162142)]
# INFO:utils.ml:Fitted classifier: XGBClassifier19; Done in 14.077306270599365 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier20
# INFO:utils.ml:Top 10 features for XGBClassifier20: [('color_moments_lab_A_min', 0.056545112), ('color_moments_hsv_H_max', 0.018916111), ('color_moments_lab_B_skew', 0.016644023), ('color_moments_hsv_V_min', 0.016489783), ('color_moments_hsv_S_min', 0.016077267), ('color_moments_lab_A_iqr', 0.013312113), ('lbp_rad4_bins32_28', 0.012990783), ('lbp_rad1_bins8_4', 0.0124202175), ('lbp_rad4_bins32_27', 0.010887941), ('lbp_rad4_bins32_29', 0.010257045)]
# INFO:utils.ml:Fitted classifier: XGBClassifier20; Done in 11.807379961013794 seconds
# INFO:utils.ml:Fitting completed in 318.42 seconds.

# %%
pipeline.predict_with_classifiers(VAL_PATH)
# Out:
# INFO:utils.ml:Predicting with classifiers on dataset: C:\Users\gimes\Src\repos\CADx-Project\dataset\binary\val
# Processed 5/159 batches.
# Processed 10/159 batches.
# Processed 15/159 batches.
# Processed 20/159 batches.
# Processed 25/159 batches.
# Processed 30/159 batches.
# Processed 35/159 batches.
# Processed 40/159 batches.
# Processed 45/159 batches.
# Processed 50/159 batches.
# Processed 55/159 batches.
# Processed 60/159 batches.
# Processed 65/159 batches.
# Processed 70/159 batches.
# Processed 75/159 batches.
# Processed 80/159 batches.
# Processed 85/159 batches.
# Processed 90/159 batches.
# Processed 95/159 batches.
# Processed 100/159 batches.
# Processed 105/159 batches.
# Processed 110/159 batches.
# Processed 115/159 batches.
# Processed 120/159 batches.
# Processed 125/159 batches.
# Processed 130/159 batches.
# Processed 135/159 batches.
# Processed 140/159 batches.
# Processed 145/159 batches.
# Processed 150/159 batches.
# Processed 155/159 batches.
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier0
# Processed 159/159 batches.
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier1
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier2
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier3
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier4
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier5
# INFO:utils.ml:Predictions made with classifier: XGBClassifier6
# INFO:utils.ml:Predictions made with classifier: XGBClassifier7
# INFO:utils.ml:Predictions made with classifier: XGBClassifier8
# INFO:utils.ml:Predictions made with classifier: XGBClassifier9
# INFO:utils.ml:Predictions made with classifier: XGBClassifier10
# INFO:utils.ml:Predictions made with classifier: XGBClassifier11
# INFO:utils.ml:Predictions made with classifier: XGBClassifier12
# INFO:utils.ml:Predictions made with classifier: XGBClassifier13
# INFO:utils.ml:Predictions made with classifier: XGBClassifier14
# INFO:utils.ml:Predictions made with classifier: XGBClassifier15
# INFO:utils.ml:Predictions made with classifier: XGBClassifier16
# INFO:utils.ml:Predictions made with classifier: XGBClassifier17
# INFO:utils.ml:Predictions made with classifier: XGBClassifier18
# INFO:utils.ml:Predictions made with classifier: XGBClassifier19
# INFO:utils.ml:Predictions made with classifier: XGBClassifier20
# {'GT': array([0, 0, 0, ..., 1, 1, 1]),
#  'RandomForestClassifier0': array([0, 0, 0, ..., 0, 0, 1]),
#  'RandomForestClassifier1': array([0, 0, 0, ..., 0, 0, 1]),
#  'RandomForestClassifier2': array([0, 0, 0, ..., 0, 0, 1]),
#  'RandomForestClassifier3': array([0, 0, 0, ..., 0, 0, 1]),
#  'RandomForestClassifier4': array([0, 0, 0, ..., 0, 0, 1]),
#  'RandomForestClassifier5': array([0, 0, 0, ..., 0, 0, 1]),
#  'XGBClassifier6': array([0, 0, 0, ..., 1, 1, 1]),
#  'XGBClassifier7': array([0, 0, 0, ..., 1, 1, 1]),
#  'XGBClassifier8': array([0, 0, 0, ..., 1, 1, 1]),
#  'XGBClassifier9': array([0, 0, 0, ..., 0, 1, 1]),
#  'XGBClassifier10': array([0, 0, 0, ..., 1, 1, 1]),
#  'XGBClassifier11': array([0, 0, 0, ..., 1, 1, 1]),
#  'XGBClassifier12': array([0, 0, 0, ..., 1, 1, 1]),
#  'XGBClassifier13': array([0, 0, 0, ..., 0, 1, 1]),
#  'XGBClassifier14': array([0, 0, 0, ..., 1, 1, 1]),
#  'XGBClassifier15': array([0, 0, 0, ..., 1, 1, 1]),
#  'XGBClassifier16': array([0, 0, 0, ..., 1, 1, 1]),
#  'XGBClassifier17': array([0, 0, 0, ..., 0, 0, 1]),
#  'XGBClassifier18': array([0, 0, 0, ..., 1, 1, 1]),
#  'XGBClassifier19': array([0, 0, 0, ..., 1, 1, 1]),
#  'XGBClassifier20': array([0, 0, 0, ..., 1, 1, 1])}

# %%
import pandas as pd

df = pd.DataFrame(data=pipeline.calculate_metrics())
df = df.T
df
# Out:
# INFO:utils.ml:Metrics for classifier GT: {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'kappa': 1.0}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier0: {'accuracy': 0.8308746048472075, 'precision': 0.8309650520443814, 'recall': 0.8306768499839642, 'f1': 0.8307618076984935, 'kappa': 0.6615476830972439}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier1: {'accuracy': 0.8308746048472075, 'precision': 0.8309650520443814, 'recall': 0.8306768499839642, 'f1': 0.8307618076984935, 'kappa': 0.6615476830972439}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier2: {'accuracy': 0.8408851422550052, 'precision': 0.8409873438758884, 'recall': 0.840690414473602, 'f1': 0.8407790215730375, 'kappa': 0.6815806862784038}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier3: {'accuracy': 0.8279768177028451, 'precision': 0.8280174713256869, 'recall': 0.8278102581973529, 'f1': 0.8278779015973172, 'kappa': 0.6557707423156293}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier4: {'accuracy': 0.8279768177028451, 'precision': 0.8280174713256869, 'recall': 0.8278102581973529, 'f1': 0.8278779015973172, 'kappa': 0.6557707423156293}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier5: {'accuracy': 0.8403582718651211, 'precision': 0.8405095621431588, 'recall': 0.8401358948050921, 'f1': 0.8402383531960997, 'kappa': 0.6805087469351214}
# INFO:utils.ml:Metrics for classifier XGBClassifier6: {'accuracy': 0.8385142255005269, 'precision': 0.8384876022040526, 'recall': 0.8384241589530491, 'f1': 0.8384511625979216, 'kappa': 0.6769041421064821}
# INFO:utils.ml:Metrics for classifier XGBClassifier7: {'accuracy': 0.8414120126448894, 'precision': 0.8414588979913341, 'recall': 0.8412540974616216, 'f1': 0.8413228162923959, 'kappa': 0.6826583249155748}
# INFO:utils.ml:Metrics for classifier XGBClassifier8: {'accuracy': 0.8437829293993677, 'precision': 0.8438257445680621, 'recall': 0.8436303128162908, 'f1': 0.8436970092756443, 'kappa': 0.687405500706002}
# INFO:utils.ml:Metrics for classifier XGBClassifier9: {'accuracy': 0.839041095890411, 'precision': 0.838994148695119, 'recall': 0.8389878419410688, 'f1': 0.8389909370462336, 'kappa': 0.6779818964468765}
# INFO:utils.ml:Metrics for classifier XGBClassifier10: {'accuracy': 0.8353530031612223, 'precision': 0.8353071227424957, 'recall': 0.8353902671662989, 'f1': 0.8353277588396024, 'kappa': 0.6706637697108948}
# INFO:utils.ml:Metrics for classifier XGBClassifier11: {'accuracy': 0.8353530031612223, 'precision': 0.8353007151423621, 'recall': 0.8353719405272797, 'f1': 0.8353232782779778, 'kappa': 0.670651700117441}
# INFO:utils.ml:Metrics for classifier XGBClassifier12: {'accuracy': 0.8387776606954689, 'precision': 0.8387289087458332, 'recall': 0.8387289087458332, 'f1': 0.8387289087458332, 'kappa': 0.6774578174916662}
# INFO:utils.ml:Metrics for classifier XGBClassifier13: {'accuracy': 0.8424657534246576, 'precision': 0.8426199969255257, 'recall': 0.8422440136450158, 'f1': 0.8423474178403756, 'kappa': 0.684726453246209}
# INFO:utils.ml:Metrics for classifier XGBClassifier14: {'accuracy': 0.839831401475237, 'precision': 0.8397759500260281, 'recall': 0.8398287847633434, 'f1': 0.8397965360032429, 'kappa': 0.679595296038338}
# INFO:utils.ml:Metrics for classifier XGBClassifier15: {'accuracy': 0.839831401475237, 'precision': 0.8397759500260281, 'recall': 0.8398287847633434, 'f1': 0.8397965360032429, 'kappa': 0.679595296038338}
# INFO:utils.ml:Metrics for classifier XGBClassifier16: {'accuracy': 0.8408851422550052, 'precision': 0.8408452014490279, 'recall': 0.8408187009467375, 'f1': 0.8408310167309094, 'kappa': 0.6816623870544762}
# INFO:utils.ml:Metrics for classifier XGBClassifier17: {'accuracy': 0.8406217070600632, 'precision': 0.8407823263520162, 'recall': 0.8403948280003277, 'f1': 0.8404996711136528, 'kappa': 0.6810330364097168}
# INFO:utils.ml:Metrics for classifier XGBClassifier18: {'accuracy': 0.839304531085353, 'precision': 0.8392530438493682, 'recall': 0.8392651017753237, 'f1': 0.8392588396670165, 'kappa': 0.6785177686004341}
# INFO:utils.ml:Metrics for classifier XGBClassifier19: {'accuracy': 0.839304531085353, 'precision': 0.8392530438493682, 'recall': 0.8392651017753237, 'f1': 0.8392588396670165, 'kappa': 0.6785177686004341}
# INFO:utils.ml:Metrics for classifier XGBClassifier20: {'accuracy': 0.8422023182297155, 'precision': 0.8421775017774618, 'recall': 0.8421133669229157, 'f1': 0.8421406955891599, 'kappa': 0.6842831665934466}
#                          accuracy  precision    recall        f1     kappa
# GT                       1.000000   1.000000  1.000000  1.000000  1.000000
# RandomForestClassifier0  0.830875   0.830965  0.830677  0.830762  0.661548
# RandomForestClassifier1  0.830875   0.830965  0.830677  0.830762  0.661548
# RandomForestClassifier2  0.840885   0.840987  0.840690  0.840779  0.681581
# RandomForestClassifier3  0.827977   0.828017  0.827810  0.827878  0.655771
# RandomForestClassifier4  0.827977   0.828017  0.827810  0.827878  0.655771
# RandomForestClassifier5  0.840358   0.840510  0.840136  0.840238  0.680509
# XGBClassifier6           0.838514   0.838488  0.838424  0.838451  0.676904
# XGBClassifier7           0.841412   0.841459  0.841254  0.841323  0.682658
# XGBClassifier8           0.843783   0.843826  0.843630  0.843697  0.687406
# XGBClassifier9           0.839041   0.838994  0.838988  0.838991  0.677982
# XGBClassifier10          0.835353   0.835307  0.835390  0.835328  0.670664
# XGBClassifier11          0.835353   0.835301  0.835372  0.835323  0.670652
# XGBClassifier12          0.838778   0.838729  0.838729  0.838729  0.677458
# XGBClassifier13          0.842466   0.842620  0.842244  0.842347  0.684726
# XGBClassifier14          0.839831   0.839776  0.839829  0.839797  0.679595
# XGBClassifier15          0.839831   0.839776  0.839829  0.839797  0.679595
# XGBClassifier16          0.840885   0.840845  0.840819  0.840831  0.681662
# XGBClassifier17          0.840622   0.840782  0.840395  0.840500  0.681033
# XGBClassifier18          0.839305   0.839253  0.839265  0.839259  0.678518
# XGBClassifier19          0.839305   0.839253  0.839265  0.839259  0.678518
# XGBClassifier20          0.842202   0.842178  0.842113  0.842141  0.684283

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

highest = df[df["accuracy"] == df.iloc[1:]["accuracy"].max()]
idx = highest.index[0]

print(classification_report(pipeline.predictions["GT"], pipeline.predictions[idx]))
print(confusion_matrix(pipeline.predictions["GT"], pipeline.predictions[idx]))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.85      0.85      1931
#            1       0.85      0.83      0.84      1865
#
#     accuracy                           0.84      3796
#    macro avg       0.84      0.84      0.84      3796
# weighted avg       0.84      0.84      0.84      3796
#
# [[1646  285]
#  [ 308 1557]]

# %%
df_sorted = df.sort_values("accuracy", ascending=False)
df_sorted.head(8).index
df_sorted
# Out:
#                          accuracy  precision    recall        f1     kappa
# GT                       1.000000   1.000000  1.000000  1.000000  1.000000
# XGBClassifier8           0.843783   0.843826  0.843630  0.843697  0.687406
# XGBClassifier13          0.842466   0.842620  0.842244  0.842347  0.684726
# XGBClassifier20          0.842202   0.842178  0.842113  0.842141  0.684283
# XGBClassifier7           0.841412   0.841459  0.841254  0.841323  0.682658
# RandomForestClassifier2  0.840885   0.840987  0.840690  0.840779  0.681581
# XGBClassifier16          0.840885   0.840845  0.840819  0.840831  0.681662
# XGBClassifier17          0.840622   0.840782  0.840395  0.840500  0.681033
# RandomForestClassifier5  0.840358   0.840510  0.840136  0.840238  0.680509
# XGBClassifier15          0.839831   0.839776  0.839829  0.839797  0.679595
# XGBClassifier14          0.839831   0.839776  0.839829  0.839797  0.679595
# XGBClassifier19          0.839305   0.839253  0.839265  0.839259  0.678518
# XGBClassifier18          0.839305   0.839253  0.839265  0.839259  0.678518
# XGBClassifier9           0.839041   0.838994  0.838988  0.838991  0.677982
# XGBClassifier12          0.838778   0.838729  0.838729  0.838729  0.677458
# XGBClassifier6           0.838514   0.838488  0.838424  0.838451  0.676904
# XGBClassifier10          0.835353   0.835307  0.835390  0.835328  0.670664
# XGBClassifier11          0.835353   0.835301  0.835372  0.835323  0.670652
# RandomForestClassifier1  0.830875   0.830965  0.830677  0.830762  0.661548
# RandomForestClassifier0  0.830875   0.830965  0.830677  0.830762  0.661548
# RandomForestClassifier4  0.827977   0.828017  0.827810  0.827878  0.655771
# RandomForestClassifier3  0.827977   0.828017  0.827810  0.827878  0.655771
