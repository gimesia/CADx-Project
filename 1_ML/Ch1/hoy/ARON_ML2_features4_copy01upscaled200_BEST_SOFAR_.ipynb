# %%
from utils.loader import FactoryLoader
from utils.ml import MLPipeline
from utils.preprocessing import PreprocessingFactory
from utils.feature_extraction import *
from utils.utils import *

VAL_PATH = r"C:\Users\gimes\Src\repos\CADx-Project\dataset\binary\val"
TRAIN_PATH = r"C:\Users\gimes\Src\repos\CADx-Project\dataset\binary\train"

# %%
percent = 100
random = False
batch_size = 24

# Initialize the FactoryLoader
factory = PreprocessingFactory()
factory.pad2square(fill=np.nan)
factory.resize((200,200))
factory.normalize2float()

# Create the feature extraction pipeline strategy and add desired features
strategy = FeatureExtractionStrategy()

strategy.add_extractor(GradientExtractor()) # Add gradient feature

strategy.add_extractor(ColorMomentsExtractor("rgb", ))   # Add color moments feature
strategy.add_extractor(ColorMomentsExtractor("lab", ))   # Add color moments feature
strategy.add_extractor(ColorMomentsExtractor("hsv", ))   # Add color moments feature

strategy.add_extractor(LBPExtractor(radius=1, n_points=8))
strategy.add_extractor(LBPExtractor(radius=2, n_points=16))
strategy.add_extractor(LBPExtractor(radius=3, n_points=24))
strategy.add_extractor(LBPExtractor(radius=4, n_points=32))
strategy.add_extractor(LBPExtractor(radius=5, n_points=40))

strategy.add_extractor(FourierTransformExtractor())
strategy.add_extractor(FFTExtractor())

strategy.add_extractor(GLCMExtractor(properties=['contrast', 'dissimilarity', 'homogeneity', 'energy', 'correlation', "ASM"]))

pipeline = MLPipeline(dataset_path=TRAIN_PATH, preprocessing_factory=factory, feature_strategy=strategy, classifiers=[], percentage=percent, verbose=True, shuffle=random, batch_size=batch_size)
# Out:
# INFO:utils.ml:MLPipeline initialized with dataset path: C:\Users\gimes\Src\repos\CADx-Project\dataset\binary\train
# INFO:utils.ml:Preprocessing steps

# %%
pipeline.run_feature_extraction()
# Out:
# INFO:utils.ml:Running feature extraction...
# Processed 5/634 batches.
# Processed 10/634 batches.
# Processed 15/634 batches.
# Processed 20/634 batches.
# Processed 25/634 batches.
# Processed 30/634 batches.
# Processed 35/634 batches.
# Processed 40/634 batches.
# Processed 45/634 batches.
# Processed 50/634 batches.
# Processed 55/634 batches.
# Processed 60/634 batches.
# Processed 65/634 batches.
# Processed 70/634 batches.
# Processed 75/634 batches.
# C:\Users\gimes\Src\repos\CADx-Project\utils\feature_extraction.py:355: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   skew_val = skew(channel.flatten(), nan_policy='omit')
# C:\Users\gimes\Src\repos\CADx-Project\utils\feature_extraction.py:356: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   kurtosis_val = kurtosis(channel.flatten(), nan_policy='omit')
# Processed 80/634 batches.
# Processed 85/634 batches.
# Processed 90/634 batches.
# Processed 95/634 batches.
# Processed 100/634 batches.
# Processed 105/634 batches.
# Processed 110/634 batches.
# Processed 115/634 batches.
# Processed 120/634 batches.
# Processed 125/634 batches.
# Processed 130/634 batches.
# Processed 135/634 batches.
# Processed 140/634 batches.
# Processed 145/634 batches.
# Processed 150/634 batches.
# Processed 155/634 batches.
# Processed 160/634 batches.
# Processed 165/634 batches.
# Processed 170/634 batches.
# Processed 175/634 batches.
# Processed 180/634 batches.
# Processed 185/634 batches.
# Processed 190/634 batches.
# Processed 195/634 batches.
# Processed 200/634 batches.
# Processed 205/634 batches.
# Processed 210/634 batches.
# Processed 215/634 batches.
# Processed 220/634 batches.
# Processed 225/634 batches.
# Processed 230/634 batches.
# Processed 235/634 batches.
# Processed 240/634 batches.
# Processed 245/634 batches.
# Processed 250/634 batches.
# Processed 255/634 batches.
# Processed 260/634 batches.
# Processed 265/634 batches.
# Processed 270/634 batches.
# Processed 275/634 batches.
# Processed 280/634 batches.
# Processed 285/634 batches.
# Processed 290/634 batches.
# Processed 295/634 batches.
# Processed 300/634 batches.
# Processed 305/634 batches.
# Processed 310/634 batches.
# Processed 315/634 batches.
# Processed 320/634 batches.
# Processed 325/634 batches.
# Processed 330/634 batches.
# Processed 335/634 batches.
# Processed 340/634 batches.
# Processed 345/634 batches.
# Processed 350/634 batches.
# Processed 355/634 batches.
# Processed 360/634 batches.
# Processed 365/634 batches.
# Processed 370/634 batches.
# Processed 375/634 batches.
# Processed 380/634 batches.
# Processed 385/634 batches.
# Processed 390/634 batches.
# Processed 395/634 batches.
# Processed 400/634 batches.
# Processed 405/634 batches.
# Processed 410/634 batches.
# Processed 415/634 batches.
# Processed 420/634 batches.
# Processed 425/634 batches.
# Processed 430/634 batches.
# Processed 435/634 batches.
# Processed 440/634 batches.
# Processed 445/634 batches.
# Processed 450/634 batches.
# Processed 455/634 batches.
# Processed 460/634 batches.
# Processed 465/634 batches.
# Processed 470/634 batches.
# Processed 475/634 batches.
# Processed 480/634 batches.
# Processed 485/634 batches.
# Processed 490/634 batches.
# Processed 495/634 batches.
# Processed 500/634 batches.
# Processed 505/634 batches.
# Processed 510/634 batches.
# Processed 515/634 batches.
# Processed 520/634 batches.
# Processed 525/634 batches.
# Processed 530/634 batches.
# Processed 535/634 batches.
# Processed 540/634 batches.
# Processed 545/634 batches.
# Processed 550/634 batches.
# Processed 555/634 batches.
# Processed 560/634 batches.
# Processed 565/634 batches.
# Processed 570/634 batches.
# Processed 575/634 batches.
# Processed 580/634 batches.
# Processed 585/634 batches.
# Processed 590/634 batches.
# Processed 595/634 batches.
# Processed 600/634 batches.
# Processed 605/634 batches.
# Processed 610/634 batches.
# Processed 615/634 batches.
# Processed 620/634 batches.
# Processed 625/634 batches.
# Processed 630/634 batches.
# INFO:utils.ml:Feature extraction completed. Extracted 15195 features.
# Processed 634/634 batches.

# %%
from xgboost import XGBClassifier
from sklearn.ensemble import RandomForestClassifier

rf0 = RandomForestClassifier(n_estimators=300, max_features='sqrt', random_state=42) # Random Forest with Feature Selection via max_features
rf1 = RandomForestClassifier(n_estimators=300, oob_score=True, random_state=42) # Random Forest with Out-of-Bag Error (OOB)
rf2 = RandomForestClassifier(n_estimators=300, bootstrap=False, random_state=42) # Random Forest with Bootstrap Disabled
rf3 = RandomForestClassifier(n_estimators=100, max_features='sqrt', random_state=42) # Random Forest with Feature Selection via max_features
rf4 = RandomForestClassifier(n_estimators=100, oob_score=True, random_state=42) # Random Forest with Out-of-Bag Error (OOB)
rf5 = RandomForestClassifier(n_estimators=100, bootstrap=False, random_state=42) # Random Forest with Bootstrap Disabled

xgb6 = XGBClassifier(n_estimators=350)
xgb7 = XGBClassifier(n_estimators=450)
xgb8 = XGBClassifier(n_estimators=550)
xgb9 = XGBClassifier(learning_rate=0.1, n_estimators=400, max_depth=7, min_child_weight=3, subsample=0.7, colsample_bytree=0.7)
xgb10 = XGBClassifier(learning_rate=0.1, n_estimators=400, max_depth=7, min_child_weight=1, subsample=0.8, colsample_bytree=0.8)
xgb11 = XGBClassifier(learning_rate=0.1, n_estimators=500, max_depth=7, min_child_weight=1, subsample=0.8, colsample_bytree=0.8)
xgb12 = XGBClassifier(learning_rate=0.1, n_estimators=500, min_child_weight=1, subsample=0.8, colsample_bytree=0.8)
xgb13 = XGBClassifier(learning_rate=0.1, n_estimators=1250, max_depth=7, min_child_weight=3, subsample=0.7, colsample_bytree=0.7)
xgb14 = XGBClassifier(learning_rate=0.1, n_estimators=1250, max_depth=7, min_child_weight=1, subsample=0.8, colsample_bytree=0.8)
xgb15 = XGBClassifier(learning_rate=0.1, n_estimators=1250, max_depth=7, min_child_weight=1, subsample=0.8, colsample_bytree=0.8)
xgb16 = XGBClassifier(learning_rate=0.1, n_estimators=1250, min_child_weight=1, subsample=0.8, colsample_bytree=0.8)
xgb17 = XGBClassifier(learning_rate=0.1, n_estimators=1000, max_depth=7, min_child_weight=3, subsample=0.7, colsample_bytree=0.7)
xgb18 = XGBClassifier(learning_rate=0.1, n_estimators=1000, max_depth=7, min_child_weight=1, subsample=0.8, colsample_bytree=0.8)
xgb19 = XGBClassifier(learning_rate=0.1, n_estimators=1000, max_depth=7, min_child_weight=1, subsample=0.8, colsample_bytree=0.8)
xgb20 = XGBClassifier(learning_rate=0.1, n_estimators=1000, min_child_weight=1, subsample=0.8, colsample_bytree=0.8)



pipeline.classifiers = [rf0, rf1, rf2, rf3, rf4, rf5, 
                        # svm1, svm2, svm3, svm6, svm7, svm8,
                       xgb6, xgb7, xgb8, xgb9, xgb10, xgb11, xgb12, xgb13, xgb14, xgb15, xgb16, xgb17, xgb18, xgb19, xgb20 ]
pipeline.fitted_classifiers = {}

# %%
pipeline.fit_classifiers()
# Out:
# INFO:utils.ml:Fitting classifiers...
# INFO:utils.ml:Fitting classifier: RandomForestClassifier0
# INFO:utils.ml:Top 10 features for RandomForestClassifier0: [('color_moments_hsv_H_max', 0.018333137584647958), ('color_moments_lab_A_min', 0.018314751640426667), ('color_moments_lab_A_mean', 0.01767215762306855), ('color_moments_lab_A_median', 0.01638008008241453), ('color_moments_lab_B_skew', 0.01598509091764813), ('lbp_rad1_bins8_4', 0.01525044018622877), ('color_moments_hsv_S_min', 0.014645754199324623), ('lbp_rad1_bins8_9', 0.013922791524984794), ('color_moments_hsv_V_min', 0.012678642455362099), ('color_moments_lab_A_iqr', 0.012193837586541637)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier0; Done in 39.45484781265259 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier1
# INFO:utils.ml:Top 10 features for RandomForestClassifier1: [('color_moments_hsv_H_max', 0.018333137584647958), ('color_moments_lab_A_min', 0.018314751640426667), ('color_moments_lab_A_mean', 0.01767215762306855), ('color_moments_lab_A_median', 0.01638008008241453), ('color_moments_lab_B_skew', 0.01598509091764813), ('lbp_rad1_bins8_4', 0.01525044018622877), ('color_moments_hsv_S_min', 0.014645754199324623), ('lbp_rad1_bins8_9', 0.013922791524984794), ('color_moments_hsv_V_min', 0.012678642455362099), ('color_moments_lab_A_iqr', 0.012193837586541637)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier1; Done in 39.97624349594116 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier2
# INFO:utils.ml:Top 10 features for RandomForestClassifier2: [('color_moments_lab_A_min', 0.01924114930376661), ('color_moments_hsv_H_max', 0.01895302684574336), ('color_moments_lab_A_mean', 0.01793213495237773), ('color_moments_lab_B_skew', 0.016435318092763617), ('lbp_rad1_bins8_4', 0.016015726941461413), ('color_moments_hsv_S_min', 0.015765349219483686), ('color_moments_lab_A_median', 0.01531707711626526), ('lbp_rad1_bins8_9', 0.014125889585653407), ('color_moments_hsv_V_min', 0.013586755336143706), ('color_moments_lab_A_iqr', 0.012483899745320905)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier2; Done in 57.161431550979614 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier3
# INFO:utils.ml:Top 10 features for RandomForestClassifier3: [('lbp_rad1_bins8_4', 0.02152249530629327), ('color_moments_lab_A_median', 0.02080411684984519), ('color_moments_hsv_S_min', 0.01821470151725808), ('color_moments_lab_A_min', 0.017470437817873042), ('color_moments_hsv_H_max', 0.017283335934483956), ('color_moments_lab_B_skew', 0.0168306370043541), ('color_moments_hsv_V_min', 0.01574259113204283), ('color_moments_lab_A_mean', 0.01444133003623561), ('lbp_rad4_bins32_6', 0.014105822753228824), ('lbp_rad2_bins16_1', 0.013128103421746)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier3; Done in 12.998924732208252 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier4
# INFO:utils.ml:Top 10 features for RandomForestClassifier4: [('lbp_rad1_bins8_4', 0.02152249530629327), ('color_moments_lab_A_median', 0.02080411684984519), ('color_moments_hsv_S_min', 0.01821470151725808), ('color_moments_lab_A_min', 0.017470437817873042), ('color_moments_hsv_H_max', 0.017283335934483956), ('color_moments_lab_B_skew', 0.0168306370043541), ('color_moments_hsv_V_min', 0.01574259113204283), ('color_moments_lab_A_mean', 0.01444133003623561), ('lbp_rad4_bins32_6', 0.014105822753228824), ('lbp_rad2_bins16_1', 0.013128103421746)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier4; Done in 13.329344272613525 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier5
# INFO:utils.ml:Top 10 features for RandomForestClassifier5: [('lbp_rad1_bins8_4', 0.02300115176809798), ('color_moments_lab_A_mean', 0.018709152263302397), ('color_moments_lab_B_skew', 0.018514787068415778), ('color_moments_hsv_H_max', 0.017860857964665265), ('color_moments_hsv_S_min', 0.017098528284623465), ('color_moments_lab_A_min', 0.016157633100019705), ('color_moments_lab_A_median', 0.01585041262147778), ('color_moments_hsv_V_min', 0.015596115436081298), ('lbp_rad1_bins8_9', 0.012712797498050958), ('color_moments_lab_A_iqr', 0.012403799712561645)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier5; Done in 18.89460325241089 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier6
# INFO:utils.ml:Top 10 features for XGBClassifier6: [('color_moments_lab_A_min', 0.064735144), ('lbp_rad2_bins16_8', 0.03979721), ('color_moments_lab_B_skew', 0.022302637), ('color_moments_hsv_H_max', 0.022146216), ('color_moments_lab_A_mean', 0.016033975), ('color_moments_hsv_V_min', 0.012822841), ('lbp_rad4_bins32_27', 0.012774086), ('color_moments_lab_A_iqr', 0.011631485), ('lbp_rad4_bins32_4', 0.011542883), ('color_moments_rgb_G_skew', 0.01003824)]
# INFO:utils.ml:Fitted classifier: XGBClassifier6; Done in 3.0989627838134766 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier7
# INFO:utils.ml:Top 10 features for XGBClassifier7: [('color_moments_lab_A_min', 0.061392203), ('lbp_rad2_bins16_8', 0.04101969), ('color_moments_lab_B_skew', 0.023140667), ('color_moments_hsv_H_max', 0.022737969), ('color_moments_lab_A_mean', 0.016461845), ('lbp_rad4_bins32_27', 0.013946065), ('color_moments_hsv_V_min', 0.012273959), ('lbp_rad4_bins32_4', 0.0118283285), ('color_moments_lab_A_iqr', 0.011603898), ('color_moments_rgb_G_skew', 0.010010293)]
# INFO:utils.ml:Fitted classifier: XGBClassifier7; Done in 3.8466336727142334 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier8
# INFO:utils.ml:Top 10 features for XGBClassifier8: [('color_moments_lab_A_min', 0.06332987), ('lbp_rad2_bins16_8', 0.037075758), ('color_moments_lab_B_skew', 0.023662496), ('color_moments_hsv_H_max', 0.023351474), ('color_moments_lab_A_mean', 0.016430391), ('lbp_rad4_bins32_27', 0.0139093045), ('lbp_rad4_bins32_4', 0.011972141), ('color_moments_lab_A_iqr', 0.01173908), ('color_moments_hsv_V_min', 0.011368243), ('color_moments_rgb_R_min', 0.010523788)]
# INFO:utils.ml:Fitted classifier: XGBClassifier8; Done in 4.518348693847656 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier9
# INFO:utils.ml:Top 10 features for XGBClassifier9: [('color_moments_lab_A_min', 0.054211896), ('color_moments_hsv_H_max', 0.016966762), ('color_moments_lab_B_skew', 0.0155487135), ('color_moments_lab_A_mean', 0.014608851), ('color_moments_lab_A_iqr', 0.013737012), ('color_moments_hsv_V_min', 0.013180314), ('lbp_rad2_bins16_1', 0.012843773), ('lbp_rad2_bins16_8', 0.011850712), ('lbp_rad1_bins8_4', 0.011233918), ('lbp_rad4_bins32_27', 0.01015025)]
# INFO:utils.ml:Fitted classifier: XGBClassifier9; Done in 3.8090689182281494 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier10
# INFO:utils.ml:Top 10 features for XGBClassifier10: [('color_moments_lab_A_min', 0.053760838), ('color_moments_hsv_H_max', 0.018235946), ('color_moments_lab_B_skew', 0.016744481), ('lbp_rad2_bins16_8', 0.016555784), ('color_moments_lab_A_iqr', 0.014256856), ('color_moments_lab_A_mean', 0.014164524), ('color_moments_hsv_V_min', 0.013127739), ('lbp_rad4_bins32_27', 0.011688057), ('lbp_rad2_bins16_1', 0.010169153), ('lbp_rad4_bins32_4', 0.010077872)]
# INFO:utils.ml:Fitted classifier: XGBClassifier10; Done in 4.4590489864349365 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier11
# INFO:utils.ml:Top 10 features for XGBClassifier11: [('color_moments_lab_A_min', 0.05393569), ('color_moments_hsv_H_max', 0.018250415), ('color_moments_lab_B_skew', 0.017021611), ('lbp_rad2_bins16_8', 0.016604668), ('color_moments_lab_A_mean', 0.014702512), ('color_moments_lab_A_iqr', 0.0142514175), ('color_moments_hsv_V_min', 0.013493201), ('lbp_rad4_bins32_27', 0.011963127), ('lbp_rad1_bins8_4', 0.010375495), ('lbp_rad2_bins16_1', 0.0098641785)]
# INFO:utils.ml:Fitted classifier: XGBClassifier11; Done in 5.332530975341797 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier12
# INFO:utils.ml:Top 10 features for XGBClassifier12: [('color_moments_lab_A_min', 0.05161536), ('color_moments_hsv_H_max', 0.01919776), ('color_moments_lab_B_skew', 0.017151257), ('color_moments_lab_A_mean', 0.014456847), ('color_moments_lab_A_iqr', 0.014148959), ('color_moments_hsv_V_min', 0.013682939), ('lbp_rad2_bins16_8', 0.013326174), ('lbp_rad4_bins32_27', 0.012575431), ('lbp_rad1_bins8_4', 0.012077821), ('color_moments_rgb_R_min', 0.010374052)]
# INFO:utils.ml:Fitted classifier: XGBClassifier12; Done in 3.981497049331665 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier13
# INFO:utils.ml:Top 10 features for XGBClassifier13: [('color_moments_lab_A_min', 0.051600996), ('color_moments_hsv_H_max', 0.01636559), ('color_moments_lab_B_skew', 0.015579953), ('color_moments_lab_A_mean', 0.014623226), ('color_moments_hsv_V_min', 0.0129234055), ('lbp_rad2_bins16_1', 0.012787519), ('color_moments_lab_A_iqr', 0.011880223), ('lbp_rad1_bins8_4', 0.011816729), ('lbp_rad2_bins16_8', 0.011424045), ('color_moments_rgb_B_std', 0.009918491)]
# INFO:utils.ml:Fitted classifier: XGBClassifier13; Done in 9.286156177520752 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier14
# INFO:utils.ml:Top 10 features for XGBClassifier14: [('color_moments_lab_A_min', 0.053399406), ('color_moments_hsv_H_max', 0.017906608), ('lbp_rad2_bins16_8', 0.017894678), ('color_moments_lab_B_skew', 0.017162465), ('color_moments_lab_A_mean', 0.015373565), ('color_moments_lab_A_iqr', 0.013596286), ('color_moments_hsv_V_min', 0.013051335), ('lbp_rad4_bins32_27', 0.011364152), ('color_moments_hsv_H_min', 0.011206624), ('lbp_rad1_bins8_4', 0.010529286)]
# INFO:utils.ml:Fitted classifier: XGBClassifier14; Done in 14.58791732788086 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier15
# INFO:utils.ml:Top 10 features for XGBClassifier15: [('color_moments_lab_A_min', 0.053399406), ('color_moments_hsv_H_max', 0.017906608), ('lbp_rad2_bins16_8', 0.017894678), ('color_moments_lab_B_skew', 0.017162465), ('color_moments_lab_A_mean', 0.015373565), ('color_moments_lab_A_iqr', 0.013596286), ('color_moments_hsv_V_min', 0.013051335), ('lbp_rad4_bins32_27', 0.011364152), ('color_moments_hsv_H_min', 0.011206624), ('lbp_rad1_bins8_4', 0.010529286)]
# INFO:utils.ml:Fitted classifier: XGBClassifier15; Done in 15.631603956222534 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier16
# INFO:utils.ml:Top 10 features for XGBClassifier16: [('color_moments_lab_A_min', 0.05031554), ('color_moments_hsv_H_max', 0.01899636), ('color_moments_lab_B_skew', 0.017176203), ('color_moments_lab_A_iqr', 0.014332965), ('color_moments_lab_A_mean', 0.013894347), ('lbp_rad2_bins16_8', 0.0136176925), ('color_moments_hsv_V_min', 0.013236921), ('lbp_rad4_bins32_27', 0.013186684), ('color_moments_rgb_R_min', 0.01140221), ('lbp_rad1_bins8_4', 0.011263936)]
# INFO:utils.ml:Fitted classifier: XGBClassifier16; Done in 13.221006631851196 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier17
# INFO:utils.ml:Top 10 features for XGBClassifier17: [('color_moments_lab_A_min', 0.051957674), ('color_moments_hsv_H_max', 0.016401423), ('color_moments_lab_B_skew', 0.015659936), ('color_moments_lab_A_mean', 0.014720138), ('color_moments_hsv_V_min', 0.012825186), ('lbp_rad2_bins16_1', 0.012653796), ('lbp_rad2_bins16_8', 0.01203368), ('color_moments_lab_A_iqr', 0.011885388), ('lbp_rad1_bins8_4', 0.01160341), ('color_moments_rgb_B_std', 0.010071869)]
# INFO:utils.ml:Fitted classifier: XGBClassifier17; Done in 11.027848243713379 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier18
# INFO:utils.ml:Top 10 features for XGBClassifier18: [('color_moments_lab_A_min', 0.053370673), ('color_moments_hsv_H_max', 0.018163528), ('lbp_rad2_bins16_8', 0.017784795), ('color_moments_lab_B_skew', 0.016989551), ('color_moments_lab_A_mean', 0.015165191), ('color_moments_lab_A_iqr', 0.013653821), ('color_moments_hsv_V_min', 0.013430436), ('lbp_rad4_bins32_27', 0.011259242), ('lbp_rad1_bins8_4', 0.010460216), ('color_moments_hsv_H_min', 0.009959143)]
# INFO:utils.ml:Fitted classifier: XGBClassifier18; Done in 13.068686962127686 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier19
# INFO:utils.ml:Top 10 features for XGBClassifier19: [('color_moments_lab_A_min', 0.053370673), ('color_moments_hsv_H_max', 0.018163528), ('lbp_rad2_bins16_8', 0.017784795), ('color_moments_lab_B_skew', 0.016989551), ('color_moments_lab_A_mean', 0.015165191), ('color_moments_lab_A_iqr', 0.013653821), ('color_moments_hsv_V_min', 0.013430436), ('lbp_rad4_bins32_27', 0.011259242), ('lbp_rad1_bins8_4', 0.010460216), ('color_moments_hsv_H_min', 0.009959143)]
# INFO:utils.ml:Fitted classifier: XGBClassifier19; Done in 12.875642776489258 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier20
# INFO:utils.ml:Top 10 features for XGBClassifier20: [('color_moments_lab_A_min', 0.04946164), ('color_moments_hsv_H_max', 0.018557545), ('color_moments_lab_B_skew', 0.016905857), ('color_moments_lab_A_iqr', 0.014324874), ('color_moments_lab_A_mean', 0.014287303), ('lbp_rad2_bins16_8', 0.013676771), ('color_moments_hsv_V_min', 0.013286582), ('lbp_rad4_bins32_27', 0.012800494), ('lbp_rad1_bins8_4', 0.011675759), ('color_moments_rgb_R_min', 0.011107001)]
# INFO:utils.ml:Fitted classifier: XGBClassifier20; Done in 10.2542085647583 seconds
# INFO:utils.ml:Fitting completed in 310.83 seconds.

# %%
pipeline.predict_with_classifiers(VAL_PATH)
# Out:
# INFO:utils.ml:Predicting with classifiers on dataset: C:\Users\gimes\Src\repos\CADx-Project\dataset\binary\val
# Processed 5/159 batches.
# Processed 10/159 batches.
# Processed 15/159 batches.
# Processed 20/159 batches.
# Processed 25/159 batches.
# Processed 30/159 batches.
# Processed 35/159 batches.
# Processed 40/159 batches.
# Processed 45/159 batches.
# Processed 50/159 batches.
# Processed 55/159 batches.
# Processed 60/159 batches.
# Processed 65/159 batches.
# Processed 70/159 batches.
# Processed 75/159 batches.
# Processed 80/159 batches.
# Processed 85/159 batches.
# Processed 90/159 batches.
# Processed 95/159 batches.
# Processed 100/159 batches.
# Processed 105/159 batches.
# Processed 110/159 batches.
# Processed 115/159 batches.
# Processed 120/159 batches.
# Processed 125/159 batches.
# Processed 130/159 batches.
# Processed 135/159 batches.
# Processed 140/159 batches.
# Processed 145/159 batches.
# Processed 150/159 batches.
# Processed 155/159 batches.
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier0
# Processed 159/159 batches.
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier1
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier2
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier3
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier4
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier5
# INFO:utils.ml:Predictions made with classifier: XGBClassifier6
# INFO:utils.ml:Predictions made with classifier: XGBClassifier7
# INFO:utils.ml:Predictions made with classifier: XGBClassifier8
# INFO:utils.ml:Predictions made with classifier: XGBClassifier9
# INFO:utils.ml:Predictions made with classifier: XGBClassifier10
# INFO:utils.ml:Predictions made with classifier: XGBClassifier11
# INFO:utils.ml:Predictions made with classifier: XGBClassifier12
# INFO:utils.ml:Predictions made with classifier: XGBClassifier13
# INFO:utils.ml:Predictions made with classifier: XGBClassifier14
# INFO:utils.ml:Predictions made with classifier: XGBClassifier15
# INFO:utils.ml:Predictions made with classifier: XGBClassifier16
# INFO:utils.ml:Predictions made with classifier: XGBClassifier17
# INFO:utils.ml:Predictions made with classifier: XGBClassifier18
# INFO:utils.ml:Predictions made with classifier: XGBClassifier19
# INFO:utils.ml:Predictions made with classifier: XGBClassifier20
# {'GT': array([0, 0, 0, ..., 1, 1, 1]),
#  'RandomForestClassifier0': array([0, 0, 0, ..., 0, 0, 1]),
#  'RandomForestClassifier1': array([0, 0, 0, ..., 0, 0, 1]),
#  'RandomForestClassifier2': array([0, 0, 0, ..., 0, 0, 1]),
#  'RandomForestClassifier3': array([0, 0, 0, ..., 0, 0, 1]),
#  'RandomForestClassifier4': array([0, 0, 0, ..., 0, 0, 1]),
#  'RandomForestClassifier5': array([0, 0, 0, ..., 0, 0, 1]),
#  'XGBClassifier6': array([0, 0, 0, ..., 1, 1, 1]),
#  'XGBClassifier7': array([0, 0, 0, ..., 1, 1, 1]),
#  'XGBClassifier8': array([0, 0, 0, ..., 1, 1, 1]),
#  'XGBClassifier9': array([0, 0, 0, ..., 0, 1, 1]),
#  'XGBClassifier10': array([0, 0, 0, ..., 0, 0, 1]),
#  'XGBClassifier11': array([0, 0, 0, ..., 0, 0, 1]),
#  'XGBClassifier12': array([0, 0, 0, ..., 1, 0, 1]),
#  'XGBClassifier13': array([0, 0, 0, ..., 1, 1, 1]),
#  'XGBClassifier14': array([0, 0, 0, ..., 0, 0, 1]),
#  'XGBClassifier15': array([0, 0, 0, ..., 0, 0, 1]),
#  'XGBClassifier16': array([0, 0, 0, ..., 1, 0, 1]),
#  'XGBClassifier17': array([0, 0, 0, ..., 1, 1, 1]),
#  'XGBClassifier18': array([0, 0, 0, ..., 0, 0, 1]),
#  'XGBClassifier19': array([0, 0, 0, ..., 0, 0, 1]),
#  'XGBClassifier20': array([0, 0, 0, ..., 1, 0, 1])}

# %%
import pandas as pd

df = pd.DataFrame(data=pipeline.calculate_metrics())
df = df.T
df
# Out:
# INFO:utils.ml:Metrics for classifier GT: {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'kappa': 1.0}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier0: {'accuracy': 0.8335089567966281, 'precision': 0.8336338541650742, 'recall': 0.8332936718948495, 'f1': 0.8333886604350293, 'kappa': 0.6668073098532357}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier1: {'accuracy': 0.8335089567966281, 'precision': 0.8336338541650742, 'recall': 0.8332936718948495, 'f1': 0.8333886604350293, 'kappa': 0.6668073098532357}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier2: {'accuracy': 0.8414120126448894, 'precision': 0.8415148329196518, 'recall': 0.8412174441835829, 'f1': 0.8413062433559083, 'kappa': 0.682635054866886}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier3: {'accuracy': 0.8303477344573235, 'precision': 0.8305022831050228, 'recall': 0.8301131669959445, 'f1': 0.8302153436706075, 'kappa': 0.6604684173172463}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier4: {'accuracy': 0.8303477344573235, 'precision': 0.8305022831050228, 'recall': 0.8301131669959445, 'f1': 0.8302153436706075, 'kappa': 0.6604684173172463}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier5: {'accuracy': 0.839831401475237, 'precision': 0.8399646657547732, 'recall': 0.8396180284146209, 'f1': 0.8397156733299016, 'kappa': 0.6794601968208344}
# INFO:utils.ml:Metrics for classifier XGBClassifier6: {'accuracy': 0.8395679662802951, 'precision': 0.8396106419716074, 'recall': 0.839707301360753, 'f1': 0.8395610074293196, 'kappa': 0.6791594451667486}
# INFO:utils.ml:Metrics for classifier XGBClassifier7: {'accuracy': 0.8403582718651211, 'precision': 0.8404071483873046, 'recall': 0.8405024275854792, 'f1': 0.840351890202262, 'kappa': 0.6807428648672205}
# INFO:utils.ml:Metrics for classifier XGBClassifier8: {'accuracy': 0.8424657534246576, 'precision': 0.8424322305356848, 'recall': 0.8425280765498159, 'f1': 0.8424464659964581, 'kappa': 0.6849055289029449}
# INFO:utils.ml:Metrics for classifier XGBClassifier9: {'accuracy': 0.8427291886195996, 'precision': 0.8427118363501633, 'recall': 0.842631233313387, 'f1': 0.8426644511228272, 'kappa': 0.6853315456579261}
# INFO:utils.ml:Metrics for classifier XGBClassifier10: {'accuracy': 0.839831401475237, 'precision': 0.8402222744733572, 'recall': 0.8395080685805045, 'f1': 0.839654738796171, 'kappa': 0.6793896650353468}
# INFO:utils.ml:Metrics for classifier XGBClassifier11: {'accuracy': 0.839831401475237, 'precision': 0.8401242330354066, 'recall': 0.8395447218585433, 'f1': 0.8396764809916744, 'kappa': 0.679413179079114}
# INFO:utils.ml:Metrics for classifier XGBClassifier12: {'accuracy': 0.8435194942044257, 'precision': 0.8434921044705477, 'recall': 0.8435912992892873, 'f1': 0.8435021171547838, 'kappa': 0.6870189188581448}
# INFO:utils.ml:Metrics for classifier XGBClassifier13: {'accuracy': 0.8469441517386723, 'precision': 0.8469150223116837, 'recall': 0.8468657976322538, 'f1': 0.8468875273035035, 'kappa': 0.6937760963087781}
# INFO:utils.ml:Metrics for classifier XGBClassifier14: {'accuracy': 0.8414120126448894, 'precision': 0.8417808739433792, 'recall': 0.8410983210299572, 'f1': 0.8412426081543729, 'kappa': 0.6825594036341047}
# INFO:utils.ml:Metrics for classifier XGBClassifier15: {'accuracy': 0.8414120126448894, 'precision': 0.8417808739433792, 'recall': 0.8410983210299572, 'f1': 0.8412426081543729, 'kappa': 0.6825594036341047}
# INFO:utils.ml:Metrics for classifier XGBClassifier16: {'accuracy': 0.8482613277133825, 'precision': 0.8482077689304416, 'recall': 0.8482704234425481, 'f1': 0.8482306149222236, 'kappa': 0.6964642637901819}
# INFO:utils.ml:Metrics for classifier XGBClassifier17: {'accuracy': 0.8477344573234984, 'precision': 0.8476852195078473, 'recall': 0.8476975771350187, 'f1': 0.8476911628320255, 'kappa': 0.6953824102476245}
# INFO:utils.ml:Metrics for classifier XGBClassifier18: {'accuracy': 0.8416754478398314, 'precision': 0.8417864353115911, 'recall': 0.8414763773788185, 'f1': 0.8415676868070874, 'kappa': 0.683159334997303}
# INFO:utils.ml:Metrics for classifier XGBClassifier19: {'accuracy': 0.8416754478398314, 'precision': 0.8417864353115911, 'recall': 0.8414763773788185, 'f1': 0.8415676868070874, 'kappa': 0.683159334997303}
# INFO:utils.ml:Metrics for classifier XGBClassifier20: {'accuracy': 0.845100105374078, 'precision': 0.8450461595524441, 'recall': 0.8451082451826624, 'f1': 0.8450687527331033, 'kappa': 0.6901406026191441}
#                          accuracy  precision    recall        f1     kappa
# GT                       1.000000   1.000000  1.000000  1.000000  1.000000
# RandomForestClassifier0  0.833509   0.833634  0.833294  0.833389  0.666807
# RandomForestClassifier1  0.833509   0.833634  0.833294  0.833389  0.666807
# RandomForestClassifier2  0.841412   0.841515  0.841217  0.841306  0.682635
# RandomForestClassifier3  0.830348   0.830502  0.830113  0.830215  0.660468
# RandomForestClassifier4  0.830348   0.830502  0.830113  0.830215  0.660468
# RandomForestClassifier5  0.839831   0.839965  0.839618  0.839716  0.679460
# XGBClassifier6           0.839568   0.839611  0.839707  0.839561  0.679159
# XGBClassifier7           0.840358   0.840407  0.840502  0.840352  0.680743
# XGBClassifier8           0.842466   0.842432  0.842528  0.842446  0.684906
# XGBClassifier9           0.842729   0.842712  0.842631  0.842664  0.685332
# XGBClassifier10          0.839831   0.840222  0.839508  0.839655  0.679390
# XGBClassifier11          0.839831   0.840124  0.839545  0.839676  0.679413
# XGBClassifier12          0.843519   0.843492  0.843591  0.843502  0.687019
# XGBClassifier13          0.846944   0.846915  0.846866  0.846888  0.693776
# XGBClassifier14          0.841412   0.841781  0.841098  0.841243  0.682559
# XGBClassifier15          0.841412   0.841781  0.841098  0.841243  0.682559
# XGBClassifier16          0.848261   0.848208  0.848270  0.848231  0.696464
# XGBClassifier17          0.847734   0.847685  0.847698  0.847691  0.695382
# XGBClassifier18          0.841675   0.841786  0.841476  0.841568  0.683159
# XGBClassifier19          0.841675   0.841786  0.841476  0.841568  0.683159
# XGBClassifier20          0.845100   0.845046  0.845108  0.845069  0.690141

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

highest = df[df["accuracy"] == df.iloc[1:]["accuracy"].max()]
idx = highest.index[0]

print(classification_report(pipeline.predictions["GT"], pipeline.predictions[idx]))
print(confusion_matrix(pipeline.predictions["GT"], pipeline.predictions[idx]))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.85      0.85      1931
#            1       0.84      0.85      0.85      1865
#
#     accuracy                           0.85      3796
#    macro avg       0.85      0.85      0.85      3796
# weighted avg       0.85      0.85      0.85      3796
#
# [[1637  294]
#  [ 282 1583]]

# %%
df_sorted = df.sort_values("accuracy", ascending=False)
df_sorted.head(8).index
df_sorted
# Out:
#                          accuracy  precision    recall        f1     kappa
# GT                       1.000000   1.000000  1.000000  1.000000  1.000000
# XGBClassifier16          0.848261   0.848208  0.848270  0.848231  0.696464
# XGBClassifier17          0.847734   0.847685  0.847698  0.847691  0.695382
# XGBClassifier13          0.846944   0.846915  0.846866  0.846888  0.693776
# XGBClassifier20          0.845100   0.845046  0.845108  0.845069  0.690141
# XGBClassifier12          0.843519   0.843492  0.843591  0.843502  0.687019
# XGBClassifier9           0.842729   0.842712  0.842631  0.842664  0.685332
# XGBClassifier8           0.842466   0.842432  0.842528  0.842446  0.684906
# XGBClassifier19          0.841675   0.841786  0.841476  0.841568  0.683159
# XGBClassifier18          0.841675   0.841786  0.841476  0.841568  0.683159
# XGBClassifier14          0.841412   0.841781  0.841098  0.841243  0.682559
# RandomForestClassifier2  0.841412   0.841515  0.841217  0.841306  0.682635
# XGBClassifier15          0.841412   0.841781  0.841098  0.841243  0.682559
# XGBClassifier7           0.840358   0.840407  0.840502  0.840352  0.680743
# XGBClassifier10          0.839831   0.840222  0.839508  0.839655  0.679390
# RandomForestClassifier5  0.839831   0.839965  0.839618  0.839716  0.679460
# XGBClassifier11          0.839831   0.840124  0.839545  0.839676  0.679413
# XGBClassifier6           0.839568   0.839611  0.839707  0.839561  0.679159
# RandomForestClassifier1  0.833509   0.833634  0.833294  0.833389  0.666807
# RandomForestClassifier0  0.833509   0.833634  0.833294  0.833389  0.666807
# RandomForestClassifier3  0.830348   0.830502  0.830113  0.830215  0.660468
# RandomForestClassifier4  0.830348   0.830502  0.830113  0.830215  0.660468
