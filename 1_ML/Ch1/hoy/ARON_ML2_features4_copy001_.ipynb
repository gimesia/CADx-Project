# %%
from utils.loader import FactoryLoader
from utils.ml import MLPipeline
from utils.preprocessing import PreprocessingFactory
from utils.feature_extraction import *
from utils.utils import *

VAL_PATH = r"C:\Users\gimes\Src\repos\CADx-Project\dataset\binary\val"
TRAIN_PATH = r"C:\Users\gimes\Src\repos\CADx-Project\dataset\binary\train"

# %%
percent = 2
random = False
batch_size = 24

# Initialize the FactoryLoader
factory = PreprocessingFactory()
factory.pad2square(fill=np.nan)
factory.resize((150,150))
factory.normalize2float()

# Create the feature extraction pipeline strategy and add desired features
strategy = FeatureExtractionStrategy()

strategy.add_extractor(GradientExtractor()) # Add gradient feature

strategy.add_extractor(ColorMomentsExtractor("rgb", ))   # Add color moments feature
strategy.add_extractor(ColorMomentsExtractor("lab", ))   # Add color moments feature
strategy.add_extractor(ColorMomentsExtractor("hsv", ))   # Add color moments feature

strategy.add_extractor(LBPExtractor(radius=1, n_points=8))
strategy.add_extractor(LBPExtractor(radius=2, n_points=16))
strategy.add_extractor(LBPExtractor(radius=3, n_points=24))
strategy.add_extractor(LBPExtractor(radius=4, n_points=32))
strategy.add_extractor(LBPExtractor(radius=5, n_points=40))

strategy.add_extractor(FourierTransformExtractor())
strategy.add_extractor(FFTExtractor())

strategy.add_extractor(GLCMExtractor(properties=['contrast', 'dissimilarity', 'homogeneity', 'energy', 'correlation', "ASM"]))

pipeline = MLPipeline(dataset_path=TRAIN_PATH, preprocessing_factory=factory, feature_strategy=strategy, classifiers=[], percentage=percent, verbose=True, shuffle=random, batch_size=batch_size)
# Out:
# INFO:utils.ml:MLPipeline initialized with dataset path: C:\Users\gimes\Src\repos\CADx-Project\dataset\binary\train
# INFO:utils.ml:Preprocessing steps

# %%
pipeline.run_feature_extraction()
# Out:
# INFO:utils.ml:Running feature extraction...
# Processed 5/13 batches.
# Processed 10/13 batches.
# INFO:utils.ml:Feature extraction completed. Extracted 302 features.
# Processed 13/13 batches.

# %%
from xgboost import XGBClassifier
from sklearn.ensemble import RandomForestClassifier

rf0 = RandomForestClassifier(n_estimators=300, max_features='sqrt', random_state=42) # Random Forest with Feature Selection via max_features
rf1 = RandomForestClassifier(n_estimators=300, oob_score=True, random_state=42) # Random Forest with Out-of-Bag Error (OOB)
rf2 = RandomForestClassifier(n_estimators=300, bootstrap=False, random_state=42) # Random Forest with Bootstrap Disabled
rf3 = RandomForestClassifier(n_estimators=400, max_features='sqrt', random_state=42) # Random Forest with Feature Selection via max_features
rf4 = RandomForestClassifier(n_estimators=400, oob_score=True, random_state=42) # Random Forest with Out-of-Bag Error (OOB)
rf5 = RandomForestClassifier(n_estimators=400, bootstrap=False, random_state=42) # Random Forest with Bootstrap Disabled

xgb6 = XGBClassifier(n_estimators=350)
xgb7 = XGBClassifier(n_estimators=450)
xgb8 = XGBClassifier(n_estimators=550)
xgb9 = XGBClassifier(learning_rate=0.1, n_estimators=400, max_depth=7, min_child_weight=3, subsample=0.7, colsample_bytree=0.7)
xgb10 = XGBClassifier(learning_rate=0.1, n_estimators=400, max_depth=7, min_child_weight=1, subsample=0.8, colsample_bytree=0.8)
xgb11 = XGBClassifier(learning_rate=0.1, n_estimators=500, max_depth=7, min_child_weight=1, subsample=0.8, colsample_bytree=0.8)
xgb12 = XGBClassifier(learning_rate=0.1, n_estimators=500, min_child_weight=1, subsample=0.8, colsample_bytree=0.8)
xgb13 = XGBClassifier(learning_rate=0.1, n_estimators=750, max_depth=7, min_child_weight=3, subsample=0.7, colsample_bytree=0.7)
xgb14 = XGBClassifier(learning_rate=0.1, n_estimators=750, max_depth=7, min_child_weight=1, subsample=0.8, colsample_bytree=0.8)
xgb15 = XGBClassifier(learning_rate=0.1, n_estimators=750, max_depth=7, min_child_weight=1, subsample=0.8, colsample_bytree=0.8)
xgb16 = XGBClassifier(learning_rate=0.1, n_estimators=750, min_child_weight=1, subsample=0.8, colsample_bytree=0.8)
xgb17 = XGBClassifier(learning_rate=0.1, n_estimators=1000, max_depth=7, min_child_weight=3, subsample=0.7, colsample_bytree=0.7)
xgb18 = XGBClassifier(learning_rate=0.1, n_estimators=1000, max_depth=7, min_child_weight=1, subsample=0.8, colsample_bytree=0.8)
xgb19 = XGBClassifier(learning_rate=0.1, n_estimators=1000, max_depth=7, min_child_weight=1, subsample=0.8, colsample_bytree=0.8)
xgb20 = XGBClassifier(learning_rate=0.1, n_estimators=1000, min_child_weight=1, subsample=0.8, colsample_bytree=0.8)



pipeline.classifiers = [rf0, rf1, rf2, rf3, rf4, rf5, 
                        # svm1, svm2, svm3, svm6, svm7, svm8,
                       xgb6, xgb7, xgb8, xgb9, xgb10, xgb11, xgb12, xgb13, xgb14, xgb15, xgb16, xgb17, xgb18, xgb19, xgb20 ]
pipeline.fitted_classifiers = {}
# Out:
# INFO:numexpr.utils:Note: NumExpr detected 16 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 29
#      24 xgb19 = XGBClassifier(learning_rate=0.1, n_estimators=1000, max_depth=7, min_child_weight=1, subsample=0.8, colsample_bytree=0.8)
#      25 xgb20 = XGBClassifier(learning_rate=0.1, n_estimators=1000, min_child_weight=1, subsample=0.8, colsample_bytree=0.8)
# ---> 29 pipeline.classifiers = [rf0, rf1, rf2, rf3, rf4, rf5,
#      30                         # svm1, svm2, svm3, svm6, svm7, svm8,
#      31                        xgb6, xgb7, xgb8, xgb9, xgb10, xgb11, xgb12, xgb13, xgb14, xgb15, xgb16, xgb17, xgb18, xgb19, xgb20 ]
#      32 pipeline.fitted_classifiers = {}
#
# NameError: name 'pipeline' is not defined

# %%
pipeline.fit_classifiers()
# Out:
# INFO:utils.ml:Fitting classifiers...
# INFO:utils.ml:Fitting classifier: RandomForestClassifier0
# INFO:utils.ml:Top 10 features for RandomForestClassifier0: [('color_moments_lab_A_min', 0.021533613170027305), ('color_moments_hsv_H_max', 0.01905071972407517), ('color_moments_lab_A_mean', 0.018273773407071592), ('color_moments_hsv_S_min', 0.017531669926098503), ('color_moments_lab_A_median', 0.016883403070022764), ('color_moments_lab_B_skew', 0.01642640646039712), ('color_moments_hsv_V_min', 0.01477926804323294), ('lbp_rad1_bins8_4', 0.01312992904781671), ('color_moments_lab_A_iqr', 0.012861311971709827), ('glcm_correlation_dist_1_angle_0', 0.012292590422853878)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier0; Done in 39.127785205841064 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier1
# INFO:utils.ml:Top 10 features for RandomForestClassifier1: [('color_moments_lab_A_min', 0.021533613170027305), ('color_moments_hsv_H_max', 0.01905071972407517), ('color_moments_lab_A_mean', 0.018273773407071592), ('color_moments_hsv_S_min', 0.017531669926098503), ('color_moments_lab_A_median', 0.016883403070022764), ('color_moments_lab_B_skew', 0.01642640646039712), ('color_moments_hsv_V_min', 0.01477926804323294), ('lbp_rad1_bins8_4', 0.01312992904781671), ('color_moments_lab_A_iqr', 0.012861311971709827), ('glcm_correlation_dist_1_angle_0', 0.012292590422853878)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier1; Done in 40.027437925338745 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier2
# INFO:utils.ml:Top 10 features for RandomForestClassifier2: [('color_moments_lab_A_min', 0.022062748602183265), ('color_moments_lab_A_mean', 0.019036279799971623), ('color_moments_hsv_H_max', 0.018553728584324528), ('color_moments_hsv_S_min', 0.018291505307495615), ('color_moments_lab_A_median', 0.017160731418745242), ('color_moments_lab_B_skew', 0.016919046822882738), ('color_moments_hsv_V_min', 0.014347930777217964), ('color_moments_lab_A_iqr', 0.012922630119571572), ('lbp_rad1_bins8_4', 0.012672897205936503), ('glcm_correlation_dist_1_angle_0', 0.01263112218750874)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier2; Done in 57.5259690284729 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier3
# INFO:utils.ml:Top 10 features for RandomForestClassifier3: [('color_moments_lab_A_min', 0.01947529943935101), ('color_moments_lab_A_mean', 0.019122655053888868), ('color_moments_hsv_H_max', 0.018842795576806185), ('color_moments_hsv_S_min', 0.01813240420230635), ('color_moments_lab_A_median', 0.017691164668825858), ('color_moments_lab_B_skew', 0.01588666717506029), ('color_moments_hsv_V_min', 0.014416864251224943), ('lbp_rad1_bins8_4', 0.013208274121821685), ('color_moments_lab_A_iqr', 0.012938346947293766), ('color_moments_rgb_R_min', 0.012633326116159742)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier3; Done in 51.30143880844116 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier4
# INFO:utils.ml:Top 10 features for RandomForestClassifier4: [('color_moments_lab_A_min', 0.01947529943935101), ('color_moments_lab_A_mean', 0.019122655053888868), ('color_moments_hsv_H_max', 0.018842795576806185), ('color_moments_hsv_S_min', 0.01813240420230635), ('color_moments_lab_A_median', 0.017691164668825858), ('color_moments_lab_B_skew', 0.01588666717506029), ('color_moments_hsv_V_min', 0.014416864251224943), ('lbp_rad1_bins8_4', 0.013208274121821685), ('color_moments_lab_A_iqr', 0.012938346947293766), ('color_moments_rgb_R_min', 0.012633326116159742)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier4; Done in 52.3050856590271 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier5
# INFO:utils.ml:Top 10 features for RandomForestClassifier5: [('color_moments_lab_A_min', 0.020084884069301853), ('color_moments_lab_A_mean', 0.01918182443545506), ('color_moments_hsv_S_min', 0.01858356724300322), ('color_moments_hsv_H_max', 0.01825043558691685), ('color_moments_lab_A_median', 0.01822502788918788), ('color_moments_lab_B_skew', 0.016263282558818915), ('color_moments_hsv_V_min', 0.014604314181963058), ('color_moments_lab_A_iqr', 0.013395400017142029), ('lbp_rad1_bins8_4', 0.013316951779896478), ('color_moments_rgb_R_min', 0.013284105096720244)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier5; Done in 87.54421210289001 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier6
# INFO:utils.ml:Top 10 features for XGBClassifier6: [('color_moments_lab_A_min', 0.0751464), ('color_moments_lab_B_skew', 0.025645208), ('color_moments_hsv_V_min', 0.02267054), ('color_moments_hsv_H_max', 0.021810118), ('lbp_rad1_bins8_4', 0.018709706), ('lbp_rad4_bins32_19', 0.013946708), ('lbp_rad4_bins32_27', 0.013743164), ('color_moments_hsv_S_min', 0.013660295), ('lbp_rad4_bins32_28', 0.012431553), ('lbp_rad4_bins32_5', 0.012068639)]
# INFO:utils.ml:Fitted classifier: XGBClassifier6; Done in 4.27302360534668 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier7
# INFO:utils.ml:Top 10 features for XGBClassifier7: [('color_moments_lab_A_min', 0.07663859), ('color_moments_lab_B_skew', 0.026087157), ('color_moments_hsv_H_max', 0.022496067), ('color_moments_hsv_V_min', 0.021677516), ('lbp_rad1_bins8_4', 0.01912028), ('color_moments_hsv_S_min', 0.0137380995), ('lbp_rad4_bins32_27', 0.013727298), ('lbp_rad4_bins32_19', 0.013191624), ('lbp_rad4_bins32_28', 0.012714816), ('gradient_magnitude_mean', 0.012279634)]
# INFO:utils.ml:Fitted classifier: XGBClassifier7; Done in 4.9236791133880615 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier8
# INFO:utils.ml:Top 10 features for XGBClassifier8: [('color_moments_lab_A_min', 0.07322401), ('color_moments_lab_B_skew', 0.02606785), ('color_moments_hsv_H_max', 0.022882808), ('color_moments_hsv_V_min', 0.020755492), ('lbp_rad1_bins8_4', 0.018800149), ('color_moments_hsv_S_min', 0.014112042), ('lbp_rad4_bins32_19', 0.013481917), ('lbp_rad4_bins32_27', 0.013414212), ('lbp_rad4_bins32_28', 0.013377866), ('gradient_magnitude_mean', 0.012444575)]
# INFO:utils.ml:Fitted classifier: XGBClassifier8; Done in 6.086417198181152 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier9
# INFO:utils.ml:Top 10 features for XGBClassifier9: [('color_moments_lab_A_min', 0.05616191), ('color_moments_lab_B_skew', 0.016878149), ('color_moments_hsv_S_min', 0.016222784), ('color_moments_hsv_H_max', 0.01596077), ('lbp_rad4_bins32_28', 0.015266456), ('color_moments_hsv_V_min', 0.012384691), ('lbp_rad2_bins16_8', 0.012017189), ('color_moments_lab_A_iqr', 0.011908737), ('lbp_rad1_bins8_4', 0.010724501), ('glcm_correlation_dist_1_angle_0', 0.010361148)]
# INFO:utils.ml:Fitted classifier: XGBClassifier9; Done in 5.399112939834595 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier10
# INFO:utils.ml:Top 10 features for XGBClassifier10: [('color_moments_lab_A_min', 0.053035628), ('color_moments_hsv_H_max', 0.01857454), ('color_moments_hsv_V_min', 0.018569669), ('color_moments_hsv_S_min', 0.018205855), ('color_moments_lab_B_skew', 0.016963731), ('color_moments_lab_A_iqr', 0.014885354), ('lbp_rad4_bins32_28', 0.013568416), ('lbp_rad4_bins32_27', 0.012390643), ('lbp_rad1_bins8_4', 0.011851503), ('color_moments_lab_A_mean', 0.009542185)]
# INFO:utils.ml:Fitted classifier: XGBClassifier10; Done in 5.947652578353882 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier11
# INFO:utils.ml:Top 10 features for XGBClassifier11: [('color_moments_lab_A_min', 0.05452408), ('color_moments_hsv_H_max', 0.018903421), ('color_moments_hsv_V_min', 0.018249592), ('color_moments_hsv_S_min', 0.017106097), ('color_moments_lab_B_skew', 0.016926508), ('color_moments_lab_A_iqr', 0.014669517), ('lbp_rad4_bins32_28', 0.013611947), ('lbp_rad1_bins8_4', 0.012078059), ('lbp_rad4_bins32_27', 0.012005644), ('color_moments_lab_A_mean', 0.009417257)]
# INFO:utils.ml:Fitted classifier: XGBClassifier11; Done in 7.321082592010498 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier12
# INFO:utils.ml:Top 10 features for XGBClassifier12: [('color_moments_lab_A_min', 0.054469403), ('color_moments_hsv_S_min', 0.020704817), ('color_moments_hsv_H_max', 0.019362329), ('color_moments_hsv_V_min', 0.01676702), ('color_moments_lab_B_skew', 0.016739774), ('lbp_rad1_bins8_4', 0.012759902), ('lbp_rad4_bins32_28', 0.01272418), ('color_moments_lab_A_iqr', 0.012624215), ('lbp_rad4_bins32_27', 0.010077565), ('glcm_correlation_dist_1_angle_0', 0.009211648)]
# INFO:utils.ml:Fitted classifier: XGBClassifier12; Done in 5.459641695022583 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier13
# INFO:utils.ml:Top 10 features for XGBClassifier13: [('color_moments_lab_A_min', 0.0562587), ('color_moments_lab_B_skew', 0.016424352), ('color_moments_hsv_H_max', 0.015639188), ('color_moments_hsv_S_min', 0.014472349), ('lbp_rad4_bins32_28', 0.013843158), ('color_moments_hsv_V_min', 0.012107287), ('color_moments_lab_A_iqr', 0.011537555), ('lbp_rad2_bins16_8', 0.010804573), ('lbp_rad1_bins8_4', 0.010646659), ('glcm_correlation_dist_1_angle_0', 0.010243636)]
# INFO:utils.ml:Fitted classifier: XGBClassifier13; Done in 8.738988399505615 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier14
# INFO:utils.ml:Top 10 features for XGBClassifier14: [('color_moments_lab_A_min', 0.055483658), ('color_moments_hsv_H_max', 0.018763924), ('color_moments_hsv_V_min', 0.018011676), ('color_moments_hsv_S_min', 0.017631616), ('color_moments_lab_B_skew', 0.016930716), ('color_moments_lab_A_iqr', 0.014673992), ('lbp_rad4_bins32_28', 0.013054763), ('lbp_rad1_bins8_4', 0.012601872), ('lbp_rad4_bins32_27', 0.011014388), ('color_moments_lab_A_mean', 0.009146603)]
# INFO:utils.ml:Fitted classifier: XGBClassifier14; Done in 10.371845483779907 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier15
# INFO:utils.ml:Top 10 features for XGBClassifier15: [('color_moments_lab_A_min', 0.055483658), ('color_moments_hsv_H_max', 0.018763924), ('color_moments_hsv_V_min', 0.018011676), ('color_moments_hsv_S_min', 0.017631616), ('color_moments_lab_B_skew', 0.016930716), ('color_moments_lab_A_iqr', 0.014673992), ('lbp_rad4_bins32_28', 0.013054763), ('lbp_rad1_bins8_4', 0.012601872), ('lbp_rad4_bins32_27', 0.011014388), ('color_moments_lab_A_mean', 0.009146603)]
# INFO:utils.ml:Fitted classifier: XGBClassifier15; Done in 10.314990282058716 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier16
# INFO:utils.ml:Top 10 features for XGBClassifier16: [('color_moments_lab_A_min', 0.05481618), ('color_moments_hsv_S_min', 0.019802596), ('color_moments_hsv_H_max', 0.01839163), ('color_moments_lab_B_skew', 0.017352013), ('color_moments_hsv_V_min', 0.015360101), ('lbp_rad1_bins8_4', 0.012790421), ('lbp_rad4_bins32_28', 0.012753191), ('color_moments_lab_A_iqr', 0.011827958), ('lbp_rad4_bins32_27', 0.009758906), ('glcm_correlation_dist_1_angle_0', 0.009409949)]
# INFO:utils.ml:Fitted classifier: XGBClassifier16; Done in 8.07554817199707 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier17
# INFO:utils.ml:Top 10 features for XGBClassifier17: [('color_moments_lab_A_min', 0.0548387), ('color_moments_lab_B_skew', 0.017018605), ('color_moments_hsv_H_max', 0.0151919415), ('color_moments_hsv_S_min', 0.014590261), ('lbp_rad4_bins32_28', 0.013553394), ('color_moments_hsv_V_min', 0.012995925), ('color_moments_lab_A_iqr', 0.0115179205), ('lbp_rad2_bins16_8', 0.010247562), ('lbp_rad1_bins8_4', 0.010004409), ('lbp_rad4_bins32_27', 0.009927327)]
# INFO:utils.ml:Fitted classifier: XGBClassifier17; Done in 10.916695594787598 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier18
# INFO:utils.ml:Top 10 features for XGBClassifier18: [('color_moments_lab_A_min', 0.05583966), ('color_moments_hsv_H_max', 0.018624233), ('color_moments_hsv_V_min', 0.01817106), ('color_moments_hsv_S_min', 0.017397232), ('color_moments_lab_B_skew', 0.016592354), ('color_moments_lab_A_iqr', 0.014533264), ('lbp_rad4_bins32_28', 0.012852309), ('lbp_rad1_bins8_4', 0.012500472), ('lbp_rad4_bins32_27', 0.0112526445), ('color_moments_lab_A_mean', 0.009032405)]
# INFO:utils.ml:Fitted classifier: XGBClassifier18; Done in 9.371803760528564 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier19
# INFO:utils.ml:Top 10 features for XGBClassifier19: [('color_moments_lab_A_min', 0.05583966), ('color_moments_hsv_H_max', 0.018624233), ('color_moments_hsv_V_min', 0.01817106), ('color_moments_hsv_S_min', 0.017397232), ('color_moments_lab_B_skew', 0.016592354), ('color_moments_lab_A_iqr', 0.014533264), ('lbp_rad4_bins32_28', 0.012852309), ('lbp_rad1_bins8_4', 0.012500472), ('lbp_rad4_bins32_27', 0.0112526445), ('color_moments_lab_A_mean', 0.009032405)]
# INFO:utils.ml:Fitted classifier: XGBClassifier19; Done in 9.073846101760864 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier20
# INFO:utils.ml:Top 10 features for XGBClassifier20: [('color_moments_lab_A_min', 0.056234676), ('color_moments_hsv_S_min', 0.019311132), ('color_moments_hsv_H_max', 0.018185169), ('color_moments_lab_B_skew', 0.017217409), ('color_moments_hsv_V_min', 0.015232919), ('lbp_rad1_bins8_4', 0.0132878795), ('lbp_rad4_bins32_28', 0.012554975), ('color_moments_lab_A_iqr', 0.011745513), ('glcm_correlation_dist_1_angle_0', 0.009894245), ('lbp_rad4_bins32_27', 0.009780621)]
# INFO:utils.ml:Fitted classifier: XGBClassifier20; Done in 7.297093629837036 seconds
# INFO:utils.ml:Fitting completed in 441.40 seconds.

# %%
pipeline.predict_with_classifiers(VAL_PATH, percent)
# Out:
# INFO:utils.ml:Predicting with classifiers on dataset: C:\Users\gimes\Src\repos\CADx-Project\dataset\binary\val
# Processed 5/159 batches.
# Processed 10/159 batches.
# Processed 15/159 batches.
# Processed 20/159 batches.
# Processed 25/159 batches.
# Processed 30/159 batches.
# Processed 35/159 batches.
# Processed 40/159 batches.
# Processed 45/159 batches.
# Processed 50/159 batches.
# Processed 55/159 batches.
# Processed 60/159 batches.
# Processed 65/159 batches.
# Processed 70/159 batches.
# Processed 75/159 batches.
# Processed 80/159 batches.
# Processed 85/159 batches.
# Processed 90/159 batches.
# Processed 95/159 batches.
# Processed 100/159 batches.
# Processed 105/159 batches.
# Processed 110/159 batches.
# Processed 115/159 batches.
# Processed 120/159 batches.
# Processed 125/159 batches.
# Processed 130/159 batches.
# Processed 135/159 batches.
# Processed 140/159 batches.
# Processed 145/159 batches.
# Processed 150/159 batches.
# Processed 155/159 batches.
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier0
# Processed 159/159 batches.
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier1
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier2
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier3
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier4
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier5
# INFO:utils.ml:Predictions made with classifier: XGBClassifier6
# INFO:utils.ml:Predictions made with classifier: XGBClassifier7
# INFO:utils.ml:Predictions made with classifier: XGBClassifier8
# INFO:utils.ml:Predictions made with classifier: XGBClassifier9
# INFO:utils.ml:Predictions made with classifier: XGBClassifier10
# INFO:utils.ml:Predictions made with classifier: XGBClassifier11
# INFO:utils.ml:Predictions made with classifier: XGBClassifier12
# INFO:utils.ml:Predictions made with classifier: XGBClassifier13
# INFO:utils.ml:Predictions made with classifier: XGBClassifier14
# INFO:utils.ml:Predictions made with classifier: XGBClassifier15
# INFO:utils.ml:Predictions made with classifier: XGBClassifier16
# INFO:utils.ml:Predictions made with classifier: XGBClassifier17
# INFO:utils.ml:Predictions made with classifier: XGBClassifier18
# INFO:utils.ml:Predictions made with classifier: XGBClassifier19
# INFO:utils.ml:Predictions made with classifier: XGBClassifier20
# {'GT': array([0, 0, 0, ..., 1, 1, 1]),
#  'RandomForestClassifier0': array([0, 0, 0, ..., 0, 0, 1]),
#  'RandomForestClassifier1': array([0, 0, 0, ..., 0, 0, 1]),
#  'RandomForestClassifier2': array([0, 0, 0, ..., 0, 0, 1]),
#  'RandomForestClassifier3': array([0, 0, 0, ..., 0, 0, 1]),
#  'RandomForestClassifier4': array([0, 0, 0, ..., 0, 0, 1]),
#  'RandomForestClassifier5': array([0, 0, 0, ..., 0, 0, 1]),
#  'XGBClassifier6': array([0, 0, 0, ..., 1, 1, 1]),
#  'XGBClassifier7': array([0, 0, 0, ..., 1, 0, 1]),
#  'XGBClassifier8': array([0, 0, 0, ..., 1, 0, 1]),
#  'XGBClassifier9': array([0, 0, 0, ..., 0, 1, 1]),
#  'XGBClassifier10': array([0, 0, 0, ..., 1, 1, 1]),
#  'XGBClassifier11': array([0, 0, 0, ..., 1, 1, 1]),
#  'XGBClassifier12': array([0, 0, 0, ..., 1, 1, 1]),
#  'XGBClassifier13': array([0, 0, 0, ..., 0, 1, 1]),
#  'XGBClassifier14': array([0, 0, 0, ..., 1, 1, 1]),
#  'XGBClassifier15': array([0, 0, 0, ..., 1, 1, 1]),
#  'XGBClassifier16': array([0, 0, 0, ..., 1, 0, 1]),
#  'XGBClassifier17': array([0, 0, 0, ..., 1, 1, 1]),
#  'XGBClassifier18': array([0, 0, 0, ..., 1, 1, 1]),
#  'XGBClassifier19': array([0, 0, 0, ..., 1, 1, 1]),
#  'XGBClassifier20': array([0, 0, 0, ..., 1, 0, 1])}

# %%
import pandas as pd

df = pd.DataFrame(data=pipeline.calculate_metrics())
df = df.T
df
# Out:
# INFO:utils.ml:Metrics for classifier GT: {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'kappa': 1.0}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier0: {'accuracy': 0.8358798735511064, 'precision': 0.8360163046378822, 'recall': 0.8356607239300089, 'f1': 0.835758951988842, 'kappa': 0.6715491317726704}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier1: {'accuracy': 0.8358798735511064, 'precision': 0.8360163046378822, 'recall': 0.8356607239300089, 'f1': 0.835758951988842, 'kappa': 0.6715491317726704}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier2: {'accuracy': 0.8469441517386723, 'precision': 0.8471328867300096, 'recall': 0.8467100212005892, 'f1': 0.8468224462183276, 'kappa': 0.6936806555180305}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier3: {'accuracy': 0.8348261327713382, 'precision': 0.8348611439881666, 'recall': 0.8346708077466147, 'f1': 0.8347352863673339, 'kappa': 0.6694827132254019}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier4: {'accuracy': 0.8348261327713382, 'precision': 0.8348611439881666, 'recall': 0.8346708077466147, 'f1': 0.8347352863673339, 'kappa': 0.6694827132254019}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier5: {'accuracy': 0.8464172813487882, 'precision': 0.8466454598033546, 'recall': 0.8461646648515889, 'f1': 0.8462858474456487, 'kappa': 0.6926149290383157}
# INFO:utils.ml:Metrics for classifier XGBClassifier6: {'accuracy': 0.8377239199157007, 'precision': 0.8377245796739614, 'recall': 0.8376015427697938, 'f1': 0.8376481612165112, 'kappa': 0.6753020936811869}
# INFO:utils.ml:Metrics for classifier XGBClassifier7: {'accuracy': 0.839304531085353, 'precision': 0.8395106319382173, 'recall': 0.8390543454266011, 'f1': 0.8391694789573423, 'kappa': 0.678382205100583}
# INFO:utils.ml:Metrics for classifier XGBClassifier8: {'accuracy': 0.8411485774499473, 'precision': 0.8413477846471751, 'recall': 0.8409035310712892, 'f1': 0.8410174933765624, 'kappa': 0.6820758155235596}
# INFO:utils.ml:Metrics for classifier XGBClassifier9: {'accuracy': 0.8432560590094836, 'precision': 0.8434204746999071, 'recall': 0.8430299765502324, 'f1': 0.8431360401861543, 'kappa': 0.6863052176260851}
# INFO:utils.ml:Metrics for classifier XGBClassifier10: {'accuracy': 0.8440463645943098, 'precision': 0.8440833821612006, 'recall': 0.843898409331036, 'f1': 0.8439625070962997, 'kappa': 0.6879355016637556}
# INFO:utils.ml:Metrics for classifier XGBClassifier11: {'accuracy': 0.8448366701791359, 'precision': 0.844813144329897, 'recall': 0.8447485154728203, 'f1': 0.8447760762971873, 'kappa': 0.6895538983698499}
# INFO:utils.ml:Metrics for classifier XGBClassifier12: {'accuracy': 0.839831401475237, 'precision': 0.839981953447567, 'recall': 0.839608865095111, 'f1': 0.8397110870350307, 'kappa': 0.6794543203573495}
# INFO:utils.ml:Metrics for classifier XGBClassifier13: {'accuracy': 0.8408851422550052, 'precision': 0.8412277927034291, 'recall': 0.8405804546394858, 'f1': 0.840720619182073, 'kappa': 0.6815106236562247}
# INFO:utils.ml:Metrics for classifier XGBClassifier14: {'accuracy': 0.8458904109589042, 'precision': 0.8459118815456843, 'recall': 0.8457567582952339, 'f1': 0.8458131014496135, 'kappa': 0.6916339321818497}
# INFO:utils.ml:Metrics for classifier XGBClassifier15: {'accuracy': 0.8458904109589042, 'precision': 0.8459118815456843, 'recall': 0.8457567582952339, 'f1': 0.8458131014496135, 'kappa': 0.6916339321818497}
# INFO:utils.ml:Metrics for classifier XGBClassifier16: {'accuracy': 0.8429926238145417, 'precision': 0.8431133031213911, 'recall': 0.8427893699940161, 'f1': 0.8428835880067913, 'kappa': 0.6857924005740803}
# INFO:utils.ml:Metrics for classifier XGBClassifier17: {'accuracy': 0.8408851422550052, 'precision': 0.8411142653989823, 'recall': 0.8406262712370343, 'f1': 0.8407465073453825, 'kappa': 0.6815398201620814}
# INFO:utils.ml:Metrics for classifier XGBClassifier18: {'accuracy': 0.8461538461538461, 'precision': 0.8461601281998932, 'recall': 0.8460340181294888, 'f1': 0.8460820229714977, 'kappa': 0.6921695173860603}
# INFO:utils.ml:Metrics for classifier XGBClassifier19: {'accuracy': 0.8461538461538461, 'precision': 0.8461601281998932, 'recall': 0.8460340181294888, 'f1': 0.8460820229714977, 'kappa': 0.6921695173860603}
# INFO:utils.ml:Metrics for classifier XGBClassifier20: {'accuracy': 0.8440463645943098, 'precision': 0.8441369650973269, 'recall': 0.8438617560529973, 'f1': 0.8439465570400821, 'kappa': 0.6879126189996736}
#                          accuracy  precision    recall        f1     kappa
# GT                       1.000000   1.000000  1.000000  1.000000  1.000000
# RandomForestClassifier0  0.835880   0.836016  0.835661  0.835759  0.671549
# RandomForestClassifier1  0.835880   0.836016  0.835661  0.835759  0.671549
# RandomForestClassifier2  0.846944   0.847133  0.846710  0.846822  0.693681
# RandomForestClassifier3  0.834826   0.834861  0.834671  0.834735  0.669483
# RandomForestClassifier4  0.834826   0.834861  0.834671  0.834735  0.669483
# RandomForestClassifier5  0.846417   0.846645  0.846165  0.846286  0.692615
# XGBClassifier6           0.837724   0.837725  0.837602  0.837648  0.675302
# XGBClassifier7           0.839305   0.839511  0.839054  0.839169  0.678382
# XGBClassifier8           0.841149   0.841348  0.840904  0.841017  0.682076
# XGBClassifier9           0.843256   0.843420  0.843030  0.843136  0.686305
# XGBClassifier10          0.844046   0.844083  0.843898  0.843963  0.687936
# XGBClassifier11          0.844837   0.844813  0.844749  0.844776  0.689554
# XGBClassifier12          0.839831   0.839982  0.839609  0.839711  0.679454
# XGBClassifier13          0.840885   0.841228  0.840580  0.840721  0.681511
# XGBClassifier14          0.845890   0.845912  0.845757  0.845813  0.691634
# XGBClassifier15          0.845890   0.845912  0.845757  0.845813  0.691634
# XGBClassifier16          0.842993   0.843113  0.842789  0.842884  0.685792
# XGBClassifier17          0.840885   0.841114  0.840626  0.840747  0.681540
# XGBClassifier18          0.846154   0.846160  0.846034  0.846082  0.692170
# XGBClassifier19          0.846154   0.846160  0.846034  0.846082  0.692170
# XGBClassifier20          0.844046   0.844137  0.843862  0.843947  0.687913

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

highest = df[df["accuracy"] == df.iloc[1:]["accuracy"].max()]
idx = highest.index[0]

print(classification_report(pipeline.predictions["GT"], pipeline.predictions[idx]))
print(confusion_matrix(pipeline.predictions["GT"], pipeline.predictions[idx]))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.86      0.85      1931
#            1       0.85      0.83      0.84      1865
#
#     accuracy                           0.85      3796
#    macro avg       0.85      0.85      0.85      3796
# weighted avg       0.85      0.85      0.85      3796
#
# [[1661  270]
#  [ 311 1554]]

# %%
pipeline.top_features_per_classifier[idx]
# Out:
# [('color_moments_lab_A_min', 0.022062748602183265),
#  ('color_moments_lab_A_mean', 0.019036279799971623),
#  ('color_moments_hsv_H_max', 0.018553728584324528),
#  ('color_moments_hsv_S_min', 0.018291505307495615),
#  ('color_moments_lab_A_median', 0.017160731418745242),
#  ('color_moments_lab_B_skew', 0.016919046822882738),
#  ('color_moments_hsv_V_min', 0.014347930777217964),
#  ('color_moments_lab_A_iqr', 0.012922630119571572),
#  ('lbp_rad1_bins8_4', 0.012672897205936503),
#  ('glcm_correlation_dist_1_angle_0', 0.01263112218750874)]

# %%
df_sorted = df.sort_values("accuracy", ascending=False)
df_sorted
# Out:
#                          accuracy  precision    recall        f1     kappa
# GT                       1.000000   1.000000  1.000000  1.000000  1.000000
# RandomForestClassifier2  0.846944   0.847133  0.846710  0.846822  0.693681
# RandomForestClassifier5  0.846417   0.846645  0.846165  0.846286  0.692615
# XGBClassifier19          0.846154   0.846160  0.846034  0.846082  0.692170
# XGBClassifier18          0.846154   0.846160  0.846034  0.846082  0.692170
# XGBClassifier15          0.845890   0.845912  0.845757  0.845813  0.691634
# XGBClassifier14          0.845890   0.845912  0.845757  0.845813  0.691634
# XGBClassifier11          0.844837   0.844813  0.844749  0.844776  0.689554
# XGBClassifier10          0.844046   0.844083  0.843898  0.843963  0.687936
# XGBClassifier20          0.844046   0.844137  0.843862  0.843947  0.687913
# XGBClassifier9           0.843256   0.843420  0.843030  0.843136  0.686305
# XGBClassifier16          0.842993   0.843113  0.842789  0.842884  0.685792
# XGBClassifier8           0.841149   0.841348  0.840904  0.841017  0.682076
# XGBClassifier13          0.840885   0.841228  0.840580  0.840721  0.681511
# XGBClassifier17          0.840885   0.841114  0.840626  0.840747  0.681540
# XGBClassifier12          0.839831   0.839982  0.839609  0.839711  0.679454
# XGBClassifier7           0.839305   0.839511  0.839054  0.839169  0.678382
# XGBClassifier6           0.837724   0.837725  0.837602  0.837648  0.675302
# RandomForestClassifier0  0.835880   0.836016  0.835661  0.835759  0.671549
# RandomForestClassifier1  0.835880   0.836016  0.835661  0.835759  0.671549
# RandomForestClassifier4  0.834826   0.834861  0.834671  0.834735  0.669483
# RandomForestClassifier3  0.834826   0.834861  0.834671  0.834735  0.669483
