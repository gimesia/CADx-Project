# %%
from utils.loader import FactoryLoader
from utils.ml import MLPipeline
from utils.preprocessing import PreprocessingFactory
from utils.feature_extraction import *
from utils.utils import *

VAL_PATH = r"C:\Users\gimes\Src\repos\CADx-Project\dataset\binary\val"
TRAIN_PATH = r"C:\Users\gimes\Src\repos\CADx-Project\dataset\binary\train"

# %%
percent = 100
random = False
batch_size = 48

# Initialize the FactoryLoader
factory = PreprocessingFactory()
factory.gaussian_smoothing(5)
factory.clahe(clip_limit=1.5)
factory.pad2square(fill=np.nan)
factory.resize((150,150))
factory.hair_removal()
factory.normalize2float()

factory_loader = FactoryLoader(path=VAL_PATH, batch_size=batch_size, factory=factory, percentage=percent, shuffle=random)

# Create the feature extraction pipeline strategy and add desired features
strategy = FeatureExtractionStrategy()

strategy.add_extractor(GradientExtractor())   # Add variance feature

# strategy.add_extractor(MeanExtractor())  # Add mean feature
# strategy.add_extractor(StdExtractor())   # Add standard deviation feature
strategy.add_extractor(VarExtractor())   # Add variance feature
strategy.add_extractor(ColorMomentsExtractor())   # Add color moments feature


# strategy.add_extractor(MeanExtractor("lab"))  # Add mean feature
# strategy.add_extractor(StdExtractor("lab"))   # Add standard deviation feature
strategy.add_extractor(VarExtractor("lab"))   # Add variance feature
strategy.add_extractor(ColorMomentsExtractor("lab"))   # Add color moments feature

# strategy.add_extractor(MeanExtractor("hsv"))  # Add mean feature
# strategy.add_extractor(StdExtractor("hsv"))   # Add standard deviation feature
strategy.add_extractor(VarExtractor("hsv"))   # Add variance feature
strategy.add_extractor(ColorMomentsExtractor("hsv"))   # Add color moments feature

strategy.add_extractor(LBPExtractor(radius=1, n_points=16))
strategy.add_extractor(LBPExtractor(radius=2, n_points=16))
strategy.add_extractor(LBPExtractor(radius=3, n_points=16))
strategy.add_extractor(LBPExtractor(radius=1, n_points=32))
strategy.add_extractor(LBPExtractor(radius=2, n_points=32))
strategy.add_extractor(LBPExtractor(radius=3, n_points=32))
strategy.add_extractor(LBPExtractor(radius=1, n_points=64))
strategy.add_extractor(LBPExtractor(radius=2, n_points=64))
strategy.add_extractor(LBPExtractor(radius=3, n_points=64))

strategy.add_extractor(GLCMExtractor(properties=['contrast', 'dissimilarity', 'homogeneity', 'energy', 'correlation',]))

pipeline = MLPipeline(dataset_path=TRAIN_PATH, preprocessing_factory=factory, feature_strategy=strategy, classifiers=[], percentage=percent, verbose=True, shuffle=random, batch_size=batch_size)
# Out:
# INFO:utils.ml:MLPipeline initialized with dataset path: C:\Users\gimes\Src\repos\CADx-Project\dataset\binary\train
# INFO:utils.ml:Preprocessing steps

# %%
pipeline.run_feature_extraction()
# Out:
# INFO:utils.ml:Running feature extraction...
# Processed 5/317 batches.
# Processed 10/317 batches.
# Processed 15/317 batches.
# Processed 20/317 batches.
# Processed 25/317 batches.
# Processed 30/317 batches.
# Processed 35/317 batches.
# Processed 40/317 batches.
# Processed 45/317 batches.
# Processed 50/317 batches.
# Processed 55/317 batches.
# Processed 60/317 batches.
# Processed 65/317 batches.
# Processed 70/317 batches.
# Processed 75/317 batches.
# Processed 80/317 batches.
# Processed 85/317 batches.
# Processed 90/317 batches.
# Processed 95/317 batches.
# Processed 100/317 batches.
# Processed 105/317 batches.
# Processed 110/317 batches.
# Processed 115/317 batches.
# Processed 120/317 batches.
# Processed 125/317 batches.
# Processed 130/317 batches.
# Processed 135/317 batches.
# Processed 140/317 batches.
# Processed 145/317 batches.
# Processed 150/317 batches.
# Processed 155/317 batches.
# Processed 160/317 batches.
# Processed 165/317 batches.
# Processed 170/317 batches.
# Processed 175/317 batches.
# Processed 180/317 batches.
# Processed 185/317 batches.
# Processed 190/317 batches.
# Processed 195/317 batches.
# Processed 200/317 batches.
# Processed 205/317 batches.
# Processed 210/317 batches.
# Processed 215/317 batches.
# Processed 220/317 batches.
# Processed 225/317 batches.
# Processed 230/317 batches.
# Processed 235/317 batches.
# Processed 240/317 batches.
# Processed 245/317 batches.
# Processed 250/317 batches.
# Processed 255/317 batches.
# Processed 260/317 batches.
# Processed 265/317 batches.
# Processed 270/317 batches.
# Processed 275/317 batches.
# Processed 280/317 batches.
# Processed 285/317 batches.
# Processed 290/317 batches.
# Processed 295/317 batches.
# Processed 300/317 batches.
# Processed 305/317 batches.
# Processed 310/317 batches.
# Processed 315/317 batches.
# INFO:utils.ml:Feature extraction completed. Extracted 15195 features.
# Processed 317/317 batches.

# %%
from xgboost import XGBClassifier
from sklearn.ensemble import RandomForestClassifier

rf1 = RandomForestClassifier(n_estimators=100)
rf2 = RandomForestClassifier(n_estimators=150)
rf3 = RandomForestClassifier(n_estimators=250)

# Random Forest with Class Weight Balancing
rf4 = RandomForestClassifier(n_estimators=100, class_weight="balanced", random_state=42)
# Random Forest with Feature Selection via max_features
rf5 = RandomForestClassifier(n_estimators=100, max_features='sqrt', random_state=42)
# Random Forest with Min Samples per Leaf
rf6 = RandomForestClassifier(n_estimators=100, min_samples_leaf=5, random_state=42)
# Random Forest with Out-of-Bag Error (OOB)
rf7 = RandomForestClassifier(n_estimators=100, oob_score=True, random_state=42)
# Random Forest with Bootstrap Disabled
rf8 = RandomForestClassifier(n_estimators=100, bootstrap=False, random_state=42)
# Random Forest with High Number of Trees and Limited Depth
rf9 = RandomForestClassifier(n_estimators=100, max_depth=5, random_state=42)

xgb1 = XGBClassifier(n_estimators=350)
xgb2 = XGBClassifier(n_estimators=450)
xgb3 = XGBClassifier(n_estimators=550)
xgb4 = XGBClassifier(learning_rate=0.05, n_estimators=400, max_depth=3, min_child_weight=1, subsample=0.8, colsample_bytree=0.8)
xgb5 = XGBClassifier(learning_rate=0.1, n_estimators=400, max_depth=7, min_child_weight=3, subsample=0.7, colsample_bytree=0.7)
xgb6 = XGBClassifier(learning_rate=0.1, n_estimators=400, max_depth=5, min_child_weight=5, gamma=0.2, subsample=0.8, colsample_bytree=0.8)
xgb7 = XGBClassifier(learning_rate=0.1, n_estimators=400, max_depth=5, min_child_weight=1, subsample=0.8, colsample_bytree=0.8, reg_alpha=0.1, reg_lambda=0.1)
xgb8 = XGBClassifier(learning_rate=0.05, n_estimators=500, max_depth=7, min_child_weight=1, subsample=0.8, colsample_bytree=0.8)
xgb9 = XGBClassifier(learning_rate=0.05, n_estimators=400, max_depth=7, min_child_weight=1, subsample=0.8, colsample_bytree=0.8)
xgb10 = XGBClassifier(learning_rate=0.1, n_estimators=400, max_depth=7, min_child_weight=1, subsample=0.8, colsample_bytree=0.8)
xgb11 = XGBClassifier(learning_rate=0.1, n_estimators=500, max_depth=7, min_child_weight=1, subsample=0.8, colsample_bytree=0.8)


pipeline.classifiers = [rf1, rf2, rf3, rf4, rf5, rf6, rf7, rf8, rf9,
                        # svm1, svm2, svm3, svm6, svm7, svm8,
                        xgb1, xgb2, xgb3, xgb4, xgb5, xgb6, xgb7, xgb8, xgb9, xgb10, xgb11]
pipeline.fitted_classifiers = {}

# %%
pipeline.fit_classifiers()
# Out:
# INFO:utils.ml:Fitting classifiers...
# INFO:utils.ml:Fitting classifier: RandomForestClassifier0
# INFO:utils.ml:Top 10 features for RandomForestClassifier0: [('lbp_rad1_bins16_10', 0.028082191376127438), ('color_moments_lab_channel_2_std', 0.020123520598845784), ('lbp_rad1_bins32_10', 0.01972732740133852), ('lbp_rad1_bins64_10', 0.01884910963690939), ('lbp_rad1_bins64_40', 0.014071808312560054), ('lbp_rad2_bins32_10', 0.013087178456433361), ('lbp_rad2_bins64_10', 0.011351491421494574), ('gradient_magnitude_mean', 0.011273371213664191), ('lbp_rad1_bins64_63', 0.009823702374122566), ('color_moments_rgb_channel_0_mean', 0.00967162478132344)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier0; Done in 17.774466276168823 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier1
# INFO:utils.ml:Top 10 features for RandomForestClassifier1: [('lbp_rad1_bins64_10', 0.02163518314717745), ('lbp_rad1_bins16_10', 0.01975516511707207), ('color_moments_lab_channel_2_std', 0.019584428680643626), ('lbp_rad1_bins32_10', 0.01903134809615701), ('gradient_magnitude_mean', 0.012276484636507143), ('lbp_rad2_bins32_10', 0.01149331164622798), ('lbp_rad2_bins32_2', 0.011245918252764386), ('lbp_rad1_bins32_25', 0.01015082079795443), ('lbp_rad2_bins64_10', 0.010064193635418134), ('lbp_rad2_bins32_8', 0.00942631216411644)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier1; Done in 26.514487266540527 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier2
# INFO:utils.ml:Top 10 features for RandomForestClassifier2: [('lbp_rad1_bins32_10', 0.024647443087034086), ('lbp_rad1_bins16_10', 0.022355802936273816), ('color_moments_lab_channel_2_std', 0.020041815898292892), ('lbp_rad1_bins64_10', 0.01888145179762958), ('lbp_rad2_bins64_10', 0.012080258473460408), ('gradient_magnitude_mean', 0.010610076068839751), ('lbp_rad1_bins32_25', 0.010528239569154114), ('lbp_rad1_bins64_41', 0.010109187396038456), ('color_moments_rgb_channel_0_mean', 0.009849030714286175), ('lbp_rad2_bins16_4', 0.009455503168175559)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier2; Done in 44.6478271484375 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier3
# INFO:utils.ml:Top 10 features for RandomForestClassifier3: [('lbp_rad1_bins64_10', 0.025790884883564402), ('lbp_rad1_bins32_10', 0.02274810771842289), ('lbp_rad1_bins16_10', 0.018627831010746065), ('color_moments_lab_channel_2_std', 0.017645063619946368), ('lbp_rad2_bins64_10', 0.01547047549553898), ('lbp_rad1_bins64_41', 0.01263098555109918), ('lbp_rad1_bins64_40', 0.01253741269732547), ('lbp_rad1_bins64_63', 0.011720947994860884), ('color_moments_rgb_channel_0_mean', 0.011011645519782634), ('gradient_magnitude_mean', 0.010677039403139627)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier3; Done in 17.982049465179443 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier4
# INFO:utils.ml:Top 10 features for RandomForestClassifier4: [('lbp_rad1_bins64_10', 0.02421336426555791), ('lbp_rad1_bins32_10', 0.023913678605652876), ('color_moments_lab_channel_2_std', 0.020532462991106466), ('lbp_rad1_bins16_10', 0.019062984367213317), ('lbp_rad1_bins64_41', 0.01268317220584773), ('lbp_rad2_bins64_10', 0.012320469198458412), ('lbp_rad1_bins64_63', 0.010868581500929201), ('gradient_magnitude_mean', 0.010738213403049524), ('lbp_rad2_bins16_4', 0.009764040861909526), ('color_moments_rgb_channel_0_mean', 0.009722995205456886)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier4; Done in 17.72375226020813 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier5
# INFO:utils.ml:Top 10 features for RandomForestClassifier5: [('lbp_rad1_bins64_10', 0.0306570260358336), ('lbp_rad1_bins32_10', 0.030010623671954173), ('lbp_rad1_bins16_10', 0.025106181191061686), ('color_moments_lab_channel_2_std', 0.01983505744507641), ('lbp_rad2_bins64_10', 0.016506679530258063), ('color_moments_rgb_channel_0_mean', 0.015586226603660037), ('lbp_rad1_bins64_41', 0.015173580523225934), ('lbp_rad1_bins64_63', 0.01456485106396743), ('gradient_magnitude_mean', 0.013252298865809663), ('lbp_rad1_bins64_40', 0.011945313654104193)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier5; Done in 14.60758638381958 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier6
# INFO:utils.ml:Top 10 features for RandomForestClassifier6: [('lbp_rad1_bins64_10', 0.02421336426555791), ('lbp_rad1_bins32_10', 0.023913678605652876), ('color_moments_lab_channel_2_std', 0.020532462991106466), ('lbp_rad1_bins16_10', 0.019062984367213317), ('lbp_rad1_bins64_41', 0.01268317220584773), ('lbp_rad2_bins64_10', 0.012320469198458412), ('lbp_rad1_bins64_63', 0.010868581500929201), ('gradient_magnitude_mean', 0.010738213403049524), ('lbp_rad2_bins16_4', 0.009764040861909526), ('color_moments_rgb_channel_0_mean', 0.009722995205456886)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier6; Done in 18.05461835861206 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier7
# INFO:utils.ml:Top 10 features for RandomForestClassifier7: [('lbp_rad1_bins64_10', 0.027423958859542758), ('lbp_rad1_bins32_10', 0.023119317518278257), ('lbp_rad1_bins16_10', 0.020220011463977797), ('color_moments_lab_channel_2_std', 0.017939666429666455), ('lbp_rad1_bins64_41', 0.012818762620579014), ('lbp_rad2_bins64_10', 0.01237314844125896), ('gradient_magnitude_mean', 0.011200756804310603), ('lbp_rad1_bins64_63', 0.011197044016709927), ('color_moments_rgb_channel_0_mean', 0.010040137429827551), ('lbp_rad2_bins16_4', 0.00970327211242195)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier7; Done in 25.91653871536255 seconds
# INFO:utils.ml:Fitting classifier: RandomForestClassifier8
# INFO:utils.ml:Top 10 features for RandomForestClassifier8: [('lbp_rad1_bins32_10', 0.06519599020231232), ('lbp_rad1_bins64_10', 0.057950862792182596), ('lbp_rad1_bins16_10', 0.057839387147289055), ('lbp_rad1_bins64_41', 0.03658702702176815), ('lbp_rad2_bins64_10', 0.03366709981746516), ('color_moments_lab_channel_2_std', 0.0308567193959775), ('lbp_rad1_bins64_63', 0.030487616435185903), ('lbp_rad2_bins16_4', 0.025633598218020956), ('lbp_rad1_bins64_40', 0.02469184564031554), ('lbp_rad2_bins32_2', 0.023295355273346238)]
# INFO:utils.ml:Fitted classifier: RandomForestClassifier8; Done in 5.270726919174194 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier9
# INFO:utils.ml:Top 10 features for XGBClassifier9: [('lbp_rad1_bins32_10', 0.13340628), ('color_moments_hsv_channel_2_std', 0.023158876), ('lbp_rad1_bins64_10', 0.018507963), ('color_moments_lab_channel_2_std', 0.018454589), ('lbp_rad1_bins16_10', 0.010459337), ('lbp_rad1_bins64_41', 0.0074416804), ('lbp_rad3_bins16_8', 0.0072330693), ('color_moments_hsv_channel_0_std', 0.0055938982), ('lbp_rad2_bins16_16', 0.00555739), ('lbp_rad1_bins16_3', 0.0052868384)]
# INFO:utils.ml:Fitted classifier: XGBClassifier9; Done in 7.040252447128296 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier10
# INFO:utils.ml:Top 10 features for XGBClassifier10: [('lbp_rad1_bins32_10', 0.13850576), ('color_moments_hsv_channel_2_std', 0.020519027), ('color_moments_lab_channel_2_std', 0.018469956), ('lbp_rad1_bins64_10', 0.018074227), ('lbp_rad1_bins16_10', 0.011258858), ('lbp_rad1_bins64_41', 0.008109045), ('lbp_rad2_bins16_16', 0.0056323954), ('color_moments_hsv_channel_0_std', 0.0055826223), ('lbp_rad1_bins32_32', 0.005187092), ('lbp_rad1_bins16_3', 0.0051115816)]
# INFO:utils.ml:Fitted classifier: XGBClassifier10; Done in 15.551525354385376 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier11
# INFO:utils.ml:Top 10 features for XGBClassifier11: [('lbp_rad1_bins32_10', 0.13847257), ('color_moments_lab_channel_2_std', 0.019083843), ('color_moments_hsv_channel_2_std', 0.018718978), ('lbp_rad1_bins64_10', 0.01847459), ('lbp_rad1_bins16_10', 0.0106510455), ('lbp_rad1_bins64_41', 0.007758409), ('lbp_rad2_bins16_16', 0.0059943725), ('color_moments_hsv_channel_0_std', 0.005661501), ('color_moments_rgb_channel_1_mean', 0.0053096404), ('lbp_rad3_bins32_24', 0.005219126)]
# INFO:utils.ml:Fitted classifier: XGBClassifier11; Done in 19.63785719871521 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier12
# INFO:utils.ml:Top 10 features for XGBClassifier12: [('lbp_rad1_bins16_10', 0.0649148), ('lbp_rad1_bins32_10', 0.06072373), ('lbp_rad2_bins64_7', 0.030159088), ('lbp_rad1_bins64_10', 0.026962405), ('color_moments_lab_channel_2_std', 0.015383759), ('lbp_rad1_bins64_41', 0.01509402), ('lbp_rad1_bins32_25', 0.009841613), ('lbp_rad2_bins32_20', 0.0071542882), ('lbp_rad1_bins16_3', 0.006497638), ('lbp_rad2_bins32_10', 0.006395765)]
# INFO:utils.ml:Fitted classifier: XGBClassifier12; Done in 6.980072259902954 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier13
# INFO:utils.ml:Top 10 features for XGBClassifier13: [('lbp_rad1_bins32_10', 0.058836117), ('lbp_rad1_bins64_10', 0.038697597), ('lbp_rad1_bins16_10', 0.025874188), ('lbp_rad2_bins64_7', 0.018129328), ('color_moments_lab_channel_2_std', 0.01739227), ('lbp_rad1_bins32_25', 0.0051890463), ('lbp_rad1_bins32_0', 0.0045893462), ('color_moments_hsv_channel_0_std', 0.0044175293), ('lbp_rad2_bins16_6', 0.004409896), ('var_lab_channel_1', 0.004153628)]
# INFO:utils.ml:Fitted classifier: XGBClassifier13; Done in 17.522557258605957 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier14
# INFO:utils.ml:Top 10 features for XGBClassifier14: [('lbp_rad1_bins32_10', 0.06117172), ('lbp_rad1_bins64_10', 0.039537445), ('lbp_rad1_bins16_10', 0.030626746), ('lbp_rad2_bins64_7', 0.0204472), ('color_moments_lab_channel_2_std', 0.015230472), ('lbp_rad1_bins64_41', 0.008044408), ('lbp_rad1_bins16_3', 0.0057260287), ('lbp_rad2_bins16_6', 0.0052013667), ('lbp_rad1_bins32_8', 0.004890296), ('lbp_rad1_bins32_0', 0.0044989674)]
# INFO:utils.ml:Fitted classifier: XGBClassifier14; Done in 11.070672750473022 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier15
# INFO:utils.ml:Top 10 features for XGBClassifier15: [('lbp_rad1_bins32_10', 0.05268591), ('lbp_rad1_bins64_10', 0.040313877), ('lbp_rad1_bins16_10', 0.032563902), ('lbp_rad2_bins64_7', 0.017486833), ('color_moments_lab_channel_2_std', 0.016164837), ('lbp_rad1_bins64_41', 0.0110550085), ('color_moments_hsv_channel_2_std', 0.0059376727), ('lbp_rad2_bins16_6', 0.005693468), ('lbp_rad1_bins16_3', 0.005293505), ('color_moments_rgb_channel_1_mean', 0.004871159)]
# INFO:utils.ml:Fitted classifier: XGBClassifier15; Done in 11.336955308914185 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier16
# INFO:utils.ml:Top 10 features for XGBClassifier16: [('lbp_rad1_bins32_10', 0.08082856), ('lbp_rad1_bins64_10', 0.02807598), ('lbp_rad1_bins16_10', 0.020016465), ('color_moments_lab_channel_2_std', 0.017118812), ('lbp_rad2_bins64_7', 0.009667535), ('lbp_rad1_bins64_40', 0.004626258), ('var_rgb_channel_0', 0.0045572096), ('lbp_rad1_bins16_3', 0.0044211294), ('color_moments_rgb_channel_1_mean', 0.0044132737), ('color_moments_hsv_channel_2_std', 0.0043159435)]
# INFO:utils.ml:Fitted classifier: XGBClassifier16; Done in 25.342262506484985 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier17
# INFO:utils.ml:Top 10 features for XGBClassifier17: [('lbp_rad1_bins32_10', 0.078518875), ('lbp_rad1_bins64_10', 0.029394481), ('lbp_rad1_bins16_10', 0.019363644), ('color_moments_lab_channel_2_std', 0.017189408), ('lbp_rad2_bins64_7', 0.010454676), ('lbp_rad1_bins64_40', 0.0046510496), ('lbp_rad2_bins16_6', 0.004629259), ('color_moments_hsv_channel_2_std', 0.0044342075), ('lbp_rad1_bins16_3', 0.004386533), ('lbp_rad1_bins64_41', 0.0043802056)]
# INFO:utils.ml:Fitted classifier: XGBClassifier17; Done in 21.20275378227234 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier18
# INFO:utils.ml:Top 10 features for XGBClassifier18: [('lbp_rad1_bins32_10', 0.06180041), ('lbp_rad1_bins64_10', 0.04043829), ('color_moments_lab_channel_2_std', 0.017292347), ('lbp_rad1_bins16_10', 0.016694283), ('lbp_rad2_bins64_7', 0.011214013), ('var_lab_channel_1', 0.00486054), ('color_moments_hsv_channel_0_std', 0.0047536376), ('lbp_rad1_bins32_25', 0.0045514), ('lbp_rad2_bins16_6', 0.004529403), ('var_rgb_channel_0', 0.0045107086)]
# INFO:utils.ml:Fitted classifier: XGBClassifier18; Done in 20.593189239501953 seconds
# INFO:utils.ml:Fitting classifier: XGBClassifier19
# INFO:utils.ml:Top 10 features for XGBClassifier19: [('lbp_rad1_bins32_10', 0.06619077), ('lbp_rad1_bins64_10', 0.038647626), ('lbp_rad1_bins16_10', 0.01766735), ('color_moments_lab_channel_2_std', 0.017480062), ('lbp_rad2_bins64_7', 0.011345774), ('var_lab_channel_1', 0.0050031487), ('lbp_rad2_bins16_6', 0.004838127), ('color_moments_hsv_channel_0_std', 0.004705835), ('var_rgb_channel_0', 0.0045696557), ('var_lab_channel_0', 0.0045557483)]
# INFO:utils.ml:Fitted classifier: XGBClassifier19; Done in 24.865020036697388 seconds
# INFO:utils.ml:Fitting completed in 369.64 seconds.

# %%
pipeline.predict_with_classifiers(VAL_PATH)
# Out:
# INFO:utils.ml:Predicting with classifiers on dataset: C:\Users\gimes\Src\repos\CADx-Project\dataset\binary\val
# Processed 5/80 batches.
# Processed 10/80 batches.
# Processed 15/80 batches.
# Processed 20/80 batches.
# Processed 25/80 batches.
# Processed 30/80 batches.
# Processed 35/80 batches.
# Processed 40/80 batches.
# Processed 45/80 batches.
# Processed 50/80 batches.
# Processed 55/80 batches.
# Processed 60/80 batches.
# Processed 65/80 batches.
# Processed 70/80 batches.
# Processed 75/80 batches.
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier0
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier1
# Processed 80/80 batches.
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier2
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier3
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier4
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier5
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier6
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier7
# INFO:utils.ml:Predictions made with classifier: RandomForestClassifier8
# INFO:utils.ml:Predictions made with classifier: XGBClassifier9
# INFO:utils.ml:Predictions made with classifier: XGBClassifier10
# INFO:utils.ml:Predictions made with classifier: XGBClassifier11
# INFO:utils.ml:Predictions made with classifier: XGBClassifier12
# INFO:utils.ml:Predictions made with classifier: XGBClassifier13
# INFO:utils.ml:Predictions made with classifier: XGBClassifier14
# INFO:utils.ml:Predictions made with classifier: XGBClassifier15
# INFO:utils.ml:Predictions made with classifier: XGBClassifier16
# INFO:utils.ml:Predictions made with classifier: XGBClassifier17
# INFO:utils.ml:Predictions made with classifier: XGBClassifier18
# INFO:utils.ml:Predictions made with classifier: XGBClassifier19
# {'GT': array([0, 0, 0, ..., 1, 1, 1]),
#  'RandomForestClassifier0': array([0, 0, 0, ..., 0, 0, 1]),
#  'RandomForestClassifier1': array([0, 0, 1, ..., 0, 0, 1]),
#  'RandomForestClassifier2': array([0, 0, 0, ..., 0, 0, 1]),
#  'RandomForestClassifier3': array([0, 0, 1, ..., 0, 0, 1]),
#  'RandomForestClassifier4': array([0, 0, 1, ..., 0, 0, 1]),
#  'RandomForestClassifier5': array([0, 0, 0, ..., 0, 0, 1]),
#  'RandomForestClassifier6': array([0, 0, 1, ..., 0, 0, 1]),
#  'RandomForestClassifier7': array([0, 0, 0, ..., 0, 0, 1]),
#  'RandomForestClassifier8': array([0, 0, 1, ..., 0, 0, 1]),
#  'XGBClassifier9': array([0, 0, 0, ..., 0, 0, 1]),
#  'XGBClassifier10': array([0, 0, 0, ..., 0, 0, 1]),
#  'XGBClassifier11': array([0, 0, 0, ..., 0, 0, 1]),
#  'XGBClassifier12': array([0, 0, 1, ..., 0, 0, 1]),
#  'XGBClassifier13': array([0, 0, 0, ..., 0, 0, 1]),
#  'XGBClassifier14': array([0, 0, 0, ..., 0, 0, 1]),
#  'XGBClassifier15': array([0, 0, 0, ..., 0, 0, 1]),
#  'XGBClassifier16': array([0, 0, 0, ..., 0, 0, 1]),
#  'XGBClassifier17': array([0, 0, 0, ..., 0, 0, 1]),
#  'XGBClassifier18': array([0, 0, 0, ..., 0, 0, 1]),
#  'XGBClassifier19': array([0, 0, 0, ..., 0, 0, 1])}

# %%
import pandas as pd

df = pd.DataFrame(data=pipeline.calculate_metrics())
df.T
# Out:
# INFO:utils.ml:Metrics for classifier GT: {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0, 'kappa': 1.0}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier0: {'accuracy': 0.7995258166491043, 'precision': 0.799488327470419, 'recall': 0.7995705735266145, 'f1': 0.7995000890838948, 'kappa': 0.5990149008598935}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier1: {'accuracy': 0.7995258166491043, 'precision': 0.7994652851812367, 'recall': 0.7995155936095565, 'f1': 0.7994837224156638, 'kappa': 0.5989708130488067}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier2: {'accuracy': 0.7987355110642782, 'precision': 0.7986728225135413, 'recall': 0.7987113040653206, 'f1': 0.7986885138480154, 'kappa': 0.5973788163469411}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier3: {'accuracy': 0.8029504741833509, 'precision': 0.8028883570827443, 'recall': 0.8029092151061488, 'f1': 0.8028978939830507, 'kappa': 0.6057962257947986}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier4: {'accuracy': 0.7934668071654373, 'precision': 0.793408839403116, 'recall': 0.7933860270484532, 'f1': 0.7933965515182666, 'kappa': 0.5867935620044857}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier5: {'accuracy': 0.791095890410959, 'precision': 0.7911624924353045, 'recall': 0.7912388946815261, 'f1': 0.791089496796312, 'kappa': 0.5822377040079938}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier6: {'accuracy': 0.7934668071654373, 'precision': 0.793408839403116, 'recall': 0.7933860270484532, 'f1': 0.7933965515182666, 'kappa': 0.5867935620044857}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier7: {'accuracy': 0.803213909378293, 'precision': 0.8031580835676131, 'recall': 0.8031406583428553, 'f1': 0.8031488689056572, 'kappa': 0.6062979837921414}
# INFO:utils.ml:Metrics for classifier RandomForestClassifier8: {'accuracy': 0.756059009483667, 'precision': 0.7562179689536754, 'recall': 0.7562509805446067, 'f1': 0.7560579260201843, 'kappa': 0.5122297250604944}
# INFO:utils.ml:Metrics for classifier XGBClassifier9: {'accuracy': 0.8195468914646997, 'precision': 0.8195892114569974, 'recall': 0.8196801723814773, 'f1': 0.8195390641856879, 'kappa': 0.6391202297852592}
# INFO:utils.ml:Metrics for classifier XGBClassifier10: {'accuracy': 0.8266596417281349, 'precision': 0.8266467169757897, 'recall': 0.8267446752089167, 'f1': 0.8266440501043841, 'kappa': 0.6533097558368878}
# INFO:utils.ml:Metrics for classifier XGBClassifier11: {'accuracy': 0.8256059009483667, 'precision': 0.825592973563421, 'recall': 0.8256906157889549, 'f1': 0.8255902145427088, 'kappa': 0.6512022163586926}
# INFO:utils.ml:Metrics for classifier XGBClassifier12: {'accuracy': 0.8137513171759747, 'precision': 0.8137819345497184, 'recall': 0.8138736822521773, 'f1': 0.8137418941518523, 'kappa': 0.6275231069099501}
# INFO:utils.ml:Metrics for classifier XGBClassifier13: {'accuracy': 0.8190200210748156, 'precision': 0.8190506911009647, 'recall': 0.8191439793519867, 'f1': 0.8190108646143175, 'kappa': 0.6380599355687917}
# INFO:utils.ml:Metrics for classifier XGBClassifier14: {'accuracy': 0.8208640674394099, 'precision': 0.820811939652121, 'recall': 0.8208832051625587, 'f1': 0.8208329828121048, 'kappa': 0.6416723327474296}
# INFO:utils.ml:Metrics for classifier XGBClassifier15: {'accuracy': 0.8166491043203372, 'precision': 0.8165902481346521, 'recall': 0.8166394775241821, 'f1': 0.8166091925300281, 'kappa': 0.6332209309912553}
# INFO:utils.ml:Metrics for classifier XGBClassifier16: {'accuracy': 0.8245521601685986, 'precision': 0.8245568305378381, 'recall': 0.8246548830080124, 'f1': 0.8245396913175139, 'kappa': 0.6491075347049788}
# INFO:utils.ml:Metrics for classifier XGBClassifier17: {'accuracy': 0.821127502634352, 'precision': 0.8211106077413093, 'recall': 0.821206281594362, 'f1': 0.8211105070589086, 'kappa': 0.6422418962254932}
# INFO:utils.ml:Metrics for classifier XGBClassifier18: {'accuracy': 0.821917808219178, 'precision': 0.821870656630663, 'recall': 0.8218456313874238, 'f1': 0.8218572306458524, 'kappa': 0.6437148570344801}
# INFO:utils.ml:Metrics for classifier XGBClassifier19: {'accuracy': 0.8174394099051633, 'precision': 0.8173887036989727, 'recall': 0.8173704605123406, 'f1': 0.817379071153441, 'kappa': 0.6347583705059625}
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
# cannot access local variable 'report' where it is not associated with a value
#                          accuracy  precision    recall        f1     kappa
# GT                       1.000000   1.000000  1.000000  1.000000  1.000000
# RandomForestClassifier0  0.799526   0.799488  0.799571  0.799500  0.599015
# RandomForestClassifier1  0.799526   0.799465  0.799516  0.799484  0.598971
# RandomForestClassifier2  0.798736   0.798673  0.798711  0.798689  0.597379
# RandomForestClassifier3  0.802950   0.802888  0.802909  0.802898  0.605796
# RandomForestClassifier4  0.793467   0.793409  0.793386  0.793397  0.586794
# RandomForestClassifier5  0.791096   0.791162  0.791239  0.791089  0.582238
# RandomForestClassifier6  0.793467   0.793409  0.793386  0.793397  0.586794
# RandomForestClassifier7  0.803214   0.803158  0.803141  0.803149  0.606298
# RandomForestClassifier8  0.756059   0.756218  0.756251  0.756058  0.512230
# XGBClassifier9           0.819547   0.819589  0.819680  0.819539  0.639120
# XGBClassifier10          0.826660   0.826647  0.826745  0.826644  0.653310
# XGBClassifier11          0.825606   0.825593  0.825691  0.825590  0.651202
# XGBClassifier12          0.813751   0.813782  0.813874  0.813742  0.627523
# XGBClassifier13          0.819020   0.819051  0.819144  0.819011  0.638060
# XGBClassifier14          0.820864   0.820812  0.820883  0.820833  0.641672
# XGBClassifier15          0.816649   0.816590  0.816639  0.816609  0.633221
# XGBClassifier16          0.824552   0.824557  0.824655  0.824540  0.649108
# XGBClassifier17          0.821128   0.821111  0.821206  0.821111  0.642242
# XGBClassifier18          0.821918   0.821871  0.821846  0.821857  0.643715
# XGBClassifier19          0.817439   0.817389  0.817370  0.817379  0.634758
